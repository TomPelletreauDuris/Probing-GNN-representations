# %% [markdown]
# Here we'll first be loading the FC matrices and explore their structure

# %%
#using read_dataset from Datasets/FC/create_dataset.py to read the dataset
from Datasets.FC.create_dataset import read_dataset_MDD
import torch 
print('GPU available?', torch.cuda.is_available())
# Out:
# GPU available? False

# %%
dataset = read_dataset_MDD()

# %%
#ok, let's explore the data a bit more
#dataset is a list object of torch_geometric.data objects

#let's see the first element
print(dataset[0])

#it's a dictionary object, let's see the keys
print(dataset[0].keys())

#ok, let's see the values
print(dataset[0].values())

#it has 4 keys, 'x', 'edge_index', 'edge_attr' and 'y' where y=0 menas the patient is healthy and y=1 means the patient has MDD
"""graph = Data(x=ROI.reshape(-1,116).float(),
                     edge_index=G.indices().reshape(2,-1).long(),
                     edge_attr=G.values().reshape(-1,1).float(),
                     y=y.long())"""

#how much data do we have?
print('Number of samples:', len(dataset))
# Out:
# Data(x=[116, 116], edge_index=[2, 1294], edge_attr=[1294, 1], y=[1])
# ['y', 'edge_attr', 'edge_index', 'x']
# ValuesView({'x': tensor([[ 0.0000,  0.2857,  0.0804,  ...,  0.2032,  0.1674,  0.0906],
#         [ 0.2857,  0.0000, -0.3860,  ...,  0.1637, -0.0359,  0.1674],
#         [ 0.0804, -0.3860,  0.0000,  ..., -0.0175, -0.0309,  0.0296],
#         ...,
#         [ 0.2032,  0.1637, -0.0175,  ...,  0.0000,  0.2329, -0.1452],
#         [ 0.1674, -0.0359, -0.0309,  ...,  0.2329,  0.0000,  0.0183],
#         [ 0.0906,  0.1674,  0.0296,  ..., -0.1452,  0.0183,  0.0000]]), 'edge_index': tensor([[  0,   0,   0,  ..., 113, 113, 114],
#         [ 10,  12,  14,  ..., 111, 112, 108]]), 'edge_attr': tensor([[0.7785],
#         [0.6966],
#         [0.5463],
#         ...,
#         [0.6415],
#         [0.4745],
#         [0.5401]]), 'y': tensor([0])})
# Number of samples: 1604

# %%
#set the seed
import torch
torch.manual_seed(0)

MODEL = "GCN"
DATASET = "FC_MDD"

from models.models_FC import GCN_framework as framework # import the model

gnn = framework(dataset,device="cpu")

print(gnn.model)
print(gnn.train_idx)
# Out:
# Net(
#   (conv_layers): ModuleList(
#     (0): GCNConv(116, 128)
#     (1-4): 4 x GCNConv(128, 128)
#   )
#   (batch_norms): ModuleList(
#     (0-4): 5 x BatchNorm(128)
#   )
#   (lin1): Linear(128, 128, bias=True)
#   (lin2): Linear(128, 2, bias=True)
#   (bn1): BatchNorm(128)
#   (bn2): BatchNorm(2)
# )
# tensor([1365,  984, 1017,  ...,  260,  678,   83])
# c:\Users\tomdu\miniconda3\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
gnn.iterate()
# Out:
# Epoch: 020, Loss: 0.110, Test Loss: 0.625, Train Acc: 1.000 Test Acc: 0.642
# Epoch: 040, Loss: 0.090, Test Loss: 0.614, Train Acc: 1.000 Test Acc: 0.704
# Epoch: 060, Loss: 0.077, Test Loss: 0.604, Train Acc: 1.000 Test Acc: 0.704
# Epoch: 080, Loss: 0.070, Test Loss: 0.606, Train Acc: 1.000 Test Acc: 0.716
# Epoch: 100, Loss: 0.064, Test Loss: 0.604, Train Acc: 1.000 Test Acc: 0.691
# Epoch: 120, Loss: 0.062, Test Loss: 0.602, Train Acc: 1.000 Test Acc: 0.704
# Epoch: 140, Loss: 0.059, Test Loss: 0.605, Train Acc: 1.000 Test Acc: 0.716

# %%
#gnn.train()

# %%
#save the model 
#gnn.save_model(path="models/"+DATASET+"_"+MODEL+"server.pt")
# Out:
# Model saved in: models/FC_MDD_GCNserver.pt

# %%
#save the model 
#gnn.save_model(path="models/"+DATASET+"_"+MODEL+"server.pt")

# %%
#load the model
gnn.load_model(path="models/"+DATASET+"_"+MODEL+"server.pt")

# %%
gnn.evaluate()
# Out:
# Test Loss: 0.605, Train Acc: 1.000 Test Acc: 0.716

# %%
train_features, test_features = gnn.evaluate_with_features2()

# %%
print(len(train_features[0]))
len(train_features), len(test_features)
# Out:
# 8
# (1523, 81)

# %%
import networkx as nx
def calculate_avg_path_length(G):
    if nx.is_connected(G):
        return nx.average_shortest_path_length(G)
    else:
        # Alternative metrics for disconnected graphs
        # Option 1: Use the average path length of the largest connected component
        components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
        largest_component = max(components, key=len)
        return nx.average_shortest_path_length(largest_component)
    

def compute_graph_properties(data):
    properties = []
    for graph_data in data:
        G = nx.from_edgelist(graph_data.edge_index.t().tolist())
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()
        density = nx.density(G)
        avg_path_len = calculate_avg_path_length(G)
        num_cliques = len(list(nx.find_cliques(G)))
        num_triangles = sum(nx.triangles(G).values()) / 3
        num_squares = sum(nx.square_clustering(G).values()) / 4
        number_of_node_in_the_largest_fully_connected_component = len(max(nx.connected_components(G), key=len))
        #small_world = nx.algorithms.smallworld.sigma(G)

        properties.append((num_nodes, num_edges, density, avg_path_len, num_cliques, num_triangles, num_squares, number_of_node_in_the_largest_fully_connected_component)) #, small_world))
    return properties

train_idx_list = gnn.train_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in train_idx_list]
train_properties = compute_graph_properties(selected_dataset)
test_idx_list = gnn.test_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in test_idx_list]
test_properties = compute_graph_properties(selected_dataset)

# %%
print(len(train_properties))
train_properties[0:5]
# Out:
# 1523
# [(116,
#   488,
#   0.07316341829085457,
#   3.314842578710645,
#   148,
#   938.0,
#   6.439699892510922,
#   116),
#  (114,
#   598,
#   0.0928427262847384,
#   3.166744294364229,
#   164,
#   1378.0,
#   7.519630514954544,
#   114),
#  (114,
#   408,
#   0.06334420121099209,
#   3.391864617295451,
#   135,
#   511.0,
#   5.279502013122494,
#   114),
#  (115,
#   744,
#   0.11350114416475973,
#   2.796796338672769,
#   198,
#   1870.0,
#   7.980704583203741,
#   115),
#  (112,
#   706,
#   0.11357786357786358,
#   3.3745173745173744,
#   181,
#   2528.0,
#   9.050100863174576,
#   112)]

# %%
import pickle as pkl
# save the properties in a file
with open("results/"+DATASET+"_"+MODEL+"_train_properties.pkl", "wb") as f:
    pkl.dump(train_properties, f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties.pkl", "wb") as f:
    pkl.dump(test_properties, f)

#load the properties
with open("results/"+DATASET+"_"+MODEL+"_train_properties.pkl", "rb") as f:
    train_properties = pkl.load(f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties.pkl", "rb") as f:
    test_properties = pkl.load(f)

# %%
"""
The embeddings of GCN are like this:
return F.log_softmax(x7, dim=-1), (x1, x2, x3, x4, x5, x_global, x6, x7)
"""


import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
output_size = 1  # Predicting one property at a time
# Define the linear model
class LinearModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearModel, self).__init__()
        self.linear = nn.Linear(input_size, output_size)

    def forward(self, x):
        return self.linear(x)

# Assume we have already evaluated to get features
#train_features, test_features = gnn.evaluate_with_features2()

# Extract x embeddings
train_x = np.array([feat[0] for feat in train_features])
test_x = np.array([feat[0] for feat in test_features])

# Extract 2, 3, 4, global, 5, 6, 7 embeddings
train_x2 = np.array([feat[1] for feat in train_features])
test_x2 = np.array([feat[1] for feat in test_features])

train_x3 = np.array([feat[2] for feat in train_features])
test_x3 = np.array([feat[2] for feat in test_features])

train_x4 = np.array([feat[3] for feat in train_features])
test_x4 = np.array([feat[3] for feat in test_features])

train_x5 = np.array([feat[4] for feat in train_features])
test_x5 = np.array([feat[4] for feat in test_features])

train_x_global = np.array([feat[5] for feat in train_features])
test_x_global = np.array([feat[5] for feat in test_features])

train_x6 = np.array([feat[6] for feat in train_features])
test_x6 = np.array([feat[6] for feat in test_features])

train_x7 = np.array([feat[7] for feat in train_features])
test_x7 = np.array([feat[7] for feat in test_features])

# Compute graph properties
# train_properties = compute_graph_properties(gnn.dataset[gnn.train_idx])
# test_properties = compute_graph_properties(gnn.dataset[gnn.test_idx])

# Convert to PyTorch tensors
train_x = torch.tensor(train_x, dtype=torch.float32)
train_x2 = torch.tensor(train_x2, dtype=torch.float32)
train_x3 = torch.tensor(train_x3, dtype=torch.float32)
train_x4 = torch.tensor(train_x4, dtype=torch.float32)
train_x5 = torch.tensor(train_x5, dtype=torch.float32)
train_x_global = torch.tensor(train_x_global, dtype=torch.float32)
train_x6 = torch.tensor(train_x6, dtype=torch.float32)
train_x7 = torch.tensor(train_x7, dtype=torch.float32)

test_x = torch.tensor(test_x, dtype=torch.float32)
test_x2 = torch.tensor(test_x2, dtype=torch.float32)
test_x3 = torch.tensor(test_x3, dtype=torch.float32)
test_x4 = torch.tensor(test_x4, dtype=torch.float32)
test_x5 = torch.tensor(test_x5, dtype=torch.float32)
test_x_global = torch.tensor(test_x_global, dtype=torch.float32)
test_x6 = torch.tensor(test_x6, dtype=torch.float32)
test_x7 = torch.tensor(test_x7, dtype=torch.float32)

train_y = torch.tensor(train_properties, dtype=torch.float32)
test_y = torch.tensor(test_properties, dtype=torch.float32)

# Train and evaluate a model for each graph property and each embedding
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component']
embeddings = [(train_x, test_x), (train_x2, test_x2), (train_x3, test_x3), (train_x4, test_x4), (train_x5, test_x5), (train_x_global, test_x_global), (train_x6, test_x6), (train_x7, test_x7)]
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

# %%
#create a dictionary where we will sotre the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    input_size = train_embedding.shape[1]

    for i, property_name in enumerate(property_names):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 500000  # Adjust this as needed

        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding).squeeze()
            target = train_y[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Adjust this for more frequent/lower print frequency
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding).squeeze().cpu().numpy()
            test_pred = model(test_embedding).squeeze().cpu().numpy()

            train_target = train_y[:, i].cpu().numpy()
            test_target = test_y[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embdedding = embeddings_names[ii]
            results[(name_of_embdedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1

#save results
with open("results/"+DATASET+"_"+MODEL+"_results.pkl", "wb") as f:
    pkl.dump(results, f)

# %%
# check train_features shape, ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (40,) + inhomogeneous part.
# check train_features[0] shape, (40,) -> it should be (40,1)
# check train_features[0][0] shape, (1,) -> it should be (1,1)

#print(train_features[0].shape)

#load results 
with open("results/"+DATASET+"_"+MODEL+"_results.pkl", "rb") as f:
    results = pkl.load(f)

# %%
import matplotlib.pyplot as plt

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_name)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+'_'+MODEL+'_test_R2_plot.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        train_r2 = results[(name_of_embedding, property_name)][2]
        if train_r2 < -0.05:  # Handle negative R² values
            train_r2 = -0.05
        x_points.append(j)
        y_points.append(train_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+'_'+MODEL+'_train_R2_plot.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Test with new function that has limited convergence to see if it impacts the test R2

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score

#create a dictionary where we will store the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    input_size = train_embedding.shape[1]

    for i, property_name in enumerate(property_names):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 800000  # Maximum number of epochs
        min_epochs = 1000  # Minimum number of epochs
        patience = 3000  # Number of epochs to wait for improvement
        tolerance = 1e-6  # Tolerance for considering the loss as stable

        best_loss = float('inf')
        no_improve_count = 0
        
        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding).squeeze()
            target = train_y[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Print every 1000 epochs
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

            # Check for early stopping, but only after minimum epochs
            if epoch >= min_epochs:
                if loss.item() < best_loss - tolerance:
                    best_loss = loss.item()
                    no_improve_count = 0
                else:
                    no_improve_count += 1

                if no_improve_count >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding).squeeze().cpu().numpy()
            test_pred = model(test_embedding).squeeze().cpu().numpy()

            train_target = train_y[:, i].cpu().numpy()
            test_target = test_y[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embedding = embeddings_names[ii]
            results[(name_of_embedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1

#save results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv.pkl", "wb") as f:
    pkl.dump(results, f)
# Out:
# Epoch [1000/800000], Property: num_nodes, Loss: 11341.2871
# Epoch [2000/800000], Property: num_nodes, Loss: 10082.5352
# Epoch [3000/800000], Property: num_nodes, Loss: 9039.9912
# Epoch [4000/800000], Property: num_nodes, Loss: 8154.3652
# Epoch [5000/800000], Property: num_nodes, Loss: 7387.4019
# Epoch [6000/800000], Property: num_nodes, Loss: 6718.8745
# Epoch [7000/800000], Property: num_nodes, Loss: 6135.7793
# Epoch [8000/800000], Property: num_nodes, Loss: 5628.4307
# Epoch [9000/800000], Property: num_nodes, Loss: 5187.0342
# Epoch [10000/800000], Property: num_nodes, Loss: 4801.5547
# Epoch [11000/800000], Property: num_nodes, Loss: 4462.5332
# Epoch [12000/800000], Property: num_nodes, Loss: 4162.6948
# Epoch [13000/800000], Property: num_nodes, Loss: 3898.1255
# Epoch [14000/800000], Property: num_nodes, Loss: 3665.4441
# Epoch [15000/800000], Property: num_nodes, Loss: 3460.3237
# Epoch [16000/800000], Property: num_nodes, Loss: 3279.0203
# Epoch [17000/800000], Property: num_nodes, Loss: 3118.6458
# Epoch [18000/800000], Property: num_nodes, Loss: 2976.8235
# Epoch [19000/800000], Property: num_nodes, Loss: 2851.1895
# Epoch [20000/800000], Property: num_nodes, Loss: 2739.3413
# Epoch [21000/800000], Property: num_nodes, Loss: 2639.0925
# Epoch [22000/800000], Property: num_nodes, Loss: 2548.5151
# Epoch [23000/800000], Property: num_nodes, Loss: 2465.8816
# Epoch [24000/800000], Property: num_nodes, Loss: 2389.9697
# Epoch [25000/800000], Property: num_nodes, Loss: 2320.0115
# Epoch [26000/800000], Property: num_nodes, Loss: 2255.3079
# Epoch [27000/800000], Property: num_nodes, Loss: 2195.0383
# Epoch [28000/800000], Property: num_nodes, Loss: 2138.3616
# Epoch [29000/800000], Property: num_nodes, Loss: 2084.5559
# Epoch [30000/800000], Property: num_nodes, Loss: 2033.0076
# Epoch [31000/800000], Property: num_nodes, Loss: 1983.2533
# Epoch [32000/800000], Property: num_nodes, Loss: 1935.0691
# Epoch [33000/800000], Property: num_nodes, Loss: 1888.3358
# Epoch [34000/800000], Property: num_nodes, Loss: 1842.8282
# Epoch [35000/800000], Property: num_nodes, Loss: 1798.2775
# Epoch [36000/800000], Property: num_nodes, Loss: 1754.5151
# Epoch [37000/800000], Property: num_nodes, Loss: 1711.3461
# Epoch [38000/800000], Property: num_nodes, Loss: 1668.6271
# Epoch [39000/800000], Property: num_nodes, Loss: 1626.4456
# Epoch [40000/800000], Property: num_nodes, Loss: 1584.8058
# Epoch [41000/800000], Property: num_nodes, Loss: 1543.7098
# Epoch [42000/800000], Property: num_nodes, Loss: 1503.1554
# Epoch [43000/800000], Property: num_nodes, Loss: 1463.1433
# Epoch [44000/800000], Property: num_nodes, Loss: 1423.6729
# Epoch [45000/800000], Property: num_nodes, Loss: 1384.7443
# Epoch [46000/800000], Property: num_nodes, Loss: 1346.3972
# Epoch [47000/800000], Property: num_nodes, Loss: 1308.6962
# Epoch [48000/800000], Property: num_nodes, Loss: 1271.5327
# Epoch [49000/800000], Property: num_nodes, Loss: 1234.9066
# Epoch [50000/800000], Property: num_nodes, Loss: 1198.8180
# Epoch [51000/800000], Property: num_nodes, Loss: 1163.2667
# Epoch [52000/800000], Property: num_nodes, Loss: 1128.2532
# Epoch [53000/800000], Property: num_nodes, Loss: 1093.7770
# Epoch [54000/800000], Property: num_nodes, Loss: 1059.8380
# Epoch [55000/800000], Property: num_nodes, Loss: 1026.4366
# Epoch [56000/800000], Property: num_nodes, Loss: 993.5727
# Epoch [57000/800000], Property: num_nodes, Loss: 961.2464
# Epoch [58000/800000], Property: num_nodes, Loss: 929.4574
# Epoch [59000/800000], Property: num_nodes, Loss: 898.2059
# Epoch [60000/800000], Property: num_nodes, Loss: 867.4919
# Epoch [61000/800000], Property: num_nodes, Loss: 837.3153
# Epoch [62000/800000], Property: num_nodes, Loss: 807.7617
# Epoch [63000/800000], Property: num_nodes, Loss: 778.7701
# Epoch [64000/800000], Property: num_nodes, Loss: 750.3119
# Epoch [65000/800000], Property: num_nodes, Loss: 722.3871
# Epoch [66000/800000], Property: num_nodes, Loss: 694.9955
# Epoch [67000/800000], Property: num_nodes, Loss: 668.0867
# Epoch [68000/800000], Property: num_nodes, Loss: 641.8641
# Epoch [69000/800000], Property: num_nodes, Loss: 616.1708
# Epoch [70000/800000], Property: num_nodes, Loss: 591.0066
# Epoch [71000/800000], Property: num_nodes, Loss: 566.3716
# Epoch [72000/800000], Property: num_nodes, Loss: 542.2656
# Epoch [73000/800000], Property: num_nodes, Loss: 518.6888
# Epoch [74000/800000], Property: num_nodes, Loss: 495.6414
# Epoch [75000/800000], Property: num_nodes, Loss: 473.1229
# Epoch [76000/800000], Property: num_nodes, Loss: 451.1337
# Epoch [77000/800000], Property: num_nodes, Loss: 429.6736
# Epoch [78000/800000], Property: num_nodes, Loss: 408.7426
# Epoch [79000/800000], Property: num_nodes, Loss: 388.3408
# Epoch [80000/800000], Property: num_nodes, Loss: 368.4682
# Epoch [81000/800000], Property: num_nodes, Loss: 349.1248
# Epoch [82000/800000], Property: num_nodes, Loss: 330.4221
# Epoch [83000/800000], Property: num_nodes, Loss: 312.2746
# Epoch [84000/800000], Property: num_nodes, Loss: 294.6480
# Epoch [85000/800000], Property: num_nodes, Loss: 277.5423
# Epoch [86000/800000], Property: num_nodes, Loss: 260.9576
# Epoch [87000/800000], Property: num_nodes, Loss: 244.8938
# Epoch [88000/800000], Property: num_nodes, Loss: 229.3510
# Epoch [89000/800000], Property: num_nodes, Loss: 214.3290
# Epoch [90000/800000], Property: num_nodes, Loss: 199.8882
# Epoch [91000/800000], Property: num_nodes, Loss: 186.0139
# Epoch [92000/800000], Property: num_nodes, Loss: 172.6524
# Epoch [93000/800000], Property: num_nodes, Loss: 159.8037
# Epoch [94000/800000], Property: num_nodes, Loss: 147.4677
# Epoch [95000/800000], Property: num_nodes, Loss: 135.6641
# Epoch [96000/800000], Property: num_nodes, Loss: 124.4405
# Epoch [97000/800000], Property: num_nodes, Loss: 113.7215
# Epoch [98000/800000], Property: num_nodes, Loss: 103.5072
# Epoch [99000/800000], Property: num_nodes, Loss: 93.8346
# Epoch [100000/800000], Property: num_nodes, Loss: 84.6993
# Epoch [101000/800000], Property: num_nodes, Loss: 76.0606
# Epoch [102000/800000], Property: num_nodes, Loss: 67.9645
# Epoch [103000/800000], Property: num_nodes, Loss: 60.3757
# Epoch [104000/800000], Property: num_nodes, Loss: 53.3083
# Epoch [105000/800000], Property: num_nodes, Loss: 46.7463
# Epoch [106000/800000], Property: num_nodes, Loss: 40.7077
# Epoch [107000/800000], Property: num_nodes, Loss: 35.1696
# Epoch [108000/800000], Property: num_nodes, Loss: 30.1344
# Epoch [109000/800000], Property: num_nodes, Loss: 25.5987
# Epoch [110000/800000], Property: num_nodes, Loss: 21.5552
# Epoch [111000/800000], Property: num_nodes, Loss: 17.9984
# Epoch [112000/800000], Property: num_nodes, Loss: 14.9194
# Epoch [113000/800000], Property: num_nodes, Loss: 12.3090
# Epoch [114000/800000], Property: num_nodes, Loss: 10.1526
# Epoch [115000/800000], Property: num_nodes, Loss: 8.4339
# Epoch [116000/800000], Property: num_nodes, Loss: 7.1299
# Epoch [117000/800000], Property: num_nodes, Loss: 6.2097
# Epoch [118000/800000], Property: num_nodes, Loss: 5.6284
# Epoch [119000/800000], Property: num_nodes, Loss: 5.3228
# Epoch [120000/800000], Property: num_nodes, Loss: 5.2063
# Epoch [121000/800000], Property: num_nodes, Loss: 5.1815
# Epoch [122000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [123000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [124000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [125000/800000], Property: num_nodes, Loss: 5.1796
# Early stopping at epoch 125705
# Embedding: torch.Size([1523, 128])
# Property: num_nodes
#   Train MSE: 5.1796, Test MSE: 7.4190
#   Train R²: 0.0874, Test R²: -0.1763
# Epoch [1000/800000], Property: num_edges, Loss: 271787.7188
# Epoch [2000/800000], Property: num_edges, Loss: 263919.5625
# Epoch [3000/800000], Property: num_edges, Loss: 256612.0312
# Epoch [4000/800000], Property: num_edges, Loss: 249666.8125
# Epoch [5000/800000], Property: num_edges, Loss: 243013.4688
# Epoch [6000/800000], Property: num_edges, Loss: 236638.5312
# Epoch [7000/800000], Property: num_edges, Loss: 230529.3438
# Epoch [8000/800000], Property: num_edges, Loss: 224676.8906
# Epoch [9000/800000], Property: num_edges, Loss: 219068.1719
# Epoch [10000/800000], Property: num_edges, Loss: 213680.7656
# Epoch [11000/800000], Property: num_edges, Loss: 208489.3438
# Epoch [12000/800000], Property: num_edges, Loss: 203480.2656
# Epoch [13000/800000], Property: num_edges, Loss: 198645.6562
# Epoch [14000/800000], Property: num_edges, Loss: 193975.8906
# Epoch [15000/800000], Property: num_edges, Loss: 189464.7344
# Epoch [16000/800000], Property: num_edges, Loss: 185107.5469
# Epoch [17000/800000], Property: num_edges, Loss: 180897.4688
# Epoch [18000/800000], Property: num_edges, Loss: 176824.5625
# Epoch [19000/800000], Property: num_edges, Loss: 172878.5156
# Epoch [20000/800000], Property: num_edges, Loss: 169054.0938
# Epoch [21000/800000], Property: num_edges, Loss: 165350.2344
# Epoch [22000/800000], Property: num_edges, Loss: 161765.6562
# Epoch [23000/800000], Property: num_edges, Loss: 158298.3281
# Epoch [24000/800000], Property: num_edges, Loss: 154946.6719
# Epoch [25000/800000], Property: num_edges, Loss: 151709.8281
# Epoch [26000/800000], Property: num_edges, Loss: 148585.9844
# Epoch [27000/800000], Property: num_edges, Loss: 145570.8125
# Epoch [28000/800000], Property: num_edges, Loss: 142658.1562
# Epoch [29000/800000], Property: num_edges, Loss: 139841.6562
# Epoch [30000/800000], Property: num_edges, Loss: 137117.7031
# Epoch [31000/800000], Property: num_edges, Loss: 134485.7812
# Epoch [32000/800000], Property: num_edges, Loss: 131944.3906
# Epoch [33000/800000], Property: num_edges, Loss: 129491.8438
# Epoch [34000/800000], Property: num_edges, Loss: 127125.6172
# Epoch [35000/800000], Property: num_edges, Loss: 124842.9297
# Epoch [36000/800000], Property: num_edges, Loss: 122640.0859
# Epoch [37000/800000], Property: num_edges, Loss: 120510.9688
# Epoch [38000/800000], Property: num_edges, Loss: 118451.2031
# Epoch [39000/800000], Property: num_edges, Loss: 116455.3828
# Epoch [40000/800000], Property: num_edges, Loss: 114518.3750
# Epoch [41000/800000], Property: num_edges, Loss: 112636.5938
# Epoch [42000/800000], Property: num_edges, Loss: 110807.8984
# Epoch [43000/800000], Property: num_edges, Loss: 109031.7500
# Epoch [44000/800000], Property: num_edges, Loss: 107307.8906
# Epoch [45000/800000], Property: num_edges, Loss: 105635.7578
# Epoch [46000/800000], Property: num_edges, Loss: 104013.6172
# Epoch [47000/800000], Property: num_edges, Loss: 102440.4062
# Epoch [48000/800000], Property: num_edges, Loss: 100916.1953
# Epoch [49000/800000], Property: num_edges, Loss: 99439.8516
# Epoch [50000/800000], Property: num_edges, Loss: 98011.0938
# Epoch [51000/800000], Property: num_edges, Loss: 96628.9297
# Epoch [52000/800000], Property: num_edges, Loss: 95291.7969
# Epoch [53000/800000], Property: num_edges, Loss: 93997.7656
# Epoch [54000/800000], Property: num_edges, Loss: 92744.6641
# Epoch [55000/800000], Property: num_edges, Loss: 91531.0078
# Epoch [56000/800000], Property: num_edges, Loss: 90355.0234
# Epoch [57000/800000], Property: num_edges, Loss: 89215.2422
# Epoch [58000/800000], Property: num_edges, Loss: 88110.2344
# Epoch [59000/800000], Property: num_edges, Loss: 87037.5000
# Epoch [60000/800000], Property: num_edges, Loss: 85993.9219
# Epoch [61000/800000], Property: num_edges, Loss: 84979.8906
# Epoch [62000/800000], Property: num_edges, Loss: 83995.4297
# Epoch [63000/800000], Property: num_edges, Loss: 83039.6406
# Epoch [64000/800000], Property: num_edges, Loss: 82112.0547
# Epoch [65000/800000], Property: num_edges, Loss: 81212.2266
# Epoch [66000/800000], Property: num_edges, Loss: 80340.5391
# Epoch [67000/800000], Property: num_edges, Loss: 79495.2969
# Epoch [68000/800000], Property: num_edges, Loss: 78676.0938
# Epoch [69000/800000], Property: num_edges, Loss: 77882.3516
# Epoch [70000/800000], Property: num_edges, Loss: 77113.6094
# Epoch [71000/800000], Property: num_edges, Loss: 76369.1953
# Epoch [72000/800000], Property: num_edges, Loss: 75647.7031
# Epoch [73000/800000], Property: num_edges, Loss: 74947.4844
# Epoch [74000/800000], Property: num_edges, Loss: 74267.0703
# Epoch [75000/800000], Property: num_edges, Loss: 73605.9375
# Epoch [76000/800000], Property: num_edges, Loss: 72963.7266
# Epoch [77000/800000], Property: num_edges, Loss: 72338.3594
# Epoch [78000/800000], Property: num_edges, Loss: 71729.0312
# Epoch [79000/800000], Property: num_edges, Loss: 71136.6094
# Epoch [80000/800000], Property: num_edges, Loss: 70560.7266
# Epoch [81000/800000], Property: num_edges, Loss: 70000.8906
# Epoch [82000/800000], Property: num_edges, Loss: 69456.7578
# Epoch [83000/800000], Property: num_edges, Loss: 68927.7109
# Epoch [84000/800000], Property: num_edges, Loss: 68412.9141
# Epoch [85000/800000], Property: num_edges, Loss: 67911.8906
# Epoch [86000/800000], Property: num_edges, Loss: 67424.0703
# Epoch [87000/800000], Property: num_edges, Loss: 66948.6719
# Epoch [88000/800000], Property: num_edges, Loss: 66485.1328
# Epoch [89000/800000], Property: num_edges, Loss: 66032.2969
# Epoch [90000/800000], Property: num_edges, Loss: 65589.3438
# Epoch [91000/800000], Property: num_edges, Loss: 65155.9961
# Epoch [92000/800000], Property: num_edges, Loss: 64732.1758
# Epoch [93000/800000], Property: num_edges, Loss: 64317.5781
# Epoch [94000/800000], Property: num_edges, Loss: 63911.9375
# Epoch [95000/800000], Property: num_edges, Loss: 63515.2344
# Epoch [96000/800000], Property: num_edges, Loss: 63127.0859
# Epoch [97000/800000], Property: num_edges, Loss: 62747.2930
# Epoch [98000/800000], Property: num_edges, Loss: 62375.5547
# Epoch [99000/800000], Property: num_edges, Loss: 62011.7188
# Epoch [100000/800000], Property: num_edges, Loss: 61655.5859
# Epoch [101000/800000], Property: num_edges, Loss: 61307.0000
# Epoch [102000/800000], Property: num_edges, Loss: 60965.9609
# Epoch [103000/800000], Property: num_edges, Loss: 60632.2695
# Epoch [104000/800000], Property: num_edges, Loss: 60305.6719
# Epoch [105000/800000], Property: num_edges, Loss: 59986.0391
# Epoch [106000/800000], Property: num_edges, Loss: 59673.2344
# Epoch [107000/800000], Property: num_edges, Loss: 59367.0430
# Epoch [108000/800000], Property: num_edges, Loss: 59067.2773
# Epoch [109000/800000], Property: num_edges, Loss: 58773.6328
# Epoch [110000/800000], Property: num_edges, Loss: 58485.7656
# Epoch [111000/800000], Property: num_edges, Loss: 58203.2188
# Epoch [112000/800000], Property: num_edges, Loss: 57925.4961
# Epoch [113000/800000], Property: num_edges, Loss: 57652.1250
# Epoch [114000/800000], Property: num_edges, Loss: 57382.7227
# Epoch [115000/800000], Property: num_edges, Loss: 57117.1016
# Epoch [116000/800000], Property: num_edges, Loss: 56855.1172
# Epoch [117000/800000], Property: num_edges, Loss: 56596.5898
# Epoch [118000/800000], Property: num_edges, Loss: 56341.1367
# Epoch [119000/800000], Property: num_edges, Loss: 56088.5234
# Epoch [120000/800000], Property: num_edges, Loss: 55838.5391
# Epoch [121000/800000], Property: num_edges, Loss: 55590.5039
# Epoch [122000/800000], Property: num_edges, Loss: 55343.5703
# Epoch [123000/800000], Property: num_edges, Loss: 55098.9609
# Epoch [124000/800000], Property: num_edges, Loss: 54856.6992
# Epoch [125000/800000], Property: num_edges, Loss: 54616.7656
# Epoch [126000/800000], Property: num_edges, Loss: 54379.1406
# Epoch [127000/800000], Property: num_edges, Loss: 54143.7891
# Epoch [128000/800000], Property: num_edges, Loss: 53910.6992
# Epoch [129000/800000], Property: num_edges, Loss: 53679.8633
# Epoch [130000/800000], Property: num_edges, Loss: 53452.0391
# Epoch [131000/800000], Property: num_edges, Loss: 53227.1680
# Epoch [132000/800000], Property: num_edges, Loss: 53004.3633
# Epoch [133000/800000], Property: num_edges, Loss: 52783.5625
# Epoch [134000/800000], Property: num_edges, Loss: 52564.6680
# Epoch [135000/800000], Property: num_edges, Loss: 52347.5703
# Epoch [136000/800000], Property: num_edges, Loss: 52132.2109
# Epoch [137000/800000], Property: num_edges, Loss: 51918.4727
# Epoch [138000/800000], Property: num_edges, Loss: 51706.2578
# Epoch [139000/800000], Property: num_edges, Loss: 51495.5000
# Epoch [140000/800000], Property: num_edges, Loss: 51286.0234
# Epoch [141000/800000], Property: num_edges, Loss: 51077.7031
# Epoch [142000/800000], Property: num_edges, Loss: 50870.3945
# Epoch [143000/800000], Property: num_edges, Loss: 50664.0508
# Epoch [144000/800000], Property: num_edges, Loss: 50458.6680
# Epoch [145000/800000], Property: num_edges, Loss: 50254.2188
# Epoch [146000/800000], Property: num_edges, Loss: 50050.6641
# Epoch [147000/800000], Property: num_edges, Loss: 49847.9570
# Epoch [148000/800000], Property: num_edges, Loss: 49646.0547
# Epoch [149000/800000], Property: num_edges, Loss: 49444.9219
# Epoch [150000/800000], Property: num_edges, Loss: 49244.4844
# Epoch [151000/800000], Property: num_edges, Loss: 49044.6641
# Epoch [152000/800000], Property: num_edges, Loss: 48845.3984
# Epoch [153000/800000], Property: num_edges, Loss: 48646.6641
# Epoch [154000/800000], Property: num_edges, Loss: 48448.4883
# Epoch [155000/800000], Property: num_edges, Loss: 48250.8516
# Epoch [156000/800000], Property: num_edges, Loss: 48053.7578
# Epoch [157000/800000], Property: num_edges, Loss: 47857.2188
# Epoch [158000/800000], Property: num_edges, Loss: 47661.2266
# Epoch [159000/800000], Property: num_edges, Loss: 47465.7695
# Epoch [160000/800000], Property: num_edges, Loss: 47270.8594
# Epoch [161000/800000], Property: num_edges, Loss: 47076.5000
# Epoch [162000/800000], Property: num_edges, Loss: 46882.6875
# Epoch [163000/800000], Property: num_edges, Loss: 46689.4180
# Epoch [164000/800000], Property: num_edges, Loss: 46496.7031
# Epoch [165000/800000], Property: num_edges, Loss: 46304.5234
# Epoch [166000/800000], Property: num_edges, Loss: 46112.8867
# Epoch [167000/800000], Property: num_edges, Loss: 45921.8086
# Epoch [168000/800000], Property: num_edges, Loss: 45731.2656
# Epoch [169000/800000], Property: num_edges, Loss: 45541.2695
# Epoch [170000/800000], Property: num_edges, Loss: 45351.8281
# Epoch [171000/800000], Property: num_edges, Loss: 45162.9297
# Epoch [172000/800000], Property: num_edges, Loss: 44974.5664
# Epoch [173000/800000], Property: num_edges, Loss: 44786.7578
# Epoch [174000/800000], Property: num_edges, Loss: 44599.4961
# Epoch [175000/800000], Property: num_edges, Loss: 44412.7812
# Epoch [176000/800000], Property: num_edges, Loss: 44226.6055
# Epoch [177000/800000], Property: num_edges, Loss: 44040.9727
# Epoch [178000/800000], Property: num_edges, Loss: 43855.8906
# Epoch [179000/800000], Property: num_edges, Loss: 43671.3594
# Epoch [180000/800000], Property: num_edges, Loss: 43487.3711
# Epoch [181000/800000], Property: num_edges, Loss: 43303.9297
# Epoch [182000/800000], Property: num_edges, Loss: 43121.0312
# Epoch [183000/800000], Property: num_edges, Loss: 42938.6797
# Epoch [184000/800000], Property: num_edges, Loss: 42756.8711
# Epoch [185000/800000], Property: num_edges, Loss: 42575.6094
# Epoch [186000/800000], Property: num_edges, Loss: 42394.8984
# Epoch [187000/800000], Property: num_edges, Loss: 42214.7266
# Epoch [188000/800000], Property: num_edges, Loss: 42035.1055
# Epoch [189000/800000], Property: num_edges, Loss: 41856.0312
# Epoch [190000/800000], Property: num_edges, Loss: 41677.5000
# Epoch [191000/800000], Property: num_edges, Loss: 41499.5117
# Epoch [192000/800000], Property: num_edges, Loss: 41322.0742
# Epoch [193000/800000], Property: num_edges, Loss: 41145.1836
# Epoch [194000/800000], Property: num_edges, Loss: 40968.8320
# Epoch [195000/800000], Property: num_edges, Loss: 40793.0312
# Epoch [196000/800000], Property: num_edges, Loss: 40617.7773
# Epoch [197000/800000], Property: num_edges, Loss: 40443.0625
# Epoch [198000/800000], Property: num_edges, Loss: 40268.8945
# Epoch [199000/800000], Property: num_edges, Loss: 40095.2852
# Epoch [200000/800000], Property: num_edges, Loss: 39922.2070
# Epoch [201000/800000], Property: num_edges, Loss: 39749.6836
# Epoch [202000/800000], Property: num_edges, Loss: 39577.6992
# Epoch [203000/800000], Property: num_edges, Loss: 39406.2656
# Epoch [204000/800000], Property: num_edges, Loss: 39235.3789
# Epoch [205000/800000], Property: num_edges, Loss: 39065.0312
# Epoch [206000/800000], Property: num_edges, Loss: 38895.2344
# Epoch [207000/800000], Property: num_edges, Loss: 38725.9805
# Epoch [208000/800000], Property: num_edges, Loss: 38557.2773
# Epoch [209000/800000], Property: num_edges, Loss: 38389.1133
# Epoch [210000/800000], Property: num_edges, Loss: 38221.5000
# Epoch [211000/800000], Property: num_edges, Loss: 38054.4336
# Epoch [212000/800000], Property: num_edges, Loss: 37887.9062
# Epoch [213000/800000], Property: num_edges, Loss: 37721.9375
# Epoch [214000/800000], Property: num_edges, Loss: 37556.5000
# Epoch [215000/800000], Property: num_edges, Loss: 37391.6172
# Epoch [216000/800000], Property: num_edges, Loss: 37227.2734
# Epoch [217000/800000], Property: num_edges, Loss: 37063.4844
# Epoch [218000/800000], Property: num_edges, Loss: 36900.2266
# Epoch [219000/800000], Property: num_edges, Loss: 36737.5352
# Epoch [220000/800000], Property: num_edges, Loss: 36575.3789
# Epoch [221000/800000], Property: num_edges, Loss: 36413.7617
# Epoch [222000/800000], Property: num_edges, Loss: 36252.7031
# Epoch [223000/800000], Property: num_edges, Loss: 36092.1836
# Epoch [224000/800000], Property: num_edges, Loss: 35932.2109
# Epoch [225000/800000], Property: num_edges, Loss: 35772.7812
# Epoch [226000/800000], Property: num_edges, Loss: 35613.8984
# Epoch [227000/800000], Property: num_edges, Loss: 35455.5625
# Epoch [228000/800000], Property: num_edges, Loss: 35297.7773
# Epoch [229000/800000], Property: num_edges, Loss: 35140.5312
# Epoch [230000/800000], Property: num_edges, Loss: 34983.8320
# Epoch [231000/800000], Property: num_edges, Loss: 34827.6797
# Epoch [232000/800000], Property: num_edges, Loss: 34672.0664
# Epoch [233000/800000], Property: num_edges, Loss: 34517.0156
# Epoch [234000/800000], Property: num_edges, Loss: 34362.5000
# Epoch [235000/800000], Property: num_edges, Loss: 34208.5312
# Epoch [236000/800000], Property: num_edges, Loss: 34055.1094
# Epoch [237000/800000], Property: num_edges, Loss: 33902.2305
# Epoch [238000/800000], Property: num_edges, Loss: 33749.8984
# Epoch [239000/800000], Property: num_edges, Loss: 33598.1133
# Epoch [240000/800000], Property: num_edges, Loss: 33446.8750
# Epoch [241000/800000], Property: num_edges, Loss: 33296.1797
# Epoch [242000/800000], Property: num_edges, Loss: 33146.0312
# Epoch [243000/800000], Property: num_edges, Loss: 32996.4297
# Epoch [244000/800000], Property: num_edges, Loss: 32847.3711
# Epoch [245000/800000], Property: num_edges, Loss: 32698.8594
# Epoch [246000/800000], Property: num_edges, Loss: 32550.8945
# Epoch [247000/800000], Property: num_edges, Loss: 32403.4805
# Epoch [248000/800000], Property: num_edges, Loss: 32256.6035
# Epoch [249000/800000], Property: num_edges, Loss: 32110.2793
# Epoch [250000/800000], Property: num_edges, Loss: 31964.4961
# Epoch [251000/800000], Property: num_edges, Loss: 31819.2598
# Epoch [252000/800000], Property: num_edges, Loss: 31674.5703
# Epoch [253000/800000], Property: num_edges, Loss: 31530.4277
# Epoch [254000/800000], Property: num_edges, Loss: 31386.8320
# Epoch [255000/800000], Property: num_edges, Loss: 31243.7715
# Epoch [256000/800000], Property: num_edges, Loss: 31101.2656
# Epoch [257000/800000], Property: num_edges, Loss: 30959.3066
# Epoch [258000/800000], Property: num_edges, Loss: 30817.8945
# Epoch [259000/800000], Property: num_edges, Loss: 30676.0625
# Epoch [260000/800000], Property: num_edges, Loss: 30533.5859
# Epoch [261000/800000], Property: num_edges, Loss: 30391.6738
# Epoch [262000/800000], Property: num_edges, Loss: 30250.3262
# Epoch [263000/800000], Property: num_edges, Loss: 30109.5410
# Epoch [264000/800000], Property: num_edges, Loss: 29969.3184
# Epoch [265000/800000], Property: num_edges, Loss: 29829.6582
# Epoch [266000/800000], Property: num_edges, Loss: 29690.5586
# Epoch [267000/800000], Property: num_edges, Loss: 29552.0293
# Epoch [268000/800000], Property: num_edges, Loss: 29414.0508
# Epoch [269000/800000], Property: num_edges, Loss: 29276.6426
# Epoch [270000/800000], Property: num_edges, Loss: 29139.7969
# Epoch [271000/800000], Property: num_edges, Loss: 29003.5137
# Epoch [272000/800000], Property: num_edges, Loss: 28867.7891
# Epoch [273000/800000], Property: num_edges, Loss: 28732.6387
# Epoch [274000/800000], Property: num_edges, Loss: 28598.0371
# Epoch [275000/800000], Property: num_edges, Loss: 28464.0020
# Epoch [276000/800000], Property: num_edges, Loss: 28330.5371
# Epoch [277000/800000], Property: num_edges, Loss: 28197.6289
# Epoch [278000/800000], Property: num_edges, Loss: 28065.2812
# Epoch [279000/800000], Property: num_edges, Loss: 27933.5020
# Epoch [280000/800000], Property: num_edges, Loss: 27802.2832
# Epoch [281000/800000], Property: num_edges, Loss: 27671.6250
# Epoch [282000/800000], Property: num_edges, Loss: 27541.5332
# Epoch [283000/800000], Property: num_edges, Loss: 27412.0020
# Epoch [284000/800000], Property: num_edges, Loss: 27283.0352
# Epoch [285000/800000], Property: num_edges, Loss: 27154.6270
# Epoch [286000/800000], Property: num_edges, Loss: 27026.7832
# Epoch [287000/800000], Property: num_edges, Loss: 26899.5098
# Epoch [288000/800000], Property: num_edges, Loss: 26772.7871
# Epoch [289000/800000], Property: num_edges, Loss: 26646.6348
# Epoch [290000/800000], Property: num_edges, Loss: 26521.0430
# Epoch [291000/800000], Property: num_edges, Loss: 26396.0137
# Epoch [292000/800000], Property: num_edges, Loss: 26271.5488
# Epoch [293000/800000], Property: num_edges, Loss: 26147.6445
# Epoch [294000/800000], Property: num_edges, Loss: 26024.3047
# Epoch [295000/800000], Property: num_edges, Loss: 25901.5234
# Epoch [296000/800000], Property: num_edges, Loss: 25779.3125
# Epoch [297000/800000], Property: num_edges, Loss: 25657.6582
# Epoch [298000/800000], Property: num_edges, Loss: 25536.5703
# Epoch [299000/800000], Property: num_edges, Loss: 25416.0449
# Epoch [300000/800000], Property: num_edges, Loss: 25296.0762
# Epoch [301000/800000], Property: num_edges, Loss: 25176.6777
# Epoch [302000/800000], Property: num_edges, Loss: 25057.8359
# Epoch [303000/800000], Property: num_edges, Loss: 24939.5605
# Epoch [304000/800000], Property: num_edges, Loss: 24821.8496
# Epoch [305000/800000], Property: num_edges, Loss: 24704.6953
# Epoch [306000/800000], Property: num_edges, Loss: 24588.1094
# Epoch [307000/800000], Property: num_edges, Loss: 24472.0859
# Epoch [308000/800000], Property: num_edges, Loss: 24356.6250
# Epoch [309000/800000], Property: num_edges, Loss: 24241.7246
# Epoch [310000/800000], Property: num_edges, Loss: 24127.3848
# Epoch [311000/800000], Property: num_edges, Loss: 24013.6133
# Epoch [312000/800000], Property: num_edges, Loss: 23900.4023
# Epoch [313000/800000], Property: num_edges, Loss: 23787.7539
# Epoch [314000/800000], Property: num_edges, Loss: 23675.6699
# Epoch [315000/800000], Property: num_edges, Loss: 23564.1445
# Epoch [316000/800000], Property: num_edges, Loss: 23453.1836
# Epoch [317000/800000], Property: num_edges, Loss: 23342.7891
# Epoch [318000/800000], Property: num_edges, Loss: 23232.9531
# Epoch [319000/800000], Property: num_edges, Loss: 23123.6797
# Epoch [320000/800000], Property: num_edges, Loss: 23014.9727
# Epoch [321000/800000], Property: num_edges, Loss: 22906.8262
# Epoch [322000/800000], Property: num_edges, Loss: 22799.2441
# Epoch [323000/800000], Property: num_edges, Loss: 22692.2207
# Epoch [324000/800000], Property: num_edges, Loss: 22585.7617
# Epoch [325000/800000], Property: num_edges, Loss: 22479.8691
# Epoch [326000/800000], Property: num_edges, Loss: 22374.5352
# Epoch [327000/800000], Property: num_edges, Loss: 22269.7656
# Epoch [328000/800000], Property: num_edges, Loss: 22165.5605
# Epoch [329000/800000], Property: num_edges, Loss: 22061.9141
# Epoch [330000/800000], Property: num_edges, Loss: 21958.8320
# Epoch [331000/800000], Property: num_edges, Loss: 21856.3145
# Epoch [332000/800000], Property: num_edges, Loss: 21754.3574
# Epoch [333000/800000], Property: num_edges, Loss: 21652.9648
# Epoch [334000/800000], Property: num_edges, Loss: 21552.1348
# Epoch [335000/800000], Property: num_edges, Loss: 21451.8633
# Epoch [336000/800000], Property: num_edges, Loss: 21352.1582
# Epoch [337000/800000], Property: num_edges, Loss: 21253.0156
# Epoch [338000/800000], Property: num_edges, Loss: 21154.4395
# Epoch [339000/800000], Property: num_edges, Loss: 21056.4180
# Epoch [340000/800000], Property: num_edges, Loss: 20958.9668
# Epoch [341000/800000], Property: num_edges, Loss: 20862.0723
# Epoch [342000/800000], Property: num_edges, Loss: 20765.7461
# Epoch [343000/800000], Property: num_edges, Loss: 20669.9805
# Epoch [344000/800000], Property: num_edges, Loss: 20574.7793
# Epoch [345000/800000], Property: num_edges, Loss: 20480.1348
# Epoch [346000/800000], Property: num_edges, Loss: 20386.0586
# Epoch [347000/800000], Property: num_edges, Loss: 20292.5449
# Epoch [348000/800000], Property: num_edges, Loss: 20199.5918
# Epoch [349000/800000], Property: num_edges, Loss: 20107.2031
# Epoch [350000/800000], Property: num_edges, Loss: 20015.3770
# Epoch [351000/800000], Property: num_edges, Loss: 19924.1113
# Epoch [352000/800000], Property: num_edges, Loss: 19833.4121
# Epoch [353000/800000], Property: num_edges, Loss: 19743.2734
# Epoch [354000/800000], Property: num_edges, Loss: 19653.6973
# Epoch [355000/800000], Property: num_edges, Loss: 19564.6836
# Epoch [356000/800000], Property: num_edges, Loss: 19476.2344
# Epoch [357000/800000], Property: num_edges, Loss: 19388.3457
# Epoch [358000/800000], Property: num_edges, Loss: 19301.0215
# Epoch [359000/800000], Property: num_edges, Loss: 19214.2617
# Epoch [360000/800000], Property: num_edges, Loss: 19128.0605
# Epoch [361000/800000], Property: num_edges, Loss: 19042.4219
# Epoch [362000/800000], Property: num_edges, Loss: 18957.3496
# Epoch [363000/800000], Property: num_edges, Loss: 18872.8398
# Epoch [364000/800000], Property: num_edges, Loss: 18788.8906
# Epoch [365000/800000], Property: num_edges, Loss: 18705.5039
# Epoch [366000/800000], Property: num_edges, Loss: 18622.6836
# Epoch [367000/800000], Property: num_edges, Loss: 18540.4219
# Epoch [368000/800000], Property: num_edges, Loss: 18458.7266
# Epoch [369000/800000], Property: num_edges, Loss: 18377.5918
# Epoch [370000/800000], Property: num_edges, Loss: 18297.0176
# Epoch [371000/800000], Property: num_edges, Loss: 18217.0098
# Epoch [372000/800000], Property: num_edges, Loss: 18137.5625
# Epoch [373000/800000], Property: num_edges, Loss: 18058.6816
# Epoch [374000/800000], Property: num_edges, Loss: 17980.3594
# Epoch [375000/800000], Property: num_edges, Loss: 17902.6035
# Epoch [376000/800000], Property: num_edges, Loss: 17825.4062
# Epoch [377000/800000], Property: num_edges, Loss: 17748.7734
# Epoch [378000/800000], Property: num_edges, Loss: 17672.7070
# Epoch [379000/800000], Property: num_edges, Loss: 17597.1973
# Epoch [380000/800000], Property: num_edges, Loss: 17522.2520
# Epoch [381000/800000], Property: num_edges, Loss: 17447.8711
# Epoch [382000/800000], Property: num_edges, Loss: 17374.0547
# Epoch [383000/800000], Property: num_edges, Loss: 17300.7969
# Epoch [384000/800000], Property: num_edges, Loss: 17228.1035
# Epoch [385000/800000], Property: num_edges, Loss: 17155.9746
# Epoch [386000/800000], Property: num_edges, Loss: 17084.4043
# Epoch [387000/800000], Property: num_edges, Loss: 17013.4004
# Epoch [388000/800000], Property: num_edges, Loss: 16942.9570
# Epoch [389000/800000], Property: num_edges, Loss: 16873.0801
# Epoch [390000/800000], Property: num_edges, Loss: 16803.7617
# Epoch [391000/800000], Property: num_edges, Loss: 16735.0078
# Epoch [392000/800000], Property: num_edges, Loss: 16666.8164
# Epoch [393000/800000], Property: num_edges, Loss: 16599.9863
# Epoch [394000/800000], Property: num_edges, Loss: 16534.2656
# Epoch [395000/800000], Property: num_edges, Loss: 16469.5938
# Epoch [396000/800000], Property: num_edges, Loss: 16405.6113
# Epoch [397000/800000], Property: num_edges, Loss: 16342.1572
# Epoch [398000/800000], Property: num_edges, Loss: 16279.2305
# Epoch [399000/800000], Property: num_edges, Loss: 16216.8369
# Epoch [400000/800000], Property: num_edges, Loss: 16154.9707
# Epoch [401000/800000], Property: num_edges, Loss: 16093.6318
# Epoch [402000/800000], Property: num_edges, Loss: 16032.8262
# Epoch [403000/800000], Property: num_edges, Loss: 15972.5449
# Epoch [404000/800000], Property: num_edges, Loss: 15912.7959
# Epoch [405000/800000], Property: num_edges, Loss: 15853.5742
# Epoch [406000/800000], Property: num_edges, Loss: 15794.8838
# Epoch [407000/800000], Property: num_edges, Loss: 15736.7207
# Epoch [408000/800000], Property: num_edges, Loss: 15679.0889
# Epoch [409000/800000], Property: num_edges, Loss: 15621.9844
# Epoch [410000/800000], Property: num_edges, Loss: 15565.4092
# Epoch [411000/800000], Property: num_edges, Loss: 15509.3633
# Epoch [412000/800000], Property: num_edges, Loss: 15453.8477
# Epoch [413000/800000], Property: num_edges, Loss: 15398.8604
# Epoch [414000/800000], Property: num_edges, Loss: 15344.4014
# Epoch [415000/800000], Property: num_edges, Loss: 15290.4717
# Epoch [416000/800000], Property: num_edges, Loss: 15237.0713
# Epoch [417000/800000], Property: num_edges, Loss: 15184.2012
# Epoch [418000/800000], Property: num_edges, Loss: 15131.8584
# Epoch [419000/800000], Property: num_edges, Loss: 15080.0459
# Epoch [420000/800000], Property: num_edges, Loss: 15028.7646
# Epoch [421000/800000], Property: num_edges, Loss: 14978.0107
# Epoch [422000/800000], Property: num_edges, Loss: 14927.7842
# Epoch [423000/800000], Property: num_edges, Loss: 14878.0889
# Epoch [424000/800000], Property: num_edges, Loss: 14828.9229
# Epoch [425000/800000], Property: num_edges, Loss: 14780.2861
# Epoch [426000/800000], Property: num_edges, Loss: 14732.1777
# Epoch [427000/800000], Property: num_edges, Loss: 14684.5986
# Epoch [428000/800000], Property: num_edges, Loss: 14637.5469
# Epoch [429000/800000], Property: num_edges, Loss: 14591.0283
# Epoch [430000/800000], Property: num_edges, Loss: 14545.0352
# Epoch [431000/800000], Property: num_edges, Loss: 14499.5732
# Epoch [432000/800000], Property: num_edges, Loss: 14454.6396
# Epoch [433000/800000], Property: num_edges, Loss: 14410.2363
# Epoch [434000/800000], Property: num_edges, Loss: 14366.3594
# Epoch [435000/800000], Property: num_edges, Loss: 14323.0146
# Epoch [436000/800000], Property: num_edges, Loss: 14280.1982
# Epoch [437000/800000], Property: num_edges, Loss: 14237.9092
# Epoch [438000/800000], Property: num_edges, Loss: 14196.1514
# Epoch [439000/800000], Property: num_edges, Loss: 14154.9229
# Epoch [440000/800000], Property: num_edges, Loss: 14114.2217
# Epoch [441000/800000], Property: num_edges, Loss: 14074.0508
# Epoch [442000/800000], Property: num_edges, Loss: 14034.4102
# Epoch [443000/800000], Property: num_edges, Loss: 13995.2959
# Epoch [444000/800000], Property: num_edges, Loss: 13956.7148
# Epoch [445000/800000], Property: num_edges, Loss: 13918.6592
# Epoch [446000/800000], Property: num_edges, Loss: 13881.1328
# Epoch [447000/800000], Property: num_edges, Loss: 13844.1367
# Epoch [448000/800000], Property: num_edges, Loss: 13807.6719
# Epoch [449000/800000], Property: num_edges, Loss: 13771.7334
# Epoch [450000/800000], Property: num_edges, Loss: 13736.3252
# Epoch [451000/800000], Property: num_edges, Loss: 13701.4463
# Epoch [452000/800000], Property: num_edges, Loss: 13667.0967
# Epoch [453000/800000], Property: num_edges, Loss: 13633.2754
# Epoch [454000/800000], Property: num_edges, Loss: 13599.9834
# Epoch [455000/800000], Property: num_edges, Loss: 13567.2217
# Epoch [456000/800000], Property: num_edges, Loss: 13534.9893
# Epoch [457000/800000], Property: num_edges, Loss: 13503.2832
# Epoch [458000/800000], Property: num_edges, Loss: 13472.1094
# Epoch [459000/800000], Property: num_edges, Loss: 13441.4619
# Epoch [460000/800000], Property: num_edges, Loss: 13411.3447
# Epoch [461000/800000], Property: num_edges, Loss: 13381.7568
# Epoch [462000/800000], Property: num_edges, Loss: 13352.6982
# Epoch [463000/800000], Property: num_edges, Loss: 13324.1689
# Epoch [464000/800000], Property: num_edges, Loss: 13296.1680
# Epoch [465000/800000], Property: num_edges, Loss: 13268.6982
# Epoch [466000/800000], Property: num_edges, Loss: 13241.7568
# Epoch [467000/800000], Property: num_edges, Loss: 13215.3438
# Epoch [468000/800000], Property: num_edges, Loss: 13189.4590
# Epoch [469000/800000], Property: num_edges, Loss: 13164.1055
# Epoch [470000/800000], Property: num_edges, Loss: 13139.2803
# Epoch [471000/800000], Property: num_edges, Loss: 13114.9834
# Epoch [472000/800000], Property: num_edges, Loss: 13091.2178
# Epoch [473000/800000], Property: num_edges, Loss: 13067.9775
# Epoch [474000/800000], Property: num_edges, Loss: 13045.2695
# Epoch [475000/800000], Property: num_edges, Loss: 13023.0908
# Epoch [476000/800000], Property: num_edges, Loss: 13001.4404
# Epoch [477000/800000], Property: num_edges, Loss: 12980.3174
# Epoch [478000/800000], Property: num_edges, Loss: 12959.7266
# Epoch [479000/800000], Property: num_edges, Loss: 12939.6641
# Epoch [480000/800000], Property: num_edges, Loss: 12920.1309
# Epoch [481000/800000], Property: num_edges, Loss: 12901.1270
# Epoch [482000/800000], Property: num_edges, Loss: 12882.6514
# Epoch [483000/800000], Property: num_edges, Loss: 12864.7041
# Epoch [484000/800000], Property: num_edges, Loss: 12847.2881
# Epoch [485000/800000], Property: num_edges, Loss: 12830.4004
# Epoch [486000/800000], Property: num_edges, Loss: 12814.0391
# Epoch [487000/800000], Property: num_edges, Loss: 12798.2109
# Epoch [488000/800000], Property: num_edges, Loss: 12782.9102
# Epoch [489000/800000], Property: num_edges, Loss: 12768.1396
# Epoch [490000/800000], Property: num_edges, Loss: 12753.8965
# Epoch [491000/800000], Property: num_edges, Loss: 12740.1836
# Epoch [492000/800000], Property: num_edges, Loss: 12727.2646
# Epoch [493000/800000], Property: num_edges, Loss: 12714.9863
# Epoch [494000/800000], Property: num_edges, Loss: 12703.2051
# Epoch [495000/800000], Property: num_edges, Loss: 12691.9229
# Epoch [496000/800000], Property: num_edges, Loss: 12681.1328
# Epoch [497000/800000], Property: num_edges, Loss: 12670.8418
# Epoch [498000/800000], Property: num_edges, Loss: 12661.0469
# Epoch [499000/800000], Property: num_edges, Loss: 12651.7510
# Epoch [500000/800000], Property: num_edges, Loss: 12642.9482
# Epoch [501000/800000], Property: num_edges, Loss: 12634.6436
# Epoch [502000/800000], Property: num_edges, Loss: 12626.8350
# Epoch [503000/800000], Property: num_edges, Loss: 12619.5244
# Epoch [504000/800000], Property: num_edges, Loss: 12612.8232
# Epoch [505000/800000], Property: num_edges, Loss: 12606.6934
# Epoch [506000/800000], Property: num_edges, Loss: 12601.0283
# Epoch [507000/800000], Property: num_edges, Loss: 12595.8262
# Epoch [508000/800000], Property: num_edges, Loss: 12591.0898
# Epoch [509000/800000], Property: num_edges, Loss: 12586.9141
# Epoch [510000/800000], Property: num_edges, Loss: 12583.2158
# Epoch [511000/800000], Property: num_edges, Loss: 12579.9590
# Epoch [512000/800000], Property: num_edges, Loss: 12577.2236
# Epoch [513000/800000], Property: num_edges, Loss: 12574.9170
# Epoch [514000/800000], Property: num_edges, Loss: 12573.0586
# Epoch [515000/800000], Property: num_edges, Loss: 12571.6240
# Epoch [516000/800000], Property: num_edges, Loss: 12570.5820
# Epoch [517000/800000], Property: num_edges, Loss: 12569.8965
# Epoch [518000/800000], Property: num_edges, Loss: 12569.5098
# Epoch [519000/800000], Property: num_edges, Loss: 12569.3418
# Epoch [520000/800000], Property: num_edges, Loss: 12569.2979
# Epoch [521000/800000], Property: num_edges, Loss: 12569.2920
# Epoch [522000/800000], Property: num_edges, Loss: 12569.2910
# Epoch [523000/800000], Property: num_edges, Loss: 12569.2920
# Early stopping at epoch 523684
# Embedding: torch.Size([1523, 128])
# Property: num_edges
#   Train MSE: 12569.2920, Test MSE: 22440.4746
#   Train R²: 0.0791, Test R²: -0.1380
# Epoch [1000/800000], Property: density, Loss: 0.0003
# Epoch [2000/800000], Property: density, Loss: 0.0003
# Epoch [3000/800000], Property: density, Loss: 0.0003
# Epoch [4000/800000], Property: density, Loss: 0.0003
# Early stopping at epoch 4001
# Embedding: torch.Size([1523, 128])
# Property: density
#   Train MSE: 0.0003, Test MSE: 0.0005
#   Train R²: 0.0780, Test R²: -0.1615
# Epoch [1000/800000], Property: avg_path_len, Loss: 2.1033
# Epoch [2000/800000], Property: avg_path_len, Loss: 1.2516
# Epoch [3000/800000], Property: avg_path_len, Loss: 0.7100
# Epoch [4000/800000], Property: avg_path_len, Loss: 0.3572
# Epoch [5000/800000], Property: avg_path_len, Loss: 0.1880
# Epoch [6000/800000], Property: avg_path_len, Loss: 0.1391
# Epoch [7000/800000], Property: avg_path_len, Loss: 0.1330
# Epoch [8000/800000], Property: avg_path_len, Loss: 0.1329
# Epoch [9000/800000], Property: avg_path_len, Loss: 0.1329
# Epoch [10000/800000], Property: avg_path_len, Loss: 0.1329
# Early stopping at epoch 10949
# Embedding: torch.Size([1523, 128])
# Property: avg_path_len
#   Train MSE: 0.1329, Test MSE: 0.1748
#   Train R²: 0.0733, Test R²: -0.1533
# Epoch [1000/800000], Property: num_cliques, Loss: 23850.5391
# Epoch [2000/800000], Property: num_cliques, Loss: 21895.0488
# Epoch [3000/800000], Property: num_cliques, Loss: 20194.9121
# Epoch [4000/800000], Property: num_cliques, Loss: 18696.5957
# Epoch [5000/800000], Property: num_cliques, Loss: 17358.2832
# Epoch [6000/800000], Property: num_cliques, Loss: 16150.3818
# Epoch [7000/800000], Property: num_cliques, Loss: 15056.6787
# Epoch [8000/800000], Property: num_cliques, Loss: 14065.3457
# Epoch [9000/800000], Property: num_cliques, Loss: 13168.2637
# Epoch [10000/800000], Property: num_cliques, Loss: 12359.8516
# Epoch [11000/800000], Property: num_cliques, Loss: 11632.0049
# Epoch [12000/800000], Property: num_cliques, Loss: 10975.4336
# Epoch [13000/800000], Property: num_cliques, Loss: 10382.0254
# Epoch [14000/800000], Property: num_cliques, Loss: 9842.3662
# Epoch [15000/800000], Property: num_cliques, Loss: 9348.1133
# Epoch [16000/800000], Property: num_cliques, Loss: 8895.5957
# Epoch [17000/800000], Property: num_cliques, Loss: 8483.5918
# Epoch [18000/800000], Property: num_cliques, Loss: 8109.9595
# Epoch [19000/800000], Property: num_cliques, Loss: 7770.8564
# Epoch [20000/800000], Property: num_cliques, Loss: 7461.9873
# Epoch [21000/800000], Property: num_cliques, Loss: 7180.1147
# Epoch [22000/800000], Property: num_cliques, Loss: 6922.5308
# Epoch [23000/800000], Property: num_cliques, Loss: 6687.4434
# Epoch [24000/800000], Property: num_cliques, Loss: 6473.3105
# Epoch [25000/800000], Property: num_cliques, Loss: 6278.3413
# Epoch [26000/800000], Property: num_cliques, Loss: 6100.2148
# Epoch [27000/800000], Property: num_cliques, Loss: 5937.1436
# Epoch [28000/800000], Property: num_cliques, Loss: 5787.2168
# Epoch [29000/800000], Property: num_cliques, Loss: 5648.6626
# Epoch [30000/800000], Property: num_cliques, Loss: 5519.8989
# Epoch [31000/800000], Property: num_cliques, Loss: 5399.4067
# Epoch [32000/800000], Property: num_cliques, Loss: 5286.2163
# Epoch [33000/800000], Property: num_cliques, Loss: 5179.8301
# Epoch [34000/800000], Property: num_cliques, Loss: 5079.7109
# Epoch [35000/800000], Property: num_cliques, Loss: 4985.4912
# Epoch [36000/800000], Property: num_cliques, Loss: 4896.4224
# Epoch [37000/800000], Property: num_cliques, Loss: 4811.5713
# Epoch [38000/800000], Property: num_cliques, Loss: 4730.4204
# Epoch [39000/800000], Property: num_cliques, Loss: 4652.3115
# Epoch [40000/800000], Property: num_cliques, Loss: 4576.8647
# Epoch [41000/800000], Property: num_cliques, Loss: 4503.7090
# Epoch [42000/800000], Property: num_cliques, Loss: 4432.5171
# Epoch [43000/800000], Property: num_cliques, Loss: 4362.9956
# Epoch [44000/800000], Property: num_cliques, Loss: 4295.2632
# Epoch [45000/800000], Property: num_cliques, Loss: 4229.1997
# Epoch [46000/800000], Property: num_cliques, Loss: 4164.6353
# Epoch [47000/800000], Property: num_cliques, Loss: 4101.3447
# Epoch [48000/800000], Property: num_cliques, Loss: 4039.1008
# Epoch [49000/800000], Property: num_cliques, Loss: 3977.7397
# Epoch [50000/800000], Property: num_cliques, Loss: 3917.1775
# Epoch [51000/800000], Property: num_cliques, Loss: 3857.2505
# Epoch [52000/800000], Property: num_cliques, Loss: 3797.7817
# Epoch [53000/800000], Property: num_cliques, Loss: 3738.8601
# Epoch [54000/800000], Property: num_cliques, Loss: 3680.4812
# Epoch [55000/800000], Property: num_cliques, Loss: 3622.6487
# Epoch [56000/800000], Property: num_cliques, Loss: 3565.3630
# Epoch [57000/800000], Property: num_cliques, Loss: 3508.6238
# Epoch [58000/800000], Property: num_cliques, Loss: 3452.4314
# Epoch [59000/800000], Property: num_cliques, Loss: 3396.7832
# Epoch [60000/800000], Property: num_cliques, Loss: 3341.6819
# Epoch [61000/800000], Property: num_cliques, Loss: 3287.1260
# Epoch [62000/800000], Property: num_cliques, Loss: 3233.1162
# Epoch [63000/800000], Property: num_cliques, Loss: 3179.7019
# Epoch [64000/800000], Property: num_cliques, Loss: 3126.9851
# Epoch [65000/800000], Property: num_cliques, Loss: 3074.8105
# Epoch [66000/800000], Property: num_cliques, Loss: 3023.1465
# Epoch [67000/800000], Property: num_cliques, Loss: 2971.8591
# Epoch [68000/800000], Property: num_cliques, Loss: 2921.1174
# Epoch [69000/800000], Property: num_cliques, Loss: 2870.9226
# Epoch [70000/800000], Property: num_cliques, Loss: 2821.2725
# Epoch [71000/800000], Property: num_cliques, Loss: 2772.1687
# Epoch [72000/800000], Property: num_cliques, Loss: 2723.6104
# Epoch [73000/800000], Property: num_cliques, Loss: 2675.5979
# Epoch [74000/800000], Property: num_cliques, Loss: 2628.1316
# Epoch [75000/800000], Property: num_cliques, Loss: 2581.2112
# Epoch [76000/800000], Property: num_cliques, Loss: 2534.8359
# Epoch [77000/800000], Property: num_cliques, Loss: 2489.0071
# Epoch [78000/800000], Property: num_cliques, Loss: 2443.7236
# Epoch [79000/800000], Property: num_cliques, Loss: 2399.2051
# Epoch [80000/800000], Property: num_cliques, Loss: 2355.3486
# Epoch [81000/800000], Property: num_cliques, Loss: 2312.0295
# Epoch [82000/800000], Property: num_cliques, Loss: 2269.2483
# Epoch [83000/800000], Property: num_cliques, Loss: 2227.0046
# Epoch [84000/800000], Property: num_cliques, Loss: 2185.2979
# Epoch [85000/800000], Property: num_cliques, Loss: 2144.1289
# Epoch [86000/800000], Property: num_cliques, Loss: 2103.4973
# Epoch [87000/800000], Property: num_cliques, Loss: 2063.4031
# Epoch [88000/800000], Property: num_cliques, Loss: 2023.8463
# Epoch [89000/800000], Property: num_cliques, Loss: 1984.8271
# Epoch [90000/800000], Property: num_cliques, Loss: 1946.3451
# Epoch [91000/800000], Property: num_cliques, Loss: 1908.4010
# Epoch [92000/800000], Property: num_cliques, Loss: 1870.9943
# Epoch [93000/800000], Property: num_cliques, Loss: 1834.1249
# Epoch [94000/800000], Property: num_cliques, Loss: 1797.7930
# Epoch [95000/800000], Property: num_cliques, Loss: 1761.9985
# Epoch [96000/800000], Property: num_cliques, Loss: 1726.7415
# Epoch [97000/800000], Property: num_cliques, Loss: 1692.0220
# Epoch [98000/800000], Property: num_cliques, Loss: 1657.8400
# Epoch [99000/800000], Property: num_cliques, Loss: 1624.1953
# Epoch [100000/800000], Property: num_cliques, Loss: 1591.0881
# Epoch [101000/800000], Property: num_cliques, Loss: 1558.5184
# Epoch [102000/800000], Property: num_cliques, Loss: 1526.4862
# Epoch [103000/800000], Property: num_cliques, Loss: 1494.9915
# Epoch [104000/800000], Property: num_cliques, Loss: 1464.0342
# Epoch [105000/800000], Property: num_cliques, Loss: 1433.6143
# Epoch [106000/800000], Property: num_cliques, Loss: 1403.7319
# Epoch [107000/800000], Property: num_cliques, Loss: 1374.3868
# Epoch [108000/800000], Property: num_cliques, Loss: 1345.5793
# Epoch [109000/800000], Property: num_cliques, Loss: 1317.3093
# Epoch [110000/800000], Property: num_cliques, Loss: 1289.5769
# Epoch [111000/800000], Property: num_cliques, Loss: 1262.3818
# Epoch [112000/800000], Property: num_cliques, Loss: 1235.8999
# Epoch [113000/800000], Property: num_cliques, Loss: 1209.9766
# Epoch [114000/800000], Property: num_cliques, Loss: 1184.5825
# Epoch [115000/800000], Property: num_cliques, Loss: 1159.7175
# Epoch [116000/800000], Property: num_cliques, Loss: 1135.3816
# Epoch [117000/800000], Property: num_cliques, Loss: 1111.5750
# Epoch [118000/800000], Property: num_cliques, Loss: 1088.2974
# Epoch [119000/800000], Property: num_cliques, Loss: 1065.5490
# Epoch [120000/800000], Property: num_cliques, Loss: 1043.3298
# Epoch [121000/800000], Property: num_cliques, Loss: 1021.6398
# ...
# Epoch [24000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7953.3403
# Epoch [25000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7777.2954
# Epoch [26000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7603.3408
# Epoch [27000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7431.3638
# Epoch [28000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7261.3613
# Epoch [29000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7093.3354
# Epoch [30000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6927.2842
# Epoch [31000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6763.2119
# Epoch [32000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6601.1147
# Epoch [33000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6440.9941
# Epoch [34000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6282.8501
# Epoch [35000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6126.6816
# Epoch [36000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5972.4907
# Epoch [37000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5820.2739
# Epoch [38000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5670.0356
# Epoch [39000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5521.7729
# Epoch [40000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5375.4854
# Epoch [41000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5231.1748
# Epoch [42000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5088.8398
# Epoch [43000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4948.4863
# Epoch [44000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4810.6309
# Epoch [45000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4674.7368
# Epoch [46000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4540.8052
# Epoch [47000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4408.8335
# Epoch [48000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4278.8228
# Epoch [49000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4150.7729
# Epoch [50000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4024.6831
# Epoch [51000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3900.5554
# Epoch [52000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3778.3884
# Epoch [53000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3658.1829
# Epoch [54000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3539.9370
# Epoch [55000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3423.6521
# Epoch [56000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3309.3289
# Epoch [57000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3196.9661
# Epoch [58000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3086.5637
# Epoch [59000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2978.2781
# Epoch [60000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2872.2019
# Epoch [61000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2768.0715
# Epoch [62000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2665.8860
# Epoch [63000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2565.6470
# Epoch [64000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2467.3528
# Epoch [65000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2371.0046
# Epoch [66000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2276.9219
# Epoch [67000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2184.8123
# Epoch [68000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2094.6335
# Epoch [69000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2006.3856
# Epoch [70000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1920.0673
# Epoch [71000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1835.6799
# Epoch [72000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1753.2225
# Epoch [73000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1672.6956
# Epoch [74000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1594.0983
# Epoch [75000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1517.4315
# Epoch [76000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1442.6947
# Epoch [77000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1369.8879
# Epoch [78000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1299.0109
# Epoch [79000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1230.2644
# Epoch [80000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1163.7560
# Epoch [81000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1099.1472
# Epoch [82000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1036.4379
# Epoch [83000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 975.6276
# Epoch [84000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 916.7162
# Epoch [85000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 859.7035
# Epoch [86000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 804.5885
# Epoch [87000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 751.4178
# Epoch [88000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 700.4905
# Epoch [89000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 651.4269
# Epoch [90000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 604.2220
# Epoch [91000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 558.8632
# Epoch [92000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 515.3286
# Epoch [93000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 473.7784
# Epoch [94000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 434.1817
# Epoch [95000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 396.3769
# Epoch [96000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 360.3645
# Epoch [97000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 326.3423
# Epoch [98000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 294.1570
# Epoch [99000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 263.7363
# Epoch [100000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 235.2998
# Epoch [101000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 208.6036
# Epoch [102000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 183.8102
# Epoch [103000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 160.7837
# Epoch [104000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 139.6026
# Epoch [105000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 120.2194
# Epoch [106000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 102.6132
# Epoch [107000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 86.7711
# Epoch [108000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 72.6739
# Epoch [109000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 60.3067
# Epoch [110000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 49.6245
# Epoch [111000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 40.5933
# Epoch [112000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 33.1636
# Epoch [113000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 27.2686
# Epoch [114000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 22.8220
# Epoch [115000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 19.7005
# Epoch [116000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 17.7313
# Epoch [117000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 16.6680
# Epoch [118000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 16.1863
# Epoch [119000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.9540
# Epoch [120000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.7756
# Epoch [121000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.6053
# Epoch [122000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.4395
# Epoch [123000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.2779
# Epoch [124000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 15.1201
# Epoch [125000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.9664
# Epoch [126000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.8168
# Epoch [127000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.6710
# Epoch [128000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.5291
# Epoch [129000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.3910
# Epoch [130000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.2567
# Epoch [131000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.1267
# Epoch [132000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 14.0004
# Epoch [133000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.8780
# Epoch [134000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.7594
# Epoch [135000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.6448
# Epoch [136000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.5340
# Epoch [137000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.4272
# Epoch [138000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.3242
# Epoch [139000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.2250
# Epoch [140000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.1297
# Epoch [141000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 13.0383
# Epoch [142000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.9507
# Epoch [143000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.8670
# Epoch [144000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.7871
# Epoch [145000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.7110
# Epoch [146000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.6387
# Epoch [147000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.5702
# Epoch [148000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.5055
# Epoch [149000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.4446
# Epoch [150000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.3874
# Epoch [151000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.3340
# Epoch [152000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.2844
# Epoch [153000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.2384
# Epoch [154000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.1961
# Epoch [155000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.1575
# Epoch [156000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.1225
# Epoch [157000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.0911
# Epoch [158000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.0632
# Epoch [159000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.0388
# Epoch [160000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.0179
# Epoch [161000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.0003
# Epoch [162000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9859
# Epoch [163000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9747
# Epoch [164000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9664
# Epoch [165000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9607
# Epoch [166000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9573
# Epoch [167000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9557
# Epoch [168000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9552
# Epoch [169000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9551
# Epoch [170000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9551
# Epoch [171000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9551
# Epoch [172000/800000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11.9551
# Early stopping at epoch 172457
# Embedding: torch.Size([1523, 2])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 11.9551, Test MSE: 22.2552
#   Train R²: 0.0014, Test R²: -0.0922

# %%
#load results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv.pkl", "rb") as f:
    results = pkl.load(f)

# %%
import matplotlib.pyplot as plt

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_name)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_test_R2_plot_limited_cv.png', dpi=300, bbox_inches='tight')

# %%
# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        train_r2 = results[(name_of_embedding, property_name)][2]
        if train_r2 < -0.05:  # Handle negative R² values
            train_r2 = -0.05
        x_points.append(j)
        y_points.append(train_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_train_R2_plot_limited_cv.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### Test with more properties

# %%
import networkx as nx
import numpy as np

def calculate_avg_path_length(G):
    if nx.is_connected(G):
        return nx.average_shortest_path_length(G)
    else:
        # Use the average path length of the largest connected component for disconnected graphs
        components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
        largest_component = max(components, key=len)
        return nx.average_shortest_path_length(largest_component)
    
def betweenness_centralization(G):
    n = len(G)
    betweenness = nx.betweenness_centrality(G)
    max_betweenness = max(betweenness.values())
    centralization = sum(max_betweenness - bet for bet in betweenness.values())
    if n > 2:
        centralization /= (n - 1) * (n - 2) / 2
    return centralization

def pagerank_centralization(G, alpha=0.85):
    n = len(G)
    pagerank = nx.pagerank(G, alpha=alpha)
    max_pagerank = max(pagerank.values())
    centralization = sum(max_pagerank - pr for pr in pagerank.values())
    if n > 1:
        centralization /= (n - 1)
    return centralization

def clustering_properties(G):
    average_clustering = nx.average_clustering(G)
    transitivity = nx.transitivity(G)
    return average_clustering, transitivity

def compute_graph_properties(data):
    properties = []
    for graph_data in data:
        G = nx.from_edgelist(graph_data.edge_index.t().tolist())
        
        # Number of nodes
        num_nodes = G.number_of_nodes()
        
        # Number of edges
        num_edges = G.number_of_edges()
        
        # Density
        density = nx.density(G)
        
        # Average Path Length
        avg_path_len = calculate_avg_path_length(G)
        
        # Diameter
        if nx.is_connected(G):
            diameter = nx.diameter(G)
        else:
            # Use the diameter of the largest connected component for disconnected graphs
            components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
            largest_component = max(components, key=len)
            diameter = nx.diameter(largest_component)
        
        # Radius
        if nx.is_connected(G):
            radius = nx.radius(G)
        else:
            radius = nx.radius(largest_component)
        
        # Clustering Coefficient
        clustering_coeff = nx.average_clustering(G)
        
        # Transitivity
        transitivity = nx.transitivity(G)
        
        # Assortativity
        assortativity = nx.degree_assortativity_coefficient(G)
        
        # Number of Cliques
        num_cliques = len(list(nx.find_cliques(G)))
        
        # Number of Triangles
        num_triangles = sum(nx.triangles(G).values()) / 3
        
        # Number of Squares (4-cycles)
        num_squares = sum(nx.square_clustering(G).values()) / 4
        
        # Size of the Largest Connected Component
        largest_component_size = len(max(nx.connected_components(G), key=len))
        
        # Average Degree
        degrees = [d for n, d in G.degree()]
        avg_degree = np.mean(degrees)
        
        # Betweenness Centrality
        betweenness_centrality = nx.betweenness_centrality(G)
        avg_betweenness_centrality = np.mean(list(betweenness_centrality.values()))
        
        # Eigenvalues of the Adjacency Matrix (for spectral properties)
        eigenvalues = np.linalg.eigvals(nx.adjacency_matrix(G).todense())
        spectral_radius = max(eigenvalues)
        algebraic_connectivity = sorted(eigenvalues)[1]  # second smallest eigenvalue
        
        # Graph Laplacian Eigenvalues
        laplacian_eigenvalues = np.linalg.eigvals(nx.laplacian_matrix(G).todense())
        graph_energy = sum(abs(laplacian_eigenvalues))
        
        # Small-World-ness
        # Compare clustering coefficient and average path length with those of a random graph
        random_graph = nx.gnm_random_graph(num_nodes, num_edges)
        random_clustering_coeff = nx.average_clustering(random_graph)
        random_avg_path_len = calculate_avg_path_length(random_graph)
        small_world_coefficient = (clustering_coeff / random_clustering_coeff) / (avg_path_len / random_avg_path_len)

        # Calculate Betweenness Centralization
        betweenness_cent = betweenness_centralization(G)
        print(f"Betweenness Centralization: {betweenness_cent}")

        # Calculate PageRank Centralization
        pagerank_cent = pagerank_centralization(G)
        print(f"PageRank Centralization: {pagerank_cent}")

        # Calculate Clustering properties
        avg_clustering, transitivity = clustering_properties(G)
        print(f"Average Clustering Coefficient: {avg_clustering}")
        print(f"Transitivity: {transitivity}")
        
        properties.append((
            num_nodes,
            num_edges,
            density,
            avg_path_len,
            diameter,
            radius,
            clustering_coeff,
            transitivity,
            assortativity,
            num_cliques,
            num_triangles,
            num_squares,
            largest_component_size,
            avg_degree,
            avg_betweenness_centrality,
            spectral_radius,
            algebraic_connectivity,
            graph_energy,
            small_world_coefficient
        ))
    return properties

train_idx_list = gnn.train_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in train_idx_list]
train_properties_long = compute_graph_properties(selected_dataset)
test_idx_list = gnn.test_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in test_idx_list]
test_properties_long = compute_graph_properties(selected_dataset)

#save the properties in a file
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "wb") as f:
    pkl.dump(train_properties_long, f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "wb") as f:
    pkl.dump(test_properties_long, f)
# Out:
# Betweenness Centralization: 0.001724022477030078
# PageRank Centralization: 0.011393522233220854
# Average Clustering Coefficient: 0.46590185426058695
# Transitivity: 0.5531747591900924
# Betweenness Centralization: 0.0017261983853566708
# PageRank Centralization: 0.00892683265732043
# Average Clustering Coefficient: 0.5182009816568728
# Transitivity: 0.5797223390828776
# Betweenness Centralization: 0.003333083015572392
# PageRank Centralization: 0.015313849504207902
# Average Clustering Coefficient: 0.4704590487485227
# Transitivity: 0.4714022140221402
# Betweenness Centralization: 0.0010671877568257148
# PageRank Centralization: 0.0052237203197423076
# Average Clustering Coefficient: 0.5604119583322708
# Transitivity: 0.5464108308171812
# Betweenness Centralization: 0.0022241433151757965
# PageRank Centralization: 0.010110693464664746
# Average Clustering Coefficient: 0.5817108880061148
# Transitivity: 0.6164350158497928
# Betweenness Centralization: 0.0008253715900658974
# PageRank Centralization: 0.008937849000785933
# Average Clustering Coefficient: 0.4146660148328239
# Transitivity: 0.46489595669091527
# Betweenness Centralization: 0.0016989429074265865
# PageRank Centralization: 0.00998571984905696
# Average Clustering Coefficient: 0.42030943207413796
# Transitivity: 0.4767932489451477
# Betweenness Centralization: 0.0013180826590328235
# PageRank Centralization: 0.008994403593535837
# Average Clustering Coefficient: 0.4044114120006975
# Transitivity: 0.3950561797752809
# Betweenness Centralization: 0.0012432437397652783
# PageRank Centralization: 0.009286945925239867
# Average Clustering Coefficient: 0.4313596445055707
# Transitivity: 0.48718439173680184
# Betweenness Centralization: 0.0009833060550498555
# PageRank Centralization: 0.008280866857818142
# Average Clustering Coefficient: 0.5240555953920303
# Transitivity: 0.5112676056338028
# Betweenness Centralization: 0.0010810206428395154
# PageRank Centralization: 0.00745355165901899
# Average Clustering Coefficient: 0.3972178224220709
# Transitivity: 0.47979171832382844
# Betweenness Centralization: 0.0016576131595639186
# PageRank Centralization: 0.008305770452343644
# Average Clustering Coefficient: 0.46938839454319325
# Transitivity: 0.5319089900110988
# Betweenness Centralization: 0.002449885128111572
# PageRank Centralization: 0.008408126396155029
# Average Clustering Coefficient: 0.4541005621362766
# Transitivity: 0.44315352697095434
# Betweenness Centralization: 0.001351786125211133
# PageRank Centralization: 0.007776276645881898
# Average Clustering Coefficient: 0.5214480319567023
# Transitivity: 0.5312250256878639
# Betweenness Centralization: 0.0024508554419170035
# PageRank Centralization: 0.006171382983151406
# Average Clustering Coefficient: 0.5025732647424664
# Transitivity: 0.6351634197391725
# Betweenness Centralization: 0.001056852720731249
# PageRank Centralization: 0.008302768600852418
# Average Clustering Coefficient: 0.4585568896429254
# Transitivity: 0.5094987411306935
# Betweenness Centralization: 0.0012572258814907793
# PageRank Centralization: 0.00731577517388635
# Average Clustering Coefficient: 0.49614506738712366
# Transitivity: 0.5365612648221344
# Betweenness Centralization: 0.0018937482906275984
# PageRank Centralization: 0.010066928282474992
# Average Clustering Coefficient: 0.4044530833230523
# Transitivity: 0.4377605717689101
# Betweenness Centralization: 0.002075955194366935
# PageRank Centralization: 0.008053791479616107
# Average Clustering Coefficient: 0.48988208760936014
# Transitivity: 0.5027173913043478
# Betweenness Centralization: 0.0010778746647121269
# PageRank Centralization: 0.010858190773727131
# Average Clustering Coefficient: 0.462056032336308
# Transitivity: 0.5372714486638537
# Betweenness Centralization: 0.0009129315122783417
# PageRank Centralization: 0.005556544133820713
# Average Clustering Coefficient: 0.5346370651619764
# Transitivity: 0.5242718446601942
# Betweenness Centralization: 0.0010979444397795496
# PageRank Centralization: 0.0067577860745086605
# Average Clustering Coefficient: 0.4553446640113577
# Transitivity: 0.4521994134897361
# Betweenness Centralization: 0.0014316391586610873
# PageRank Centralization: 0.006902389129390512
# Average Clustering Coefficient: 0.5374194134098587
# Transitivity: 0.563050744454573
# Betweenness Centralization: 0.0014867401912010282
# PageRank Centralization: 0.007483617259594625
# Average Clustering Coefficient: 0.45991543878941116
# Transitivity: 0.49654071314529
# Betweenness Centralization: 0.0008409540473997282
# PageRank Centralization: 0.009495805703552834
# Average Clustering Coefficient: 0.5350417657148218
# Transitivity: 0.5327294479576141
# Betweenness Centralization: 0.0011974975426398027
# PageRank Centralization: 0.009753549589943034
# Average Clustering Coefficient: 0.4832573868369749
# Transitivity: 0.4869431643625192
# Betweenness Centralization: 0.0011140672333858738
# PageRank Centralization: 0.006780673565124401
# Average Clustering Coefficient: 0.506721872696311
# Transitivity: 0.5505743905855982
# Betweenness Centralization: 0.0018769085158095832
# PageRank Centralization: 0.009937747367704402
# Average Clustering Coefficient: 0.5088095443684493
# Transitivity: 0.5322976287816844
# Betweenness Centralization: 0.002035137701447397
# PageRank Centralization: 0.009234335891475171
# Average Clustering Coefficient: 0.47313859333983177
# Transitivity: 0.6508785332314744
# Betweenness Centralization: 0.0016582433074813952
# PageRank Centralization: 0.008332497868540456
# Average Clustering Coefficient: 0.5059849273918612
# Transitivity: 0.4829857299670692
# Betweenness Centralization: 0.0011832088347876048
# PageRank Centralization: 0.008333755491237275
# Average Clustering Coefficient: 0.4950047065600976
# Transitivity: 0.5143892131213524
# Betweenness Centralization: 0.001706848971901353
# PageRank Centralization: 0.011120891976782251
# Average Clustering Coefficient: 0.5039229940362415
# Transitivity: 0.5354767184035477
# Betweenness Centralization: 0.002081984082470731
# PageRank Centralization: 0.007519647710293104
# Average Clustering Coefficient: 0.4384811787829028
# Transitivity: 0.4696969696969697
# Betweenness Centralization: 0.0012855290617376908
# PageRank Centralization: 0.008249724689845427
# Average Clustering Coefficient: 0.5117180937645369
# Transitivity: 0.5622674274373605
# Betweenness Centralization: 0.0010012795261250664
# PageRank Centralization: 0.008701960413259416
# Average Clustering Coefficient: 0.4412505308016144
# Transitivity: 0.48495981630309987
# Betweenness Centralization: 0.0024473935405313917
# PageRank Centralization: 0.011769398439152926
# Average Clustering Coefficient: 0.3449695232303926
# Transitivity: 0.3746113989637306
# Betweenness Centralization: 0.0023256678158561
# PageRank Centralization: 0.010409917060353725
# Average Clustering Coefficient: 0.5493073784681585
# Transitivity: 0.5850380767507839
# Betweenness Centralization: 0.00126847198839921
# PageRank Centralization: 0.009517781784950495
# Average Clustering Coefficient: 0.38277967072609936
# Transitivity: 0.4600715137067938
# Betweenness Centralization: 0.0011895995671168955
# PageRank Centralization: 0.006344626544234039
# Average Clustering Coefficient: 0.5107444697289082
# Transitivity: 0.5340141398271799
# Betweenness Centralization: 0.0028273426176076287
# PageRank Centralization: 0.013949852001056869
# Average Clustering Coefficient: 0.42972657001294773
# Transitivity: 0.45390781563126253
# Betweenness Centralization: 0.0030021713038256128
# PageRank Centralization: 0.01116077233083449
# Average Clustering Coefficient: 0.44357412789230943
# Transitivity: 0.48114380439287197
# Betweenness Centralization: 0.0027192789212076114
# PageRank Centralization: 0.006529164764697979
# Average Clustering Coefficient: 0.49421834686270727
# Transitivity: 0.6163318211276734
# Betweenness Centralization: 0.0012942700548884717
# PageRank Centralization: 0.007135367884390579
# Average Clustering Coefficient: 0.4012719512719511
# Transitivity: 0.433801775147929
# Betweenness Centralization: 0.0029928070185238705
# PageRank Centralization: 0.007277912237855971
# Average Clustering Coefficient: 0.46427324916393103
# Transitivity: 0.6416610850636303
# Betweenness Centralization: 0.007472421257727974
# PageRank Centralization: 0.0127749817672117
# Average Clustering Coefficient: 0.49017560839990737
# Transitivity: 0.5125136017410229
# Betweenness Centralization: 0.0017814844544027277
# PageRank Centralization: 0.01065436771721213
# Average Clustering Coefficient: 0.4866543999822969
# Transitivity: 0.5406446381512264
# Betweenness Centralization: 0.001078428822044226
# PageRank Centralization: 0.009063561996750147
# Average Clustering Coefficient: 0.5532543094005744
# Transitivity: 0.5523364485981308
# Betweenness Centralization: 0.001653614405354768
# PageRank Centralization: 0.007032983882622251
# Average Clustering Coefficient: 0.5508670653133515
# Transitivity: 0.5519043035886154
# Betweenness Centralization: 0.0015445362029709983
# PageRank Centralization: 0.00937031329613198
# Average Clustering Coefficient: 0.503380722715761
# Transitivity: 0.5818673883626523
# Betweenness Centralization: 0.0017807546976311142
# PageRank Centralization: 0.009501326946814097
# Average Clustering Coefficient: 0.4149566523606274
# Transitivity: 0.4692404834926935
# Betweenness Centralization: 0.0020229469275225478
# PageRank Centralization: 0.007260008922385327
# Average Clustering Coefficient: 0.5209656672192529
# Transitivity: 0.5912332579579057
# Betweenness Centralization: 0.0011742922774086507
# PageRank Centralization: 0.0074486415980829805
# Average Clustering Coefficient: 0.497729710965005
# Transitivity: 0.5278013582342954
# Betweenness Centralization: 0.0007051157843794551
# PageRank Centralization: 0.007754579865495439
# Average Clustering Coefficient: 0.4887194702204087
# Transitivity: 0.4952408012501776
# Betweenness Centralization: 0.001264433939719466
# PageRank Centralization: 0.008438435518529136
# Average Clustering Coefficient: 0.4749541777526703
# Transitivity: 0.4756235827664399
# Betweenness Centralization: 0.001050118752921632
# PageRank Centralization: 0.006873730400787573
# Average Clustering Coefficient: 0.4894680123295975
# Transitivity: 0.5396796170134414
# Betweenness Centralization: 0.001581352175143873
# PageRank Centralization: 0.010537204075940753
# Average Clustering Coefficient: 0.3394853916977809
# Transitivity: 0.4314671814671815
# Betweenness Centralization: 0.0013782437922120181
# PageRank Centralization: 0.006276340132824835
# Average Clustering Coefficient: 0.4877287189460245
# Transitivity: 0.5310407239819005
# Betweenness Centralization: 0.0017925351158777879
# PageRank Centralization: 0.007143361968729159
# Average Clustering Coefficient: 0.48013943311291574
# Transitivity: 0.5355351170568562
# Betweenness Centralization: 0.0010678519207515044
# PageRank Centralization: 0.008371518772971561
# Average Clustering Coefficient: 0.508570527725865
# Transitivity: 0.4972785749628897
# Betweenness Centralization: 0.0012910969851131497
# PageRank Centralization: 0.006157722576733615
# Average Clustering Coefficient: 0.5555990859866319
# Transitivity: 0.567986798679868
# Betweenness Centralization: 0.0018532324023761491
# PageRank Centralization: 0.008015755161404714
# Average Clustering Coefficient: 0.4779174496339811
# Transitivity: 0.5889105058365759
# Betweenness Centralization: 0.0019970359882480917
# PageRank Centralization: 0.008709123780750262
# Average Clustering Coefficient: 0.4924666530365059
# Transitivity: 0.4821138211382114
# Betweenness Centralization: 0.0012024450986595717
# PageRank Centralization: 0.006983684078550825
# Average Clustering Coefficient: 0.6277283774479929
# Transitivity: 0.5980699008868023
# Betweenness Centralization: 0.0026582097899229343
# PageRank Centralization: 0.011246225137244348
# Average Clustering Coefficient: 0.5323025594319936
# Transitivity: 0.5196936542669585
# Betweenness Centralization: 0.0022880191337668137
# PageRank Centralization: 0.008975153891132412
# Average Clustering Coefficient: 0.48409602645550054
# Transitivity: 0.6319702602230484
# Betweenness Centralization: 0.0013804158545741043
# PageRank Centralization: 0.008967331754781892
# Average Clustering Coefficient: 0.4619203509663017
# Transitivity: 0.46885617214043035
# Betweenness Centralization: 0.0009255985076616782
# PageRank Centralization: 0.008390754309411034
# Average Clustering Coefficient: 0.5186400790141769
# Transitivity: 0.53828125
# Betweenness Centralization: 0.0014782302057288522
# PageRank Centralization: 0.00805559429861751
# Average Clustering Coefficient: 0.48060748252175356
# Transitivity: 0.5713904100440764
# Betweenness Centralization: 0.002124281581759754
# PageRank Centralization: 0.008150362453573364
# Average Clustering Coefficient: 0.5131943863788372
# Transitivity: 0.5210562258137946
# Betweenness Centralization: 0.001509503591886828
# PageRank Centralization: 0.009182615877606286
# Average Clustering Coefficient: 0.4577641433822426
# Transitivity: 0.4630454140694568
# Betweenness Centralization: 0.0015754023210290892
# PageRank Centralization: 0.008375408586631314
# Average Clustering Coefficient: 0.5359933246053091
# Transitivity: 0.5695172155688623
# Betweenness Centralization: 0.0009750417080757513
# PageRank Centralization: 0.006500632008272422
# Average Clustering Coefficient: 0.4800165183025223
# Transitivity: 0.4588594704684318
# Betweenness Centralization: 0.0019220600589339191
# PageRank Centralization: 0.010794798318471797
# Average Clustering Coefficient: 0.5135492283490419
# Transitivity: 0.5521695257315843
# Betweenness Centralization: 0.001260168674576421
# PageRank Centralization: 0.010060863818272642
# Average Clustering Coefficient: 0.39761881278909145
# Transitivity: 0.4348936170212766
# Betweenness Centralization: 0.0018185068325751836
# PageRank Centralization: 0.00816471294980466
# Average Clustering Coefficient: 0.44495892995892994
# Transitivity: 0.47237880496054113
# Betweenness Centralization: 0.0026270379194951524
# PageRank Centralization: 0.01103736497932437
# Average Clustering Coefficient: 0.37327674921132864
# Transitivity: 0.44809010773751223
# Betweenness Centralization: 0.002505553650706847
# PageRank Centralization: 0.005315464867906419
# Average Clustering Coefficient: 0.5915436897527886
# Transitivity: 0.666117840762084
# Betweenness Centralization: 0.0017984871471154176
# PageRank Centralization: 0.010117411876624184
# Average Clustering Coefficient: 0.37300898215840367
# Transitivity: 0.4317984361424848
# Betweenness Centralization: 0.0018171408838686595
# PageRank Centralization: 0.006807537201975098
# Average Clustering Coefficient: 0.5389778648779665
# Transitivity: 0.5350671140939597
# Betweenness Centralization: 0.0013831145458146415
# PageRank Centralization: 0.008815933545146532
# Average Clustering Coefficient: 0.4127746067515886
# Transitivity: 0.4228788289509352
# Betweenness Centralization: 0.002017817366296172
# PageRank Centralization: 0.010751370991197154
# Average Clustering Coefficient: 0.5453992323436037
# Transitivity: 0.5861610113107119
# Betweenness Centralization: 0.001793702555366255
# PageRank Centralization: 0.009728873443673102
# Average Clustering Coefficient: 0.5314605594032906
# Transitivity: 0.5887984681665869
# Betweenness Centralization: 0.0009640378416863377
# PageRank Centralization: 0.007008962821097019
# Average Clustering Coefficient: 0.5287971960959577
# Transitivity: 0.5064402810304449
# Betweenness Centralization: 0.0009895453836463264
# PageRank Centralization: 0.009219587193289138
# Average Clustering Coefficient: 0.4254129875747858
# Transitivity: 0.4216574585635359
# Betweenness Centralization: 0.0009637351454207804
# PageRank Centralization: 0.006861440659955685
# Average Clustering Coefficient: 0.49638401539532234
# Transitivity: 0.5367097832027692
# Betweenness Centralization: 0.0010964705267577312
# PageRank Centralization: 0.007369355571695728
# Average Clustering Coefficient: 0.4954715586774946
# Transitivity: 0.49294911097486205
# Betweenness Centralization: 0.001708385093333258
# PageRank Centralization: 0.007798111066449937
# Average Clustering Coefficient: 0.416643271817669
# Transitivity: 0.5459110473457676
# Betweenness Centralization: 0.0012577296131722779
# PageRank Centralization: 0.012301513794425513
# Average Clustering Coefficient: 0.45052208237607416
# Transitivity: 0.4677149548343928
# Betweenness Centralization: 0.0019251629841840752
# PageRank Centralization: 0.011125805815428562
# Average Clustering Coefficient: 0.3769646028574599
# Transitivity: 0.4287949921752739
# Betweenness Centralization: 0.0011316741078986874
# PageRank Centralization: 0.009077784591350621
# Average Clustering Coefficient: 0.5304014576829221
# Transitivity: 0.5686227256295939
# Betweenness Centralization: 0.0012753461872866349
# PageRank Centralization: 0.007245276843166122
# Average Clustering Coefficient: 0.5176318540360417
# Transitivity: 0.535394265232975
# Betweenness Centralization: 0.0007917665327836651
# PageRank Centralization: 0.006048054484348676
# Average Clustering Coefficient: 0.49373512056511104
# Transitivity: 0.5193036641864383
# Betweenness Centralization: 0.0010914474082738801
# PageRank Centralization: 0.009126440311914046
# Average Clustering Coefficient: 0.4677095114948748
# Transitivity: 0.47178947368421054
# Betweenness Centralization: 0.0012685107404340795
# PageRank Centralization: 0.006816839320975924
# Average Clustering Coefficient: 0.5186194311514003
# Transitivity: 0.5033734232912878
# Betweenness Centralization: 0.0009491348124185677
# PageRank Centralization: 0.006918374381046993
# Average Clustering Coefficient: 0.48102698538622907
# Transitivity: 0.4596774193548387
# Betweenness Centralization: 0.0012768517676512569
# PageRank Centralization: 0.012649930264661277
# Average Clustering Coefficient: 0.5059288865619318
# Transitivity: 0.4874008810572687
# Betweenness Centralization: 0.0009213240690828585
# PageRank Centralization: 0.01080048500110151
# Average Clustering Coefficient: 0.4979806981681155
# Transitivity: 0.5099398139704542
# Betweenness Centralization: 0.002157265795254701
# PageRank Centralization: 0.008179831460735679
# Average Clustering Coefficient: 0.5752182147069974
# Transitivity: 0.6369971075466737
# Betweenness Centralization: 0.001030061292253858
# PageRank Centralization: 0.007086030566420548
# Average Clustering Coefficient: 0.43727026493443294
# Transitivity: 0.4872748069774092
# Betweenness Centralization: 0.002648449399068735
# PageRank Centralization: 0.008650800774719166
# Average Clustering Coefficient: 0.5037856680799265
# Transitivity: 0.515485407980941
# Betweenness Centralization: 0.0011942195505497098
# PageRank Centralization: 0.008895706996781343
# Average Clustering Coefficient: 0.49155372913446466
# Transitivity: 0.47512772250605
# Betweenness Centralization: 0.0012462516901258045
# PageRank Centralization: 0.010735937892222571
# Average Clustering Coefficient: 0.4179564291946858
# Transitivity: 0.42358803986710963
# Betweenness Centralization: 0.0012918044896982376
# PageRank Centralization: 0.012757878792306696
# Average Clustering Coefficient: 0.52617586098669
# Transitivity: 0.49039010466222643
# Betweenness Centralization: 0.001009000416682601
# PageRank Centralization: 0.00597888418278473
# Average Clustering Coefficient: 0.5138492569569079
# Transitivity: 0.5396511627906977
# Betweenness Centralization: 0.0011674590446232003
# PageRank Centralization: 0.008354392563636487
# Average Clustering Coefficient: 0.4570268013351825
# Transitivity: 0.4534673366834171
# Betweenness Centralization: 0.00119833883063881
# PageRank Centralization: 0.007590347093084271
# Average Clustering Coefficient: 0.4562429415110308
# Transitivity: 0.48752622989041733
# Betweenness Centralization: 0.0008481536527629034
# PageRank Centralization: 0.00906086936789035
# Average Clustering Coefficient: 0.5231651521579859
# Transitivity: 0.5445754004230885
# Betweenness Centralization: 0.0025413914139434998
# PageRank Centralization: 0.009221700707927242
# Average Clustering Coefficient: 0.510348053848579
# Transitivity: 0.5456204379562044
# Betweenness Centralization: 0.0017537680666194033
# PageRank Centralization: 0.009483912960126038
# Average Clustering Coefficient: 0.4510929146683587
# Transitivity: 0.5272846811308349
# Betweenness Centralization: 0.001271122545775715
# PageRank Centralization: 0.007310232096734695
# Average Clustering Coefficient: 0.44786018755328216
# Transitivity: 0.45012626262626265
# Betweenness Centralization: 0.0013642381844220092
# PageRank Centralization: 0.008582376823348219
# Average Clustering Coefficient: 0.5053971243494674
# Transitivity: 0.5401929260450161
# Betweenness Centralization: 0.0018550895291142256
# PageRank Centralization: 0.009990346306393864
# Average Clustering Coefficient: 0.5030989907143861
# Transitivity: 0.5035175879396985
# Betweenness Centralization: 0.0009532383920110503
# PageRank Centralization: 0.00811843970899024
# Average Clustering Coefficient: 0.4573421999278731
# Transitivity: 0.476017130620985
# Betweenness Centralization: 0.0010575791371717324
# PageRank Centralization: 0.008577324572002727
# Average Clustering Coefficient: 0.3982109996989407
# Transitivity: 0.4480761274306992
# Betweenness Centralization: 0.0035992935734455696
# PageRank Centralization: 0.009459254891960516
# Average Clustering Coefficient: 0.42327929823604565
# Transitivity: 0.4868519909842224
# Betweenness Centralization: 0.0017775597193707034
# PageRank Centralization: 0.008504157125264125
# Average Clustering Coefficient: 0.49183846920999225
# Transitivity: 0.5338799131902581
# Betweenness Centralization: 0.001171190336444098
# PageRank Centralization: 0.007983653882959888
# Average Clustering Coefficient: 0.5275878057826217
# Transitivity: 0.6021918321468714
# Betweenness Centralization: 0.002265664252136667
# PageRank Centralization: 0.009745641294945508
# Average Clustering Coefficient: 0.4356318853298893
# Transitivity: 0.6368286445012787
# Betweenness Centralization: 0.0016022927994789385
# PageRank Centralization: 0.007932992233320498
# Average Clustering Coefficient: 0.514334107211345
# Transitivity: 0.5139838408949658
# Betweenness Centralization: 0.0016524111917168326
# PageRank Centralization: 0.006537475625897153
# Average Clustering Coefficient: 0.5014411288350301
# Transitivity: 0.5011713822310326
# Betweenness Centralization: 0.0021767899986516108
# PageRank Centralization: 0.013144936179807457
# Average Clustering Coefficient: 0.5401238323404596
# Transitivity: 0.5907666001709889
# Betweenness Centralization: 0.0012825870825036343
# PageRank Centralization: 0.011446138348884857
# Average Clustering Coefficient: 0.4493741638478481
# Transitivity: 0.48732111473763495
# Betweenness Centralization: 0.0008608475865285273
# PageRank Centralization: 0.006127319107507121
# Average Clustering Coefficient: 0.5354834957070905
# Transitivity: 0.5280076384468492
# Betweenness Centralization: 0.0022357431840105955
# PageRank Centralization: 0.012779602944295556
# Average Clustering Coefficient: 0.5245337526995927
# Transitivity: 0.5166185877336009
# Betweenness Centralization: 0.0020255313223011356
# PageRank Centralization: 0.010928454734631358
# Average Clustering Coefficient: 0.4743561131386826
# Transitivity: 0.4568380213385063
# Betweenness Centralization: 0.0021445144678407064
# PageRank Centralization: 0.008761930920186697
# Average Clustering Coefficient: 0.5299215377889553
# Transitivity: 0.5944912012241775
# Betweenness Centralization: 0.0013530449037781657
# PageRank Centralization: 0.007686371268809015
# Average Clustering Coefficient: 0.46835520801038044
# Transitivity: 0.4675324675324675
# Betweenness Centralization: 0.0008387748148104381
# PageRank Centralization: 0.007677658674700016
# Average Clustering Coefficient: 0.4117876801895542
# Transitivity: 0.45
# Betweenness Centralization: 0.001037409195042119
# PageRank Centralization: 0.010745845172097259
# Average Clustering Coefficient: 0.4796967909641858
# Transitivity: 0.49357226334242305
# Betweenness Centralization: 0.0008378365306448644
# PageRank Centralization: 0.008088235833930611
# Average Clustering Coefficient: 0.49011362152140636
# Transitivity: 0.4978723404255319
# Betweenness Centralization: 0.0021243318131415126
# PageRank Centralization: 0.009665233753965356
# Average Clustering Coefficient: 0.41448460427210776
# Transitivity: 0.5231220392510715
# Betweenness Centralization: 0.001265736149628901
# PageRank Centralization: 0.007425159757251405
# Average Clustering Coefficient: 0.5016527512497827
# Transitivity: 0.5429376335729551
# Betweenness Centralization: 0.0015162477551000084
# PageRank Centralization: 0.011244666955891788
# Average Clustering Coefficient: 0.4716887633780047
# Transitivity: 0.44034917555771097
# Betweenness Centralization: 0.0018760795566622067
# PageRank Centralization: 0.008906825633916685
# Average Clustering Coefficient: 0.49190012355441537
# Transitivity: 0.5359202936549554
# Betweenness Centralization: 0.0010047826168246212
# PageRank Centralization: 0.007260858744305044
# Average Clustering Coefficient: 0.4344261961275145
# Transitivity: 0.4527115535761069
# Betweenness Centralization: 0.0008265485976692734
# PageRank Centralization: 0.006588333087835756
# Average Clustering Coefficient: 0.48454421365452827
# Transitivity: 0.5237964613907558
# Betweenness Centralization: 0.0010233616887506216
# PageRank Centralization: 0.008527265270511859
# Average Clustering Coefficient: 0.5539047729118753
# Transitivity: 0.5608033546678437
# Betweenness Centralization: 0.0013162044999282516
# PageRank Centralization: 0.007494266394597076
# Average Clustering Coefficient: 0.5130616817404957
# Transitivity: 0.5461897915168943
# Betweenness Centralization: 0.0015906975639688602
# PageRank Centralization: 0.009703507119299034
# Average Clustering Coefficient: 0.4380468922164223
# Transitivity: 0.4976958525345622
# Betweenness Centralization: 0.0018844204684231544
# PageRank Centralization: 0.009696681730930105
# Average Clustering Coefficient: 0.4778778278778279
# Transitivity: 0.46482213438735176
# Betweenness Centralization: 0.0014654430088957636
# PageRank Centralization: 0.007175270605341495
# Average Clustering Coefficient: 0.5313838022553865
# Transitivity: 0.5791930643547849
# Betweenness Centralization: 0.0023295450822815385
# PageRank Centralization: 0.007339947681879867
# Average Clustering Coefficient: 0.4882268866324595
# Transitivity: 0.49248774315989247
# Betweenness Centralization: 0.0014804367483372718
# PageRank Centralization: 0.006898064630729408
# Average Clustering Coefficient: 0.4274698304110067
# Transitivity: 0.4977714748784441
# Betweenness Centralization: 0.0013696492907756873
# PageRank Centralization: 0.006859673356675676
# Average Clustering Coefficient: 0.4807573723501981
# Transitivity: 0.5229514415781487
# Betweenness Centralization: 0.0011823545553778186
# PageRank Centralization: 0.008095825644688965
# Average Clustering Coefficient: 0.48566923118476035
# Transitivity: 0.5588270640548011
# Betweenness Centralization: 0.0008939702680792592
# PageRank Centralization: 0.0076129297104203415
# Average Clustering Coefficient: 0.3800020752194666
# Transitivity: 0.4211026615969582
# Betweenness Centralization: 0.0009211976650046467
# PageRank Centralization: 0.007010620482007374
# Average Clustering Coefficient: 0.4583687353811193
# Transitivity: 0.4783302919708029
# Betweenness Centralization: 0.0028776551596659677
# PageRank Centralization: 0.008620538897637437
# Average Clustering Coefficient: 0.5448862232032533
# Transitivity: 0.5186101149993817
# Betweenness Centralization: 0.0017045483049580518
# PageRank Centralization: 0.012526839955002157
# Average Clustering Coefficient: 0.3854449442684736
# Transitivity: 0.47899860917941584
# Betweenness Centralization: 0.001158865308664767
# PageRank Centralization: 0.00656999471060607
# Average Clustering Coefficient: 0.5039998452253414
# Transitivity: 0.5557963163596966
# Betweenness Centralization: 0.0014010305027286685
# PageRank Centralization: 0.007115891483457591
# Average Clustering Coefficient: 0.449611360506501
# Transitivity: 0.4533665835411471
# Betweenness Centralization: 0.0011090764577380838
# PageRank Centralization: 0.005601215223748661
# Average Clustering Coefficient: 0.5169030338308122
# Transitivity: 0.5244803695150115
# Betweenness Centralization: 0.0014023634798560444
# PageRank Centralization: 0.008407465476511574
# Average Clustering Coefficient: 0.5320206647379165
# Transitivity: 0.5261106780982073
# Betweenness Centralization: 0.0013293713387895654
# PageRank Centralization: 0.009477684862170715
# Average Clustering Coefficient: 0.5210647844796358
# Transitivity: 0.5633261778330132
# Betweenness Centralization: 0.0011163941420311073
# PageRank Centralization: 0.006897836139506031
# Average Clustering Coefficient: 0.4745746292414751
# Transitivity: 0.4897265814593108
# Betweenness Centralization: 0.0013922935512597034
# PageRank Centralization: 0.007177300312121669
# Average Clustering Coefficient: 0.49443423363701994
# Transitivity: 0.4880038387715931
# Betweenness Centralization: 0.0018220497494300305
# PageRank Centralization: 0.011039325378239238
# Average Clustering Coefficient: 0.48279254738444155
# Transitivity: 0.5106035889070146
# Betweenness Centralization: 0.0020573279454530343
# PageRank Centralization: 0.00798719749280135
# Average Clustering Coefficient: 0.429129139423257
# Transitivity: 0.6090882609962133
# Betweenness Centralization: 0.002390168929655556
# PageRank Centralization: 0.010606993772543047
# Average Clustering Coefficient: 0.5386840041231438
# Transitivity: 0.5507273062051188
# Betweenness Centralization: 0.0011905591981819345
# PageRank Centralization: 0.007006193449946703
# Average Clustering Coefficient: 0.5280850524255328
# Transitivity: 0.5087837837837837
# Betweenness Centralization: 0.001118425710998791
# PageRank Centralization: 0.009818847055446105
# Average Clustering Coefficient: 0.5140068811354686
# Transitivity: 0.4832739237729641
# Betweenness Centralization: 0.0015602450716884703
# PageRank Centralization: 0.013458682462470511
# Average Clustering Coefficient: 0.4492432692794669
# Transitivity: 0.46153846153846156
# Betweenness Centralization: 0.001446717143424795
# PageRank Centralization: 0.008793315173689682
# Average Clustering Coefficient: 0.4275664766376839
# Transitivity: 0.4461384653836541
# Betweenness Centralization: 0.0018698483016118877
# PageRank Centralization: 0.007310344375479715
# Average Clustering Coefficient: 0.5333726264724373
# Transitivity: 0.5447776628748707
# Betweenness Centralization: 0.0010841966855547227
# PageRank Centralization: 0.008907317914758362
# Average Clustering Coefficient: 0.4767414715084513
# Transitivity: 0.5029635901778154
# Betweenness Centralization: 0.0017489502624515756
# PageRank Centralization: 0.0070785828375372435
# Average Clustering Coefficient: 0.4982689546883919
# Transitivity: 0.5608591885441527
# Betweenness Centralization: 0.0023521577937462923
# PageRank Centralization: 0.007735415880748524
# Average Clustering Coefficient: 0.5186269731026765
# Transitivity: 0.596123417721519
# Betweenness Centralization: 0.0011513012347950226
# PageRank Centralization: 0.006900405928120543
# Average Clustering Coefficient: 0.5194796155253717
# Transitivity: 0.6014111322656512
# Betweenness Centralization: 0.0013655126989094149
# PageRank Centralization: 0.008784322343043466
# Average Clustering Coefficient: 0.4907799128914775
# Transitivity: 0.528323892035988
# Betweenness Centralization: 0.0008843834267392419
# PageRank Centralization: 0.005993722287439941
# Average Clustering Coefficient: 0.49020523511207925
# Transitivity: 0.4969896004378763
# Betweenness Centralization: 0.0020482093706904346
# PageRank Centralization: 0.0103302688101685
# Average Clustering Coefficient: 0.44723710361038216
# Transitivity: 0.48725418790968683
# Betweenness Centralization: 0.0011904000517756904
# PageRank Centralization: 0.0068016502706017765
# Average Clustering Coefficient: 0.4733055085609267
# Transitivity: 0.43938873626373626
# Betweenness Centralization: 0.0013166874170977372
# PageRank Centralization: 0.006781487961192776
# Average Clustering Coefficient: 0.4721940301586317
# Transitivity: 0.49550359712230213
# Betweenness Centralization: 0.000996017569500384
# PageRank Centralization: 0.007059540974963011
# Average Clustering Coefficient: 0.5560047338400673
# Transitivity: 0.5082359701206666
# Betweenness Centralization: 0.001448248385316063
# PageRank Centralization: 0.009777437572710658
# Average Clustering Coefficient: 0.49055116177708574
# Transitivity: 0.5224892174984597
# Betweenness Centralization: 0.0019453300554446197
# PageRank Centralization: 0.011088927711015517
# Average Clustering Coefficient: 0.5168935246665334
# Transitivity: 0.5590655694186355
# Betweenness Centralization: 0.0020490033012345245
# PageRank Centralization: 0.008664711571909942
# Average Clustering Coefficient: 0.5616299746659482
# Transitivity: 0.6058941058941059
# Betweenness Centralization: 0.001497829548157462
# PageRank Centralization: 0.009777245192083036
# Average Clustering Coefficient: 0.38607206279318057
# Transitivity: 0.45911477869467365
# Betweenness Centralization: 0.001584442035852812
# PageRank Centralization: 0.011264994430285584
# Average Clustering Coefficient: 0.45932053051945937
# Transitivity: 0.5022026431718062
# Betweenness Centralization: 0.003821930066061852
# PageRank Centralization: 0.009394424618677283
# Average Clustering Coefficient: 0.5915215014502904
# Transitivity: 0.6846731660540195
# Betweenness Centralization: 0.0020935664713378943
# PageRank Centralization: 0.011200368039759778
# Average Clustering Coefficient: 0.5251710450599935
# Transitivity: 0.6139107108641502
# Betweenness Centralization: 0.001674011618050779
# PageRank Centralization: 0.009914630840378027
# Average Clustering Coefficient: 0.41666340051295814
# Transitivity: 0.4791511541325391
# Betweenness Centralization: 0.0009891491593351767
# PageRank Centralization: 0.007027438324888424
# Average Clustering Coefficient: 0.4609295196636393
# Transitivity: 0.4445757504136138
# Betweenness Centralization: 0.0013940797238918305
# PageRank Centralization: 0.007346393673697583
# Average Clustering Coefficient: 0.49702131911850567
# Transitivity: 0.5048418334409296
# Betweenness Centralization: 0.0007891668184026563
# PageRank Centralization: 0.006072713927971936
# Average Clustering Coefficient: 0.5060378182722585
# Transitivity: 0.5087798799139005
# Betweenness Centralization: 0.0023663928569996754
# PageRank Centralization: 0.010479937220992766
# Average Clustering Coefficient: 0.40516212087419506
# Transitivity: 0.4718985606579849
# Betweenness Centralization: 0.0007162682787337847
# PageRank Centralization: 0.008947032081459878
# Average Clustering Coefficient: 0.41375953274526434
# Transitivity: 0.4521642619311876
# Betweenness Centralization: 0.0011434019801239968
# PageRank Centralization: 0.009548973385956889
# Average Clustering Coefficient: 0.41876977368463436
# Transitivity: 0.4487510766580534
# Betweenness Centralization: 0.0015447532700325556
# PageRank Centralization: 0.01063250198665506
# Average Clustering Coefficient: 0.46562118234926914
# Transitivity: 0.4886090278760436
# Betweenness Centralization: 0.0010981793433088153
# PageRank Centralization: 0.010430659885190638
# Average Clustering Coefficient: 0.49216030073268235
# Transitivity: 0.5008333333333334
# Betweenness Centralization: 0.0010822288739901177
# PageRank Centralization: 0.009496451064002627
# Average Clustering Coefficient: 0.5314784783320485
# Transitivity: 0.5385813782991202
# Betweenness Centralization: 0.0016729574129879109
# PageRank Centralization: 0.006654958290201033
# Average Clustering Coefficient: 0.5015817273765852
# Transitivity: 0.5380464112250405
# Betweenness Centralization: 0.0008482845832820954
# PageRank Centralization: 0.008129157314089301
# Average Clustering Coefficient: 0.525087095522534
# Transitivity: 0.5904088050314465
# Betweenness Centralization: 0.0020963333678904556
# PageRank Centralization: 0.00704280712575737
# Average Clustering Coefficient: 0.555920280910346
# Transitivity: 0.6912999664091367
# Betweenness Centralization: 0.0014001519984216128
# PageRank Centralization: 0.007751313600216958
# Average Clustering Coefficient: 0.5290625102662969
# Transitivity: 0.5314155942467828
# Betweenness Centralization: 0.0020688102334521824
# PageRank Centralization: 0.012106429451480228
# Average Clustering Coefficient: 0.3692275073854021
# Transitivity: 0.39486356340288925
# Betweenness Centralization: 0.0007350630687972829
# PageRank Centralization: 0.008602431366654945
# Average Clustering Coefficient: 0.4746756370337049
# Transitivity: 0.4672462899115575
# Betweenness Centralization: 0.0012761760239112208
# PageRank Centralization: 0.0101549080008076
# Average Clustering Coefficient: 0.4861635039127659
# Transitivity: 0.5350059332090185
# Betweenness Centralization: 0.0009952558796569929
# PageRank Centralization: 0.0073658552712635005
# Average Clustering Coefficient: 0.5634924574764831
# Transitivity: 0.5248852806212495
# Betweenness Centralization: 0.0007915083742982307
# PageRank Centralization: 0.006622848631453793
# Average Clustering Coefficient: 0.5137708932491378
# Transitivity: 0.5069337442218799
# Betweenness Centralization: 0.0016396456849788704
# PageRank Centralization: 0.011762756179176728
# Average Clustering Coefficient: 0.42868090278576226
# Transitivity: 0.4302120141342756
# Betweenness Centralization: 0.000863566308907995
# PageRank Centralization: 0.009035238602472335
# Average Clustering Coefficient: 0.4621414644918179
# Transitivity: 0.46692200557103064
# Betweenness Centralization: 0.002359488978500142
# PageRank Centralization: 0.008613633551672457
# Average Clustering Coefficient: 0.47621952627204717
# Transitivity: 0.5257218718884833
# Betweenness Centralization: 0.002170450778015948
# PageRank Centralization: 0.008606596527946507
# Average Clustering Coefficient: 0.5580122865590471
# Transitivity: 0.5726549086936163
# Betweenness Centralization: 0.0016946257006871515
# PageRank Centralization: 0.009995651098307797
# Average Clustering Coefficient: 0.511639003403846
# Transitivity: 0.49694467382328655
# Betweenness Centralization: 0.001972139618901843
# PageRank Centralization: 0.009893046621482582
# Average Clustering Coefficient: 0.4556080144301617
# Transitivity: 0.5112966601178782
# Betweenness Centralization: 0.0011032641089861884
# PageRank Centralization: 0.010327338707287949
# Average Clustering Coefficient: 0.43729544627162087
# Transitivity: 0.4517096580683863
# Betweenness Centralization: 0.0019334983209537092
# PageRank Centralization: 0.007760666755932455
# Average Clustering Coefficient: 0.42750477813503024
# Transitivity: 0.5357833655705996
# Betweenness Centralization: 0.0018029389334216688
# PageRank Centralization: 0.00696462075220321
# Average Clustering Coefficient: 0.5209394090899062
# Transitivity: 0.518664047151277
# Betweenness Centralization: 0.0016600566881456412
# PageRank Centralization: 0.0063879409066750145
# Average Clustering Coefficient: 0.5023846481512387
# Transitivity: 0.5278215814372607
# Betweenness Centralization: 0.0008872932474788753
# PageRank Centralization: 0.007988721947267663
# Average Clustering Coefficient: 0.49170938570696626
# Transitivity: 0.49657231313578065
# Betweenness Centralization: 0.002074217016695157
# PageRank Centralization: 0.011151442918807687
# Average Clustering Coefficient: 0.44945424380139676
# Transitivity: 0.484775399457341
# Betweenness Centralization: 0.0020247757919904705
# PageRank Centralization: 0.006806631874642428
# Average Clustering Coefficient: 0.5031748375878728
# Transitivity: 0.6184058529072006
# Betweenness Centralization: 0.0018715008410272057
# PageRank Centralization: 0.008133645114151085
# Average Clustering Coefficient: 0.4493791122231488
# Transitivity: 0.4290139390810532
# Betweenness Centralization: 0.0019912647534775004
# PageRank Centralization: 0.0074095678281685
# Average Clustering Coefficient: 0.45353380918598313
# Transitivity: 0.4582317073170732
# Betweenness Centralization: 0.0016626631849661277
# PageRank Centralization: 0.011638015054584337
# Average Clustering Coefficient: 0.4517969569130559
# Transitivity: 0.46564885496183206
# Betweenness Centralization: 0.0018391061086651713
# PageRank Centralization: 0.00714294700140788
# Average Clustering Coefficient: 0.5454204958613361
# Transitivity: 0.5852545348156817
# Betweenness Centralization: 0.0011235539149513389
# PageRank Centralization: 0.010904270136449047
# Average Clustering Coefficient: 0.4819307114989576
# Transitivity: 0.5237237237237238
# Betweenness Centralization: 0.0015122572438883164
# PageRank Centralization: 0.008860771976145336
# Average Clustering Coefficient: 0.5129093441369655
# Transitivity: 0.5450772423334102
# Betweenness Centralization: 0.0011909726321549501
# PageRank Centralization: 0.006962588614401503
# Average Clustering Coefficient: 0.4042403502929817
# Transitivity: 0.435456595264938
# Betweenness Centralization: 0.001603521644674907
# PageRank Centralization: 0.009577532612353027
# Average Clustering Coefficient: 0.5266224556258968
# Transitivity: 0.5041854475209272
# Betweenness Centralization: 0.001499512975246024
# PageRank Centralization: 0.006376873839088856
# Average Clustering Coefficient: 0.5350447348227669
# Transitivity: 0.5709021752050398
# Betweenness Centralization: 0.000652259313387686
# PageRank Centralization: 0.009390957712413855
# Average Clustering Coefficient: 0.4553314572014877
# Transitivity: 0.4507877350499746
# Betweenness Centralization: 0.0016583989780498628
# PageRank Centralization: 0.007511107378486601
# Average Clustering Coefficient: 0.45901957415014355
# Transitivity: 0.5012675731735423
# Betweenness Centralization: 0.0014433782368929375
# PageRank Centralization: 0.0098729442510267
# Average Clustering Coefficient: 0.43626161128787183
# Transitivity: 0.42830540037243947
# Betweenness Centralization: 0.001607355975352535
# PageRank Centralization: 0.007312672656266656
# Average Clustering Coefficient: 0.502816707230491
# Transitivity: 0.595171620955822
# Betweenness Centralization: 0.0013841338679049246
# PageRank Centralization: 0.006757438082412682
# Average Clustering Coefficient: 0.48618515700559034
# Transitivity: 0.4688142563399589
# Betweenness Centralization: 0.0023004174623414363
# PageRank Centralization: 0.00814161822650688
# Average Clustering Coefficient: 0.49386229548357297
# Transitivity: 0.5536144578313253
# Betweenness Centralization: 0.0008963097391684444
# PageRank Centralization: 0.007093040140828206
# Average Clustering Coefficient: 0.4289627345926981
# Transitivity: 0.46945169712793733
# Betweenness Centralization: 0.0013425383212578223
# PageRank Centralization: 0.008172678020683265
# Average Clustering Coefficient: 0.4769884158556929
# Transitivity: 0.44416011698044233
# Betweenness Centralization: 0.001956965640076141
# PageRank Centralization: 0.009370718026949021
# Average Clustering Coefficient: 0.4986909248519155
# Transitivity: 0.64555633310007
# Betweenness Centralization: 0.001097834255933805
# PageRank Centralization: 0.012307833521830803
# Average Clustering Coefficient: 0.5119456513881813
# Transitivity: 0.4922660479505027
# Betweenness Centralization: 0.0009281198376291561
# PageRank Centralization: 0.007246837695014187
# Average Clustering Coefficient: 0.5122449653285183
# Transitivity: 0.5569395017793595
# Betweenness Centralization: 0.0022617902301814673
# PageRank Centralization: 0.009629642317162129
# Average Clustering Coefficient: 0.45033410327527973
# Transitivity: 0.6300099370652534
# Betweenness Centralization: 0.0020996979398163096
# PageRank Centralization: 0.008304006896864722
# Average Clustering Coefficient: 0.41661745334311706
# Transitivity: 0.4287369640787949
# Betweenness Centralization: 0.0012498034543931896
# PageRank Centralization: 0.008991904382429276
# Average Clustering Coefficient: 0.4893009200889593
# Transitivity: 0.552185089974293
# Betweenness Centralization: 0.001452234410118574
# PageRank Centralization: 0.00648252379541938
# Average Clustering Coefficient: 0.4563749052879488
# Transitivity: 0.4939879759519038
# Betweenness Centralization: 0.002096665062687758
# PageRank Centralization: 0.0080969452661344
# Average Clustering Coefficient: 0.46974154277396896
# Transitivity: 0.48461019995506627
# Betweenness Centralization: 0.0016662721747680216
# PageRank Centralization: 0.006680113255087523
# Average Clustering Coefficient: 0.46393716967885773
# Transitivity: 0.5065512978986403
# Betweenness Centralization: 0.0012978855945164876
# PageRank Centralization: 0.012818821892579348
# Average Clustering Coefficient: 0.447707202548029
# Transitivity: 0.47230732971953804
# Betweenness Centralization: 0.001108608485369617
# PageRank Centralization: 0.012200789887599005
# Average Clustering Coefficient: 0.4839844673941141
# Transitivity: 0.46124454148471616
# Betweenness Centralization: 0.001585694235336069
# PageRank Centralization: 0.008533377262652948
# Average Clustering Coefficient: 0.48430417587380814
# Transitivity: 0.549209586945436
# Betweenness Centralization: 0.0017106997325288728
# PageRank Centralization: 0.007918145686444006
# Average Clustering Coefficient: 0.5248319727120668
# Transitivity: 0.589492338163244
# Betweenness Centralization: 0.0012383238919739614
# PageRank Centralization: 0.007782719233933659
# Average Clustering Coefficient: 0.4569051372018576
# Transitivity: 0.46414182111200647
# Betweenness Centralization: 0.0012115169246263437
# PageRank Centralization: 0.008050679714968952
# Average Clustering Coefficient: 0.47409525172683065
# Transitivity: 0.47341160220994477
# Betweenness Centralization: 0.002217337190832716
# PageRank Centralization: 0.00913657168425857
# Average Clustering Coefficient: 0.5067621901306646
# Transitivity: 0.4906030855539972
# Betweenness Centralization: 0.0019147538219149581
# PageRank Centralization: 0.007245970137886112
# Average Clustering Coefficient: 0.5387413770153707
# Transitivity: 0.5455770094297261
# Betweenness Centralization: 0.0013693527018507935
# PageRank Centralization: 0.010075935545804543
# Average Clustering Coefficient: 0.4546224744754156
# Transitivity: 0.4948453608247423
# Betweenness Centralization: 0.0013896198465336296
# PageRank Centralization: 0.008117417521593224
# Average Clustering Coefficient: 0.4884150978998582
# Transitivity: 0.49604392055546587
# Betweenness Centralization: 0.001193186229560235
# PageRank Centralization: 0.008949002278516967
# Average Clustering Coefficient: 0.43148143207180356
# Transitivity: 0.4546402502606882
# Betweenness Centralization: 0.0019700206301581616
# PageRank Centralization: 0.010553509951811032
# Average Clustering Coefficient: 0.4716989711012956
# Transitivity: 0.5306380290587492
# Betweenness Centralization: 0.000910454161892271
# PageRank Centralization: 0.011923970117854796
# Average Clustering Coefficient: 0.49184912852359397
# Transitivity: 0.45316948898546383
# Betweenness Centralization: 0.002388454598217368
# PageRank Centralization: 0.009623260844224182
# Average Clustering Coefficient: 0.6024913410977414
# Transitivity: 0.5975457570715474
# Betweenness Centralization: 0.0010854378937109551
# PageRank Centralization: 0.007130844167318395
# Average Clustering Coefficient: 0.5409217962416693
# Transitivity: 0.5560782837786977
# Betweenness Centralization: 0.0013463744069730872
# PageRank Centralization: 0.007414692027012044
# Average Clustering Coefficient: 0.5019764009789583
# Transitivity: 0.4831168831168831
# Betweenness Centralization: 0.0008656178419409985
# PageRank Centralization: 0.007091182628754204
# Average Clustering Coefficient: 0.5023986508373186
# Transitivity: 0.469030969030969
# Betweenness Centralization: 0.0016010133423310156
# PageRank Centralization: 0.007185806785732772
# Average Clustering Coefficient: 0.5713150389824662
# Transitivity: 0.5181535269709544
# Betweenness Centralization: 0.0010867851435593257
# PageRank Centralization: 0.006185046822967338
# Average Clustering Coefficient: 0.5272124052555992
# Transitivity: 0.5622672734795201
# Betweenness Centralization: 0.001468959552883665
# PageRank Centralization: 0.007227163528386012
# Average Clustering Coefficient: 0.5696247975827083
# Transitivity: 0.5290725612686209
# Betweenness Centralization: 0.0016221768019265494
# PageRank Centralization: 0.00600076384212436
# Average Clustering Coefficient: 0.546836916250088
# Transitivity: 0.5644181585677749
# Betweenness Centralization: 0.0016771268819141074
# PageRank Centralization: 0.00917652736669622
# Average Clustering Coefficient: 0.4777666777666777
# Transitivity: 0.4722483537158984
# Betweenness Centralization: 0.0010318509043936552
# PageRank Centralization: 0.009338855259661353
# Average Clustering Coefficient: 0.5532666334839892
# Transitivity: 0.529871754770097
# Betweenness Centralization: 0.0014532250941337189
# PageRank Centralization: 0.007302161991953932
# Average Clustering Coefficient: 0.47624484934856465
# Transitivity: 0.511937672782106
# Betweenness Centralization: 0.0016620637059329662
# PageRank Centralization: 0.009921098259691955
# Average Clustering Coefficient: 0.5404479195144158
# Transitivity: 0.5240691989469726
# Betweenness Centralization: 0.0007791248469927514
# PageRank Centralization: 0.005977221732201117
# Average Clustering Coefficient: 0.5692671481841656
# Transitivity: 0.592694335139951
# Betweenness Centralization: 0.0015778933506969363
# PageRank Centralization: 0.008136543632935181
# Average Clustering Coefficient: 0.5177985475413328
# Transitivity: 0.5029845505617978
# Betweenness Centralization: 0.0025696877850059485
# PageRank Centralization: 0.007642930788876595
# Average Clustering Coefficient: 0.5271775293020087
# ...
# Betweenness Centralization: 0.001780508660456589
# PageRank Centralization: 0.010098991973361884
# Average Clustering Coefficient: 0.3633809133809135
# Transitivity: 0.40391908975979773
# Betweenness Centralization: 0.0009443370701569247
# PageRank Centralization: 0.00649009269007002
# Average Clustering Coefficient: 0.5288407797827431
# Transitivity: 0.5704968944099379
# Betweenness Centralization: 0.0011825330210505336
# PageRank Centralization: 0.005151984366719956
# Average Clustering Coefficient: 0.5114106982292471
# Transitivity: 0.5216992665036675
# Betweenness Centralization: 0.000994686512437602
# PageRank Centralization: 0.009960381928126278
# Average Clustering Coefficient: 0.5104578177664486
# Transitivity: 0.49707685726507916
# Betweenness Centralization: 0.0010454255060655282
# PageRank Centralization: 0.008653305776330581
# Average Clustering Coefficient: 0.49699118526735836
# Transitivity: 0.5457834958287265
# Betweenness Centralization: 0.0010252335202028582
# PageRank Centralization: 0.0072117441410252635
# Average Clustering Coefficient: 0.5055031619389411
# Transitivity: 0.5172629602586837
# Betweenness Centralization: 0.0018651883230504796
# PageRank Centralization: 0.00863341998011983
# Average Clustering Coefficient: 0.46208705310205256
# Transitivity: 0.5028928136419001
# Betweenness Centralization: 0.00325457029847878
# PageRank Centralization: 0.0072076693003102375
# Average Clustering Coefficient: 0.5168090392131314
# Transitivity: 0.5826068003487358
# Betweenness Centralization: 0.0011166595036882514
# PageRank Centralization: 0.008396152148142965
# Average Clustering Coefficient: 0.45682039861399104
# Transitivity: 0.5079113924050633
# Betweenness Centralization: 0.002525278772450546
# PageRank Centralization: 0.006547444089251021
# Average Clustering Coefficient: 0.49979191533697004
# Transitivity: 0.5644768856447688
# Betweenness Centralization: 0.0013624970080141805
# PageRank Centralization: 0.008295848539677802
# Average Clustering Coefficient: 0.5311018765186334
# Transitivity: 0.5872698158526821
# Betweenness Centralization: 0.00124360472679897
# PageRank Centralization: 0.011867629511767829
# Average Clustering Coefficient: 0.4724622986973525
# Transitivity: 0.42723977213878817
# Betweenness Centralization: 0.0023151124801857517
# PageRank Centralization: 0.013240888076847722
# Average Clustering Coefficient: 0.41367930049748236
# Transitivity: 0.46560402684563756
# Betweenness Centralization: 0.001319195675667196
# PageRank Centralization: 0.008203683782102735
# Average Clustering Coefficient: 0.49145695957808944
# Transitivity: 0.49302964853720793
# Betweenness Centralization: 0.0013304051363212306
# PageRank Centralization: 0.011308031231303485
# Average Clustering Coefficient: 0.4684671436335595
# Transitivity: 0.47487270312154084
# Betweenness Centralization: 0.0011575301340351622
# PageRank Centralization: 0.007508765687592212
# Average Clustering Coefficient: 0.564576465269958
# Transitivity: 0.5786350148367952
# Betweenness Centralization: 0.0011720199531485163
# PageRank Centralization: 0.009914984287476005
# Average Clustering Coefficient: 0.4400846687742695
# Transitivity: 0.46696665984863983
# Betweenness Centralization: 0.0020427746935174295
# PageRank Centralization: 0.008514572099399582
# Average Clustering Coefficient: 0.458322257664363
# Transitivity: 0.5150893641957223
# Betweenness Centralization: 0.0009497320032780242
# PageRank Centralization: 0.0075399618318635125
# Average Clustering Coefficient: 0.4868892026841561
# Transitivity: 0.4892683691054363
# Betweenness Centralization: 0.0017553668978511963
# PageRank Centralization: 0.007050286215844919
# Average Clustering Coefficient: 0.4287121164276337
# Transitivity: 0.4963527851458886
# Betweenness Centralization: 0.0008140083005664208
# PageRank Centralization: 0.006302896899957454
# Average Clustering Coefficient: 0.5162148268325981
# Transitivity: 0.5791429279167699
# Betweenness Centralization: 0.0012072696496697867
# PageRank Centralization: 0.008905452454419848
# Average Clustering Coefficient: 0.44398809720817833
# Transitivity: 0.4521181001283697
# Betweenness Centralization: 0.0013891680341095573
# PageRank Centralization: 0.00581845930448916
# Average Clustering Coefficient: 0.4546313360968532
# Transitivity: 0.4981889105600446
# Betweenness Centralization: 0.0009983843394725828
# PageRank Centralization: 0.009208300779673733
# Average Clustering Coefficient: 0.5479076336984479
# Transitivity: 0.5349555813055233
# Betweenness Centralization: 0.001631659356237039
# PageRank Centralization: 0.008655191145867358
# Average Clustering Coefficient: 0.48627151264278307
# Transitivity: 0.4444444444444444
# Betweenness Centralization: 0.0019788619410303007
# PageRank Centralization: 0.010105473937722058
# Average Clustering Coefficient: 0.44801567655549945
# Transitivity: 0.47914735866543096
# Betweenness Centralization: 0.0017092292210379068
# PageRank Centralization: 0.013498525967663096
# Average Clustering Coefficient: 0.533241199647028
# Transitivity: 0.5973425765453495
# Betweenness Centralization: 0.001099880824824205
# PageRank Centralization: 0.0066210468847991005
# Average Clustering Coefficient: 0.48717149140357907
# Transitivity: 0.5336565355211635
# Betweenness Centralization: 0.0016948658425095199
# PageRank Centralization: 0.00867715508114541
# Average Clustering Coefficient: 0.5078321239174962
# Transitivity: 0.531021897810219
# Betweenness Centralization: 0.0008175160697364297
# PageRank Centralization: 0.007144907773189242
# Average Clustering Coefficient: 0.531537293028324
# Transitivity: 0.4796310530361261
# Betweenness Centralization: 0.0017825140959566613
# PageRank Centralization: 0.008994004275997157
# Average Clustering Coefficient: 0.4737438378614847
# Transitivity: 0.47686832740213525
# Betweenness Centralization: 0.002050039036354173
# PageRank Centralization: 0.010667134257076083
# Average Clustering Coefficient: 0.5075388165561193
# Transitivity: 0.5165155440414507
# Betweenness Centralization: 0.0021454299846267967
# PageRank Centralization: 0.009379607242797603
# Average Clustering Coefficient: 0.5040125642636253
# Transitivity: 0.5804406881980079
# Betweenness Centralization: 0.0023595139873628782
# PageRank Centralization: 0.007373442663642685
# Average Clustering Coefficient: 0.440782275738028
# Transitivity: 0.46499339498018494
# Betweenness Centralization: 0.0018725335386450886
# PageRank Centralization: 0.007245943133068982
# Average Clustering Coefficient: 0.4946911784496375
# Transitivity: 0.5397951142631994
# Betweenness Centralization: 0.0014602740805331183
# PageRank Centralization: 0.007306392398065559
# Average Clustering Coefficient: 0.5374211470718824
# Transitivity: 0.5546218487394958
# Betweenness Centralization: 0.0010363405382612287
# PageRank Centralization: 0.007632693289819422
# Average Clustering Coefficient: 0.4930994749370991
# Transitivity: 0.5193026151930261
# Betweenness Centralization: 0.0013084239538916393
# PageRank Centralization: 0.005960927368897958
# Average Clustering Coefficient: 0.5067425141848649
# Transitivity: 0.5448451962974784
# Betweenness Centralization: 0.0036999034712721047
# PageRank Centralization: 0.007686829001799145
# Average Clustering Coefficient: 0.4581219098944938
# Transitivity: 0.6450953678474114
# Betweenness Centralization: 0.0010586692027693874
# PageRank Centralization: 0.010040919015076272
# Average Clustering Coefficient: 0.45414379598455507
# Transitivity: 0.4777003484320557
# Betweenness Centralization: 0.0017224009142697632
# PageRank Centralization: 0.008023577136219718
# Average Clustering Coefficient: 0.4168381215702336
# Transitivity: 0.5473833097595474
# Betweenness Centralization: 0.002357123140008079
# PageRank Centralization: 0.00899216938593846
# Average Clustering Coefficient: 0.422579632643571
# Transitivity: 0.4568111983612154
# Betweenness Centralization: 0.0004972359966034233
# PageRank Centralization: 0.006393882293834377
# Average Clustering Coefficient: 0.5421247444811909
# Transitivity: 0.5367834285321038
# Betweenness Centralization: 0.001918913124074296
# PageRank Centralization: 0.008786251235441408
# Average Clustering Coefficient: 0.4615216754922637
# Transitivity: 0.4556714471968709
# Betweenness Centralization: 0.000912322236439258
# PageRank Centralization: 0.00838888191024399
# Average Clustering Coefficient: 0.5562288605866639
# Transitivity: 0.5371457935692262
# Betweenness Centralization: 0.0006340836482097547
# PageRank Centralization: 0.006783399861617502
# Average Clustering Coefficient: 0.586609906145334
# Transitivity: 0.6297864152395612
# Betweenness Centralization: 0.0016410045516152506
# PageRank Centralization: 0.0073911596304166785
# Average Clustering Coefficient: 0.5239834413880023
# Transitivity: 0.5313821138211382
# Betweenness Centralization: 0.0022923801000441116
# PageRank Centralization: 0.008491163025660817
# Average Clustering Coefficient: 0.5214067544373259
# Transitivity: 0.5634007373477824
# Betweenness Centralization: 0.0014679393959926056
# PageRank Centralization: 0.00885896570904973
# Average Clustering Coefficient: 0.5083215238055375
# Transitivity: 0.583737517831669
# Betweenness Centralization: 0.0016741453313562343
# PageRank Centralization: 0.007669370145939054
# Average Clustering Coefficient: 0.484494016865956
# Transitivity: 0.5405355150613611
# Betweenness Centralization: 0.0011937954772553358
# PageRank Centralization: 0.008700131838736667
# Average Clustering Coefficient: 0.43370295816461774
# Transitivity: 0.4405854626643513
# Betweenness Centralization: 0.0014889755159215644
# PageRank Centralization: 0.00945875134765689
# Average Clustering Coefficient: 0.45936628004926267
# Transitivity: 0.466417088746972
# Betweenness Centralization: 0.0024772027657902567
# PageRank Centralization: 0.009639479596790703
# Average Clustering Coefficient: 0.40297546490207065
# Transitivity: 0.5080731969860065
# Betweenness Centralization: 0.001492425205185118
# PageRank Centralization: 0.009056501695954181
# Average Clustering Coefficient: 0.4486759120456368
# Transitivity: 0.5282505105513955
# Betweenness Centralization: 0.0016532582879640984
# PageRank Centralization: 0.00930203060162845
# Average Clustering Coefficient: 0.5461501536309811
# Transitivity: 0.5677593781683001
# Betweenness Centralization: 0.001803232914366494
# PageRank Centralization: 0.008752652935359793
# Average Clustering Coefficient: 0.4705517718702305
# Transitivity: 0.45074977947662453
# Betweenness Centralization: 0.0012637692117679381
# PageRank Centralization: 0.011544341719494327
# Average Clustering Coefficient: 0.5275812823993428
# Transitivity: 0.5485031104199067
# Betweenness Centralization: 0.0018693184415470498
# PageRank Centralization: 0.009653495337144314
# Average Clustering Coefficient: 0.5354929897499555
# Transitivity: 0.5305591677503251
# Betweenness Centralization: 0.0008553450602764611
# PageRank Centralization: 0.007585065308115217
# Average Clustering Coefficient: 0.46276718592575367
# Transitivity: 0.46038677479725515
# Betweenness Centralization: 0.00112646749111862
# PageRank Centralization: 0.010268766303577466
# Average Clustering Coefficient: 0.5112918271585841
# Transitivity: 0.4879767827529022
# Betweenness Centralization: 0.0024942437482542157
# PageRank Centralization: 0.008810446756478164
# Average Clustering Coefficient: 0.5068086603690319
# Transitivity: 0.5027322404371585
# Betweenness Centralization: 0.0012417635259602757
# PageRank Centralization: 0.007623680145143383
# Average Clustering Coefficient: 0.5915816828385075
# Transitivity: 0.6449089978802719
# Betweenness Centralization: 0.0013954038255213693
# PageRank Centralization: 0.006993729299675583
# Average Clustering Coefficient: 0.5095662039012424
# Transitivity: 0.5204366000928936
# Betweenness Centralization: 0.0015868546427589758
# PageRank Centralization: 0.008883798900057973
# Average Clustering Coefficient: 0.45325290131324597
# Transitivity: 0.45181255526083114
# Betweenness Centralization: 0.0023466568829991195
# PageRank Centralization: 0.008319393588301272
# Average Clustering Coefficient: 0.4301510682041654
# Transitivity: 0.4356193142057383
# Betweenness Centralization: 0.002862916203205466
# PageRank Centralization: 0.013808503447373773
# Average Clustering Coefficient: 0.26507936507936497
# Transitivity: 0.35
# Betweenness Centralization: 0.001929097615535771
# PageRank Centralization: 0.010670642573089873
# Average Clustering Coefficient: 0.5096106686635118
# Transitivity: 0.5312923851966673
# Betweenness Centralization: 0.0015849851714680877
# PageRank Centralization: 0.006561513407075881
# Average Clustering Coefficient: 0.5243943790018559
# Transitivity: 0.536086051353227
# Betweenness Centralization: 0.001016438056481488
# PageRank Centralization: 0.008980251930315935
# Average Clustering Coefficient: 0.5484875621965619
# Transitivity: 0.5702389572773353
# Betweenness Centralization: 0.0013663227064505928
# PageRank Centralization: 0.00984862867623356
# Average Clustering Coefficient: 0.4686829087179184
# Transitivity: 0.5193155995187809
# Betweenness Centralization: 0.0009613901757506289
# PageRank Centralization: 0.009434619162885651
# Average Clustering Coefficient: 0.46023554655787474
# Transitivity: 0.4430992736077482
# Betweenness Centralization: 0.003662597544724925
# PageRank Centralization: 0.0162667586810966
# Average Clustering Coefficient: 0.42035536024966114
# Transitivity: 0.4863119040295294
# Betweenness Centralization: 0.001592022009838015
# PageRank Centralization: 0.009811442092534723
# Average Clustering Coefficient: 0.5123059645925231
# Transitivity: 0.5203232420697141
# Betweenness Centralization: 0.000943463200595248
# PageRank Centralization: 0.005551249076980689
# Average Clustering Coefficient: 0.5143050671417485
# Transitivity: 0.5276980798940631
# Betweenness Centralization: 0.0019439039945425272
# PageRank Centralization: 0.011003448223362465
# Average Clustering Coefficient: 0.49467126830533753
# Transitivity: 0.5593308037254225
# Betweenness Centralization: 0.006214483392348014
# PageRank Centralization: 0.007264613494433046
# Average Clustering Coefficient: 0.5194554147491212
# Transitivity: 0.6403425309229306
# Betweenness Centralization: 0.0023765746484108053
# PageRank Centralization: 0.006714646004531542
# Average Clustering Coefficient: 0.4363585150285917
# Transitivity: 0.5367504835589942
# Betweenness Centralization: 0.0018852710343283507
# PageRank Centralization: 0.011692085791356544
# Average Clustering Coefficient: 0.45656917328407426
# Transitivity: 0.551932929669306
# Betweenness Centralization: 0.0021016435070389918
# PageRank Centralization: 0.006947808518462196
# Average Clustering Coefficient: 0.5435945827790746
# Transitivity: 0.6119109947643979
# Betweenness Centralization: 0.0009779680272496768
# PageRank Centralization: 0.007269752370707873
# Average Clustering Coefficient: 0.5183056746392635
# Transitivity: 0.5735749005744587
# Betweenness Centralization: 0.0016626734824900101
# PageRank Centralization: 0.008593396287355155
# Average Clustering Coefficient: 0.3785274745096173
# Transitivity: 0.42304015296367115
# Betweenness Centralization: 0.0013592639899775083
# PageRank Centralization: 0.007185393623893865
# Average Clustering Coefficient: 0.48036741664022536
# Transitivity: 0.5384186305954539
# Betweenness Centralization: 0.002172761939002001
# PageRank Centralization: 0.008992443646060208
# Average Clustering Coefficient: 0.46383411130143176
# Transitivity: 0.5622367805334582
# Betweenness Centralization: 0.0014600247905782603
# PageRank Centralization: 0.008105239804114822
# Average Clustering Coefficient: 0.5235589022541248
# Transitivity: 0.5750425687180735
# Betweenness Centralization: 0.0022758957058504653
# PageRank Centralization: 0.010615577450633759
# Average Clustering Coefficient: 0.48383175938314427
# Transitivity: 0.5961138098542679
# Betweenness Centralization: 0.0016185381331036512
# PageRank Centralization: 0.008223945292561576
# Average Clustering Coefficient: 0.5075588164463729
# Transitivity: 0.5021657118904569
# Betweenness Centralization: 0.0027428760626861657
# PageRank Centralization: 0.01539798226201099
# Average Clustering Coefficient: 0.4246723972558164
# Transitivity: 0.5001670564650852
# Betweenness Centralization: 0.0013387993679811457
# PageRank Centralization: 0.009312706789112708
# Average Clustering Coefficient: 0.4846391051499411
# Transitivity: 0.5415636294464523
# Betweenness Centralization: 0.00127382794014825
# PageRank Centralization: 0.00755669622044969
# Average Clustering Coefficient: 0.4772282849992121
# Transitivity: 0.5437665782493368

# %%
#load the properties
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "rb") as f:
    train_properties_long = pkl.load(f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "rb") as f:
    test_properties_long = pkl.load(f)

# %%
#print the names of the properties
# print(train_properties_long[0].keys())

#print the first element of the properties
# print(train_properties_long[0])

#copare train_properties and train_properties_long
print(train_properties[0])
print(train_properties_long[0])
print(len(train_properties_long))
# Out:
# (116, 488, 0.07316341829085457, 3.314842578710645, 148, 938.0, 6.439699892510922, 116)
# (116, 488, 0.07316341829085457, 3.314842578710645, 7, 4, 0.46590185426058695, 0.5531747591900924, 0.4167832357774365, 148, 938.0, 6.439699892510922, 116, 8.413793103448276, 0.02030563665535653, 14.95587231892924, -4.061650998933738, 976.0000000000007, 4.553913064548185)
# 1523

# %%
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient']
train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
#create a dictionary where we will store the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    input_size = train_embedding.shape[1]

    for i, property_name in enumerate(property_names_long):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 800000  # Maximum number of epochs
        min_epochs = 1000  # Minimum number of epochs
        patience = 3000  # Number of epochs to wait for improvement
        tolerance = 1e-6  # Tolerance for considering the loss as stable

        best_loss = float('inf')
        no_improve_count = 0
        
        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding).squeeze()
            target = train_y_long[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Print every 1000 epochs
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

            # Check for early stopping, but only after minimum epochs
            if epoch >= min_epochs:
                if loss.item() < best_loss - tolerance:
                    best_loss = loss.item()
                    no_improve_count = 0
                else:
                    no_improve_count += 1

                if no_improve_count >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding).squeeze().cpu().numpy()
            test_pred = model(test_embedding).squeeze().cpu().numpy()

            train_target = train_y_long[:, i].cpu().numpy()
            test_target = test_y_long[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embedding = embeddings_names[ii]
            results[(name_of_embedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1

#save results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long.pkl", "wb") as f:
    pkl.dump(results, f)
# Out:
# C:\Users\tomdu\AppData\Local\Temp\ipykernel_4340\1310961172.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#   train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
# C:\Users\tomdu\AppData\Local\Temp\ipykernel_4340\1310961172.py:3: ComplexWarning: Casting complex values to real discards the imaginary part
#   test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
# Epoch [1000/800000], Property: num_nodes, Loss: 11316.3281
# Epoch [2000/800000], Property: num_nodes, Loss: 10060.5898
# Epoch [3000/800000], Property: num_nodes, Loss: 9020.5049
# Epoch [4000/800000], Property: num_nodes, Loss: 8136.6973
# Epoch [5000/800000], Property: num_nodes, Loss: 7371.2759
# Epoch [6000/800000], Property: num_nodes, Loss: 6704.2192
# Epoch [7000/800000], Property: num_nodes, Loss: 6122.5757
# Epoch [8000/800000], Property: num_nodes, Loss: 5616.6626
# Epoch [9000/800000], Property: num_nodes, Loss: 5176.6523
# Epoch [10000/800000], Property: num_nodes, Loss: 4792.4106
# Epoch [11000/800000], Property: num_nodes, Loss: 4454.3672
# Epoch [12000/800000], Property: num_nodes, Loss: 4155.3003
# Epoch [13000/800000], Property: num_nodes, Loss: 3891.3599
# Epoch [14000/800000], Property: num_nodes, Loss: 3659.1582
# Epoch [15000/800000], Property: num_nodes, Loss: 3454.4497
# Epoch [16000/800000], Property: num_nodes, Loss: 3273.5803
# Epoch [17000/800000], Property: num_nodes, Loss: 3113.6660
# Epoch [18000/800000], Property: num_nodes, Loss: 2972.2839
# Epoch [19000/800000], Property: num_nodes, Loss: 2847.0315
# Epoch [20000/800000], Property: num_nodes, Loss: 2735.5032
# Epoch [21000/800000], Property: num_nodes, Loss: 2635.5198
# Epoch [22000/800000], Property: num_nodes, Loss: 2545.1611
# Epoch [23000/800000], Property: num_nodes, Loss: 2462.7104
# Epoch [24000/800000], Property: num_nodes, Loss: 2386.9622
# Epoch [25000/800000], Property: num_nodes, Loss: 2317.1626
# Epoch [26000/800000], Property: num_nodes, Loss: 2252.6133
# Epoch [27000/800000], Property: num_nodes, Loss: 2192.4858
# Epoch [28000/800000], Property: num_nodes, Loss: 2135.9336
# Epoch [29000/800000], Property: num_nodes, Loss: 2082.2283
# Epoch [30000/800000], Property: num_nodes, Loss: 2030.7567
# Epoch [31000/800000], Property: num_nodes, Loss: 1981.0642
# Epoch [32000/800000], Property: num_nodes, Loss: 1932.9357
# Epoch [33000/800000], Property: num_nodes, Loss: 1886.2539
# Epoch [34000/800000], Property: num_nodes, Loss: 1840.7856
# Epoch [35000/800000], Property: num_nodes, Loss: 1796.2723
# Epoch [36000/800000], Property: num_nodes, Loss: 1752.5428
# Epoch [37000/800000], Property: num_nodes, Loss: 1709.3970
# Epoch [38000/800000], Property: num_nodes, Loss: 1666.7023
# Epoch [39000/800000], Property: num_nodes, Loss: 1624.5449
# Epoch [40000/800000], Property: num_nodes, Loss: 1582.9305
# Epoch [41000/800000], Property: num_nodes, Loss: 1541.8589
# Epoch [42000/800000], Property: num_nodes, Loss: 1501.3292
# Epoch [43000/800000], Property: num_nodes, Loss: 1461.3414
# Epoch [44000/800000], Property: num_nodes, Loss: 1421.8959
# Epoch [45000/800000], Property: num_nodes, Loss: 1382.9915
# Epoch [46000/800000], Property: num_nodes, Loss: 1344.6759
# Epoch [47000/800000], Property: num_nodes, Loss: 1306.9991
# Epoch [48000/800000], Property: num_nodes, Loss: 1269.8601
# Epoch [49000/800000], Property: num_nodes, Loss: 1233.2584
# Epoch [50000/800000], Property: num_nodes, Loss: 1197.1942
# Epoch [51000/800000], Property: num_nodes, Loss: 1161.6674
# Epoch [52000/800000], Property: num_nodes, Loss: 1126.6780
# Epoch [53000/800000], Property: num_nodes, Loss: 1092.2261
# Epoch [54000/800000], Property: num_nodes, Loss: 1058.3116
# Epoch [55000/800000], Property: num_nodes, Loss: 1024.9347
# Epoch [56000/800000], Property: num_nodes, Loss: 992.0952
# Epoch [57000/800000], Property: num_nodes, Loss: 959.7932
# Epoch [58000/800000], Property: num_nodes, Loss: 928.0286
# Epoch [59000/800000], Property: num_nodes, Loss: 896.8015
# Epoch [60000/800000], Property: num_nodes, Loss: 866.1118
# Epoch [61000/800000], Property: num_nodes, Loss: 835.9596
# Epoch [62000/800000], Property: num_nodes, Loss: 806.4355
# Epoch [63000/800000], Property: num_nodes, Loss: 777.4681
# Epoch [64000/800000], Property: num_nodes, Loss: 749.0343
# Epoch [65000/800000], Property: num_nodes, Loss: 721.1336
# Epoch [66000/800000], Property: num_nodes, Loss: 693.7662
# Epoch [67000/800000], Property: num_nodes, Loss: 666.8842
# Epoch [68000/800000], Property: num_nodes, Loss: 640.6856
# Epoch [69000/800000], Property: num_nodes, Loss: 615.0163
# Epoch [70000/800000], Property: num_nodes, Loss: 589.8762
# Epoch [71000/800000], Property: num_nodes, Loss: 565.2651
# Epoch [72000/800000], Property: num_nodes, Loss: 541.1832
# Epoch [73000/800000], Property: num_nodes, Loss: 517.6306
# Epoch [74000/800000], Property: num_nodes, Loss: 494.6070
# Epoch [75000/800000], Property: num_nodes, Loss: 472.1127
# Epoch [76000/800000], Property: num_nodes, Loss: 450.1474
# Epoch [77000/800000], Property: num_nodes, Loss: 428.7114
# Epoch [78000/800000], Property: num_nodes, Loss: 407.8045
# Epoch [79000/800000], Property: num_nodes, Loss: 387.4267
# Epoch [80000/800000], Property: num_nodes, Loss: 367.5781
# Epoch [81000/800000], Property: num_nodes, Loss: 348.2587
# Epoch [82000/800000], Property: num_nodes, Loss: 329.5870
# Epoch [83000/800000], Property: num_nodes, Loss: 311.4631
# Epoch [84000/800000], Property: num_nodes, Loss: 293.8603
# Epoch [85000/800000], Property: num_nodes, Loss: 276.7782
# Epoch [86000/800000], Property: num_nodes, Loss: 260.2172
# Epoch [87000/800000], Property: num_nodes, Loss: 244.1770
# Epoch [88000/800000], Property: num_nodes, Loss: 228.6578
# Epoch [89000/800000], Property: num_nodes, Loss: 213.6595
# Epoch [90000/800000], Property: num_nodes, Loss: 199.2471
# Epoch [91000/800000], Property: num_nodes, Loss: 185.3961
# Epoch [92000/800000], Property: num_nodes, Loss: 172.0580
# Epoch [93000/800000], Property: num_nodes, Loss: 159.2325
# Epoch [94000/800000], Property: num_nodes, Loss: 146.9198
# Epoch [95000/800000], Property: num_nodes, Loss: 135.1433
# Epoch [96000/800000], Property: num_nodes, Loss: 123.9426
# Epoch [97000/800000], Property: num_nodes, Loss: 113.2466
# Epoch [98000/800000], Property: num_nodes, Loss: 103.0552
# Epoch [99000/800000], Property: num_nodes, Loss: 93.4085
# Epoch [100000/800000], Property: num_nodes, Loss: 84.2957
# Epoch [101000/800000], Property: num_nodes, Loss: 75.6796
# Epoch [102000/800000], Property: num_nodes, Loss: 67.6087
# Epoch [103000/800000], Property: num_nodes, Loss: 60.0422
# Epoch [104000/800000], Property: num_nodes, Loss: 52.9996
# Epoch [105000/800000], Property: num_nodes, Loss: 46.4595
# Epoch [106000/800000], Property: num_nodes, Loss: 40.4448
# Epoch [107000/800000], Property: num_nodes, Loss: 34.9302
# Epoch [108000/800000], Property: num_nodes, Loss: 29.9180
# Epoch [109000/800000], Property: num_nodes, Loss: 25.4046
# Epoch [110000/800000], Property: num_nodes, Loss: 21.3829
# Epoch [111000/800000], Property: num_nodes, Loss: 17.8485
# Epoch [112000/800000], Property: num_nodes, Loss: 14.7911
# Epoch [113000/800000], Property: num_nodes, Loss: 12.2012
# Epoch [114000/800000], Property: num_nodes, Loss: 10.0650
# Epoch [115000/800000], Property: num_nodes, Loss: 8.3658
# Epoch [116000/800000], Property: num_nodes, Loss: 7.0802
# Epoch [117000/800000], Property: num_nodes, Loss: 6.1763
# Epoch [118000/800000], Property: num_nodes, Loss: 5.6091
# Epoch [119000/800000], Property: num_nodes, Loss: 5.3141
# Epoch [120000/800000], Property: num_nodes, Loss: 5.2039
# Epoch [121000/800000], Property: num_nodes, Loss: 5.1813
# Epoch [122000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [123000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [124000/800000], Property: num_nodes, Loss: 5.1796
# Epoch [125000/800000], Property: num_nodes, Loss: 5.1796
# Early stopping at epoch 125976
# Embedding: torch.Size([1523, 128])
# Property: num_nodes
#   Train MSE: 5.1796, Test MSE: 7.4193
#   Train R²: 0.0874, Test R²: -0.1763
# Epoch [1000/800000], Property: num_edges, Loss: 271889.2500
# Epoch [2000/800000], Property: num_edges, Loss: 264017.0938
# Epoch [3000/800000], Property: num_edges, Loss: 256706.7031
# Epoch [4000/800000], Property: num_edges, Loss: 249759.2812
# Epoch [5000/800000], Property: num_edges, Loss: 243103.2188
# Epoch [6000/800000], Property: num_edges, Loss: 236725.4375
# Epoch [7000/800000], Property: num_edges, Loss: 230613.4375
# Epoch [8000/800000], Property: num_edges, Loss: 224758.1719
# Epoch [9000/800000], Property: num_edges, Loss: 219146.7188
# Epoch [10000/800000], Property: num_edges, Loss: 213756.7656
# Epoch [11000/800000], Property: num_edges, Loss: 208563.3750
# Epoch [12000/800000], Property: num_edges, Loss: 203552.4844
# Epoch [13000/800000], Property: num_edges, Loss: 198716.2812
# Epoch [14000/800000], Property: num_edges, Loss: 194045.0625
# Epoch [15000/800000], Property: num_edges, Loss: 189532.4844
# Epoch [16000/800000], Property: num_edges, Loss: 185174.0156
# Epoch [17000/800000], Property: num_edges, Loss: 180962.8438
# Epoch [18000/800000], Property: num_edges, Loss: 176889.1875
# Epoch [19000/800000], Property: num_edges, Loss: 172942.4844
# Epoch [20000/800000], Property: num_edges, Loss: 169117.4844
# Epoch [21000/800000], Property: num_edges, Loss: 165412.9219
# Epoch [22000/800000], Property: num_edges, Loss: 161827.5781
# Epoch [23000/800000], Property: num_edges, Loss: 158359.4688
# Epoch [24000/800000], Property: num_edges, Loss: 155006.9531
# Epoch [25000/800000], Property: num_edges, Loss: 151769.2500
# Epoch [26000/800000], Property: num_edges, Loss: 148644.5938
# Epoch [27000/800000], Property: num_edges, Loss: 145628.7188
# Epoch [28000/800000], Property: num_edges, Loss: 142715.4688
# Epoch [29000/800000], Property: num_edges, Loss: 139898.4219
# Epoch [30000/800000], Property: num_edges, Loss: 137173.8906
# Epoch [31000/800000], Property: num_edges, Loss: 134541.4688
# Epoch [32000/800000], Property: num_edges, Loss: 131999.6250
# Epoch [33000/800000], Property: num_edges, Loss: 129546.6328
# Epoch [34000/800000], Property: num_edges, Loss: 127179.8203
# Epoch [35000/800000], Property: num_edges, Loss: 124896.5391
# Epoch [36000/800000], Property: num_edges, Loss: 122693.1875
# Epoch [37000/800000], Property: num_edges, Loss: 120563.6484
# Epoch [38000/800000], Property: num_edges, Loss: 118503.4688
# Epoch [39000/800000], Property: num_edges, Loss: 116507.2969
# Epoch [40000/800000], Property: num_edges, Loss: 114569.9453
# Epoch [41000/800000], Property: num_edges, Loss: 112687.7656
# Epoch [42000/800000], Property: num_edges, Loss: 110858.6953
# Epoch [43000/800000], Property: num_edges, Loss: 109082.2109
# Epoch [44000/800000], Property: num_edges, Loss: 107358.0469
# Epoch [45000/800000], Property: num_edges, Loss: 105685.5547
# Epoch [46000/800000], Property: num_edges, Loss: 104063.0938
# Epoch [47000/800000], Property: num_edges, Loss: 102489.5703
# Epoch [48000/800000], Property: num_edges, Loss: 100965.0859
# Epoch [49000/800000], Property: num_edges, Loss: 99488.4297
# Epoch [50000/800000], Property: num_edges, Loss: 98059.3672
# Epoch [51000/800000], Property: num_edges, Loss: 96676.8438
# Epoch [52000/800000], Property: num_edges, Loss: 95339.3594
# Epoch [53000/800000], Property: num_edges, Loss: 94044.9297
# Epoch [54000/800000], Property: num_edges, Loss: 92791.3672
# Epoch [55000/800000], Property: num_edges, Loss: 91577.2422
# Epoch [56000/800000], Property: num_edges, Loss: 90400.8125
# Epoch [57000/800000], Property: num_edges, Loss: 89260.5469
# Epoch [58000/800000], Property: num_edges, Loss: 88155.0312
# Epoch [59000/800000], Property: num_edges, Loss: 87081.8281
# Epoch [60000/800000], Property: num_edges, Loss: 86037.7812
# Epoch [61000/800000], Property: num_edges, Loss: 85023.3281
# Epoch [62000/800000], Property: num_edges, Loss: 84038.4219
# Epoch [63000/800000], Property: num_edges, Loss: 83082.1641
# Epoch [64000/800000], Property: num_edges, Loss: 82154.1172
# Epoch [65000/800000], Property: num_edges, Loss: 81253.7656
# Epoch [66000/800000], Property: num_edges, Loss: 80381.5703
# Epoch [67000/800000], Property: num_edges, Loss: 79535.8750
# Epoch [68000/800000], Property: num_edges, Loss: 78716.2422
# Epoch [69000/800000], Property: num_edges, Loss: 77922.0469
# Epoch [70000/800000], Property: num_edges, Loss: 77152.8672
# Epoch [71000/800000], Property: num_edges, Loss: 76407.9922
# Epoch [72000/800000], Property: num_edges, Loss: 75686.1172
# Epoch [73000/800000], Property: num_edges, Loss: 74985.4609
# Epoch [74000/800000], Property: num_edges, Loss: 74304.6406
# Epoch [75000/800000], Property: num_edges, Loss: 73643.0625
# Epoch [76000/800000], Property: num_edges, Loss: 73000.5234
# Epoch [77000/800000], Property: num_edges, Loss: 72374.9766
# Epoch [78000/800000], Property: num_edges, Loss: 71765.3672
# Epoch [79000/800000], Property: num_edges, Loss: 71172.6406
# Epoch [80000/800000], Property: num_edges, Loss: 70596.4375
# Epoch [81000/800000], Property: num_edges, Loss: 70036.2734
# Epoch [82000/800000], Property: num_edges, Loss: 69491.8594
# Epoch [83000/800000], Property: num_edges, Loss: 68962.4922
# Epoch [84000/800000], Property: num_edges, Loss: 68447.3984
# Epoch [85000/800000], Property: num_edges, Loss: 67946.0781
# Epoch [86000/800000], Property: num_edges, Loss: 67457.9297
# Epoch [87000/800000], Property: num_edges, Loss: 66982.1875
# Epoch [88000/800000], Property: num_edges, Loss: 66518.2969
# Epoch [89000/800000], Property: num_edges, Loss: 66065.1328
# Epoch [90000/800000], Property: num_edges, Loss: 65621.8594
# Epoch [91000/800000], Property: num_edges, Loss: 65188.1914
# Epoch [92000/800000], Property: num_edges, Loss: 64764.0508
# Epoch [93000/800000], Property: num_edges, Loss: 64349.1211
# Epoch [94000/800000], Property: num_edges, Loss: 63943.1445
# Epoch [95000/800000], Property: num_edges, Loss: 63546.1289
# Epoch [96000/800000], Property: num_edges, Loss: 63157.6719
# Epoch [97000/800000], Property: num_edges, Loss: 62777.5742
# Epoch [98000/800000], Property: num_edges, Loss: 62405.5273
# Epoch [99000/800000], Property: num_edges, Loss: 62041.3711
# Epoch [100000/800000], Property: num_edges, Loss: 61684.9023
# Epoch [101000/800000], Property: num_edges, Loss: 61336.0000
# Epoch [102000/800000], Property: num_edges, Loss: 60994.6367
# Epoch [103000/800000], Property: num_edges, Loss: 60660.6367
# Epoch [104000/800000], Property: num_edges, Loss: 60333.7500
# Epoch [105000/800000], Property: num_edges, Loss: 60013.8320
# Epoch [106000/800000], Property: num_edges, Loss: 59700.7266
# Epoch [107000/800000], Property: num_edges, Loss: 59394.2578
# Epoch [108000/800000], Property: num_edges, Loss: 59094.2188
# Epoch [109000/800000], Property: num_edges, Loss: 58800.3086
# Epoch [110000/800000], Property: num_edges, Loss: 58512.1797
# Epoch [111000/800000], Property: num_edges, Loss: 58229.3633
# Epoch [112000/800000], Property: num_edges, Loss: 57951.3945
# Epoch [113000/800000], Property: num_edges, Loss: 57677.8164
# Epoch [114000/800000], Property: num_edges, Loss: 57408.2305
# Epoch [115000/800000], Property: num_edges, Loss: 57142.4180
# Epoch [116000/800000], Property: num_edges, Loss: 56880.2461
# Epoch [117000/800000], Property: num_edges, Loss: 56621.5430
# Epoch [118000/800000], Property: num_edges, Loss: 56365.9297
# Epoch [119000/800000], Property: num_edges, Loss: 56113.1562
# Epoch [120000/800000], Property: num_edges, Loss: 55863.0273
# Epoch [121000/800000], Property: num_edges, Loss: 55614.8438
# Epoch [122000/800000], Property: num_edges, Loss: 55367.7461
# Epoch [123000/800000], Property: num_edges, Loss: 55122.9883
# Epoch [124000/800000], Property: num_edges, Loss: 54880.5742
# Epoch [125000/800000], Property: num_edges, Loss: 54640.4844
# Epoch [126000/800000], Property: num_edges, Loss: 54402.6992
# Epoch [127000/800000], Property: num_edges, Loss: 54167.1953
# Epoch [128000/800000], Property: num_edges, Loss: 53933.9570
# Epoch [129000/800000], Property: num_edges, Loss: 53702.9688
# Epoch [130000/800000], Property: num_edges, Loss: 53474.8164
# Epoch [131000/800000], Property: num_edges, Loss: 53249.7969
# Epoch [132000/800000], Property: num_edges, Loss: 53026.8359
# Epoch [133000/800000], Property: num_edges, Loss: 52805.8984
# Epoch [134000/800000], Property: num_edges, Loss: 52586.8594
# Epoch [135000/800000], Property: num_edges, Loss: 52369.6289
# Epoch [136000/800000], Property: num_edges, Loss: 52154.1445
# Epoch [137000/800000], Property: num_edges, Loss: 51940.2773
# Epoch [138000/800000], Property: num_edges, Loss: 51727.9414
# Epoch [139000/800000], Property: num_edges, Loss: 51517.0781
# Epoch [140000/800000], Property: num_edges, Loss: 51307.5039
# Epoch [141000/800000], Property: num_edges, Loss: 51099.1055
# Epoch [142000/800000], Property: num_edges, Loss: 50891.7227
# Epoch [143000/800000], Property: num_edges, Loss: 50685.3047
# Epoch [144000/800000], Property: num_edges, Loss: 50479.8438
# Epoch [145000/800000], Property: num_edges, Loss: 50275.3164
# Epoch [146000/800000], Property: num_edges, Loss: 50071.6836
# Epoch [147000/800000], Property: num_edges, Loss: 49868.8945
# Epoch [148000/800000], Property: num_edges, Loss: 49666.9219
# Epoch [149000/800000], Property: num_edges, Loss: 49465.7109
# Epoch [150000/800000], Property: num_edges, Loss: 49265.2188
# Epoch [151000/800000], Property: num_edges, Loss: 49065.3398
# Epoch [152000/800000], Property: num_edges, Loss: 48866.0156
# Epoch [153000/800000], Property: num_edges, Loss: 48667.2344
# Epoch [154000/800000], Property: num_edges, Loss: 48468.9961
# Epoch [155000/800000], Property: num_edges, Loss: 48271.3008
# Epoch [156000/800000], Property: num_edges, Loss: 48074.1523
# Epoch [157000/800000], Property: num_edges, Loss: 47877.5586
# Epoch [158000/800000], Property: num_edges, Loss: 47681.4961
# Epoch [159000/800000], Property: num_edges, Loss: 47485.9883
# Epoch [160000/800000], Property: num_edges, Loss: 47291.0273
# Epoch [161000/800000], Property: num_edges, Loss: 47096.6133
# Epoch [162000/800000], Property: num_edges, Loss: 46902.7383
# Epoch [163000/800000], Property: num_edges, Loss: 46709.4141
# Epoch [164000/800000], Property: num_edges, Loss: 46516.6367
# Epoch [165000/800000], Property: num_edges, Loss: 46324.4023
# Epoch [166000/800000], Property: num_edges, Loss: 46132.7188
# Epoch [167000/800000], Property: num_edges, Loss: 45941.5742
# Epoch [168000/800000], Property: num_edges, Loss: 45750.9766
# Epoch [169000/800000], Property: num_edges, Loss: 45560.9297
# Epoch [170000/800000], Property: num_edges, Loss: 45371.4258
# Epoch [171000/800000], Property: num_edges, Loss: 45182.4609
# Epoch [172000/800000], Property: num_edges, Loss: 44994.0547
# Epoch [173000/800000], Property: num_edges, Loss: 44806.1875
# Epoch [174000/800000], Property: num_edges, Loss: 44618.8672
# Epoch [175000/800000], Property: num_edges, Loss: 44432.0898
# Epoch [176000/800000], Property: num_edges, Loss: 44245.8633
# Epoch [177000/800000], Property: num_edges, Loss: 44060.1836
# Epoch [178000/800000], Property: num_edges, Loss: 43875.0430
# Epoch [179000/800000], Property: num_edges, Loss: 43690.4492
# Epoch [180000/800000], Property: num_edges, Loss: 43506.4062
# Epoch [181000/800000], Property: num_edges, Loss: 43322.9062
# Epoch [182000/800000], Property: num_edges, Loss: 43139.9531
# Epoch [183000/800000], Property: num_edges, Loss: 42957.5430
# Epoch [184000/800000], Property: num_edges, Loss: 42775.6836
# Epoch [185000/800000], Property: num_edges, Loss: 42594.3672
# Epoch [186000/800000], Property: num_edges, Loss: 42413.5938
# Epoch [187000/800000], Property: num_edges, Loss: 42233.3633
# Epoch [188000/800000], Property: num_edges, Loss: 42053.6875
# Epoch [189000/800000], Property: num_edges, Loss: 41874.5547
# Epoch [190000/800000], Property: num_edges, Loss: 41695.9688
# Epoch [191000/800000], Property: num_edges, Loss: 41517.9258
# Epoch [192000/800000], Property: num_edges, Loss: 41340.4297
# Epoch [193000/800000], Property: num_edges, Loss: 41163.4805
# Epoch [194000/800000], Property: num_edges, Loss: 40987.0742
# Epoch [195000/800000], Property: num_edges, Loss: 40811.2148
# Epoch [196000/800000], Property: num_edges, Loss: 40635.9023
# Epoch [197000/800000], Property: num_edges, Loss: 40461.1367
# Epoch [198000/800000], Property: num_edges, Loss: 40286.9219
# Epoch [199000/800000], Property: num_edges, Loss: 40113.2383
# Epoch [200000/800000], Property: num_edges, Loss: 39940.1133
# Epoch [201000/800000], Property: num_edges, Loss: 39767.5273
# Epoch [202000/800000], Property: num_edges, Loss: 39595.4922
# Epoch [203000/800000], Property: num_edges, Loss: 39423.9961
# Epoch [204000/800000], Property: num_edges, Loss: 39253.0469
# Epoch [205000/800000], Property: num_edges, Loss: 39082.6484
# Epoch [206000/800000], Property: num_edges, Loss: 38912.7969
# Epoch [207000/800000], Property: num_edges, Loss: 38743.4922
# Epoch [208000/800000], Property: num_edges, Loss: 38574.7305
# Epoch [209000/800000], Property: num_edges, Loss: 38406.5078
# Epoch [210000/800000], Property: num_edges, Loss: 38238.8398
# Epoch [211000/800000], Property: num_edges, Loss: 38071.7148
# Epoch [212000/800000], Property: num_edges, Loss: 37905.1328
# Epoch [213000/800000], Property: num_edges, Loss: 37739.0977
# Epoch [214000/800000], Property: num_edges, Loss: 37573.6055
# Epoch [215000/800000], Property: num_edges, Loss: 37408.6680
# Epoch [216000/800000], Property: num_edges, Loss: 37244.2695
# Epoch [217000/800000], Property: num_edges, Loss: 37080.4297
# Epoch [218000/800000], Property: num_edges, Loss: 36917.1172
# Epoch [219000/800000], Property: num_edges, Loss: 36754.3633
# Epoch [220000/800000], Property: num_edges, Loss: 36592.1484
# Epoch [221000/800000], Property: num_edges, Loss: 36430.4805
# Epoch [222000/800000], Property: num_edges, Loss: 36269.3594
# Epoch [223000/800000], Property: num_edges, Loss: 36108.7812
# Epoch [224000/800000], Property: num_edges, Loss: 35948.7539
# Epoch [225000/800000], Property: num_edges, Loss: 35789.2695
# Epoch [226000/800000], Property: num_edges, Loss: 35630.3281
# Epoch [227000/800000], Property: num_edges, Loss: 35471.9414
# Epoch [228000/800000], Property: num_edges, Loss: 35314.0977
# Epoch [229000/800000], Property: num_edges, Loss: 35156.7930
# Epoch [230000/800000], Property: num_edges, Loss: 35000.0391
# Epoch [231000/800000], Property: num_edges, Loss: 34843.8320
# Epoch [232000/800000], Property: num_edges, Loss: 34688.1680
# Epoch [233000/800000], Property: num_edges, Loss: 34533.0469
# Epoch [234000/800000], Property: num_edges, Loss: 34378.4805
# Epoch [235000/800000], Property: num_edges, Loss: 34224.4531
# Epoch [236000/800000], Property: num_edges, Loss: 34070.9727
# Epoch [237000/800000], Property: num_edges, Loss: 33918.0391
# Epoch [238000/800000], Property: num_edges, Loss: 33765.6523
# Epoch [239000/800000], Property: num_edges, Loss: 33613.8086
# Epoch [240000/800000], Property: num_edges, Loss: 33462.5117
# Epoch [241000/800000], Property: num_edges, Loss: 33311.7617
# Epoch [242000/800000], Property: num_edges, Loss: 33161.5586
# Epoch [243000/800000], Property: num_edges, Loss: 33011.8984
# Epoch [244000/800000], Property: num_edges, Loss: 32862.7852
# Epoch [245000/800000], Property: num_edges, Loss: 32714.2188
# Epoch [246000/800000], Property: num_edges, Loss: 32566.2012
# Epoch [247000/800000], Property: num_edges, Loss: 32418.7227
# Epoch [248000/800000], Property: num_edges, Loss: 32271.7891
# Epoch [249000/800000], Property: num_edges, Loss: 32125.4102
# Epoch [250000/800000], Property: num_edges, Loss: 31979.5723
# Epoch [251000/800000], Property: num_edges, Loss: 31834.2773
# Epoch [252000/800000], Property: num_edges, Loss: 31689.5312
# Epoch [253000/800000], Property: num_edges, Loss: 31545.3340
# Epoch [254000/800000], Property: num_edges, Loss: 31401.6777
# Epoch [255000/800000], Property: num_edges, Loss: 31258.5664
# Epoch [256000/800000], Property: num_edges, Loss: 31116.0020
# Epoch [257000/800000], Property: num_edges, Loss: 30973.9883
# Epoch [258000/800000], Property: num_edges, Loss: 30832.5156
# Epoch [259000/800000], Property: num_edges, Loss: 30690.8516
# Epoch [260000/800000], Property: num_edges, Loss: 30548.3203
# Epoch [261000/800000], Property: num_edges, Loss: 30406.3457
# Epoch [262000/800000], Property: num_edges, Loss: 30264.9434
# Epoch [263000/800000], Property: num_edges, Loss: 30124.0977
# Epoch [264000/800000], Property: num_edges, Loss: 29983.8164
# Epoch [265000/800000], Property: num_edges, Loss: 29844.0977
# Epoch [266000/800000], Property: num_edges, Loss: 29704.9434
# Epoch [267000/800000], Property: num_edges, Loss: 29566.3477
# Epoch [268000/800000], Property: num_edges, Loss: 29428.3203
# Epoch [269000/800000], Property: num_edges, Loss: 29290.8496
# Epoch [270000/800000], Property: num_edges, Loss: 29153.9453
# Epoch [271000/800000], Property: num_edges, Loss: 29017.6016
# Epoch [272000/800000], Property: num_edges, Loss: 28881.8223
# Epoch [273000/800000], Property: num_edges, Loss: 28746.6074
# Epoch [274000/800000], Property: num_edges, Loss: 28611.9551
# Epoch [275000/800000], Property: num_edges, Loss: 28477.8594
# Epoch [276000/800000], Property: num_edges, Loss: 28344.3340
# Epoch [277000/800000], Property: num_edges, Loss: 28211.3691
# Epoch [278000/800000], Property: num_edges, Loss: 28078.9648
# Epoch [279000/800000], Property: num_edges, Loss: 27947.1250
# Epoch [280000/800000], Property: num_edges, Loss: 27815.8477
# Epoch [281000/800000], Property: num_edges, Loss: 27685.1348
# Epoch [282000/800000], Property: num_edges, Loss: 27554.9805
# Epoch [283000/800000], Property: num_edges, Loss: 27425.3926
# Epoch [284000/800000], Property: num_edges, Loss: 27296.3672
# Epoch [285000/800000], Property: num_edges, Loss: 27167.9062
# Epoch [286000/800000], Property: num_edges, Loss: 27040.0000
# Epoch [287000/800000], Property: num_edges, Loss: 26912.6641
# Epoch [288000/800000], Property: num_edges, Loss: 26785.8867
# Epoch [289000/800000], Property: num_edges, Loss: 26659.6738
# Epoch [290000/800000], Property: num_edges, Loss: 26534.0254
# Epoch [291000/800000], Property: num_edges, Loss: 26408.9375
# Epoch [292000/800000], Property: num_edges, Loss: 26284.4141
# Epoch [293000/800000], Property: num_edges, Loss: 26160.4512
# Epoch [294000/800000], Property: num_edges, Loss: 26037.0527
# Epoch [295000/800000], Property: num_edges, Loss: 25914.2168
# Epoch [296000/800000], Property: num_edges, Loss: 25791.9453
# Epoch [297000/800000], Property: num_edges, Loss: 25670.2344
# Epoch [298000/800000], Property: num_edges, Loss: 25549.0840
# Epoch [299000/800000], Property: num_edges, Loss: 25428.4980
# Epoch [300000/800000], Property: num_edges, Loss: 25308.4785
# Epoch [301000/800000], Property: num_edges, Loss: 25189.0156
# Epoch [302000/800000], Property: num_edges, Loss: 25070.1172
# Epoch [303000/800000], Property: num_edges, Loss: 24951.7871
# Epoch [304000/800000], Property: num_edges, Loss: 24834.0137
# Epoch [305000/800000], Property: num_edges, Loss: 24716.8027
# Epoch [306000/800000], Property: num_edges, Loss: 24600.1602
# Epoch [307000/800000], Property: num_edges, Loss: 24484.0762
# Epoch [308000/800000], Property: num_edges, Loss: 24368.5566
# Epoch [309000/800000], Property: num_edges, Loss: 24253.5996
# Epoch [310000/800000], Property: num_edges, Loss: 24139.2051
# Epoch [311000/800000], Property: num_edges, Loss: 24025.3730
# Epoch [312000/800000], Property: num_edges, Loss: 23912.1016
# Epoch [313000/800000], Property: num_edges, Loss: 23799.3965
# Epoch [314000/800000], Property: num_edges, Loss: 23687.2539
# Epoch [315000/800000], Property: num_edges, Loss: 23575.6699
# Epoch [316000/800000], Property: num_edges, Loss: 23464.6504
# Epoch [317000/800000], Property: num_edges, Loss: 23354.1953
# Epoch [318000/800000], Property: num_edges, Loss: 23244.3027
# Epoch [319000/800000], Property: num_edges, Loss: 23134.9727
# Epoch [320000/800000], Property: num_edges, Loss: 23026.2070
# Epoch [321000/800000], Property: num_edges, Loss: 22918.0039
# Epoch [322000/800000], Property: num_edges, Loss: 22810.3594
# Epoch [323000/800000], Property: num_edges, Loss: 22703.2773
# Epoch [324000/800000], Property: num_edges, Loss: 22596.7637
# Epoch [325000/800000], Property: num_edges, Loss: 22490.8105
# Epoch [326000/800000], Property: num_edges, Loss: 22385.4199
# Epoch [327000/800000], Property: num_edges, Loss: 22280.5918
# Epoch [328000/800000], Property: num_edges, Loss: 22176.3262
# Epoch [329000/800000], Property: num_edges, Loss: 22072.6230
# Epoch [330000/800000], Property: num_edges, Loss: 21969.4824
# Epoch [331000/800000], Property: num_edges, Loss: 21866.9043
# Epoch [332000/800000], Property: num_edges, Loss: 21764.8906
# Epoch [333000/800000], Property: num_edges, Loss: 21663.4375
# Epoch [334000/800000], Property: num_edges, Loss: 21562.5508
# Epoch [335000/800000], Property: num_edges, Loss: 21462.2246
# Epoch [336000/800000], Property: num_edges, Loss: 21362.4629
# Epoch [337000/800000], Property: num_edges, Loss: 21263.2598
# Epoch [338000/800000], Property: num_edges, Loss: 21164.6230
# Epoch [339000/800000], Property: num_edges, Loss: 21066.5469
# Epoch [340000/800000], Property: num_edges, Loss: 20969.0332
# Epoch [341000/800000], Property: num_edges, Loss: 20872.0859
# Epoch [342000/800000], Property: num_edges, Loss: 20775.6973
# Epoch [343000/800000], Property: num_edges, Loss: 20679.8730
# Epoch [344000/800000], Property: num_edges, Loss: 20584.6113
# Epoch [345000/800000], Property: num_edges, Loss: 20489.9141
# Epoch [346000/800000], Property: num_edges, Loss: 20395.7773
# Epoch [347000/800000], Property: num_edges, Loss: 20302.2031
# Epoch [348000/800000], Property: num_edges, Loss: 20209.1953
# Epoch [349000/800000], Property: num_edges, Loss: 20116.7461
# Epoch [350000/800000], Property: num_edges, Loss: 20024.8594
# Epoch [351000/800000], Property: num_edges, Loss: 19933.5391
# Epoch [352000/800000], Property: num_edges, Loss: 19842.7793
# Epoch [353000/800000], Property: num_edges, Loss: 19752.5840
# Epoch [354000/800000], Property: num_edges, Loss: 19662.9473
# Epoch [355000/800000], Property: num_edges, Loss: 19573.8770
# Epoch [356000/800000], Property: num_edges, Loss: 19485.3691
# Epoch [357000/800000], Property: num_edges, Loss: 19397.4238
# Epoch [358000/800000], Property: num_edges, Loss: 19310.0371
# Epoch [359000/800000], Property: num_edges, Loss: 19223.2207
# Epoch [360000/800000], Property: num_edges, Loss: 19136.9629
# Epoch [361000/800000], Property: num_edges, Loss: 19051.2676
# Epoch [362000/800000], Property: num_edges, Loss: 18966.1348
# Epoch [363000/800000], Property: num_edges, Loss: 18881.5645
# Epoch [364000/800000], Property: num_edges, Loss: 18797.5605
# Epoch [365000/800000], Property: num_edges, Loss: 18714.1152
# Epoch [366000/800000], Property: num_edges, Loss: 18631.2344
# Epoch [367000/800000], Property: num_edges, Loss: 18548.9160
# Epoch [368000/800000], Property: num_edges, Loss: 18467.1602
# Epoch [369000/800000], Property: num_edges, Loss: 18385.9688
# Epoch [370000/800000], Property: num_edges, Loss: 18305.3379
# Epoch [371000/800000], Property: num_edges, Loss: 18225.2695
# Epoch [372000/800000], Property: num_edges, Loss: 18145.7676
# Epoch [373000/800000], Property: num_edges, Loss: 18066.8242
# Epoch [374000/800000], Property: num_edges, Loss: 17988.4473
# Epoch [375000/800000], Property: num_edges, Loss: 17910.6289
# Epoch [376000/800000], Property: num_edges, Loss: 17833.3770
# Epoch [377000/800000], Property: num_edges, Loss: 17756.6855
# Epoch [378000/800000], Property: num_edges, Loss: 17680.5566
# Epoch [379000/800000], Property: num_edges, Loss: 17604.9922
# Epoch [380000/800000], Property: num_edges, Loss: 17529.9902
# Epoch [381000/800000], Property: num_edges, Loss: 17455.5488
# Epoch [382000/800000], Property: num_edges, Loss: 17381.6719
# Epoch [383000/800000], Property: num_edges, Loss: 17308.3594
# Epoch [384000/800000], Property: num_edges, Loss: 17235.6055
# Epoch [385000/800000], Property: num_edges, Loss: 17163.4180
# Epoch [386000/800000], Property: num_edges, Loss: 17091.7910
# Epoch [387000/800000], Property: num_edges, Loss: 17020.7285
# Epoch [388000/800000], Property: num_edges, Loss: 16950.2305
# Epoch [389000/800000], Property: num_edges, Loss: 16880.2910
# Epoch [390000/800000], Property: num_edges, Loss: 16810.9160
# Epoch [391000/800000], Property: num_edges, Loss: 16742.1016
# Epoch [392000/800000], Property: num_edges, Loss: 16673.8535
# Epoch [393000/800000], Property: num_edges, Loss: 16606.8574
# Epoch [394000/800000], Property: num_edges, Loss: 16541.0410
# Epoch [395000/800000], Property: num_edges, Loss: 16476.2539
# Epoch [396000/800000], Property: num_edges, Loss: 16412.2168
# Epoch [397000/800000], Property: num_edges, Loss: 16348.7080
# Epoch [398000/800000], Property: num_edges, Loss: 16285.7285
# Epoch [399000/800000], Property: num_edges, Loss: 16223.2764
# Epoch [400000/800000], Property: num_edges, Loss: 16161.3564
# Epoch [401000/800000], Property: num_edges, Loss: 16099.9648
# Epoch [402000/800000], Property: num_edges, Loss: 16039.1006
# Epoch [403000/800000], Property: num_edges, Loss: 15978.7666
# Epoch [404000/800000], Property: num_edges, Loss: 15918.9639
# Epoch [405000/800000], Property: num_edges, Loss: 15859.6875
# Epoch [406000/800000], Property: num_edges, Loss: 15800.9404
# Epoch [407000/800000], Property: num_edges, Loss: 15742.7227
# Epoch [408000/800000], Property: num_edges, Loss: 15685.0352
# Epoch [409000/800000], Property: num_edges, Loss: 15627.8770
# Epoch [410000/800000], Property: num_edges, Loss: 15571.2461
# Epoch [411000/800000], Property: num_edges, Loss: 15515.1465
# Epoch [412000/800000], Property: num_edges, Loss: 15459.5742
# Epoch [413000/800000], Property: num_edges, Loss: 15404.5332
# Epoch [414000/800000], Property: num_edges, Loss: 15350.0195
# Epoch [415000/800000], Property: num_edges, Loss: 15296.0371
# Epoch [416000/800000], Property: num_edges, Loss: 15242.5801
# Epoch [417000/800000], Property: num_edges, Loss: 15189.6562
# Epoch [418000/800000], Property: num_edges, Loss: 15137.2598
# Epoch [419000/800000], Property: num_edges, Loss: 15085.3916
# Epoch [420000/800000], Property: num_edges, Loss: 15034.0537
# Epoch [421000/800000], Property: num_edges, Loss: 14983.2451
# Epoch [422000/800000], Property: num_edges, Loss: 14932.9648
# Epoch [423000/800000], Property: num_edges, Loss: 14883.2139
# Epoch [424000/800000], Property: num_edges, Loss: 14833.9922
# Epoch [425000/800000], Property: num_edges, Loss: 14785.3018
# Epoch [426000/800000], Property: num_edges, Loss: 14737.1377
# Epoch [427000/800000], Property: num_edges, Loss: 14689.5039
# Epoch [428000/800000], Property: num_edges, Loss: 14642.3975
# Epoch [429000/800000], Property: num_edges, Loss: 14595.8242
# Epoch [430000/800000], Property: num_edges, Loss: 14549.7764
# Epoch [431000/800000], Property: num_edges, Loss: 14504.2588
# Epoch [432000/800000], Property: num_edges, Loss: 14459.2715
# Epoch [433000/800000], Property: num_edges, Loss: 14414.8115
# Epoch [434000/800000], Property: num_edges, Loss: 14370.8828
# Epoch [435000/800000], Property: num_edges, Loss: 14327.4824
# Epoch [436000/800000], Property: num_edges, Loss: 14284.6123
# Epoch [437000/800000], Property: num_edges, Loss: 14242.2676
# Epoch [438000/800000], Property: num_edges, Loss: 14200.4541
# Epoch [439000/800000], Property: num_edges, Loss: 14159.1699
# Epoch [440000/800000], Property: num_edges, Loss: 14118.4160
# Epoch [441000/800000], Property: num_edges, Loss: 14078.1904
# Epoch [442000/800000], Property: num_edges, Loss: 14038.4922
# Epoch [443000/800000], Property: num_edges, Loss: 13999.3252
# Epoch [444000/800000], Property: num_edges, Loss: 13960.6885
# Epoch [445000/800000], Property: num_edges, Loss: 13922.5791
# Epoch [446000/800000], Property: num_edges, Loss: 13884.9980
# Epoch [447000/800000], Property: num_edges, Loss: 13847.9492
# Epoch [448000/800000], Property: num_edges, Loss: 13811.4248
# Epoch [449000/800000], Property: num_edges, Loss: 13775.4326
# Epoch [450000/800000], Property: num_edges, Loss: 13739.9707
# Epoch [451000/800000], Property: num_edges, Loss: 13705.0361
# Epoch [452000/800000], Property: num_edges, Loss: 13670.6318
# Epoch [453000/800000], Property: num_edges, Loss: 13636.7549
# Epoch [454000/800000], Property: num_edges, Loss: 13603.4092
# Epoch [455000/800000], Property: num_edges, Loss: 13570.5908
# Epoch [456000/800000], Property: num_edges, Loss: 13538.3037
# Epoch [457000/800000], Property: num_edges, Loss: 13506.5449
# Epoch [458000/800000], Property: num_edges, Loss: 13475.3145
# Epoch [459000/800000], Property: num_edges, Loss: 13444.6123
# Epoch [460000/800000], Property: num_edges, Loss: 13414.4414
# Epoch [461000/800000], Property: num_edges, Loss: 13384.7998
# Epoch [462000/800000], Property: num_edges, Loss: 13355.6865
# Epoch [463000/800000], Property: num_edges, Loss: 13327.1016
# Epoch [464000/800000], Property: num_edges, Loss: 13299.0469
# Epoch [465000/800000], Property: num_edges, Loss: 13271.5205
# Epoch [466000/800000], Property: num_edges, Loss: 13244.5225
# Epoch [467000/800000], Property: num_edges, Loss: 13218.0547
# Epoch [468000/800000], Property: num_edges, Loss: 13192.1172
# Epoch [469000/800000], Property: num_edges, Loss: 13166.7080
# Epoch [470000/800000], Property: num_edges, Loss: 13141.8281
# Epoch [471000/800000], Property: num_edges, Loss: 13117.4775
# Epoch [472000/800000], Property: num_edges, Loss: 13093.6543
# Epoch [473000/800000], Property: num_edges, Loss: 13070.3613
# Epoch [474000/800000], Property: num_edges, Loss: 13047.5986
# Epoch [475000/800000], Property: num_edges, Loss: 13025.3643
# Epoch [476000/800000], Property: num_edges, Loss: 13003.6602
# Epoch [477000/800000], Property: num_edges, Loss: 12982.4834
# Epoch [478000/800000], Property: num_edges, Loss: 12961.8369
# Epoch [479000/800000], Property: num_edges, Loss: 12941.7178
# Epoch [480000/800000], Property: num_edges, Loss: 12922.1299
# Epoch [481000/800000], Property: num_edges, Loss: 12903.0703
# Epoch [482000/800000], Property: num_edges, Loss: 12884.5410
# Epoch [483000/800000], Property: num_edges, Loss: 12866.5400
# Epoch [484000/800000], Property: num_edges, Loss: 12849.0664
# Epoch [485000/800000], Property: num_edges, Loss: 12832.1250
# Epoch [486000/800000], Property: num_edges, Loss: 12815.7109
# Epoch [487000/800000], Property: num_edges, Loss: 12799.8262
# Epoch [488000/800000], Property: num_edges, Loss: 12784.4697
# Epoch [489000/800000], Property: num_edges, Loss: 12769.6455
# Epoch [490000/800000], Property: num_edges, Loss: 12755.3486
# Epoch [491000/800000], Property: num_edges, Loss: 12741.5811
# Epoch [492000/800000], Property: num_edges, Loss: 12728.5664
# Epoch [493000/800000], Property: num_edges, Loss: 12716.2354
# Epoch [494000/800000], Property: num_edges, Loss: 12704.4043
# Epoch [495000/800000], Property: num_edges, Loss: 12693.0674
# Epoch [496000/800000], Property: num_edges, Loss: 12682.2285
# Epoch [497000/800000], Property: num_edges, Loss: 12671.8857
# Epoch [498000/800000], Property: num_edges, Loss: 12662.0391
# Epoch [499000/800000], Property: num_edges, Loss: 12652.6904
# Epoch [500000/800000], Property: num_edges, Loss: 12643.8369
# Epoch [501000/800000], Property: num_edges, Loss: 12635.4814
# Epoch [502000/800000], Property: num_edges, Loss: 12627.6221
# Epoch [503000/800000], Property: num_edges, Loss: 12620.2588
# Epoch [504000/800000], Property: num_edges, Loss: 12613.4854
# Epoch [505000/800000], Property: num_edges, Loss: 12607.3066
# Epoch [506000/800000], Property: num_edges, Loss: 12601.5938
# Epoch [507000/800000], Property: num_edges, Loss: 12596.3457
# Epoch [508000/800000], Property: num_edges, Loss: 12591.5605
# Epoch [509000/800000], Property: num_edges, Loss: 12587.3213
# Epoch [510000/800000], Property: num_edges, Loss: 12583.5801
# Epoch [511000/800000], Property: num_edges, Loss: 12580.2734
# Epoch [512000/800000], Property: num_edges, Loss: 12577.4883
# Epoch [513000/800000], Property: num_edges, Loss: 12575.1328
# Epoch [514000/800000], Property: num_edges, Loss: 12573.2275
# Epoch [515000/800000], Property: num_edges, Loss: 12571.7549
# Epoch [516000/800000], Property: num_edges, Loss: 12570.6719
# Epoch [517000/800000], Property: num_edges, Loss: 12569.9512
# Epoch [518000/800000], Property: num_edges, Loss: 12569.5391
# Epoch [519000/800000], Property: num_edges, Loss: 12569.3525
# Epoch [520000/800000], Property: num_edges, Loss: 12569.2988
# Epoch [521000/800000], Property: num_edges, Loss: 12569.2920
# Epoch [522000/800000], Property: num_edges, Loss: 12569.2920
# Epoch [523000/800000], Property: num_edges, Loss: 12569.2920
# Epoch [524000/800000], Property: num_edges, Loss: 12569.2920
# Epoch [525000/800000], Property: num_edges, Loss: 12569.2939
# Epoch [526000/800000], Property: num_edges, Loss: 12569.2939
# Early stopping at epoch 526413
# Embedding: torch.Size([1523, 128])
# Property: num_edges
#   Train MSE: 12569.2920, Test MSE: 22440.4863
#   Train R²: 0.0791, Test R²: -0.1380
# Epoch [1000/800000], Property: density, Loss: 0.0003
# Epoch [2000/800000], Property: density, Loss: 0.0003
# Epoch [3000/800000], Property: density, Loss: 0.0003
# Epoch [4000/800000], Property: density, Loss: 0.0003
# Early stopping at epoch 4582
# Embedding: torch.Size([1523, 128])
# Property: density
#   Train MSE: 0.0003, Test MSE: 0.0005
#   Train R²: 0.0780, Test R²: -0.1616
# Epoch [1000/800000], Property: avg_path_len, Loss: 2.2680
# Epoch [2000/800000], Property: avg_path_len, Loss: 1.3630
# Epoch [3000/800000], Property: avg_path_len, Loss: 0.7874
# Epoch [4000/800000], Property: avg_path_len, Loss: 0.3995
# Epoch [5000/800000], Property: avg_path_len, Loss: 0.2040
# Epoch [6000/800000], Property: avg_path_len, Loss: 0.1421
# Epoch [7000/800000], Property: avg_path_len, Loss: 0.1332
# Epoch [8000/800000], Property: avg_path_len, Loss: 0.1329
# Epoch [9000/800000], Property: avg_path_len, Loss: 0.1329
# Epoch [10000/800000], Property: avg_path_len, Loss: 0.1329
# Epoch [11000/800000], Property: avg_path_len, Loss: 0.1329
# Early stopping at epoch 11071
# Embedding: torch.Size([1523, 128])
# Property: avg_path_len
#   Train MSE: 0.1329, Test MSE: 0.1750
#   Train R²: 0.0733, Test R²: -0.1547
# Epoch [1000/800000], Property: diameter, Loss: 20.9460
# Epoch [2000/800000], Property: diameter, Loss: 13.9280
# Epoch [3000/800000], Property: diameter, Loss: 10.8051
# Epoch [4000/800000], Property: diameter, Loss: 8.6290
# Epoch [5000/800000], Property: diameter, Loss: 6.7803
# Epoch [6000/800000], Property: diameter, Loss: 5.1797
# Epoch [7000/800000], Property: diameter, Loss: 3.8951
# Epoch [8000/800000], Property: diameter, Loss: 2.9654
# Epoch [9000/800000], Property: diameter, Loss: 2.3727
# Epoch [10000/800000], Property: diameter, Loss: 2.0602
# Epoch [11000/800000], Property: diameter, Loss: 1.9410
# Epoch [12000/800000], Property: diameter, Loss: 1.9156
# Epoch [13000/800000], Property: diameter, Loss: 1.9137
# Epoch [14000/800000], Property: diameter, Loss: 1.9137
# Epoch [15000/800000], Property: diameter, Loss: 1.9137
# Epoch [16000/800000], Property: diameter, Loss: 1.9137
# Early stopping at epoch 16537
# Embedding: torch.Size([1523, 128])
# Property: diameter
#   Train MSE: 1.9137, Test MSE: 2.2290
#   Train R²: 0.0826, Test R²: -0.1899
# Epoch [1000/800000], Property: radius, Loss: 5.5111
# Epoch [2000/800000], Property: radius, Loss: 3.6256
# Epoch [3000/800000], Property: radius, Loss: 2.5390
# Epoch [4000/800000], Property: radius, Loss: 1.6732
# Epoch [5000/800000], Property: radius, Loss: 1.0379
# Epoch [6000/800000], Property: radius, Loss: 0.6556
# Epoch [7000/800000], Property: radius, Loss: 0.4845
# Epoch [8000/800000], Property: radius, Loss: 0.4378
# Epoch [9000/800000], Property: radius, Loss: 0.4324
# Epoch [10000/800000], Property: radius, Loss: 0.4322
# Epoch [11000/800000], Property: radius, Loss: 0.4322
# Epoch [12000/800000], Property: radius, Loss: 0.4322
# Early stopping at epoch 12986
# Embedding: torch.Size([1523, 128])
# Property: radius
#   Train MSE: 0.4322, Test MSE: 0.4660
#   Train R²: 0.0884, Test R²: -0.2696
# Epoch [1000/800000], Property: clustering_coeff, Loss: 0.0029
# Epoch [2000/800000], Property: clustering_coeff, Loss: 0.0021
# Epoch [3000/800000], Property: clustering_coeff, Loss: 0.0021
# Epoch [4000/800000], Property: clustering_coeff, Loss: 0.0021
# Epoch [5000/800000], Property: clustering_coeff, Loss: 0.0021
# Early stopping at epoch 5082
# Embedding: torch.Size([1523, 128])
# Property: clustering_coeff
#   Train MSE: 0.0021, Test MSE: 0.0031
#   Train R²: 0.0682, Test R²: -0.2683
# Epoch [1000/800000], Property: transitivity, Loss: 0.0042
# Epoch [2000/800000], Property: transitivity, Loss: 0.0026
# Epoch [3000/800000], Property: transitivity, Loss: 0.0026
# Epoch [4000/800000], Property: transitivity, Loss: 0.0026
# Epoch [5000/800000], Property: transitivity, Loss: 0.0026
# Early stopping at epoch 5258
# Embedding: torch.Size([1523, 128])
# Property: transitivity
#   Train MSE: 0.0026, Test MSE: 0.0038
#   Train R²: 0.0770, Test R²: -0.2274
# Epoch [1000/800000], Property: assortativity, Loss: 0.0094
# Epoch [2000/800000], Property: assortativity, Loss: 0.0089
# Epoch [3000/800000], Property: assortativity, Loss: 0.0089
# Epoch [4000/800000], Property: assortativity, Loss: 0.0089
# Epoch [5000/800000], Property: assortativity, Loss: 0.0089
# Early stopping at epoch 5099
# Embedding: torch.Size([1523, 128])
# Property: assortativity
#   Train MSE: 0.0089, Test MSE: 0.0104
#   Train R²: 0.0864, Test R²: -0.1195
# Epoch [1000/800000], Property: num_cliques, Loss: 23851.2168
# Epoch [2000/800000], Property: num_cliques, Loss: 21894.1152
# Epoch [3000/800000], Property: num_cliques, Loss: 20192.4512
# Epoch [4000/800000], Property: num_cliques, Loss: 18692.8828
# Epoch [5000/800000], Property: num_cliques, Loss: 17353.9277
# Epoch [6000/800000], Property: num_cliques, Loss: 16145.7588
# Epoch [7000/800000], Property: num_cliques, Loss: 15051.9355
# Epoch [8000/800000], Property: num_cliques, Loss: 14060.5176
# Epoch [9000/800000], Property: num_cliques, Loss: 13163.3828
# Epoch [10000/800000], Property: num_cliques, Loss: 12354.9434
# Epoch [11000/800000], Property: num_cliques, Loss: 11627.0010
# Epoch [12000/800000], Property: num_cliques, Loss: 10970.2422
# Epoch [13000/800000], Property: num_cliques, Loss: 10376.6982
# Epoch [14000/800000], Property: num_cliques, Loss: 9837.0020
# Epoch [15000/800000], Property: num_cliques, Loss: 9342.7129
# Epoch [16000/800000], Property: num_cliques, Loss: 8890.1328
# Epoch [17000/800000], Property: num_cliques, Loss: 8478.0635
# Epoch [18000/800000], Property: num_cliques, Loss: 8104.3525
# Epoch [19000/800000], Property: num_cliques, Loss: 7765.1406
# Epoch [20000/800000], Property: num_cliques, Loss: 7456.1147
# Epoch [21000/800000], Property: num_cliques, Loss: 7174.0459
# Epoch [22000/800000], Property: num_cliques, Loss: 6916.2930
# Epoch [23000/800000], Property: num_cliques, Loss: 6681.0679
# Epoch [24000/800000], Property: num_cliques, Loss: 6466.8188
# Epoch [25000/800000], Property: num_cliques, Loss: 6271.7681
# Epoch [26000/800000], Property: num_cliques, Loss: 6093.5601
# Epoch [27000/800000], Property: num_cliques, Loss: 5930.4189
# Epoch [28000/800000], Property: num_cliques, Loss: 5780.4233
# Epoch [29000/800000], Property: num_cliques, Loss: 5641.8188
# Epoch [30000/800000], Property: num_cliques, Loss: 5513.0244
# Epoch [31000/800000], Property: num_cliques, Loss: 5392.5410
# Epoch [32000/800000], Property: num_cliques, Loss: 5279.3755
# Epoch [33000/800000], Property: num_cliques, Loss: 5173.0156
# Epoch [34000/800000], Property: num_cliques, Loss: 5072.9297
# Epoch [35000/800000], Property: num_cliques, Loss: 4978.7388
# Epoch [36000/800000], Property: num_cliques, Loss: 4889.7026
# Epoch [37000/800000], Property: num_cliques, Loss: 4804.8735
# Epoch [38000/800000], Property: num_cliques, Loss: 4723.7441
# Epoch [39000/800000], Property: num_cliques, Loss: 4645.6660
# Epoch [40000/800000], Property: num_cliques, Loss: 4570.2666
# Epoch [41000/800000], Property: num_cliques, Loss: 4497.1748
# Epoch [42000/800000], Property: num_cliques, Loss: 4426.0664
# Epoch [43000/800000], Property: num_cliques, Loss: 4356.6147
# Epoch [44000/800000], Property: num_cliques, Loss: 4288.9526
# Epoch [45000/800000], Property: num_cliques, Loss: 4222.9595
# Epoch [46000/800000], Property: num_cliques, Loss: 4158.4658
# Epoch [47000/800000], Property: num_cliques, Loss: 4095.2495
# Epoch [48000/800000], Property: num_cliques, Loss: 4033.0820
# Epoch [49000/800000], Property: num_cliques, Loss: 3971.7983
# Epoch [50000/800000], Property: num_cliques, Loss: 3911.3079
# Epoch [51000/800000], Property: num_cliques, Loss: 3851.4360
# Epoch [52000/800000], Property: num_cliques, Loss: 3792.0220
# Epoch [53000/800000], Property: num_cliques, Loss: 3733.1526
# Epoch [54000/800000], Property: num_cliques, Loss: 3674.8267
# Epoch [55000/800000], Property: num_cliques, Loss: 3617.0483
# Epoch [56000/800000], Property: num_cliques, Loss: 3559.8159
# Epoch [57000/800000], Property: num_cliques, Loss: 3503.1296
# Epoch [58000/800000], Property: num_cliques, Loss: 3446.9897
# ...
# Epoch [579000/800000], Property: graph_energy, Loss: 258687.4062
# Epoch [580000/800000], Property: graph_energy, Loss: 257804.5469
# Epoch [581000/800000], Property: graph_energy, Loss: 256923.6094
# Epoch [582000/800000], Property: graph_energy, Loss: 256044.5781
# Epoch [583000/800000], Property: graph_energy, Loss: 255167.5312
# Epoch [584000/800000], Property: graph_energy, Loss: 254292.3750
# Epoch [585000/800000], Property: graph_energy, Loss: 253419.1719
# Epoch [586000/800000], Property: graph_energy, Loss: 252547.9062
# Epoch [587000/800000], Property: graph_energy, Loss: 251678.5469
# Epoch [588000/800000], Property: graph_energy, Loss: 250811.1406
# Epoch [589000/800000], Property: graph_energy, Loss: 249945.6406
# Epoch [590000/800000], Property: graph_energy, Loss: 249082.0781
# Epoch [591000/800000], Property: graph_energy, Loss: 248220.4531
# Epoch [592000/800000], Property: graph_energy, Loss: 247360.7344
# Epoch [593000/800000], Property: graph_energy, Loss: 246502.9688
# Epoch [594000/800000], Property: graph_energy, Loss: 245647.1250
# Epoch [595000/800000], Property: graph_energy, Loss: 244793.2188
# Epoch [596000/800000], Property: graph_energy, Loss: 243941.2344
# Epoch [597000/800000], Property: graph_energy, Loss: 243091.1875
# Epoch [598000/800000], Property: graph_energy, Loss: 242243.0625
# Epoch [599000/800000], Property: graph_energy, Loss: 241396.8906
# Epoch [600000/800000], Property: graph_energy, Loss: 240552.6094
# Epoch [601000/800000], Property: graph_energy, Loss: 239710.2969
# Epoch [602000/800000], Property: graph_energy, Loss: 238869.9219
# Epoch [603000/800000], Property: graph_energy, Loss: 238031.4375
# Epoch [604000/800000], Property: graph_energy, Loss: 237194.8906
# Epoch [605000/800000], Property: graph_energy, Loss: 236360.2812
# Epoch [606000/800000], Property: graph_energy, Loss: 235527.5781
# Epoch [607000/800000], Property: graph_energy, Loss: 234696.8594
# Epoch [608000/800000], Property: graph_energy, Loss: 233868.0625
# Epoch [609000/800000], Property: graph_energy, Loss: 233041.1406
# Epoch [610000/800000], Property: graph_energy, Loss: 232216.2031
# Epoch [611000/800000], Property: graph_energy, Loss: 231393.1562
# Epoch [612000/800000], Property: graph_energy, Loss: 230572.0781
# Epoch [613000/800000], Property: graph_energy, Loss: 229752.8906
# Epoch [614000/800000], Property: graph_energy, Loss: 228935.6719
# Epoch [615000/800000], Property: graph_energy, Loss: 228120.3594
# Epoch [616000/800000], Property: graph_energy, Loss: 227306.9844
# Epoch [617000/800000], Property: graph_energy, Loss: 226495.5312
# Epoch [618000/800000], Property: graph_energy, Loss: 225686.0156
# Epoch [619000/800000], Property: graph_energy, Loss: 224878.4531
# Epoch [620000/800000], Property: graph_energy, Loss: 224072.7812
# Epoch [621000/800000], Property: graph_energy, Loss: 223269.0781
# Epoch [622000/800000], Property: graph_energy, Loss: 222467.2812
# Epoch [623000/800000], Property: graph_energy, Loss: 221667.4062
# Epoch [624000/800000], Property: graph_energy, Loss: 220869.4844
# Epoch [625000/800000], Property: graph_energy, Loss: 220073.4688
# Epoch [626000/800000], Property: graph_energy, Loss: 219279.4062
# Epoch [627000/800000], Property: graph_energy, Loss: 218487.2656
# Epoch [628000/800000], Property: graph_energy, Loss: 217697.0312
# Epoch [629000/800000], Property: graph_energy, Loss: 216908.7500
# Epoch [630000/800000], Property: graph_energy, Loss: 216122.4062
# Epoch [631000/800000], Property: graph_energy, Loss: 215337.9844
# Epoch [632000/800000], Property: graph_energy, Loss: 214555.4844
# Epoch [633000/800000], Property: graph_energy, Loss: 213774.9219
# Epoch [634000/800000], Property: graph_energy, Loss: 212996.2812
# Epoch [635000/800000], Property: graph_energy, Loss: 212219.5938
# Epoch [636000/800000], Property: graph_energy, Loss: 211444.7969
# Epoch [637000/800000], Property: graph_energy, Loss: 210671.9844
# Epoch [638000/800000], Property: graph_energy, Loss: 209901.0625
# Epoch [639000/800000], Property: graph_energy, Loss: 209132.0781
# Epoch [640000/800000], Property: graph_energy, Loss: 208365.0312
# Epoch [641000/800000], Property: graph_energy, Loss: 207599.9219
# Epoch [642000/800000], Property: graph_energy, Loss: 206836.7188
# Epoch [643000/800000], Property: graph_energy, Loss: 206075.4688
# Epoch [644000/800000], Property: graph_energy, Loss: 205316.1250
# Epoch [645000/800000], Property: graph_energy, Loss: 204558.7344
# Epoch [646000/800000], Property: graph_energy, Loss: 203803.2656
# Epoch [647000/800000], Property: graph_energy, Loss: 203049.7031
# Epoch [648000/800000], Property: graph_energy, Loss: 202298.0938
# Epoch [649000/800000], Property: graph_energy, Loss: 201548.4219
# Epoch [650000/800000], Property: graph_energy, Loss: 200800.6875
# Epoch [651000/800000], Property: graph_energy, Loss: 200054.8594
# Epoch [652000/800000], Property: graph_energy, Loss: 199310.9844
# Epoch [653000/800000], Property: graph_energy, Loss: 198569.0156
# Epoch [654000/800000], Property: graph_energy, Loss: 197829.0000
# Epoch [655000/800000], Property: graph_energy, Loss: 197090.8750
# Epoch [656000/800000], Property: graph_energy, Loss: 196354.7344
# Epoch [657000/800000], Property: graph_energy, Loss: 195620.4688
# Epoch [658000/800000], Property: graph_energy, Loss: 194888.1719
# Epoch [659000/800000], Property: graph_energy, Loss: 194157.7812
# Epoch [660000/800000], Property: graph_energy, Loss: 193429.3438
# Epoch [661000/800000], Property: graph_energy, Loss: 192702.8438
# Epoch [662000/800000], Property: graph_energy, Loss: 191978.2344
# Epoch [663000/800000], Property: graph_energy, Loss: 191255.5938
# Epoch [664000/800000], Property: graph_energy, Loss: 190534.8750
# Epoch [665000/800000], Property: graph_energy, Loss: 189816.0625
# Epoch [666000/800000], Property: graph_energy, Loss: 189099.2031
# Epoch [667000/800000], Property: graph_energy, Loss: 188384.2656
# Epoch [668000/800000], Property: graph_energy, Loss: 187671.2812
# Epoch [669000/800000], Property: graph_energy, Loss: 186960.1719
# Epoch [670000/800000], Property: graph_energy, Loss: 186251.0469
# Epoch [671000/800000], Property: graph_energy, Loss: 185543.8438
# Epoch [672000/800000], Property: graph_energy, Loss: 184838.5312
# Epoch [673000/800000], Property: graph_energy, Loss: 184135.1875
# Epoch [674000/800000], Property: graph_energy, Loss: 183433.7500
# Epoch [675000/800000], Property: graph_energy, Loss: 182734.2812
# Epoch [676000/800000], Property: graph_energy, Loss: 182036.7031
# Epoch [677000/800000], Property: graph_energy, Loss: 181341.0781
# Epoch [678000/800000], Property: graph_energy, Loss: 180647.3750
# Epoch [679000/800000], Property: graph_energy, Loss: 179955.6094
# Epoch [680000/800000], Property: graph_energy, Loss: 179265.7656
# Epoch [681000/800000], Property: graph_energy, Loss: 178577.8438
# Epoch [682000/800000], Property: graph_energy, Loss: 177891.8438
# Epoch [683000/800000], Property: graph_energy, Loss: 177207.8125
# Epoch [684000/800000], Property: graph_energy, Loss: 176525.6719
# Epoch [685000/800000], Property: graph_energy, Loss: 175845.5000
# Epoch [686000/800000], Property: graph_energy, Loss: 175167.2500
# Epoch [687000/800000], Property: graph_energy, Loss: 174490.8906
# Epoch [688000/800000], Property: graph_energy, Loss: 173816.5156
# Epoch [689000/800000], Property: graph_energy, Loss: 173144.0156
# Epoch [690000/800000], Property: graph_energy, Loss: 172473.4844
# Epoch [691000/800000], Property: graph_energy, Loss: 171804.8750
# Epoch [692000/800000], Property: graph_energy, Loss: 171138.1875
# Epoch [693000/800000], Property: graph_energy, Loss: 170473.4375
# Epoch [694000/800000], Property: graph_energy, Loss: 169810.6250
# Epoch [695000/800000], Property: graph_energy, Loss: 169149.7344
# Epoch [696000/800000], Property: graph_energy, Loss: 168490.7656
# Epoch [697000/800000], Property: graph_energy, Loss: 167833.7500
# Epoch [698000/800000], Property: graph_energy, Loss: 167178.6562
# Epoch [699000/800000], Property: graph_energy, Loss: 166525.4844
# Epoch [700000/800000], Property: graph_energy, Loss: 165874.2344
# Epoch [701000/800000], Property: graph_energy, Loss: 165224.9375
# Epoch [702000/800000], Property: graph_energy, Loss: 164577.5625
# Epoch [703000/800000], Property: graph_energy, Loss: 163932.1094
# Epoch [704000/800000], Property: graph_energy, Loss: 163288.6094
# Epoch [705000/800000], Property: graph_energy, Loss: 162647.0156
# Epoch [706000/800000], Property: graph_energy, Loss: 162007.3281
# Epoch [707000/800000], Property: graph_energy, Loss: 161369.6250
# Epoch [708000/800000], Property: graph_energy, Loss: 160733.8281
# Epoch [709000/800000], Property: graph_energy, Loss: 160099.9375
# Epoch [710000/800000], Property: graph_energy, Loss: 159468.0156
# Epoch [711000/800000], Property: graph_energy, Loss: 158838.0000
# Epoch [712000/800000], Property: graph_energy, Loss: 158209.9375
# Epoch [713000/800000], Property: graph_energy, Loss: 157583.7812
# Epoch [714000/800000], Property: graph_energy, Loss: 156959.5781
# Epoch [715000/800000], Property: graph_energy, Loss: 156337.2812
# Epoch [716000/800000], Property: graph_energy, Loss: 155716.9219
# Epoch [717000/800000], Property: graph_energy, Loss: 155098.5000
# Epoch [718000/800000], Property: graph_energy, Loss: 154482.0000
# Epoch [719000/800000], Property: graph_energy, Loss: 153867.4531
# Epoch [720000/800000], Property: graph_energy, Loss: 153254.8125
# Epoch [721000/800000], Property: graph_energy, Loss: 152644.1094
# Epoch [722000/800000], Property: graph_energy, Loss: 152035.3438
# Epoch [723000/800000], Property: graph_energy, Loss: 151428.5000
# Epoch [724000/800000], Property: graph_energy, Loss: 150823.5781
# Epoch [725000/800000], Property: graph_energy, Loss: 150220.5938
# Epoch [726000/800000], Property: graph_energy, Loss: 149619.5312
# Epoch [727000/800000], Property: graph_energy, Loss: 149020.4062
# Epoch [728000/800000], Property: graph_energy, Loss: 148423.2344
# Epoch [729000/800000], Property: graph_energy, Loss: 147827.9531
# Epoch [730000/800000], Property: graph_energy, Loss: 147234.6250
# Epoch [731000/800000], Property: graph_energy, Loss: 146643.2188
# Epoch [732000/800000], Property: graph_energy, Loss: 146053.7500
# Epoch [733000/800000], Property: graph_energy, Loss: 145466.2188
# Epoch [734000/800000], Property: graph_energy, Loss: 144880.6094
# Epoch [735000/800000], Property: graph_energy, Loss: 144296.9219
# Epoch [736000/800000], Property: graph_energy, Loss: 143715.1719
# Epoch [737000/800000], Property: graph_energy, Loss: 143135.3438
# Epoch [738000/800000], Property: graph_energy, Loss: 142557.4531
# Epoch [739000/800000], Property: graph_energy, Loss: 141981.5000
# Epoch [740000/800000], Property: graph_energy, Loss: 141407.4531
# Epoch [741000/800000], Property: graph_energy, Loss: 140835.3594
# Epoch [742000/800000], Property: graph_energy, Loss: 140265.1875
# Epoch [743000/800000], Property: graph_energy, Loss: 139696.9531
# Epoch [744000/800000], Property: graph_energy, Loss: 139130.6562
# Epoch [745000/800000], Property: graph_energy, Loss: 138566.2656
# Epoch [746000/800000], Property: graph_energy, Loss: 138003.8125
# Epoch [747000/800000], Property: graph_energy, Loss: 137443.2969
# Epoch [748000/800000], Property: graph_energy, Loss: 136884.7031
# Epoch [749000/800000], Property: graph_energy, Loss: 136328.0469
# Epoch [750000/800000], Property: graph_energy, Loss: 135773.3125
# Epoch [751000/800000], Property: graph_energy, Loss: 135220.5312
# Epoch [752000/800000], Property: graph_energy, Loss: 134669.6406
# Epoch [753000/800000], Property: graph_energy, Loss: 134120.7031
# Epoch [754000/800000], Property: graph_energy, Loss: 133573.7031
# Epoch [755000/800000], Property: graph_energy, Loss: 133028.6406
# Epoch [756000/800000], Property: graph_energy, Loss: 132485.4844
# Epoch [757000/800000], Property: graph_energy, Loss: 131944.2500
# Epoch [758000/800000], Property: graph_energy, Loss: 131404.9688
# Epoch [759000/800000], Property: graph_energy, Loss: 130867.6250
# Epoch [760000/800000], Property: graph_energy, Loss: 130332.1953
# Epoch [761000/800000], Property: graph_energy, Loss: 129798.6953
# Epoch [762000/800000], Property: graph_energy, Loss: 129267.1328
# Epoch [763000/800000], Property: graph_energy, Loss: 128737.4922
# Epoch [764000/800000], Property: graph_energy, Loss: 128209.7969
# Epoch [765000/800000], Property: graph_energy, Loss: 127684.0156
# Epoch [766000/800000], Property: graph_energy, Loss: 127160.1641
# Epoch [767000/800000], Property: graph_energy, Loss: 126638.2422
# Epoch [768000/800000], Property: graph_energy, Loss: 126118.2578
# Epoch [769000/800000], Property: graph_energy, Loss: 125600.2188
# Epoch [770000/800000], Property: graph_energy, Loss: 125084.0938
# Epoch [771000/800000], Property: graph_energy, Loss: 124569.8984
# Epoch [772000/800000], Property: graph_energy, Loss: 124057.6328
# Epoch [773000/800000], Property: graph_energy, Loss: 123547.2812
# Epoch [774000/800000], Property: graph_energy, Loss: 123038.8984
# Epoch [775000/800000], Property: graph_energy, Loss: 122532.4297
# Epoch [776000/800000], Property: graph_energy, Loss: 122027.8828
# Epoch [777000/800000], Property: graph_energy, Loss: 121525.2656
# Epoch [778000/800000], Property: graph_energy, Loss: 121024.5859
# Epoch [779000/800000], Property: graph_energy, Loss: 120525.8359
# Epoch [780000/800000], Property: graph_energy, Loss: 120029.0078
# Epoch [781000/800000], Property: graph_energy, Loss: 119534.1328
# Epoch [782000/800000], Property: graph_energy, Loss: 119041.1562
# Epoch [783000/800000], Property: graph_energy, Loss: 118550.1250
# Epoch [784000/800000], Property: graph_energy, Loss: 118061.0156
# Epoch [785000/800000], Property: graph_energy, Loss: 117573.8594
# Epoch [786000/800000], Property: graph_energy, Loss: 117088.5859
# Epoch [787000/800000], Property: graph_energy, Loss: 116605.2969
# Epoch [788000/800000], Property: graph_energy, Loss: 116123.9141
# Epoch [789000/800000], Property: graph_energy, Loss: 115644.4609
# Epoch [790000/800000], Property: graph_energy, Loss: 115166.9609
# Epoch [791000/800000], Property: graph_energy, Loss: 114691.3828
# Epoch [792000/800000], Property: graph_energy, Loss: 114217.7422
# Epoch [793000/800000], Property: graph_energy, Loss: 113746.0312
# Epoch [794000/800000], Property: graph_energy, Loss: 113276.2188
# Epoch [795000/800000], Property: graph_energy, Loss: 112808.3750
# Epoch [796000/800000], Property: graph_energy, Loss: 112342.4297
# Epoch [797000/800000], Property: graph_energy, Loss: 111878.4375
# Epoch [798000/800000], Property: graph_energy, Loss: 111416.3594
# Epoch [799000/800000], Property: graph_energy, Loss: 110956.1953
# Epoch [800000/800000], Property: graph_energy, Loss: 110497.9922
# Embedding: torch.Size([1523, 2])
# Property: graph_energy
#   Train MSE: 110497.5312, Test MSE: 162194.7031
#   Train R²: -1.0240, Test R²: -1.0563
# Epoch [1000/800000], Property: small_world_coefficient, Loss: 18.1579
# Epoch [2000/800000], Property: small_world_coefficient, Loss: 11.6553
# Epoch [3000/800000], Property: small_world_coefficient, Loss: 7.0193
# Epoch [4000/800000], Property: small_world_coefficient, Loss: 3.9256
# Epoch [5000/800000], Property: small_world_coefficient, Loss: 2.0898
# Epoch [6000/800000], Property: small_world_coefficient, Loss: 1.2059
# Epoch [7000/800000], Property: small_world_coefficient, Loss: 0.9153
# Epoch [8000/800000], Property: small_world_coefficient, Loss: 0.8677
# Epoch [9000/800000], Property: small_world_coefficient, Loss: 0.8653
# Epoch [10000/800000], Property: small_world_coefficient, Loss: 0.8652
# Epoch [11000/800000], Property: small_world_coefficient, Loss: 0.8650
# Epoch [12000/800000], Property: small_world_coefficient, Loss: 0.8649
# Epoch [13000/800000], Property: small_world_coefficient, Loss: 0.8648
# Epoch [14000/800000], Property: small_world_coefficient, Loss: 0.8647
# Epoch [15000/800000], Property: small_world_coefficient, Loss: 0.8647
# Epoch [16000/800000], Property: small_world_coefficient, Loss: 0.8647
# Epoch [17000/800000], Property: small_world_coefficient, Loss: 0.8647
# Epoch [18000/800000], Property: small_world_coefficient, Loss: 0.8647
# Early stopping at epoch 18377
# Embedding: torch.Size([1523, 2])
# Property: small_world_coefficient
#   Train MSE: 0.8647, Test MSE: 0.8662
#   Train R²: 0.0004, Test R²: 0.0578

# %%
#load results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long.pkl", "rb") as f:
    results = pkl.load(f)

# %%
#print color_long length and property_names_long length
print(len(colors_long))
print(len(property_names_long))
# Out:
# 19
# 23

# %%
property_names_long
# Out:
# 'small_world_coefficient'

# %%
#import plt
import matplotlib.pyplot as plt
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient']
#make a color list for the properties names but with different colors
colors_long = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'gray', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'lime', 'teal', 'lavender', 'tan']

plt.figure(figsize=(12, 8))

for i, property_names_long in enumerate(property_names_long):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_names_long)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_names_long, color=colors_long[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_test_R2_plot_limited_cv_long.png', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(12, 8))
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient']
colors_long = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'gray', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'lime', 'teal', 'lavender', 'tan']

for i, property_names_long in enumerate(property_names_long):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        train_r2 = results[(name_of_embedding, property_names_long)][2]
        if train_r2 < -0.05:  # Handle negative R² values
            train_r2 = -0.05
        x_points.append(j)
        y_points.append(train_r2)

    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_names_long, color=colors_long[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_train_R2_plot_limited_cv_long.png', dpi=300, bbox_inches='tight')
