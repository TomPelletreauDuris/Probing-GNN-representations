# %% [markdown]
# # Probing GCN

# %% [markdown]
# ### Dataset
# Here we'll first be loading the FC matrices and explore their structure

# %%
#using read_dataset from Datasets/FC/create_dataset.py to read the dataset
from Datasets.FC.create_dataset import read_dataset
import torch 
print('GPU available?', torch.cuda.is_available())
# Out:
# GPU available? False

# %%
dataset = read_dataset()

# %%
#ok, let's explore the data a bit more
#dataset is a list object of torch_geometric.data objects

#let's see the first element
print(dataset[0])

#it's a dictionary object, let's see the keys
print(dataset[0].keys())

#ok, let's see the values
print(dataset[0].values())

#it has 4 keys, 'x', 'edge_index', 'edge_attr' and 'y' where y=0 menas the patient is healthy and y=1 means the patient has Autism Spectrum Disorder (ASD)
"""graph = Data(x=ROI.reshape(-1,116).float(),
                     edge_index=G.indices().reshape(2,-1).long(),
                     edge_attr=G.values().reshape(-1,1).float(),
                     y=y.long())"""

#how much data do we have?
len(dataset)
# Out:
# Data(x=[116, 116], edge_index=[2, 1016], edge_attr=[1016, 1], y=[1])
# ['edge_attr', 'y', 'x', 'edge_index']
# ValuesView({'x': tensor([[ 0.0000,  0.4543,  0.2477,  ...,  0.1753,  0.2247, -0.1751],
#         [ 0.4543,  0.0000, -0.2204,  ..., -0.1947, -0.2258, -0.1434],
#         [ 0.2477, -0.2204,  0.0000,  ..., -0.0521, -0.0804, -0.2025],
#         ...,
#         [ 0.1753, -0.1947, -0.0521,  ...,  0.0000,  0.6875, -0.1364],
#         [ 0.2247, -0.2258, -0.0804,  ...,  0.6875,  0.0000,  0.0929],
#         [-0.1751, -0.1434, -0.2025,  ..., -0.1364,  0.0929,  0.0000]]), 'edge_index': tensor([[  0,   0,   0,  ..., 114, 115, 115],
#         [  1,  10,  12,  ..., 113,  94, 109]]), 'edge_attr': tensor([[0.4543],
#         [0.5913],
#         [0.4224],
#         ...,
#         [0.6875],
#         [0.4846],
#         [0.5437]]), 'y': tensor([0])})
# 1099

# %% [markdown]
# ### Model
# Loading the model

# %%
#set the seed
import torch
torch.manual_seed(37)

MODEL = "GCN_wo_edge_weight"
DATASET = "FC"

from models.models_FC import GCN_framework_wo_edge_weight as framework # import the model

gnn = framework(dataset)

print(gnn.model)
print(gnn.train_idx)
# Out:
# Net(
#   (conv_layers): ModuleList(
#     (0): GCNConv(116, 128)
#     (1-4): 4 x GCNConv(128, 128)
#   )
#   (batch_norms): ModuleList(
#     (0-4): 5 x BatchNorm(128)
#   )
#   (lin1): Linear(128, 128, bias=True)
#   (lin2): Linear(128, 2, bias=True)
#   (bn1): BatchNorm(128)
#   (bn2): BatchNorm(2)
# )
# tensor([217, 137, 426,  ..., 643, 205, 434])
# c:\Users\tomdu\miniconda3\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
# gnn.iterate()

# %%
#gnn.train()

# %%
#save the model 
# gnn.save_model(path="models/"+DATASET+"_"+MODEL+"server.pt")

# %%
#load the model
gnn.load_model(path="models/"+DATASET+"_"+MODEL+"server.pt")

# %%
gnn.evaluate()
# Out:
# Test Loss: 0.728, Train Acc: 1.000 Test Acc: 0.564

# %% [markdown]
# ### Properties

# %%
import pickle as pkl
import networkx as nx

def calculate_avg_path_length(G):
    if nx.is_connected(G):
        return nx.average_shortest_path_length(G)
    else:
        # Alternative metrics for disconnected graphs
        # Option 1: Use the average path length of the largest connected component
        components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
        largest_component = max(components, key=len)
        return nx.average_shortest_path_length(largest_component)
    
def calculate_small_world(G):
    if nx.is_connected(G):
        return nx.algorithms.smallworld.sigma(G)
    else:
        # Alternative metrics for disconnected graphs
        # Option 1: Use the small world coefficient of the largest connected component
        components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
        largest_component = max(components, key=len)
        return nx.algorithms.smallworld.sigma(largest_component)
    
def compute_swi(graph):
    # Calculate clustering coefficient and average path length for the given graph
    clustering_coeff = nx.average_clustering(graph)
    avg_path_len = calculate_avg_path_length(graph)
    
    # Generate a random graph with the same number of nodes and edges
    num_nodes = graph.number_of_nodes()
    num_edges = graph.number_of_edges()
    random_graph = nx.gnm_random_graph(num_nodes, num_edges)
    
    # Generate a lattice graph with the same number of nodes and edges
    lattice_graph = nx.watts_strogatz_graph(num_nodes, k=4, p=0)  # Adjust k as needed
    
    # Calculate clustering coefficient and average path length for the random graph
    random_clustering_coeff = nx.average_clustering(random_graph)
    random_avg_path_len = calculate_avg_path_length(random_graph)
    
    # Calculate clustering coefficient and average path length for the lattice graph
    lattice_clustering_coeff = nx.average_clustering(lattice_graph)
    lattice_avg_path_len = calculate_avg_path_length(lattice_graph)
    
    # Compute the Small-World Index (SWI)
    swi = ((avg_path_len - lattice_avg_path_len) / (random_avg_path_len - lattice_avg_path_len)) * \
          ((clustering_coeff - random_clustering_coeff) / (lattice_clustering_coeff - random_clustering_coeff))
    
    return swi
    

def compute_graph_properties(data):
    properties = []
    for graph_data in data:
        G = nx.from_edgelist(graph_data.edge_index.t().tolist())
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()
        density = nx.density(G)
        avg_path_len = calculate_avg_path_length(G)
        num_cliques = len(list(nx.find_cliques(G)))
        num_triangles = sum(nx.triangles(G).values()) / 3
        num_squares = sum(nx.square_clustering(G).values()) / 4
        number_of_node_in_the_largest_fully_connected_component = len(max(nx.connected_components(G), key=len))
        assortativity = nx.degree_assortativity_coefficient(G)
        small_world = compute_swi(G)
            
        properties.append((num_nodes, num_edges, density, avg_path_len, num_cliques, num_triangles, num_squares, number_of_node_in_the_largest_fully_connected_component, assortativity, small_world))
    return properties

train_idx_list = gnn.train_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in train_idx_list]
train_properties = compute_graph_properties(selected_dataset)
test_idx_list = gnn.test_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in test_idx_list]
test_properties = compute_graph_properties(selected_dataset)

# Save the properties to files
with open("results/"+DATASET+"_"+MODEL+"_train_properties_with_sm.pkl", "wb") as f:
    pkl.dump(train_properties, f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_with_sm.pkl", "wb") as f:
    pkl.dump(test_properties, f)

# %%
# print(len(train_properties))
# train_properties[0:5]

# %%
import pickle as pkl
#save the properties in a file
# with open("results/"+DATASET+"_"+MODEL+"_train_properties.pkl", "wb") as f:
#     pkl.dump(train_properties, f)

# with open("results/"+DATASET+"_"+MODEL+"_test_properties.pkl", "wb") as f:
#     pkl.dump(test_properties, f)

#load the properties
with open("results/"+DATASET+"_"+MODEL+"_train_properties_with_sm.pkl", "rb") as f:
    train_properties = pkl.load(f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_with_sm.pkl", "rb") as f:
    test_properties = pkl.load(f)

# %%
train_properties
# Out:
# [(116,
#   717,
#   0.10749625187406296,
#   2.6724137931034484,
#   263,
#   1735.0,
#   6.64946643069199,
#   116,
#   0.3963636188813396,
#   1.0003607038785656),
#  (116,
#   473,
#   0.07091454272863568,
#   3.4743628185907047,
#   158,
#   708.0,
#   7.095858020333574,
#   116,
#   0.28679287295765565,
#   0.9389416214401753),
#  (116,
#   997,
#   0.1494752623688156,
#   2.469265367316342,
#   343,
#   3591.0,
#   7.864813698203321,
#   116,
#   0.45675805097082345,
#   1.0693818900924983),
#  (116,
#   892,
#   0.13373313343328336,
#   2.874662668665667,
#   144,
#   3409.0,
#   10.613595627764592,
#   116,
#   0.5039099001590127,
#   1.327100875670131),
#  (116,
#   504,
#   0.07556221889055473,
#   3.1734202763546033,
#   155,
#   861.0,
#   6.351955841015705,
#   114,
#   0.3455129203218888,
#   0.9282822477123186),
#  (116,
#   442,
#   0.06626686656671664,
#   3.6082458770614694,
#   147,
#   754.0,
#   6.164051723419249,
#   116,
#   0.5552921382826579,
#   0.8726738593097689),
#  (115,
#   600,
#   0.09153318077803203,
#   4.506636155606407,
#   103,
#   2162.0,
#   10.325440232309345,
#   115,
#   0.795261320414,
#   1.0544479727735585),
#  (113,
#   327,
#   0.051675094816687736,
#   4.016139993204213,
#   122,
#   305.0,
#   4.9185259201551315,
#   109,
#   0.22669072710314206,
#   0.7635583772400422),
#  (116,
#   410,
#   0.06146926536731634,
#   3.689655172413793,
#   136,
#   583.0,
#   5.983115014287172,
#   116,
#   0.5018444881340115,
#   0.8343458040549776),
#  (116,
#   465,
#   0.06971514242878561,
#   3.333133433283358,
#   156,
#   638.0,
#   6.23560092277545,
#   116,
#   0.24029790953456143,
#   0.9390537002318473),
#  (114,
#   528,
#   0.08197484862598975,
#   3.6191585157584227,
#   133,
#   1218.0,
#   7.379795131904728,
#   114,
#   0.4797934605806655,
#   0.890496015930311),
#  (115,
#   468,
#   0.07139588100686499,
#   3.4100686498855834,
#   176,
#   672.0,
#   5.077819636238219,
#   115,
#   0.25297767240957886,
#   0.8230860207183389),
#  (112,
#   373,
#   0.06000643500643501,
#   3.8001930501930503,
#   123,
#   457.0,
#   5.904737562323358,
#   112,
#   0.29808367448945605,
#   0.9290117468500074),
#  (115,
#   305,
#   0.04652936689549962,
#   5.3954233409610985,
#   115,
#   264.0,
#   5.539345322493244,
#   115,
#   0.47774584518252183,
#   0.7572484116223441),
#  (116,
#   751,
#   0.11259370314842579,
#   2.8106446776611693,
#   156,
#   2116.0,
#   8.428241623351093,
#   116,
#   0.4856534056286724,
#   1.1624858558432847),
#  (116,
#   559,
#   0.08380809595202399,
#   3.067616191904048,
#   193,
#   1010.0,
#   0.8944926582640456),
#  (116,
#   556,
#   0.08335832083958021,
#   3.012293853073463,
#   165,
#   1035.0,
#   5.481771821443612,
#   116,
#   0.3781246783634882,
#   0.8668218760630689),
#  (116,
#   512,
#   0.07676161919040479,
#   3.1245877061469267,
#   160,
#   811.0,
#   5.6968555024363186,
#   116,
#   0.3683431709157572,
#   0.8969790875515268),
#  (116,
#   592,
#   0.08875562218890555,
#   3.3793103448275863,
#   158,
#   1439.0,
#   8.377562771073142,
#   116,
#   0.5590487900631153,
#   1.077740727208024),
#  (116,
#   449,
#   0.06731634182908545,
#   3.3443778110944526,
#   165,
#   608.0,
#   5.50991101560068,
#   116,
#   0.24389191568906152,
#   0.8472613737161044),
#  (116,
#   623,
#   0.09340329835082459,
#   3.1899550224887556,
#   157,
#   1308.0,
#   9.082160834168384,
#   116,
#   0.37430618772591995,
#   1.1533908489724398),
#  (114,
#   392,
#   0.06086011488899239,
#   3.918758043758044,
#   134,
#   519.0,
#   5.313577351505982,
#   112,
#   0.3940962392302699,
#   0.7707201360101745),
#  (115,
#   394,
#   0.0601067887109077,
#   4.038443935926773,
#   136,
#   551.0,
#   6.2192848763956095,
#   115,
#   0.36383342127508966,
#   0.8284594165571814),
#  (115,
#   370,
#   0.05644546147978642,
#   3.8389016018306634,
#   130,
#   366.0,
#   4.287075891786792,
#   115,
#   0.3306058797326672,
#   0.801057140519025),
#  (115,
#   914,
#   0.13943554538520214,
#   2.6270022883295194,
#   231,
#   3274.0,
#   8.269317108114569,
#   115,
#   0.4305474475303254,
#   1.120139146076667),
#  (113,
#   352,
#   0.05562579013906448,
#   4.367256637168142,
#   118,
#   414.0,
#   5.861695152178744,
#   113,
#   0.32303830665800876,
#   0.8116950186537055),
#  (116,
#   343,
#   0.05142428785607196,
#   4.016191904047976,
#   145,
#   364.0,
#   4.438543970037556,
#   116,
#   0.4564766126176529,
#   0.678969359179649),
#  ...]

# %% [markdown]
# ### Features
#
# Concretely, train and test features are lists that correspond to graphs. train is for the train graphs and test for the test graphs. So for example, train_features is a list of length 1044. For each graph, we have a list of embeddings. These embeddings correspond to the 7 or 8 different layers in our GNN. So for exemple if we want to access the embedding of the 3rd layer for our graph number 37 in the train set, we would do train_features[37][2]. If the batch size if put to 1, we should have access for the layers before the max or mean_pooling, to a matrix of shape (number_of_nodes, number_of_features), so for exemple for our same graph and same layer we would have a feature matrix of shape (116, 128). Then starting with the max_pooling layer we should have represntation of the whole graph and a vector embedding of shape (,128).

# %%
train_features, test_features = gnn.evaluate_with_features2()
# train_features, test_features = gnn.evaluate_with_features2(return_node_embeddings=True)

# %%
print(len(train_features[0]))
len(train_features), len(test_features)
# Out:
# 8
# (1044, 55)

# %%
"""
The embeddings of GCN are like this:
return F.log_softmax(x7, dim=-1), (x1, x2, x3, x4, x5, x_global, x6, x7)
"""


import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
output_size = 1  # Predicting one property at a time
# Define the linear model
class LinearModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearModel, self).__init__()
        self.linear = nn.Linear(input_size, output_size)

    def forward(self, x):
        return self.linear(x)

# Assume we have already evaluated to get features
#train_features, test_features = gnn.evaluate_with_features2()

# Extract x embeddings
train_x = np.array([feat[0] for feat in train_features])
test_x = np.array([feat[0] for feat in test_features])

# Extract 2, 3, 4, global, 5, 6, 7 embeddings
train_x2 = np.array([feat[1] for feat in train_features])
test_x2 = np.array([feat[1] for feat in test_features])

train_x3 = np.array([feat[2] for feat in train_features])
test_x3 = np.array([feat[2] for feat in test_features])

train_x4 = np.array([feat[3] for feat in train_features])
test_x4 = np.array([feat[3] for feat in test_features])

train_x5 = np.array([feat[4] for feat in train_features])
test_x5 = np.array([feat[4] for feat in test_features])

train_x_global = np.array([feat[5] for feat in train_features])
test_x_global = np.array([feat[5] for feat in test_features])

train_x6 = np.array([feat[6] for feat in train_features])
test_x6 = np.array([feat[6] for feat in test_features])

train_x7 = np.array([feat[7] for feat in train_features])
test_x7 = np.array([feat[7] for feat in test_features])

# Compute graph properties
# train_properties = compute_graph_properties(gnn.dataset[gnn.train_idx])
# test_properties = compute_graph_properties(gnn.dataset[gnn.test_idx])

# Convert to PyTorch tensors
train_x = torch.tensor(train_x, dtype=torch.float32)
train_x2 = torch.tensor(train_x2, dtype=torch.float32)
train_x3 = torch.tensor(train_x3, dtype=torch.float32)
train_x4 = torch.tensor(train_x4, dtype=torch.float32)
train_x5 = torch.tensor(train_x5, dtype=torch.float32)
train_x_global = torch.tensor(train_x_global, dtype=torch.float32)
train_x6 = torch.tensor(train_x6, dtype=torch.float32)
train_x7 = torch.tensor(train_x7, dtype=torch.float32)

test_x = torch.tensor(test_x, dtype=torch.float32)
test_x2 = torch.tensor(test_x2, dtype=torch.float32)
test_x3 = torch.tensor(test_x3, dtype=torch.float32)
test_x4 = torch.tensor(test_x4, dtype=torch.float32)
test_x5 = torch.tensor(test_x5, dtype=torch.float32)
test_x_global = torch.tensor(test_x_global, dtype=torch.float32)
test_x6 = torch.tensor(test_x6, dtype=torch.float32)
test_x7 = torch.tensor(test_x7, dtype=torch.float32)

train_y = torch.tensor(train_properties, dtype=torch.float32)
test_y = torch.tensor(test_properties, dtype=torch.float32)

# Train and evaluate a model for each graph property and each embedding
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component','assortativity', 'small_world']
embeddings = [(train_x, test_x), (train_x2, test_x2), (train_x3, test_x3), (train_x4, test_x4), (train_x5, test_x5), (train_x_global, test_x_global), (train_x6, test_x6), (train_x7, test_x7)]
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

# %%
print(train_x2.shape)
print(train_x6.shape)
# Out:
# torch.Size([1044, 116, 128])
# torch.Size([1044, 1, 128])

# %% [markdown]
# ### Diagnostic classifier
#
# Linear classifiers need flatten inputs and these can't be multi-dimensional. Our embeddings have the shape of `(number_of_nodes, number_of_features)` before the max_pooling and of shape `(1, number_of_features)` after the max_pooling.

# %%
"""
Classifier for the embeddings with return_node_embeddings=True
"""
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pickle as pkl

#create a dictionary where we will store the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    # Flatten the embeddings before determining the input size
    train_embedding_flat = train_embedding.view(train_embedding.size(0), -1)
    test_embedding_flat = test_embedding.view(test_embedding.size(0), -1)
    #print the shapes
    print(train_embedding_flat.shape)
    print(test_embedding_flat.shape)
    input_size = train_embedding_flat.shape[1]

    for i, property_name in enumerate(property_names):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 2000000  # Maximum number of epochs
        min_epochs = 1000  # Minimum number of epochs
        patience = 3000  # Number of epochs to wait for improvement
        tolerance = 1e-6  # Tolerance for considering the loss as stable

        best_loss = float('inf')
        no_improve_count = 0
        
        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding_flat).squeeze()
            target = train_y[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Print every 1000 epochs
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

            # Check for early stopping, but only after minimum epochs
            if epoch >= min_epochs:
                if loss.item() < best_loss - tolerance:
                    best_loss = loss.item()
                    no_improve_count = 0
                else:
                    no_improve_count += 1

                if no_improve_count >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding_flat).squeeze().cpu().numpy()
            test_pred = model(test_embedding_flat).squeeze().cpu().numpy()

            train_target = train_y[:, i].cpu().numpy()
            test_target = test_y[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embedding = embeddings_names[ii]
            results[(name_of_embedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1

#save results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_full_embedding.pkl", "wb") as f:
    pkl.dump(results, f)
# Out:
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/1300000], Property: num_nodes, Loss: 1.5060
# Epoch [2000/1300000], Property: num_nodes, Loss: 0.0582
# Epoch [3000/1300000], Property: num_nodes, Loss: 0.0008
# Epoch [4000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/1300000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7170
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 39.0101
#   Train R²: 1.0000, Test R²: -43.2964
# Epoch [1000/1300000], Property: num_edges, Loss: 1551.7554
# Epoch [2000/1300000], Property: num_edges, Loss: 583.6703
# Epoch [3000/1300000], Property: num_edges, Loss: 231.4195
# Epoch [4000/1300000], Property: num_edges, Loss: 76.1155
# Epoch [5000/1300000], Property: num_edges, Loss: 17.7620
# Epoch [6000/1300000], Property: num_edges, Loss: 2.3828
# Epoch [7000/1300000], Property: num_edges, Loss: 0.1329
# Epoch [8000/1300000], Property: num_edges, Loss: 0.0026
# Epoch [9000/1300000], Property: num_edges, Loss: 0.0001
# Epoch [10000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [11000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [12000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [13000/1300000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 13058
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0426, Test MSE: 1848.2574
#   Train R²: 1.0000, Test R²: 0.8969
# Epoch [1000/1300000], Property: density, Loss: 0.0000
# Epoch [2000/1300000], Property: density, Loss: 0.0000
# Epoch [3000/1300000], Property: density, Loss: 0.0000
# Epoch [4000/1300000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1062
#   Train R²: 1.0000, Test R²: -264.1825
# Epoch [1000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [3000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/1300000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.2738
#   Train R²: 1.0000, Test R²: 0.0752
# Epoch [1000/1300000], Property: num_cliques, Loss: 63.1001
# Epoch [2000/1300000], Property: num_cliques, Loss: 6.4568
# Epoch [3000/1300000], Property: num_cliques, Loss: 0.3986
# Epoch [4000/1300000], Property: num_cliques, Loss: 0.0092
# Epoch [5000/1300000], Property: num_cliques, Loss: 0.0001
# Epoch [6000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [8000/1300000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 8883
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 374.8323
#   Train R²: 1.0000, Test R²: 0.5115
# Epoch [1000/1300000], Property: num_triangles, Loss: 138358.4219
# Epoch [2000/1300000], Property: num_triangles, Loss: 56330.2148
# Epoch [3000/1300000], Property: num_triangles, Loss: 33412.1367
# Epoch [4000/1300000], Property: num_triangles, Loss: 20512.8809
# Epoch [5000/1300000], Property: num_triangles, Loss: 11616.8838
# Epoch [6000/1300000], Property: num_triangles, Loss: 5718.6704
# Epoch [7000/1300000], Property: num_triangles, Loss: 2277.3552
# Epoch [8000/1300000], Property: num_triangles, Loss: 652.1413
# Epoch [9000/1300000], Property: num_triangles, Loss: 111.2360
# Epoch [10000/1300000], Property: num_triangles, Loss: 8.8771
# Epoch [11000/1300000], Property: num_triangles, Loss: 0.3835
# Epoch [12000/1300000], Property: num_triangles, Loss: 0.0176
# Epoch [13000/1300000], Property: num_triangles, Loss: 0.0003
# Epoch [14000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/1300000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16940
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 55280.6328
#   Train R²: 1.0000, Test R²: 0.8750
# Epoch [1000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [2000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [3000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [4000/1300000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 0.6312
#   Train R²: 1.0000, Test R²: 0.5725
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1.6554
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0683
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0010
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Early stopping at epoch 7654
# Embedding: torch.Size([1044, 116, 128])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 0.0000, Test MSE: 44.9690
#   Train R²: 1.0000, Test R²: -13.9255
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1376
#   Train R²: 1.0000, Test R²: -12.5312
# Epoch [1000/1300000], Property: small_world, Loss: 0.0000
# Epoch [2000/1300000], Property: small_world, Loss: 0.0000
# Epoch [3000/1300000], Property: small_world, Loss: 0.0000
# Epoch [4000/1300000], Property: small_world, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world
#   Train MSE: 0.0000, Test MSE: 0.1195
#   Train R²: 1.0000, Test R²: -8.1666
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/1300000], Property: num_nodes, Loss: 2.0271
# Epoch [2000/1300000], Property: num_nodes, Loss: 0.0588
# Epoch [3000/1300000], Property: num_nodes, Loss: 0.0005
# Epoch [4000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/1300000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7287
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 47.2413
#   Train R²: 1.0000, Test R²: -52.6430
# Epoch [1000/1300000], Property: num_edges, Loss: 3042.3362
# Epoch [2000/1300000], Property: num_edges, Loss: 1016.3150
# Epoch [3000/1300000], Property: num_edges, Loss: 349.6442
# Epoch [4000/1300000], Property: num_edges, Loss: 99.6679
# Epoch [5000/1300000], Property: num_edges, Loss: 19.4147
# Epoch [6000/1300000], Property: num_edges, Loss: 2.0480
# Epoch [7000/1300000], Property: num_edges, Loss: 0.1010
# Epoch [8000/1300000], Property: num_edges, Loss: 0.0056
# Epoch [9000/1300000], Property: num_edges, Loss: 0.0002
# Epoch [10000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [11000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [12000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [13000/1300000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 13068
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 4169.3848
#   Train R²: 1.0000, Test R²: 0.7674
# Epoch [1000/1300000], Property: density, Loss: 0.0000
# Epoch [2000/1300000], Property: density, Loss: 0.0000
# Epoch [3000/1300000], Property: density, Loss: 0.0000
# Epoch [4000/1300000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.0939
#   Train R²: 1.0000, Test R²: -233.4766
# Epoch [1000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/1300000], Property: avg_path_len, Loss: 0.0003
# Epoch [3000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/1300000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.2371
#   Train R²: 1.0000, Test R²: 0.1989
# Epoch [1000/1300000], Property: num_cliques, Loss: 66.9217
# Epoch [2000/1300000], Property: num_cliques, Loss: 5.3807
# Epoch [3000/1300000], Property: num_cliques, Loss: 0.2172
# Epoch [4000/1300000], Property: num_cliques, Loss: 0.0029
# Epoch [5000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [6000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [8000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [9000/1300000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 9033
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 567.2471
#   Train R²: 1.0000, Test R²: 0.2607
# Epoch [1000/1300000], Property: num_triangles, Loss: 139153.0781
# Epoch [2000/1300000], Property: num_triangles, Loss: 67109.0234
# Epoch [3000/1300000], Property: num_triangles, Loss: 39199.8711
# Epoch [4000/1300000], Property: num_triangles, Loss: 22496.5586
# Epoch [5000/1300000], Property: num_triangles, Loss: 11838.3926
# Epoch [6000/1300000], Property: num_triangles, Loss: 5366.0776
# Epoch [7000/1300000], Property: num_triangles, Loss: 1923.5022
# Epoch [8000/1300000], Property: num_triangles, Loss: 474.5019
# Epoch [9000/1300000], Property: num_triangles, Loss: 64.4358
# Epoch [10000/1300000], Property: num_triangles, Loss: 3.4813
# Epoch [11000/1300000], Property: num_triangles, Loss: 0.0657
# Epoch [12000/1300000], Property: num_triangles, Loss: 0.0010
# Epoch [13000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [14000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/1300000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16447
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 82120.1875
#   Train R²: 1.0000, Test R²: 0.8143
# Epoch [1000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [2000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [3000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [4000/1300000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 0.4410
#   Train R²: 1.0000, Test R²: 0.7013
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2.2725
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0646
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0006
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Early stopping at epoch 7419
# Embedding: torch.Size([1044, 116, 128])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 0.0000, Test MSE: 49.3113
#   Train R²: 1.0000, Test R²: -15.3668
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0195
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1171
#   Train R²: 1.0000, Test R²: -10.5169
# Epoch [1000/1300000], Property: small_world, Loss: 0.0000
# Epoch [2000/1300000], Property: small_world, Loss: 0.0000
# Epoch [3000/1300000], Property: small_world, Loss: 0.0000
# Epoch [4000/1300000], Property: small_world, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world
#   Train MSE: 0.0000, Test MSE: 0.1401
#   Train R²: 1.0000, Test R²: -9.7429
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/1300000], Property: num_nodes, Loss: 2.2405
# Epoch [2000/1300000], Property: num_nodes, Loss: 0.0368
# Epoch [3000/1300000], Property: num_nodes, Loss: 0.0002
# Epoch [4000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/1300000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7266
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 116.7594
#   Train R²: 1.0000, Test R²: -131.5815
# Epoch [1000/1300000], Property: num_edges, Loss: 4294.9243
# Epoch [2000/1300000], Property: num_edges, Loss: 1333.8453
# Epoch [3000/1300000], Property: num_edges, Loss: 424.1912
# Epoch [4000/1300000], Property: num_edges, Loss: 106.0991
# Epoch [5000/1300000], Property: num_edges, Loss: 16.7402
# Epoch [6000/1300000], Property: num_edges, Loss: 1.2433
# Epoch [7000/1300000], Property: num_edges, Loss: 0.0289
# Epoch [8000/1300000], Property: num_edges, Loss: 0.0001
# Epoch [9000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [10000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [11000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [12000/1300000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 12076
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 6837.4697
#   Train R²: 1.0000, Test R²: 0.6185
# Epoch [1000/1300000], Property: density, Loss: 0.0000
# Epoch [2000/1300000], Property: density, Loss: 0.0000
# Epoch [3000/1300000], Property: density, Loss: 0.0000
# Epoch [4000/1300000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1223
#   Train R²: 1.0000, Test R²: -304.5690
# Epoch [1000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [3000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/1300000], Property: avg_path_len, Loss: 0.0721
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.1934, Test MSE: 0.5014
#   Train R²: 0.2821, Test R²: -0.6938
# Epoch [1000/1300000], Property: num_cliques, Loss: 67.0015
# Epoch [2000/1300000], Property: num_cliques, Loss: 4.0881
# Epoch [3000/1300000], Property: num_cliques, Loss: 0.0973
# Epoch [4000/1300000], Property: num_cliques, Loss: 0.0006
# Epoch [5000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [6000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [8000/1300000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 8777
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 710.9184
#   Train R²: 1.0000, Test R²: 0.0735
# Epoch [1000/1300000], Property: num_triangles, Loss: 154055.1406
# Epoch [2000/1300000], Property: num_triangles, Loss: 80245.6250
# Epoch [3000/1300000], Property: num_triangles, Loss: 46474.9297
# Epoch [4000/1300000], Property: num_triangles, Loss: 26139.2773
# Epoch [5000/1300000], Property: num_triangles, Loss: 13290.7236
# Epoch [6000/1300000], Property: num_triangles, Loss: 5687.0918
# Epoch [7000/1300000], Property: num_triangles, Loss: 1865.1479
# Epoch [8000/1300000], Property: num_triangles, Loss: 403.0261
# Epoch [9000/1300000], Property: num_triangles, Loss: 44.2035
# Epoch [10000/1300000], Property: num_triangles, Loss: 1.7316
# Epoch [11000/1300000], Property: num_triangles, Loss: 0.0402
# Epoch [12000/1300000], Property: num_triangles, Loss: 0.0013
# Epoch [13000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [14000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/1300000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16487
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 121391.7266
#   Train R²: 1.0000, Test R²: 0.7255
# Epoch [1000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [2000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [3000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [4000/1300000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 0.8831
#   Train R²: 1.0000, Test R²: 0.4019
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2.3546
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0392
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0002
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Early stopping at epoch 7081
# Embedding: torch.Size([1044, 116, 128])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 0.0000, Test MSE: 116.1861
#   Train R²: 1.0000, Test R²: -37.5630
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1359
#   Train R²: 1.0000, Test R²: -12.3648
# Epoch [1000/1300000], Property: small_world, Loss: 0.0000
# Epoch [2000/1300000], Property: small_world, Loss: 0.0001
# Epoch [3000/1300000], Property: small_world, Loss: 0.0000
# Epoch [4000/1300000], Property: small_world, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world
#   Train MSE: 0.0000, Test MSE: 0.0830
#   Train R²: 1.0000, Test R²: -5.3606
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/1300000], Property: num_nodes, Loss: 3.3162
# Epoch [2000/1300000], Property: num_nodes, Loss: 0.0493
# Epoch [3000/1300000], Property: num_nodes, Loss: 0.0004
# Epoch [4000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/1300000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7700
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 207.6372
#   Train R²: 1.0000, Test R²: -234.7743
# Epoch [1000/1300000], Property: num_edges, Loss: 5554.8892
# Epoch [2000/1300000], Property: num_edges, Loss: 1842.6221
# Epoch [3000/1300000], Property: num_edges, Loss: 600.3586
# Epoch [4000/1300000], Property: num_edges, Loss: 152.2324
# Epoch [5000/1300000], Property: num_edges, Loss: 23.7686
# Epoch [6000/1300000], Property: num_edges, Loss: 1.6253
# Epoch [7000/1300000], Property: num_edges, Loss: 0.0297
# Epoch [8000/1300000], Property: num_edges, Loss: 0.0003
# Epoch [9000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [10000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [11000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [12000/1300000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 12752
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 11145.7803
#   Train R²: 1.0000, Test R²: 0.3782
# Epoch [1000/1300000], Property: density, Loss: 0.0000
# Epoch [2000/1300000], Property: density, Loss: 0.0000
# Epoch [3000/1300000], Property: density, Loss: 0.0000
# Epoch [4000/1300000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.0803
#   Train R²: 1.0000, Test R²: -199.6214
# Epoch [1000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [3000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/1300000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.3170
#   Train R²: 1.0000, Test R²: -0.0708
# Epoch [1000/1300000], Property: num_cliques, Loss: 84.8889
# Epoch [2000/1300000], Property: num_cliques, Loss: 4.9403
# Epoch [3000/1300000], Property: num_cliques, Loss: 0.0977
# Epoch [4000/1300000], Property: num_cliques, Loss: 0.0002
# Epoch [5000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [6000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/1300000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 7804
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 1176.8636
#   Train R²: 1.0000, Test R²: -0.5337
# Epoch [1000/1300000], Property: num_triangles, Loss: 187602.7344
# Epoch [2000/1300000], Property: num_triangles, Loss: 97582.8438
# Epoch [3000/1300000], Property: num_triangles, Loss: 56841.6875
# Epoch [4000/1300000], Property: num_triangles, Loss: 32187.3633
# Epoch [5000/1300000], Property: num_triangles, Loss: 16541.0801
# Epoch [6000/1300000], Property: num_triangles, Loss: 7214.2715
# Epoch [7000/1300000], Property: num_triangles, Loss: 2413.3955
# Epoch [8000/1300000], Property: num_triangles, Loss: 523.0865
# Epoch [9000/1300000], Property: num_triangles, Loss: 55.0449
# Epoch [10000/1300000], Property: num_triangles, Loss: 1.9330
# Epoch [11000/1300000], Property: num_triangles, Loss: 0.0583
# Epoch [12000/1300000], Property: num_triangles, Loss: 0.0027
# Epoch [13000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [14000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/1300000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16641
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0532, Test MSE: 161373.2188
#   Train R²: 1.0000, Test R²: 0.6351
# Epoch [1000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [2000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [3000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [4000/1300000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 1.3419
#   Train R²: 1.0000, Test R²: 0.0911
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3.3408
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0494
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0004
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Early stopping at epoch 7725
# Embedding: torch.Size([1044, 116, 128])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 0.0000, Test MSE: 208.2590
#   Train R²: 1.0000, Test R²: -68.1226
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.2125
#   Train R²: 1.0000, Test R²: -19.8888
# Epoch [1000/1300000], Property: small_world, Loss: 0.0000
# Epoch [2000/1300000], Property: small_world, Loss: 0.0001
# Epoch [3000/1300000], Property: small_world, Loss: 0.0000
# Epoch [4000/1300000], Property: small_world, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world
#   Train MSE: 0.0000, Test MSE: 0.1152
#   Train R²: 1.0000, Test R²: -7.8349
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/1300000], Property: num_nodes, Loss: 4.8693
# Epoch [2000/1300000], Property: num_nodes, Loss: 0.0702
# Epoch [3000/1300000], Property: num_nodes, Loss: 0.0013
# Epoch [4000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/1300000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/1300000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7824
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 432.5649
#   Train R²: 1.0000, Test R²: -490.1820
# Epoch [1000/1300000], Property: num_edges, Loss: 7355.6685
# Epoch [2000/1300000], Property: num_edges, Loss: 2549.2629
# Epoch [3000/1300000], Property: num_edges, Loss: 854.5228
# Epoch [4000/1300000], Property: num_edges, Loss: 219.1001
# Epoch [5000/1300000], Property: num_edges, Loss: 34.1341
# Epoch [6000/1300000], Property: num_edges, Loss: 2.3665
# Epoch [7000/1300000], Property: num_edges, Loss: 0.0710
# Epoch [8000/1300000], Property: num_edges, Loss: 0.0043
# Epoch [9000/1300000], Property: num_edges, Loss: 0.0001
# Epoch [10000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [11000/1300000], Property: num_edges, Loss: 0.0000
# Epoch [12000/1300000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 12953
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 17518.8535
#   Train R²: 1.0000, Test R²: 0.0226
# Epoch [1000/1300000], Property: density, Loss: 0.0000
# Epoch [2000/1300000], Property: density, Loss: 0.0000
# Epoch [3000/1300000], Property: density, Loss: 0.0000
# Epoch [4000/1300000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1073
#   Train R²: 0.9997, Test R²: -266.9347
# Epoch [1000/1300000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/1300000], Property: avg_path_len, Loss: 0.0008
# Epoch [3000/1300000], Property: avg_path_len, Loss: 0.0032
# Epoch [4000/1300000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.3407
#   Train R²: 1.0000, Test R²: -0.1510
# Epoch [1000/1300000], Property: num_cliques, Loss: 99.3278
# Epoch [2000/1300000], Property: num_cliques, Loss: 5.1526
# Epoch [3000/1300000], Property: num_cliques, Loss: 0.0888
# Epoch [4000/1300000], Property: num_cliques, Loss: 0.0002
# Epoch [5000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [6000/1300000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/1300000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 7964
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 2019.1053
#   Train R²: 1.0000, Test R²: -1.6314
# Epoch [1000/1300000], Property: num_triangles, Loss: 215021.2812
# Epoch [2000/1300000], Property: num_triangles, Loss: 111501.4844
# Epoch [3000/1300000], Property: num_triangles, Loss: 65324.6133
# Epoch [4000/1300000], Property: num_triangles, Loss: 37671.1836
# Epoch [5000/1300000], Property: num_triangles, Loss: 19887.8027
# Epoch [6000/1300000], Property: num_triangles, Loss: 8965.2500
# Epoch [7000/1300000], Property: num_triangles, Loss: 3131.4373
# Epoch [8000/1300000], Property: num_triangles, Loss: 723.1383
# Epoch [9000/1300000], Property: num_triangles, Loss: 84.8884
# Epoch [10000/1300000], Property: num_triangles, Loss: 3.6953
# Epoch [11000/1300000], Property: num_triangles, Loss: 0.1421
# Epoch [12000/1300000], Property: num_triangles, Loss: 0.0067
# Epoch [13000/1300000], Property: num_triangles, Loss: 0.0001
# Epoch [14000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/1300000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/1300000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16608
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 173486.7500
#   Train R²: 1.0000, Test R²: 0.6077
# Epoch [1000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [2000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [3000/1300000], Property: num_squares, Loss: 0.0000
# Epoch [4000/1300000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 1.9145
#   Train R²: 1.0000, Test R²: -0.2967
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4.7344
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0651
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0011
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 0.0000
# Early stopping at epoch 7778
# Embedding: torch.Size([1044, 116, 128])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 0.0000, Test MSE: 445.0709
#   Train R²: 1.0000, Test R²: -146.7221
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0000
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1166
#   Train R²: 1.0000, Test R²: -10.4637
# Epoch [1000/1300000], Property: small_world, Loss: 0.0000
# Epoch [2000/1300000], Property: small_world, Loss: 0.0000
# Epoch [3000/1300000], Property: small_world, Loss: 0.0000
# Epoch [4000/1300000], Property: small_world, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world
#   Train MSE: 0.0000, Test MSE: 0.1285
#   Train R²: 1.0000, Test R²: -8.8567
# torch.Size([1044, 128])
# torch.Size([55, 128])
# Epoch [1000/1300000], Property: num_nodes, Loss: 457.4781
# Epoch [2000/1300000], Property: num_nodes, Loss: 424.1838
# Epoch [3000/1300000], Property: num_nodes, Loss: 381.2332
# Epoch [4000/1300000], Property: num_nodes, Loss: 336.1294
# Epoch [5000/1300000], Property: num_nodes, Loss: 297.0477
# Epoch [6000/1300000], Property: num_nodes, Loss: 268.0908
# Epoch [7000/1300000], Property: num_nodes, Loss: 248.4490
# Epoch [8000/1300000], Property: num_nodes, Loss: 235.4711
# Epoch [9000/1300000], Property: num_nodes, Loss: 226.9577
# Epoch [10000/1300000], Property: num_nodes, Loss: 221.2629
# Epoch [11000/1300000], Property: num_nodes, Loss: 217.0123
# Epoch [12000/1300000], Property: num_nodes, Loss: 213.2376
# Epoch [13000/1300000], Property: num_nodes, Loss: 209.5403
# Epoch [14000/1300000], Property: num_nodes, Loss: 205.8587
# Epoch [15000/1300000], Property: num_nodes, Loss: 202.2019
# Epoch [16000/1300000], Property: num_nodes, Loss: 198.5746
# Epoch [17000/1300000], Property: num_nodes, Loss: 194.9802
# Epoch [18000/1300000], Property: num_nodes, Loss: 191.4189
# Epoch [19000/1300000], Property: num_nodes, Loss: 187.8905
# Epoch [20000/1300000], Property: num_nodes, Loss: 184.3953
# Epoch [21000/1300000], Property: num_nodes, Loss: 180.9341
# Epoch [22000/1300000], Property: num_nodes, Loss: 177.5077
# Epoch [23000/1300000], Property: num_nodes, Loss: 174.1142
# Epoch [24000/1300000], Property: num_nodes, Loss: 170.7537
# Epoch [25000/1300000], Property: num_nodes, Loss: 167.4262
# Epoch [26000/1300000], Property: num_nodes, Loss: 164.1316
# Epoch [27000/1300000], Property: num_nodes, Loss: 160.8700
# Epoch [28000/1300000], Property: num_nodes, Loss: 157.6425
# Epoch [29000/1300000], Property: num_nodes, Loss: 154.4456
# Epoch [30000/1300000], Property: num_nodes, Loss: 151.2829
# Epoch [31000/1300000], Property: num_nodes, Loss: 148.1531
# Epoch [32000/1300000], Property: num_nodes, Loss: 145.0563
# Epoch [33000/1300000], Property: num_nodes, Loss: 141.9924
# Epoch [34000/1300000], Property: num_nodes, Loss: 138.9616
# Epoch [35000/1300000], Property: num_nodes, Loss: 135.9638
# Epoch [36000/1300000], Property: num_nodes, Loss: 132.9991
# Epoch [37000/1300000], Property: num_nodes, Loss: 130.0703
# Epoch [38000/1300000], Property: num_nodes, Loss: 127.1762
# Epoch [39000/1300000], Property: num_nodes, Loss: 124.3150
# Epoch [40000/1300000], Property: num_nodes, Loss: 121.4865
# Epoch [41000/1300000], Property: num_nodes, Loss: 118.6909
# Epoch [42000/1300000], Property: num_nodes, Loss: 115.9280
# Epoch [43000/1300000], Property: num_nodes, Loss: 113.1981
# Epoch [44000/1300000], Property: num_nodes, Loss: 110.5008
# Epoch [45000/1300000], Property: num_nodes, Loss: 107.8364
# Epoch [46000/1300000], Property: num_nodes, Loss: 105.2047
# Epoch [47000/1300000], Property: num_nodes, Loss: 102.6059
# Epoch [48000/1300000], Property: num_nodes, Loss: 100.0400
# Epoch [49000/1300000], Property: num_nodes, Loss: 97.5073
# Epoch [50000/1300000], Property: num_nodes, Loss: 95.0064
# Epoch [51000/1300000], Property: num_nodes, Loss: 92.5389
# Epoch [52000/1300000], Property: num_nodes, Loss: 90.1044
# Epoch [53000/1300000], Property: num_nodes, Loss: 87.7026
# Epoch [54000/1300000], Property: num_nodes, Loss: 85.3339
# Epoch [55000/1300000], Property: num_nodes, Loss: 82.9992
# Epoch [56000/1300000], Property: num_nodes, Loss: 80.7027
# Epoch [57000/1300000], Property: num_nodes, Loss: 78.4396
# Epoch [58000/1300000], Property: num_nodes, Loss: 76.2093
# Epoch [59000/1300000], Property: num_nodes, Loss: 74.0117
# Epoch [60000/1300000], Property: num_nodes, Loss: 71.8467
# Epoch [61000/1300000], Property: num_nodes, Loss: 69.7143
# Epoch [62000/1300000], Property: num_nodes, Loss: 67.6146
# Epoch [63000/1300000], Property: num_nodes, Loss: 65.5473
# Epoch [64000/1300000], Property: num_nodes, Loss: 63.5127
# Epoch [65000/1300000], Property: num_nodes, Loss: 61.5107
# Epoch [66000/1300000], Property: num_nodes, Loss: 59.5413
# Epoch [67000/1300000], Property: num_nodes, Loss: 57.6044
# Epoch [68000/1300000], Property: num_nodes, Loss: 55.7001
# Epoch [69000/1300000], Property: num_nodes, Loss: 53.8301
# Epoch [70000/1300000], Property: num_nodes, Loss: 51.9893
# Epoch [71000/1300000], Property: num_nodes, Loss: 50.1825
# Epoch [72000/1300000], Property: num_nodes, Loss: 48.4085
# Epoch [73000/1300000], Property: num_nodes, Loss: 46.6674
# Epoch [74000/1300000], Property: num_nodes, Loss: 44.9578
# Epoch [75000/1300000], Property: num_nodes, Loss: 43.2820
# Epoch [76000/1300000], Property: num_nodes, Loss: 41.6388
# Epoch [77000/1300000], Property: num_nodes, Loss: 40.0375
# Epoch [78000/1300000], Property: num_nodes, Loss: 38.4696
# Epoch [79000/1300000], Property: num_nodes, Loss: 36.9340
# Epoch [80000/1300000], Property: num_nodes, Loss: 35.4306
# Epoch [81000/1300000], Property: num_nodes, Loss: 33.9592
# Epoch [82000/1300000], Property: num_nodes, Loss: 32.5200
# Epoch [83000/1300000], Property: num_nodes, Loss: 31.1129
# Epoch [84000/1300000], Property: num_nodes, Loss: 29.7378
# Epoch [85000/1300000], Property: num_nodes, Loss: 28.3949
# Epoch [86000/1300000], Property: num_nodes, Loss: 27.0839
# Epoch [87000/1300000], Property: num_nodes, Loss: 25.8051
# Epoch [88000/1300000], Property: num_nodes, Loss: 24.5584
# Epoch [89000/1300000], Property: num_nodes, Loss: 23.3440
# Epoch [90000/1300000], Property: num_nodes, Loss: 22.1614
# Epoch [91000/1300000], Property: num_nodes, Loss: 21.0146
# Epoch [92000/1300000], Property: num_nodes, Loss: 19.9038
# Epoch [93000/1300000], Property: num_nodes, Loss: 18.8249
# Epoch [94000/1300000], Property: num_nodes, Loss: 17.7776
# Epoch [95000/1300000], Property: num_nodes, Loss: 16.7619
# Epoch [96000/1300000], Property: num_nodes, Loss: 15.7778
# Epoch [97000/1300000], Property: num_nodes, Loss: 14.8254
# Epoch [98000/1300000], Property: num_nodes, Loss: 13.9046
# Epoch [99000/1300000], Property: num_nodes, Loss: 13.0170
# Epoch [100000/1300000], Property: num_nodes, Loss: 12.1652
# Epoch [101000/1300000], Property: num_nodes, Loss: 11.3447
# Epoch [102000/1300000], Property: num_nodes, Loss: 10.5554
# Epoch [103000/1300000], Property: num_nodes, Loss: 9.7973
# Epoch [104000/1300000], Property: num_nodes, Loss: 9.0708
# Epoch [105000/1300000], Property: num_nodes, Loss: 8.3794
# Epoch [106000/1300000], Property: num_nodes, Loss: 7.7188
# Epoch [107000/1300000], Property: num_nodes, Loss: 7.0910
# Epoch [108000/1300000], Property: num_nodes, Loss: 6.4911
# Epoch [109000/1300000], Property: num_nodes, Loss: 5.9268
# Epoch [110000/1300000], Property: num_nodes, Loss: 5.3927
# Epoch [111000/1300000], Property: num_nodes, Loss: 4.8904
# Epoch [112000/1300000], Property: num_nodes, Loss: 4.4200
# Epoch [113000/1300000], Property: num_nodes, Loss: 3.9802
# Epoch [114000/1300000], Property: num_nodes, Loss: 3.5722
# Epoch [115000/1300000], Property: num_nodes, Loss: 3.1951
# Epoch [116000/1300000], Property: num_nodes, Loss: 2.8485
# Epoch [117000/1300000], Property: num_nodes, Loss: 2.5326
# Epoch [118000/1300000], Property: num_nodes, Loss: 2.2470
# Epoch [119000/1300000], Property: num_nodes, Loss: 1.9934
# Epoch [120000/1300000], Property: num_nodes, Loss: 1.7654
# Epoch [121000/1300000], Property: num_nodes, Loss: 1.5686
# Epoch [122000/1300000], Property: num_nodes, Loss: 1.4002
# Epoch [123000/1300000], Property: num_nodes, Loss: 1.2597
# Epoch [124000/1300000], Property: num_nodes, Loss: 1.1460
# Epoch [125000/1300000], Property: num_nodes, Loss: 1.0579
# Epoch [126000/1300000], Property: num_nodes, Loss: 0.9938
# Epoch [127000/1300000], Property: num_nodes, Loss: 0.9520
# Epoch [128000/1300000], Property: num_nodes, Loss: 0.9269
# Epoch [129000/1300000], Property: num_nodes, Loss: 0.9158
# Epoch [130000/1300000], Property: num_nodes, Loss: 0.9126
# Epoch [131000/1300000], Property: num_nodes, Loss: 0.9120
# Epoch [132000/1300000], Property: num_nodes, Loss: 0.9120
# Epoch [133000/1300000], Property: num_nodes, Loss: 0.9120
# Epoch [134000/1300000], Property: num_nodes, Loss: 0.9120
# Epoch [135000/1300000], Property: num_nodes, Loss: 0.9120
# Early stopping at epoch 135277
# Embedding: torch.Size([1044, 1, 128])
# Property: num_nodes
#   Train MSE: 0.9120, Test MSE: 0.9309
#   Train R²: 0.5270, Test R²: -0.0570
# Epoch [1000/1300000], Property: num_edges, Loss: 105570.9141
# Epoch [2000/1300000], Property: num_edges, Loss: 48709.2383
# Epoch [3000/1300000], Property: num_edges, Loss: 39644.9336
# Epoch [4000/1300000], Property: num_edges, Loss: 38469.8086
# Epoch [5000/1300000], Property: num_edges, Loss: 37235.4492
# Epoch [6000/1300000], Property: num_edges, Loss: 35557.2500
# Epoch [7000/1300000], Property: num_edges, Loss: 33513.0391
# Epoch [8000/1300000], Property: num_edges, Loss: 31316.6465
# Epoch [9000/1300000], Property: num_edges, Loss: 29217.9648
# Epoch [10000/1300000], Property: num_edges, Loss: 27387.8105
# Epoch [11000/1300000], Property: num_edges, Loss: 25883.1914
# Epoch [12000/1300000], Property: num_edges, Loss: 24683.3008
# Epoch [13000/1300000], Property: num_edges, Loss: 23742.4609
# Epoch [14000/1300000], Property: num_edges, Loss: 23013.6543
# Epoch [15000/1300000], Property: num_edges, Loss: 22450.4492
# Epoch [16000/1300000], Property: num_edges, Loss: 22012.5254
# Epoch [17000/1300000], Property: num_edges, Loss: 21670.3359
# Epoch [18000/1300000], Property: num_edges, Loss: 21402.4258
# Epoch [19000/1300000], Property: num_edges, Loss: 21191.1953
# Epoch [20000/1300000], Property: num_edges, Loss: 21023.0020
# Epoch [21000/1300000], Property: num_edges, Loss: 20888.0605
# Epoch [22000/1300000], Property: num_edges, Loss: 20779.0840
# Epoch [23000/1300000], Property: num_edges, Loss: 20690.5156
# Epoch [24000/1300000], Property: num_edges, Loss: 20617.9434
# Epoch [25000/1300000], Property: num_edges, Loss: 20557.7402
# Epoch [26000/1300000], Property: num_edges, Loss: 20506.6777
# Epoch [27000/1300000], Property: num_edges, Loss: 20461.9473
# Epoch [28000/1300000], Property: num_edges, Loss: 20421.4648
# Epoch [29000/1300000], Property: num_edges, Loss: 20384.0234
# Epoch [30000/1300000], Property: num_edges, Loss: 20349.0449
# Epoch [31000/1300000], Property: num_edges, Loss: 20315.7773
# Epoch [32000/1300000], Property: num_edges, Loss: 20283.5176
# Epoch [33000/1300000], Property: num_edges, Loss: 20251.7129
# Epoch [34000/1300000], Property: num_edges, Loss: 20220.0332
# Epoch [35000/1300000], Property: num_edges, Loss: 20188.3477
# Epoch [36000/1300000], Property: num_edges, Loss: 20156.7012
# Epoch [37000/1300000], Property: num_edges, Loss: 20125.0840
# Epoch [38000/1300000], Property: num_edges, Loss: 20093.5039
# Epoch [39000/1300000], Property: num_edges, Loss: 20061.9570
# Epoch [40000/1300000], Property: num_edges, Loss: 20030.4434
# Epoch [41000/1300000], Property: num_edges, Loss: 19998.9609
# Epoch [42000/1300000], Property: num_edges, Loss: 19967.5176
# Epoch [43000/1300000], Property: num_edges, Loss: 19936.1016
# Epoch [44000/1300000], Property: num_edges, Loss: 19904.7227
# Epoch [45000/1300000], Property: num_edges, Loss: 19873.3750
# Epoch [46000/1300000], Property: num_edges, Loss: 19842.0625
# Epoch [47000/1300000], Property: num_edges, Loss: 19810.7852
# Epoch [48000/1300000], Property: num_edges, Loss: 19779.5391
# Epoch [49000/1300000], Property: num_edges, Loss: 19748.3262
# Epoch [50000/1300000], Property: num_edges, Loss: 19717.1484
# Epoch [51000/1300000], Property: num_edges, Loss: 19686.0039
# Epoch [52000/1300000], Property: num_edges, Loss: 19654.8926
# Epoch [53000/1300000], Property: num_edges, Loss: 19623.8125
# Epoch [54000/1300000], Property: num_edges, Loss: 19592.7695
# Epoch [55000/1300000], Property: num_edges, Loss: 19561.7578
# Epoch [56000/1300000], Property: num_edges, Loss: 19530.7832
# Epoch [57000/1300000], Property: num_edges, Loss: 19499.8398
# Epoch [58000/1300000], Property: num_edges, Loss: 19468.9297
# Epoch [59000/1300000], Property: num_edges, Loss: 19438.0508
# Epoch [60000/1300000], Property: num_edges, Loss: 19407.2090
# Epoch [61000/1300000], Property: num_edges, Loss: 19376.4004
# Epoch [62000/1300000], Property: num_edges, Loss: 19345.6230
# Epoch [63000/1300000], Property: num_edges, Loss: 19314.8809
# Epoch [64000/1300000], Property: num_edges, Loss: 19284.1719
# Epoch [65000/1300000], Property: num_edges, Loss: 19253.4980
# Epoch [66000/1300000], Property: num_edges, Loss: 19222.8535
# Epoch [67000/1300000], Property: num_edges, Loss: 19192.2500
# Epoch [68000/1300000], Property: num_edges, Loss: 19161.6719
# Epoch [69000/1300000], Property: num_edges, Loss: 19131.1328
# Epoch [70000/1300000], Property: num_edges, Loss: 19100.6250
# Epoch [71000/1300000], Property: num_edges, Loss: 19070.1523
# Epoch [72000/1300000], Property: num_edges, Loss: 19039.7109
# Epoch [73000/1300000], Property: num_edges, Loss: 19009.3047
# Epoch [74000/1300000], Property: num_edges, Loss: 18978.9316
# Epoch [75000/1300000], Property: num_edges, Loss: 18948.5918
# Epoch [76000/1300000], Property: num_edges, Loss: 18918.2852
# Epoch [77000/1300000], Property: num_edges, Loss: 18888.0137
# Epoch [78000/1300000], Property: num_edges, Loss: 18857.7734
# Epoch [79000/1300000], Property: num_edges, Loss: 18827.5684
# Epoch [80000/1300000], Property: num_edges, Loss: 18797.3984
# Epoch [81000/1300000], Property: num_edges, Loss: 18767.2578
# Epoch [82000/1300000], Property: num_edges, Loss: 18737.1523
# Epoch [83000/1300000], Property: num_edges, Loss: 18707.0820
# Epoch [84000/1300000], Property: num_edges, Loss: 18677.0449
# Epoch [85000/1300000], Property: num_edges, Loss: 18647.0410
# Epoch [86000/1300000], Property: num_edges, Loss: 18617.0703
# Epoch [87000/1300000], Property: num_edges, Loss: 18587.1348
# Epoch [88000/1300000], Property: num_edges, Loss: 18557.2305
# Epoch [89000/1300000], Property: num_edges, Loss: 18527.3594
# Epoch [90000/1300000], Property: num_edges, Loss: 18497.5234
# Epoch [91000/1300000], Property: num_edges, Loss: 18467.7207
# Epoch [92000/1300000], Property: num_edges, Loss: 18437.9512
# Epoch [93000/1300000], Property: num_edges, Loss: 18408.2188
# Epoch [94000/1300000], Property: num_edges, Loss: 18378.5137
# Epoch [95000/1300000], Property: num_edges, Loss: 18348.8457
# Epoch [96000/1300000], Property: num_edges, Loss: 18319.2109
# Epoch [97000/1300000], Property: num_edges, Loss: 18289.6094
# Epoch [98000/1300000], Property: num_edges, Loss: 18260.0430
# Epoch [99000/1300000], Property: num_edges, Loss: 18230.5098
# Epoch [100000/1300000], Property: num_edges, Loss: 18201.0059
# Epoch [101000/1300000], Property: num_edges, Loss: 18171.5391
# Epoch [102000/1300000], Property: num_edges, Loss: 18142.1055
# Epoch [103000/1300000], Property: num_edges, Loss: 18112.7051
# Epoch [104000/1300000], Property: num_edges, Loss: 18083.3398
# Epoch [105000/1300000], Property: num_edges, Loss: 18054.0039
# Epoch [106000/1300000], Property: num_edges, Loss: 18024.7090
# Epoch [107000/1300000], Property: num_edges, Loss: 17995.4414
# Epoch [108000/1300000], Property: num_edges, Loss: 17966.2090
# Epoch [109000/1300000], Property: num_edges, Loss: 17937.0098
# Epoch [110000/1300000], Property: num_edges, Loss: 17907.8457
# Epoch [111000/1300000], Property: num_edges, Loss: 17878.7109
# Epoch [112000/1300000], Property: num_edges, Loss: 17849.6152
# Epoch [113000/1300000], Property: num_edges, Loss: 17820.5508
# Epoch [114000/1300000], Property: num_edges, Loss: 17791.5195
# Epoch [115000/1300000], Property: num_edges, Loss: 17762.5215
# Epoch [116000/1300000], Property: num_edges, Loss: 17733.5586
# Epoch [117000/1300000], Property: num_edges, Loss: 17704.6270
# Epoch [118000/1300000], Property: num_edges, Loss: 17675.7324
# Epoch [119000/1300000], Property: num_edges, Loss: 17646.8691
# Epoch [120000/1300000], Property: num_edges, Loss: 17618.0371
# Epoch [121000/1300000], Property: num_edges, Loss: 17589.2441
# Epoch [122000/1300000], Property: num_edges, Loss: 17560.4785
# Epoch [123000/1300000], Property: num_edges, Loss: 17531.7500
# Epoch [124000/1300000], Property: num_edges, Loss: 17503.0547
# Epoch [125000/1300000], Property: num_edges, Loss: 17474.3926
# Epoch [126000/1300000], Property: num_edges, Loss: 17445.7637
# Epoch [127000/1300000], Property: num_edges, Loss: 17417.1680
# Epoch [128000/1300000], Property: num_edges, Loss: 17388.6094
# Epoch [129000/1300000], Property: num_edges, Loss: 17360.0801
# Epoch [130000/1300000], Property: num_edges, Loss: 17331.5879
# Epoch [131000/1300000], Property: num_edges, Loss: 17303.1270
# Epoch [132000/1300000], Property: num_edges, Loss: 17274.6992
# Epoch [133000/1300000], Property: num_edges, Loss: 17246.5020
# Epoch [134000/1300000], Property: num_edges, Loss: 17218.3594
# Epoch [135000/1300000], Property: num_edges, Loss: 17190.2500
# Epoch [136000/1300000], Property: num_edges, Loss: 17162.1680
# Epoch [137000/1300000], Property: num_edges, Loss: 17134.1270
# Epoch [138000/1300000], Property: num_edges, Loss: 17106.1152
# Epoch [139000/1300000], Property: num_edges, Loss: 17078.1367
# Epoch [140000/1300000], Property: num_edges, Loss: 17050.1895
# Epoch [141000/1300000], Property: num_edges, Loss: 17022.2773
# Epoch [142000/1300000], Property: num_edges, Loss: 16994.3984
# Epoch [143000/1300000], Property: num_edges, Loss: 16966.5508
# Epoch [144000/1300000], Property: num_edges, Loss: 16938.7402
# Epoch [145000/1300000], Property: num_edges, Loss: 16910.9590
# ...
# Epoch [1000/1300000], Property: num_squares, Loss: 32.2095
# Epoch [2000/1300000], Property: num_squares, Loss: 23.0556
# Epoch [3000/1300000], Property: num_squares, Loss: 15.8969
# Epoch [4000/1300000], Property: num_squares, Loss: 10.4705
# Epoch [5000/1300000], Property: num_squares, Loss: 6.5732
# Epoch [6000/1300000], Property: num_squares, Loss: 4.0134
# Epoch [7000/1300000], Property: num_squares, Loss: 2.5647
# Epoch [8000/1300000], Property: num_squares, Loss: 1.9309
# Epoch [9000/1300000], Property: num_squares, Loss: 1.7556
# Epoch [10000/1300000], Property: num_squares, Loss: 1.7337
# Epoch [11000/1300000], Property: num_squares, Loss: 1.7329
# Epoch [12000/1300000], Property: num_squares, Loss: 1.7329
# Epoch [13000/1300000], Property: num_squares, Loss: 1.7329
# Epoch [14000/1300000], Property: num_squares, Loss: 1.7329
# Early stopping at epoch 14351
# Embedding: torch.Size([1044, 1, 2])
# Property: num_squares
#   Train MSE: 1.7329, Test MSE: 1.5148
#   Train R²: 0.0002, Test R²: -0.0260
# Epoch [1000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12667.7676
# Epoch [2000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12432.6982
# Epoch [3000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12207.8633
# Epoch [4000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11988.6826
# Epoch [5000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11772.0996
# Epoch [6000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11557.1914
# Epoch [7000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11343.8594
# Epoch [8000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 11132.2275
# Epoch [9000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 10922.4492
# Epoch [10000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 10714.6260
# Epoch [11000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 10508.8418
# Epoch [12000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 10305.2422
# Epoch [13000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 10103.6709
# Epoch [14000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9904.1299
# Epoch [15000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9706.6240
# Epoch [16000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9511.1504
# Epoch [17000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9317.7109
# Epoch [18000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9126.3027
# Epoch [19000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8936.9268
# Epoch [20000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8749.5840
# Epoch [21000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8564.2754
# Epoch [22000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8380.9980
# Epoch [23000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8199.7529
# Epoch [24000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8020.5396
# Epoch [25000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7843.5903
# Epoch [26000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7668.7705
# Epoch [27000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7495.9756
# Epoch [28000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7325.2041
# Epoch [29000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7156.4541
# Epoch [30000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6989.7295
# Epoch [31000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6825.0269
# Epoch [32000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6662.3472
# Epoch [33000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6501.6890
# Epoch [34000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6343.0537
# Epoch [35000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6186.4395
# Epoch [36000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6031.8467
# Epoch [37000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5879.2764
# Epoch [38000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5728.7246
# Epoch [39000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5580.1934
# Epoch [40000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5433.6821
# Epoch [41000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5289.1895
# Epoch [42000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5146.7153
# Epoch [43000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 5006.2578
# Epoch [44000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4868.2974
# Epoch [45000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4732.3853
# Epoch [46000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4598.4702
# Epoch [47000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4466.5508
# Epoch [48000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4336.6211
# Epoch [49000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4208.6763
# Epoch [50000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 4082.7068
# Epoch [51000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3958.6926
# Epoch [52000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3836.6094
# Epoch [53000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3716.4392
# Epoch [54000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3598.1829
# Epoch [55000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3481.8425
# Epoch [56000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3367.4182
# Epoch [57000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3254.9094
# Epoch [58000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3144.3167
# Epoch [59000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 3035.6399
# Epoch [60000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2928.9380
# Epoch [61000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2824.4937
# Epoch [62000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2721.9502
# Epoch [63000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2621.3076
# Epoch [64000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2522.5659
# Epoch [65000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2425.4089
# Epoch [66000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2330.5825
# Epoch [67000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2237.9058
# Epoch [68000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2147.1145
# Epoch [69000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 2058.2092
# Epoch [70000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1971.1906
# Epoch [71000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1886.0575
# Epoch [72000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1802.8107
# Epoch [73000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1721.4497
# Epoch [74000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1641.9747
# Epoch [75000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1564.3859
# Epoch [76000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1488.6830
# Epoch [77000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1414.8662
# Epoch [78000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1342.9353
# Epoch [79000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1272.8906
# Epoch [80000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1204.8274
# Epoch [81000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1139.0624
# Epoch [82000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1075.1539
# Epoch [83000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 1013.1025
# Epoch [84000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 952.9075
# Epoch [85000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 894.5692
# Epoch [86000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 838.0876
# Epoch [87000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 783.4626
# Epoch [88000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 730.6943
# Epoch [89000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 680.1552
# Epoch [90000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 631.4654
# Epoch [91000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 584.6033
# Epoch [92000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 539.5687
# Epoch [93000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 496.3618
# Epoch [94000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 455.1827
# Epoch [95000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 415.9285
# Epoch [96000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 378.4730
# Epoch [97000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 342.8161
# Epoch [98000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 309.1942
# Epoch [99000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 277.3711
# Epoch [100000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 247.3493
# Epoch [101000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 219.2854
# Epoch [102000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 192.9630
# Epoch [103000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 168.5750
# Epoch [104000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 145.9542
# Epoch [105000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 125.1536
# Epoch [106000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 106.1764
# Epoch [107000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 88.9752
# Epoch [108000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 73.5370
# Epoch [109000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 59.8583
# Epoch [110000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 47.8892
# Epoch [111000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 37.6176
# Epoch [112000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 28.9952
# Epoch [113000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 21.9666
# Epoch [114000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 16.4693
# Epoch [115000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 12.4075
# Epoch [116000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 9.6538
# Epoch [117000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 8.0242
# Epoch [118000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7.2585
# Epoch [119000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 7.0208
# Epoch [120000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6.9859
# Epoch [121000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6.9845
# Epoch [122000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6.9845
# Epoch [123000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6.9845
# Epoch [124000/1300000], Property: number_of_nodes_in_the_largest_fully_connected_component, Loss: 6.9845
# Early stopping at epoch 124468
# Embedding: torch.Size([1044, 1, 2])
# Property: number_of_nodes_in_the_largest_fully_connected_component
#   Train MSE: 6.9845, Test MSE: 3.0409
#   Train R²: 0.0013, Test R²: -0.0093
# Epoch [1000/1300000], Property: assortativity, Loss: 0.0134
# Epoch [2000/1300000], Property: assortativity, Loss: 0.0132
# Epoch [3000/1300000], Property: assortativity, Loss: 0.0129
# Epoch [4000/1300000], Property: assortativity, Loss: 0.0126
# Epoch [5000/1300000], Property: assortativity, Loss: 0.0123
# Epoch [6000/1300000], Property: assortativity, Loss: 0.0122
# Epoch [7000/1300000], Property: assortativity, Loss: 0.0122
# Epoch [8000/1300000], Property: assortativity, Loss: 0.0122
# Epoch [9000/1300000], Property: assortativity, Loss: 0.0122
# Epoch [10000/1300000], Property: assortativity, Loss: 0.0122
# Early stopping at epoch 10474
# Embedding: torch.Size([1044, 1, 2])
# Property: assortativity
#   Train MSE: 0.0122, Test MSE: 0.0105
#   Train R²: 0.0083, Test R²: -0.0289
# Epoch [1000/1300000], Property: small_world, Loss: 0.0569
# Epoch [2000/1300000], Property: small_world, Loss: 0.0165
# Epoch [3000/1300000], Property: small_world, Loss: 0.0159
# Epoch [4000/1300000], Property: small_world, Loss: 0.0153
# Epoch [5000/1300000], Property: small_world, Loss: 0.0147
# Epoch [6000/1300000], Property: small_world, Loss: 0.0143
# Epoch [7000/1300000], Property: small_world, Loss: 0.0141
# Epoch [8000/1300000], Property: small_world, Loss: 0.0141
# Epoch [9000/1300000], Property: small_world, Loss: 0.0141
# Epoch [10000/1300000], Property: small_world, Loss: 0.0141
# Epoch [11000/1300000], Property: small_world, Loss: 0.0141
# Early stopping at epoch 11254
# Embedding: torch.Size([1044, 1, 2])
# Property: small_world
#   Train MSE: 0.0141, Test MSE: 0.0132
#   Train R²: 0.0019, Test R²: -0.0085

# %%
#load results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_full_embedding.pkl", "rb") as f:
    results = pkl.load(f)

# %% [markdown]
# ### Plots

# %%
import matplotlib.pyplot as plt

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component','assortativity', 'small_world']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'grey', 'orange', 'purple']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_name)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_test_R2_plot_limited_cv_full_embedding_full_embedding.png', dpi=300, bbox_inches='tight')

# %%
# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'num_cliques', 'num_triangles', 'num_squares', 'number_of_nodes_in_the_largest_fully_connected_component','assortativity', 'small_world']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'grey', 'orange', 'purple']

plt.figure(figsize=(12, 8))

for i, property_name in enumerate(property_names):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        train_r2 = results[(name_of_embedding, property_name)][2]
        if train_r2 < -0.05:  # Handle negative R² values
            train_r2 = -0.05
        x_points.append(j)
        y_points.append(train_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_name, color=colors[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_train_R2_plot_limited_cv_full_embedding.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Test with more properties

# %% [markdown]
# ### Properties

# %%
import networkx as nx
import numpy as np

def calculate_avg_path_length(G):
    if nx.is_connected(G):
        return nx.average_shortest_path_length(G)
    else:
        # Use the average path length of the largest connected component for disconnected graphs
        components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
        largest_component = max(components, key=len)
        return nx.average_shortest_path_length(largest_component)
    
   
def compute_swi(graph):
    # Calculate clustering coefficient and average path length for the given graph
    clustering_coeff = nx.average_clustering(graph)
    avg_path_len = calculate_avg_path_length(graph)
    
    # Generate a random graph with the same number of nodes and edges
    num_nodes = graph.number_of_nodes()
    num_edges = graph.number_of_edges()
    random_graph = nx.gnm_random_graph(num_nodes, num_edges)
    
    # Generate a lattice graph with the same number of nodes and edges
    lattice_graph = nx.watts_strogatz_graph(num_nodes, k=4, p=0)  # Adjust k as needed
    
    # Calculate clustering coefficient and average path length for the random graph
    random_clustering_coeff = nx.average_clustering(random_graph)
    random_avg_path_len = calculate_avg_path_length(random_graph)
    
    # Calculate clustering coefficient and average path length for the lattice graph
    lattice_clustering_coeff = nx.average_clustering(lattice_graph)
    lattice_avg_path_len = calculate_avg_path_length(lattice_graph)
    
    # Compute the Small-World Index (SWI)
    swi = ((avg_path_len - lattice_avg_path_len) / (random_avg_path_len - lattice_avg_path_len)) * \
          ((clustering_coeff - random_clustering_coeff) / (lattice_clustering_coeff - random_clustering_coeff))
    
    return swi


def betweenness_centralization(G):
    n = len(G)
    betweenness = nx.betweenness_centrality(G)
    max_betweenness = max(betweenness.values())
    centralization = sum(max_betweenness - bet for bet in betweenness.values())
    if n > 2:
        centralization /= (n - 1) * (n - 2) / 2
    return centralization

def pagerank_centralization(G, alpha=0.85):
    n = len(G)
    pagerank = nx.pagerank(G, alpha=alpha)
    max_pagerank = max(pagerank.values())
    centralization = sum(max_pagerank - pr for pr in pagerank.values())
    if n > 1:
        centralization /= (n - 1)
    return centralization

def clustering_properties(G):
    average_clustering = nx.average_clustering(G)
    transitivity = nx.transitivity(G)
    return average_clustering, transitivity

def compute_graph_properties(data):
    properties = []
    for graph_data in data:
        G = nx.from_edgelist(graph_data.edge_index.t().tolist())
        
        # Number of nodes
        num_nodes = G.number_of_nodes()
        
        # Number of edges
        num_edges = G.number_of_edges()
        
        # Density
        density = nx.density(G)
        
        # Average Path Length
        avg_path_len = calculate_avg_path_length(G)
        
        # Diameter
        if nx.is_connected(G):
            diameter = nx.diameter(G)
        else:
            # Use the diameter of the largest connected component for disconnected graphs
            components = [G.subgraph(c).copy() for c in nx.connected_components(G)]
            largest_component = max(components, key=len)
            diameter = nx.diameter(largest_component)
        
        # Radius
        if nx.is_connected(G):
            radius = nx.radius(G)
        else:
            radius = nx.radius(largest_component)
        
        # Clustering Coefficient
        clustering_coeff = nx.average_clustering(G)
        
        # Transitivity
        transitivity = nx.transitivity(G)
        
        # Assortativity
        assortativity = nx.degree_assortativity_coefficient(G)
        
        # Number of Cliques
        num_cliques = len(list(nx.find_cliques(G)))
        
        # Number of Triangles
        num_triangles = sum(nx.triangles(G).values()) / 3
        
        # Number of Squares (4-cycles)
        num_squares = sum(nx.square_clustering(G).values()) / 4
        
        # Size of the Largest Connected Component
        largest_component_size = len(max(nx.connected_components(G), key=len))
        
        # Average Degree
        degrees = [d for n, d in G.degree()]
        avg_degree = np.mean(degrees)
        
        # Betweenness Centrality
        betweenness_centrality = nx.betweenness_centrality(G)
        avg_betweenness_centrality = np.mean(list(betweenness_centrality.values()))
        
        # Eigenvalues of the Adjacency Matrix (for spectral properties)
        eigenvalues = np.linalg.eigvals(nx.adjacency_matrix(G).todense())
        spectral_radius = max(eigenvalues)
        algebraic_connectivity = sorted(eigenvalues)[1]  # second smallest eigenvalue
        
        # Graph Laplacian Eigenvalues
        laplacian_eigenvalues = np.linalg.eigvals(nx.laplacian_matrix(G).todense())
        graph_energy = sum(abs(laplacian_eigenvalues))
        
        # Small-World-ness
        # Compare clustering coefficient and average path length with those of a random graph
        random_graph = nx.gnm_random_graph(num_nodes, num_edges)
        random_clustering_coeff = nx.average_clustering(random_graph)
        random_avg_path_len = calculate_avg_path_length(random_graph)
        small_world_coefficient = (clustering_coeff / random_clustering_coeff) / (avg_path_len / random_avg_path_len)

        small_world_index = compute_swi(G)

        # Calculate Betweenness Centralization
        betweenness_cent = betweenness_centralization(G)
        print(f"Betweenness Centralization: {betweenness_cent}")

        # Calculate PageRank Centralization
        pagerank_cent = pagerank_centralization(G)
        print(f"PageRank Centralization: {pagerank_cent}")

        # Calculate Clustering properties
        avg_clustering, transitivity = clustering_properties(G)
        print(f"Average Clustering Coefficient: {avg_clustering}")
        print(f"Transitivity: {transitivity}")
        
        properties.append((
            num_nodes,
            num_edges,
            density,
            avg_path_len,
            diameter,
            radius,
            clustering_coeff,
            transitivity,
            assortativity,
            num_cliques,
            num_triangles,
            num_squares,
            largest_component_size,
            avg_degree,
            avg_betweenness_centrality,
            spectral_radius,
            algebraic_connectivity,
            graph_energy,
            small_world_coefficient, 
            betweenness_cent,
            pagerank_cent,
            avg_clustering,
            small_world_index           

        ))
    return properties

# %%
train_idx_list = gnn.train_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in train_idx_list]
train_properties_long = compute_graph_properties(selected_dataset)
test_idx_list = gnn.test_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in test_idx_list]
test_properties_long = compute_graph_properties(selected_dataset)

#save the properties in a file
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "wb") as f:
    pkl.dump(train_properties_long, f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "wb") as f:
    pkl.dump(test_properties_long, f)
# Out:
# Betweenness Centralization: 0.001086061741981193
# PageRank Centralization: 0.009889108225082894
# Average Clustering Coefficient: 0.5179222969842621
# Transitivity: 0.5032389055399787
# Betweenness Centralization: 0.0018289913557221417
# PageRank Centralization: 0.006459017297712483
# Average Clustering Coefficient: 0.5087813738549032
# Transitivity: 0.5213549337260678
# Betweenness Centralization: 0.00045402843483595716
# PageRank Centralization: 0.005046367337979484
# Average Clustering Coefficient: 0.5414121000696618
# Transitivity: 0.5641200188511285
# Betweenness Centralization: 0.0010550665108438862
# PageRank Centralization: 0.006308393987013973
# Average Clustering Coefficient: 0.6576803843183981
# Transitivity: 0.6348624992240363
# Betweenness Centralization: 0.001264968108251676
# PageRank Centralization: 0.007700201326596413
# Average Clustering Coefficient: 0.4949392448885353
# Transitivity: 0.5178428227746592
# Betweenness Centralization: 0.0018431551231994504
# PageRank Centralization: 0.009662184686628855
# Average Clustering Coefficient: 0.4797855570167943
# Transitivity: 0.5392133492252682
# Betweenness Centralization: 0.0033307425649824886
# PageRank Centralization: 0.00606718383942305
# Average Clustering Coefficient: 0.616315757200346
# Transitivity: 0.7496532593619972
# Betweenness Centralization: 0.002125372000538069
# PageRank Centralization: 0.007256812085864542
# Average Clustering Coefficient: 0.4297341301766081
# Transitivity: 0.4718927282104177
# Betweenness Centralization: 0.0013483215478145346
# PageRank Centralization: 0.008763462957317274
# Average Clustering Coefficient: 0.460693549182393
# Transitivity: 0.5211561382598331
# Betweenness Centralization: 0.0014614770081821783
# PageRank Centralization: 0.008837824815559106
# Average Clustering Coefficient: 0.502822708337414
# Transitivity: 0.475527950310559
# Betweenness Centralization: 0.0013820468603904785
# PageRank Centralization: 0.009957640246842972
# Average Clustering Coefficient: 0.4970691345691345
# Transitivity: 0.59559902200489
# Betweenness Centralization: 0.0014613941322424108
# PageRank Centralization: 0.011736288070906589
# Average Clustering Coefficient: 0.45174852047042124
# Transitivity: 0.4539518126548075
# Betweenness Centralization: 0.001520121157446461
# PageRank Centralization: 0.008457308609990312
# Average Clustering Coefficient: 0.5114658654837225
# Transitivity: 0.4958408679927667
# Betweenness Centralization: 0.0031242300001856006
# PageRank Centralization: 0.006276312067117581
# Average Clustering Coefficient: 0.47845782237086576
# Transitivity: 0.47539015606242496
# Betweenness Centralization: 0.001057562353296283
# PageRank Centralization: 0.0061435004662805355
# Average Clustering Coefficient: 0.5902405664431335
# Transitivity: 0.5836168061046244
# Betweenness Centralization: 0.001378747849106092
# PageRank Centralization: 0.010041220864139251
# Average Clustering Coefficient: 0.4579767777715534
# Transitivity: 0.48942012598933937
# Betweenness Centralization: 0.0007662962367118217
# PageRank Centralization: 0.007039251551452858
# Average Clustering Coefficient: 0.5086112634393022
# Transitivity: 0.5065573770491804
# Betweenness Centralization: 0.0008614429710751451
# PageRank Centralization: 0.008696188561119752
# Average Clustering Coefficient: 0.5983980804672584
# Transitivity: 0.5991622770832011
# Betweenness Centralization: 0.001177263645950601
# PageRank Centralization: 0.007998723156989525
# Average Clustering Coefficient: 0.5533807683619233
# Transitivity: 0.5076923076923077
# Betweenness Centralization: 0.0017555081372748191
# PageRank Centralization: 0.008767223096293459
# Average Clustering Coefficient: 0.5349531361802298
# Transitivity: 0.5730255164034022
# Betweenness Centralization: 0.001652271964841823
# PageRank Centralization: 0.006872407180162767
# Average Clustering Coefficient: 0.49140627488453587
# Transitivity: 0.5058860960865416
# Betweenness Centralization: 0.0017662801014066928
# PageRank Centralization: 0.009291984316490351
# Average Clustering Coefficient: 0.4476761459625911
# Transitivity: 0.5011971268954509
# Betweenness Centralization: 0.0013016758642267058
# PageRank Centralization: 0.008391233199822967
# Average Clustering Coefficient: 0.5314612549554423
# Transitivity: 0.572493477450615
# Betweenness Centralization: 0.0031849797626091144
# PageRank Centralization: 0.007250692729432615
# Average Clustering Coefficient: 0.450062820321441
# Transitivity: 0.539576802507837
# Betweenness Centralization: 0.0017714196430954113
# PageRank Centralization: 0.00868261661251534
# Average Clustering Coefficient: 0.42806661576011423
# Transitivity: 0.4889867841409692
# Betweenness Centralization: 0.002863048328405687
# PageRank Centralization: 0.008877499537492228
# Average Clustering Coefficient: 0.5135685379706943
# Transitivity: 0.5578313253012048
# Betweenness Centralization: 0.0010112827231160252
# PageRank Centralization: 0.006002872688953313
# Average Clustering Coefficient: 0.5571201204231767
# Transitivity: 0.5910519951632406
# Betweenness Centralization: 0.0007573338735141946
# PageRank Centralization: 0.006385359130933956
# Average Clustering Coefficient: 0.5176235910602569
# Transitivity: 0.5513032002639393
# Betweenness Centralization: 0.0008551783549546132
# PageRank Centralization: 0.008742023781434608
# Average Clustering Coefficient: 0.42610464541814635
# Transitivity: 0.43162175902389427
# Betweenness Centralization: 0.001180838879731684
# PageRank Centralization: 0.0064014650726448704
# Average Clustering Coefficient: 0.5067748287322325
# Transitivity: 0.5158249158249159
# Betweenness Centralization: 0.001719231266408535
# PageRank Centralization: 0.00698951903584569
# Average Clustering Coefficient: 0.5564628322995463
# Transitivity: 0.5460624071322436
# Betweenness Centralization: 0.0011080149631059783
# PageRank Centralization: 0.008098927183418583
# Average Clustering Coefficient: 0.5474584857364252
# Transitivity: 0.5089420023399632
# Betweenness Centralization: 0.0020761275558438875
# PageRank Centralization: 0.007781039938976758
# Average Clustering Coefficient: 0.5004434973820002
# Transitivity: 0.6046213093709885
# Betweenness Centralization: 0.0014466055819347713
# PageRank Centralization: 0.007327698571016982
# Average Clustering Coefficient: 0.4787972760842943
# Transitivity: 0.5096560048280024
# Betweenness Centralization: 0.0012890675144400406
# PageRank Centralization: 0.006841569716970081
# Average Clustering Coefficient: 0.47114781769954184
# Transitivity: 0.5150602409638554
# Betweenness Centralization: 0.0013495544800853272
# PageRank Centralization: 0.005852884556617709
# Average Clustering Coefficient: 0.5240055935001416
# Transitivity: 0.5654920212765957
# Betweenness Centralization: 0.0032802558838020217
# PageRank Centralization: 0.005373121741671384
# Average Clustering Coefficient: 0.6394094261412401
# Transitivity: 0.6243066061522945
# Betweenness Centralization: 0.0011332046991369606
# PageRank Centralization: 0.007229454744589893
# Average Clustering Coefficient: 0.6072089302987018
# Transitivity: 0.6584068442750122
# Betweenness Centralization: 0.0019695430471820654
# PageRank Centralization: 0.00983700437645089
# Average Clustering Coefficient: 0.47825173674682364
# Transitivity: 0.5278826927349478
# Betweenness Centralization: 0.001136367231575342
# PageRank Centralization: 0.0065723692101996856
# Average Clustering Coefficient: 0.5866502400707936
# Transitivity: 0.6160825772080246
# Betweenness Centralization: 0.001201795656714654
# PageRank Centralization: 0.00768560535317419
# Average Clustering Coefficient: 0.428275298981989
# Transitivity: 0.48969197186514674
# Betweenness Centralization: 0.0016045807565950789
# PageRank Centralization: 0.00926447562995012
# Average Clustering Coefficient: 0.515900056287651
# Transitivity: 0.5512918513988687
# Betweenness Centralization: 0.0015322477470103284
# PageRank Centralization: 0.008279261851257458
# Average Clustering Coefficient: 0.47957059769406307
# Transitivity: 0.5146931719965427
# Betweenness Centralization: 0.001330726146000826
# PageRank Centralization: 0.007528193138886812
# Average Clustering Coefficient: 0.5654128489631577
# Transitivity: 0.5733640818679735
# Betweenness Centralization: 0.0013368886619824192
# PageRank Centralization: 0.007647915395675601
# Average Clustering Coefficient: 0.48627075017404925
# Transitivity: 0.5235091060588025
# Betweenness Centralization: 0.0005089966750413166
# PageRank Centralization: 0.005312573472202948
# Average Clustering Coefficient: 0.5220023035917062
# Transitivity: 0.5102788520252391
# Betweenness Centralization: 0.004258771004745923
# PageRank Centralization: 0.009026828039776977
# Average Clustering Coefficient: 0.5324696244214352
# Transitivity: 0.5881116781747223
# Betweenness Centralization: 0.002249934020676841
# PageRank Centralization: 0.006958093193469958
# Average Clustering Coefficient: 0.5176604904495603
# Transitivity: 0.5891551584077985
# Betweenness Centralization: 0.0038523338856805292
# PageRank Centralization: 0.009673819947146852
# Average Clustering Coefficient: 0.39826718735809646
# Transitivity: 0.5340035481963336
# Betweenness Centralization: 0.0009415571619398711
# PageRank Centralization: 0.006841847000195802
# Average Clustering Coefficient: 0.441488221549468
# Transitivity: 0.4850266397207422
# Betweenness Centralization: 0.001708176235729968
# PageRank Centralization: 0.006499278216215807
# Average Clustering Coefficient: 0.5792587107642506
# Transitivity: 0.6022845275181724
# Betweenness Centralization: 0.0013510997350773552
# PageRank Centralization: 0.008786855049144855
# Average Clustering Coefficient: 0.4543976754269536
# Transitivity: 0.4414048059149723
# Betweenness Centralization: 0.0012972292108553332
# PageRank Centralization: 0.006658958495318285
# Average Clustering Coefficient: 0.4543766492104087
# Transitivity: 0.44956563706563707
# Betweenness Centralization: 0.0012117855872943145
# PageRank Centralization: 0.008786178031224817
# Average Clustering Coefficient: 0.42338826234617283
# Transitivity: 0.4410014873574616
# Betweenness Centralization: 0.001177987514297244
# PageRank Centralization: 0.0075880123013104235
# Average Clustering Coefficient: 0.4876331218025926
# Transitivity: 0.46423617990885674
# Betweenness Centralization: 0.0008956265537956804
# PageRank Centralization: 0.009649910662104338
# Average Clustering Coefficient: 0.5105872954793026
# Transitivity: 0.503282040245346
# Betweenness Centralization: 0.0019656908288803857
# PageRank Centralization: 0.007695434415971249
# Average Clustering Coefficient: 0.5157176622602656
# Transitivity: 0.4957140251687033
# Betweenness Centralization: 0.0008169909634683666
# PageRank Centralization: 0.006698519539420803
# Average Clustering Coefficient: 0.5019369668236703
# Transitivity: 0.5328534031413612
# Betweenness Centralization: 0.002471621093494298
# PageRank Centralization: 0.007520010189327002
# Average Clustering Coefficient: 0.45753489381807955
# Transitivity: 0.5063414634146342
# Betweenness Centralization: 0.0030208912883854305
# PageRank Centralization: 0.009588214695388494
# Average Clustering Coefficient: 0.45752652519893905
# Transitivity: 0.5361472833408173
# Betweenness Centralization: 0.0014159496495993816
# PageRank Centralization: 0.006433142788421221
# Average Clustering Coefficient: 0.435577941524233
# Transitivity: 0.47125506072874496
# Betweenness Centralization: 0.001274784290526014
# PageRank Centralization: 0.0071997879175372745
# Average Clustering Coefficient: 0.5624337344920242
# Transitivity: 0.5756899588960658
# Betweenness Centralization: 0.001570293063542559
# PageRank Centralization: 0.005996538036599609
# Average Clustering Coefficient: 0.5020436994094282
# Transitivity: 0.48163548163548164
# Betweenness Centralization: 0.0008716672913623098
# PageRank Centralization: 0.007420975703447383
# Average Clustering Coefficient: 0.4618055308686562
# Transitivity: 0.506469782310854
# Betweenness Centralization: 0.00201537333039496
# PageRank Centralization: 0.007091749986419697
# Average Clustering Coefficient: 0.51768250386773
# Transitivity: 0.5896364396155453
# Betweenness Centralization: 0.001263100084099505
# PageRank Centralization: 0.006800886045143563
# Average Clustering Coefficient: 0.4297077279248025
# Transitivity: 0.4526271365266934
# Betweenness Centralization: 0.0017536214426088247
# PageRank Centralization: 0.008622876683180118
# Average Clustering Coefficient: 0.511995922520219
# Transitivity: 0.5128294036061026
# Betweenness Centralization: 0.001376047629970523
# PageRank Centralization: 0.007998683245421431
# Average Clustering Coefficient: 0.46413153339192836
# Transitivity: 0.6110537951363302
# Betweenness Centralization: 0.003079328493118005
# PageRank Centralization: 0.00643119331878682
# Average Clustering Coefficient: 0.5613533356433965
# Transitivity: 0.5506487322937745
# Betweenness Centralization: 0.0038446656714755637
# PageRank Centralization: 0.011508456074013174
# Average Clustering Coefficient: 0.4514970565098442
# Transitivity: 0.5336150595466769
# Betweenness Centralization: 0.0015053178317159417
# PageRank Centralization: 0.008629530953853763
# Average Clustering Coefficient: 0.4724333141320623
# Transitivity: 0.493876589731512
# Betweenness Centralization: 0.0031090017509414316
# PageRank Centralization: 0.006561782853087306
# Average Clustering Coefficient: 0.5338671587979067
# Transitivity: 0.5280283981659518
# Betweenness Centralization: 0.0012598194951403572
# PageRank Centralization: 0.007514609815725017
# Average Clustering Coefficient: 0.46187650883925013
# Transitivity: 0.45921390479952595
# Betweenness Centralization: 0.0032855836265738227
# PageRank Centralization: 0.011124116251634272
# Average Clustering Coefficient: 0.43341969333348634
# Transitivity: 0.5006544502617801
# Betweenness Centralization: 0.0014545550717194205
# PageRank Centralization: 0.008153411333058642
# Average Clustering Coefficient: 0.4863915175223632
# Transitivity: 0.5266285714285714
# Betweenness Centralization: 0.001828241479922198
# PageRank Centralization: 0.009653016183210612
# Average Clustering Coefficient: 0.5438597525956985
# Transitivity: 0.5908344283837057
# Betweenness Centralization: 0.0018462610973567237
# PageRank Centralization: 0.008704363408449734
# Average Clustering Coefficient: 0.5262182851725927
# Transitivity: 0.5469026548672566
# Betweenness Centralization: 0.0014320739278455411
# PageRank Centralization: 0.006477908782280396
# Average Clustering Coefficient: 0.45399179364696624
# Transitivity: 0.5308056872037915
# Betweenness Centralization: 0.0029885178108584737
# PageRank Centralization: 0.0052780086889714865
# Average Clustering Coefficient: 0.5530710618278675
# Transitivity: 0.5904186447993095
# Betweenness Centralization: 0.0011206757302956551
# PageRank Centralization: 0.006815507724936629
# Average Clustering Coefficient: 0.54865747746139
# Transitivity: 0.5229977484721775
# Betweenness Centralization: 0.001351589405749422
# PageRank Centralization: 0.008188727873365874
# Average Clustering Coefficient: 0.43393505045678965
# Transitivity: 0.47181008902077154
# Betweenness Centralization: 0.0021903197768296146
# PageRank Centralization: 0.007923371393884115
# Average Clustering Coefficient: 0.5484710317693512
# Transitivity: 0.5851755526657998
# Betweenness Centralization: 0.0015007944027825354
# PageRank Centralization: 0.006723383405674433
# Average Clustering Coefficient: 0.4671868361523537
# Transitivity: 0.5032025620496398
# Betweenness Centralization: 0.0012240169223552107
# PageRank Centralization: 0.006156971488369626
# Average Clustering Coefficient: 0.5207533238038686
# Transitivity: 0.5304268846503178
# Betweenness Centralization: 0.0009579041444113615
# PageRank Centralization: 0.007578794865617527
# Average Clustering Coefficient: 0.36234118538466353
# Transitivity: 0.3898768809849521
# Betweenness Centralization: 0.0016567165373454192
# PageRank Centralization: 0.007527894964020034
# Average Clustering Coefficient: 0.5865433370864789
# Transitivity: 0.5605889014722537
# Betweenness Centralization: 0.0005767231192983937
# PageRank Centralization: 0.0057060733017260555
# Average Clustering Coefficient: 0.5366651560947984
# Transitivity: 0.554127349728806
# Betweenness Centralization: 0.0017924475923699005
# PageRank Centralization: 0.007441670334841147
# Average Clustering Coefficient: 0.4943281399033609
# Transitivity: 0.4637625289128759
# Betweenness Centralization: 0.003410724588292093
# PageRank Centralization: 0.013750340458743902
# Average Clustering Coefficient: 0.48419757696176235
# Transitivity: 0.5329693406131877
# Betweenness Centralization: 0.0027431942022414797
# PageRank Centralization: 0.00754374915371531
# Average Clustering Coefficient: 0.603517473820393
# Transitivity: 0.6325673338275266
# Betweenness Centralization: 0.0014785902356523005
# PageRank Centralization: 0.008864062094696083
# Average Clustering Coefficient: 0.47161089367318687
# Transitivity: 0.6054114994363021
# Betweenness Centralization: 0.0021639471584690303
# PageRank Centralization: 0.008377782145265229
# Average Clustering Coefficient: 0.5512677258894032
# Transitivity: 0.5669481302774427
# Betweenness Centralization: 0.0019646400406334924
# PageRank Centralization: 0.009815187832223564
# Average Clustering Coefficient: 0.44459521282175735
# Transitivity: 0.4245038826574633
# Betweenness Centralization: 0.0022671691216563806
# PageRank Centralization: 0.007768459025854732
# Average Clustering Coefficient: 0.577849554876937
# Transitivity: 0.5667556742323098
# Betweenness Centralization: 0.001454267042670509
# PageRank Centralization: 0.006001335474472275
# Average Clustering Coefficient: 0.5460483818540083
# Transitivity: 0.5746121297602257
# Betweenness Centralization: 0.0014496068652510448
# PageRank Centralization: 0.008681186183223458
# Average Clustering Coefficient: 0.5584861537502397
# Transitivity: 0.5778382053025153
# Betweenness Centralization: 0.002007966387081847
# PageRank Centralization: 0.006671939099817724
# Average Clustering Coefficient: 0.48545362139991277
# Transitivity: 0.5018324607329843
# Betweenness Centralization: 0.0017584473673798293
# PageRank Centralization: 0.0073635679264833975
# Average Clustering Coefficient: 0.5213172047784249
# Transitivity: 0.5326941514860978
# Betweenness Centralization: 0.0015424834418785048
# PageRank Centralization: 0.01024257003646897
# Average Clustering Coefficient: 0.5139321539492522
# Transitivity: 0.5262374395236323
# Betweenness Centralization: 0.000953285998619045
# PageRank Centralization: 0.006983439435948915
# Average Clustering Coefficient: 0.45892563805533026
# Transitivity: 0.4685908319185059
# Betweenness Centralization: 0.0027402049550123045
# PageRank Centralization: 0.009090195041158308
# Average Clustering Coefficient: 0.4876162630472975
# Transitivity: 0.4600980829246545
# Betweenness Centralization: 0.0016515089748864785
# PageRank Centralization: 0.011012115298489195
# Average Clustering Coefficient: 0.4667670773050372
# Transitivity: 0.451858913250715
# Betweenness Centralization: 0.0013119646906614275
# PageRank Centralization: 0.0068623455864563485
# Average Clustering Coefficient: 0.47809998909136864
# Transitivity: 0.52109375
# Betweenness Centralization: 0.003304605229062567
# PageRank Centralization: 0.007350710634438627
# Average Clustering Coefficient: 0.48614322875192434
# Transitivity: 0.5009765625
# Betweenness Centralization: 0.002133669758097061
# PageRank Centralization: 0.008968036918623874
# Average Clustering Coefficient: 0.4969806756376251
# Transitivity: 0.5423841059602649
# Betweenness Centralization: 0.0026068681303561955
# PageRank Centralization: 0.009041966809418347
# Average Clustering Coefficient: 0.5354258083809139
# Transitivity: 0.6003503138227996
# Betweenness Centralization: 0.0044296939287001265
# PageRank Centralization: 0.01004517179551138
# Average Clustering Coefficient: 0.4526741026741027
# Transitivity: 0.45725806451612905
# Betweenness Centralization: 0.0019182037349361621
# PageRank Centralization: 0.009361058959909307
# Average Clustering Coefficient: 0.47979606965675087
# Transitivity: 0.4671686746987952
# Betweenness Centralization: 0.0011825981893857668
# PageRank Centralization: 0.007742042806662439
# Average Clustering Coefficient: 0.43249586670639306
# Transitivity: 0.5139204545454545
# Betweenness Centralization: 0.001386792103626172
# PageRank Centralization: 0.007205509842708767
# Average Clustering Coefficient: 0.4675364774469633
# Transitivity: 0.5180346492473729
# Betweenness Centralization: 0.0015694154105042584
# PageRank Centralization: 0.00658798238901808
# Average Clustering Coefficient: 0.6311638382015421
# Transitivity: 0.714485022568732
# Betweenness Centralization: 0.0014266194867263674
# PageRank Centralization: 0.008961771627818903
# Average Clustering Coefficient: 0.3687002467715637
# Transitivity: 0.4336851766865535
# Betweenness Centralization: 0.0013237038721958204
# PageRank Centralization: 0.00674623011638588
# Average Clustering Coefficient: 0.550579730988265
# Transitivity: 0.5367873651771957
# Betweenness Centralization: 0.0011115961288568116
# PageRank Centralization: 0.007447825391612434
# Average Clustering Coefficient: 0.5344941484413834
# Transitivity: 0.5894912427022518
# Betweenness Centralization: 0.001866634202018737
# PageRank Centralization: 0.011503502944941426
# Average Clustering Coefficient: 0.4405369949617739
# Transitivity: 0.4267631103074141
# Betweenness Centralization: 0.0014066199019434713
# PageRank Centralization: 0.009229931563561647
# Average Clustering Coefficient: 0.4849020086736271
# Transitivity: 0.4864534528417193
# Betweenness Centralization: 0.0012966740467226356
# PageRank Centralization: 0.010516162977482525
# Average Clustering Coefficient: 0.4679713485747968
# Transitivity: 0.43670886075949367
# Betweenness Centralization: 0.0015868535944201449
# PageRank Centralization: 0.008691135508167032
# Average Clustering Coefficient: 0.5143749812621391
# Transitivity: 0.5650887573964497
# Betweenness Centralization: 0.001753876985166789
# PageRank Centralization: 0.00940701143537156
# Average Clustering Coefficient: 0.4753315115651718
# Transitivity: 0.4826450468710413
# Betweenness Centralization: 0.0017862035249081966
# PageRank Centralization: 0.007187324666997073
# Average Clustering Coefficient: 0.5281847526641904
# Transitivity: 0.5708154506437768
# Betweenness Centralization: 0.0018593214646474398
# PageRank Centralization: 0.008622890393014733
# Average Clustering Coefficient: 0.47230409066860796
# Transitivity: 0.5242662574333398
# Betweenness Centralization: 0.002005996688256071
# PageRank Centralization: 0.009418878432404248
# Average Clustering Coefficient: 0.5036767580245841
# Transitivity: 0.5722241559345632
# Betweenness Centralization: 0.001563229979068698
# PageRank Centralization: 0.006373163895996024
# Average Clustering Coefficient: 0.5278910097114966
# Transitivity: 0.5454545454545454
# Betweenness Centralization: 0.0016944092470318674
# PageRank Centralization: 0.011774182546923582
# Average Clustering Coefficient: 0.40970559307025484
# Transitivity: 0.4789915966386555
# Betweenness Centralization: 0.004392343121729625
# PageRank Centralization: 0.006180570765595875
# Average Clustering Coefficient: 0.5608739569609134
# Transitivity: 0.5485188968335035
# Betweenness Centralization: 0.0027021826980329657
# PageRank Centralization: 0.007230196509163888
# Average Clustering Coefficient: 0.48449818859301597
# Transitivity: 0.5020949720670391
# Betweenness Centralization: 0.00148362771230204
# PageRank Centralization: 0.008142683144537527
# Average Clustering Coefficient: 0.5264797420857258
# Transitivity: 0.5202422696844119
# Betweenness Centralization: 0.0036011461231192305
# PageRank Centralization: 0.00719799171934244
# Average Clustering Coefficient: 0.5071176138439561
# Transitivity: 0.584885856730517
# Betweenness Centralization: 0.0019533658715155623
# PageRank Centralization: 0.009671214228196286
# Average Clustering Coefficient: 0.5484022715562615
# Transitivity: 0.5814895606107822
# Betweenness Centralization: 0.0020444241975381364
# PageRank Centralization: 0.007101709505964528
# Average Clustering Coefficient: 0.5242646960319376
# Transitivity: 0.4881793061099171
# Betweenness Centralization: 0.0008346273998522383
# PageRank Centralization: 0.0056093411888551445
# Average Clustering Coefficient: 0.6184769738674591
# Transitivity: 0.5838053404230725
# Betweenness Centralization: 0.0019990454181621326
# PageRank Centralization: 0.008419799746916147
# Average Clustering Coefficient: 0.5315058779481987
# Transitivity: 0.48730267673301303
# Betweenness Centralization: 0.0007564655857143183
# PageRank Centralization: 0.004922908471546111
# Average Clustering Coefficient: 0.5070336029994937
# Transitivity: 0.5082304526748971
# Betweenness Centralization: 0.0010962994784915554
# PageRank Centralization: 0.008244398723258313
# Average Clustering Coefficient: 0.5046598250017283
# Transitivity: 0.46551724137931033
# Betweenness Centralization: 0.0006015627099076683
# PageRank Centralization: 0.00655508433375246
# Average Clustering Coefficient: 0.5635024512531811
# Transitivity: 0.5886552643966735
# Betweenness Centralization: 0.0014390656829104016
# PageRank Centralization: 0.006752348428128521
# Average Clustering Coefficient: 0.4929996688524082
# Transitivity: 0.47768654052124243
# Betweenness Centralization: 0.0012520603637885246
# PageRank Centralization: 0.006196132493672186
# Average Clustering Coefficient: 0.5785553546522033
# Transitivity: 0.5933280381254964
# Betweenness Centralization: 0.001180263306527351
# PageRank Centralization: 0.007837021810163505
# Average Clustering Coefficient: 0.45915392656878706
# Transitivity: 0.5055603079555175
# Betweenness Centralization: 0.004080251850728631
# PageRank Centralization: 0.011004399543414627
# Average Clustering Coefficient: 0.4854814340218046
# Transitivity: 0.4893560404470463
# Betweenness Centralization: 0.0027119481097196917
# PageRank Centralization: 0.007852615374744727
# Average Clustering Coefficient: 0.5428112510914471
# Transitivity: 0.5493345571363011
# Betweenness Centralization: 0.0009129282512773135
# PageRank Centralization: 0.006697696068120426
# Average Clustering Coefficient: 0.5043614512796099
# Transitivity: 0.5077755240027045
# Betweenness Centralization: 0.0017956453412381632
# PageRank Centralization: 0.009108386013990149
# Average Clustering Coefficient: 0.5332475819111081
# Transitivity: 0.5324466865397844
# Betweenness Centralization: 0.0014673091251938282
# PageRank Centralization: 0.010418666312293743
# Average Clustering Coefficient: 0.45601639118218884
# Transitivity: 0.4508833922261484
# Betweenness Centralization: 0.001344188359494869
# PageRank Centralization: 0.009310369122357299
# Average Clustering Coefficient: 0.5394155159259717
# Transitivity: 0.5651203416149069
# Betweenness Centralization: 0.0011114625323693124
# PageRank Centralization: 0.007313030133503113
# Average Clustering Coefficient: 0.49255847568473765
# Transitivity: 0.5330188679245284
# Betweenness Centralization: 0.001768519240707461
# PageRank Centralization: 0.007030117422300275
# Average Clustering Coefficient: 0.6244275062741061
# Transitivity: 0.6401656314699793
# Betweenness Centralization: 0.0011793304006031795
# PageRank Centralization: 0.005612847153553115
# Average Clustering Coefficient: 0.6760593857632294
# Transitivity: 0.7942441622285948
# Betweenness Centralization: 0.001583306689825017
# PageRank Centralization: 0.007693746662643521
# Average Clustering Coefficient: 0.46383056598573824
# Transitivity: 0.4289266473269789
# Betweenness Centralization: 0.0010374419386067924
# PageRank Centralization: 0.006782241707195654
# Average Clustering Coefficient: 0.4624257500858866
# Transitivity: 0.4880991196609064
# Betweenness Centralization: 0.002125851694717536
# PageRank Centralization: 0.010864721699819476
# Average Clustering Coefficient: 0.4346407061577342
# Transitivity: 0.4852433882713683
# Betweenness Centralization: 0.0014862298823986437
# PageRank Centralization: 0.008033197301323873
# Average Clustering Coefficient: 0.43806945815059395
# Transitivity: 0.44818456883509833
# Betweenness Centralization: 0.0015423060885875694
# PageRank Centralization: 0.007995766328726495
# Average Clustering Coefficient: 0.5364048113356216
# Transitivity: 0.5597199341021417
# Betweenness Centralization: 0.0008427811637052844
# PageRank Centralization: 0.0072813468311299775
# Average Clustering Coefficient: 0.4947961978636575
# Transitivity: 0.46998408795023866
# Betweenness Centralization: 0.0055982445656144585
# PageRank Centralization: 0.007843687707381426
# Average Clustering Coefficient: 0.5081072323527566
# Transitivity: 0.558862609619984
# Betweenness Centralization: 0.0015565979086558765
# PageRank Centralization: 0.006812550040386147
# Average Clustering Coefficient: 0.43349394270446906
# Transitivity: 0.4869402985074627
# Betweenness Centralization: 0.0016698451368639222
# PageRank Centralization: 0.007751331817226433
# Average Clustering Coefficient: 0.5276930316060751
# Transitivity: 0.5699351117519827
# Betweenness Centralization: 0.004846517090336696
# PageRank Centralization: 0.00938615998980637
# Average Clustering Coefficient: 0.4526438474573977
# Transitivity: 0.5300613496932516
# Betweenness Centralization: 0.0011593422455749697
# PageRank Centralization: 0.008164689627899119
# Average Clustering Coefficient: 0.5246524062831445
# Transitivity: 0.5678841617180509
# Betweenness Centralization: 0.0012702078783104849
# PageRank Centralization: 0.006723989319290412
# Average Clustering Coefficient: 0.4965874477437676
# Transitivity: 0.494498899779956
# Betweenness Centralization: 0.003588448435130282
# PageRank Centralization: 0.007272557533411365
# Average Clustering Coefficient: 0.5214123520158003
# Transitivity: 0.5269814502529511
# Betweenness Centralization: 0.001710664847614049
# PageRank Centralization: 0.0065780102629860926
# Average Clustering Coefficient: 0.5052093876518485
# Transitivity: 0.6353552859618717
# Betweenness Centralization: 0.0006764363511119735
# PageRank Centralization: 0.0077157105852242855
# Average Clustering Coefficient: 0.46619861678317953
# Transitivity: 0.45464939024390244
# Betweenness Centralization: 0.001305091691041633
# PageRank Centralization: 0.0076065631996402065
# Average Clustering Coefficient: 0.5384938093025572
# Transitivity: 0.5149390243902439
# Betweenness Centralization: 0.002337763376809459
# PageRank Centralization: 0.006152129069692748
# Average Clustering Coefficient: 0.5277029492246884
# Transitivity: 0.5852272727272727
# Betweenness Centralization: 0.002489784398180474
# PageRank Centralization: 0.011349827515547231
# Average Clustering Coefficient: 0.49828661864866086
# Transitivity: 0.5373219373219373
# Betweenness Centralization: 0.0014409080942954892
# PageRank Centralization: 0.007228716444899166
# Average Clustering Coefficient: 0.6154645585193423
# Transitivity: 0.6159108989657915
# Betweenness Centralization: 0.0014457761943454722
# PageRank Centralization: 0.005664137977634914
# Average Clustering Coefficient: 0.5473873568886355
# Transitivity: 0.5876187356698329
# Betweenness Centralization: 0.0022877260006429487
# PageRank Centralization: 0.011049424364530998
# Average Clustering Coefficient: 0.4823836592172454
# Transitivity: 0.5697077059344553
# Betweenness Centralization: 0.0013875687882786568
# PageRank Centralization: 0.007478769894377841
# Average Clustering Coefficient: 0.5036447529167983
# Transitivity: 0.48688873139617295
# Betweenness Centralization: 0.0015130778513878739
# PageRank Centralization: 0.009509384601147572
# Average Clustering Coefficient: 0.4760965548413388
# Transitivity: 0.48242475268364554
# Betweenness Centralization: 0.0016328757634226792
# PageRank Centralization: 0.007913834363362838
# Average Clustering Coefficient: 0.5296657406215715
# Transitivity: 0.570935960591133
# Betweenness Centralization: 0.0014663104394573145
# PageRank Centralization: 0.00884896218543275
# Average Clustering Coefficient: 0.5758087983432792
# Transitivity: 0.5649711360418255
# Betweenness Centralization: 0.001756869559465888
# PageRank Centralization: 0.007804622184772295
# Average Clustering Coefficient: 0.5489760471203464
# Transitivity: 0.5603790889636197
# Betweenness Centralization: 0.002323770100888851
# PageRank Centralization: 0.00885266344963442
# Average Clustering Coefficient: 0.4327963099702231
# Transitivity: 0.47287950491445213
# Betweenness Centralization: 0.0011363620897926721
# PageRank Centralization: 0.007739653725280261
# Average Clustering Coefficient: 0.48658206953603367
# Transitivity: 0.46898263027295284
# Betweenness Centralization: 0.0022652739327549006
# PageRank Centralization: 0.00822829395443624
# Average Clustering Coefficient: 0.4754396367099206
# Transitivity: 0.48040728170317804
# Betweenness Centralization: 0.002089255070779658
# PageRank Centralization: 0.010515511118321535
# Average Clustering Coefficient: 0.46735013854455476
# Transitivity: 0.5731457800511509
# Betweenness Centralization: 0.0024309495587980638
# PageRank Centralization: 0.0067442460101094105
# Average Clustering Coefficient: 0.5515147422414958
# Transitivity: 0.6014346146772117
# Betweenness Centralization: 0.0010633979760988252
# PageRank Centralization: 0.0070210605299849274
# Average Clustering Coefficient: 0.47448457559011376
# Transitivity: 0.5307532826537664
# Betweenness Centralization: 0.0010388309180568024
# PageRank Centralization: 0.009492976521010287
# Average Clustering Coefficient: 0.4675613405816511
# Transitivity: 0.44220132743362833
# Betweenness Centralization: 0.0016055636066314267
# PageRank Centralization: 0.009123993249301061
# Average Clustering Coefficient: 0.5047988931462828
# Transitivity: 0.4984025559105431
# Betweenness Centralization: 0.0015806134310432135
# PageRank Centralization: 0.006181184338559349
# Average Clustering Coefficient: 0.583161489945946
# Transitivity: 0.5853424876257385
# Betweenness Centralization: 0.0015624120183644465
# PageRank Centralization: 0.006723942896604714
# Average Clustering Coefficient: 0.5428253182021318
# Transitivity: 0.6184518241347053
# Betweenness Centralization: 0.0024427647712242768
# PageRank Centralization: 0.011743358538287684
# Average Clustering Coefficient: 0.44905318852687276
# Transitivity: 0.4775257731958763
# Betweenness Centralization: 0.0015358865503090416
# PageRank Centralization: 0.008083734996704912
# Average Clustering Coefficient: 0.49142522439197645
# Transitivity: 0.4912559618441971
# Betweenness Centralization: 0.0014614971031362304
# PageRank Centralization: 0.006832784683340629
# Average Clustering Coefficient: 0.5006335554710165
# Transitivity: 0.4737650371128743
# Betweenness Centralization: 0.0030607172896678944
# PageRank Centralization: 0.00747488219880637
# Average Clustering Coefficient: 0.551372570399119
# Transitivity: 0.6035196687370601
# Betweenness Centralization: 0.0018904785148743163
# PageRank Centralization: 0.008244167735453955
# Average Clustering Coefficient: 0.4937877510139175
# Transitivity: 0.47336531178995206
# Betweenness Centralization: 0.0005971837392109634
# PageRank Centralization: 0.006703150237079214
# Average Clustering Coefficient: 0.4771392380310655
# Transitivity: 0.5351647396331392
# Betweenness Centralization: 0.002080298906700507
# PageRank Centralization: 0.008982191184123335
# Average Clustering Coefficient: 0.43892345681138784
# Transitivity: 0.47729672650475186
# Betweenness Centralization: 0.0027777833942006294
# PageRank Centralization: 0.007932222696191668
# Average Clustering Coefficient: 0.464393647288384
# Transitivity: 0.47368421052631576
# Betweenness Centralization: 0.0009275676153334862
# PageRank Centralization: 0.008110773280972318
# Average Clustering Coefficient: 0.5398482735942641
# Transitivity: 0.6115860404304536
# Betweenness Centralization: 0.0013092745057067972
# PageRank Centralization: 0.009661273344298178
# Average Clustering Coefficient: 0.5165095803414494
# Transitivity: 0.5831615665133978
# Betweenness Centralization: 0.0017011196236348474
# PageRank Centralization: 0.009601170395707587
# Average Clustering Coefficient: 0.5110084244872708
# Transitivity: 0.46734854445318647
# Betweenness Centralization: 0.0024269842870405004
# PageRank Centralization: 0.00789967403223625
# Average Clustering Coefficient: 0.49030964246481484
# Transitivity: 0.49390243902439024
# Betweenness Centralization: 0.000637587557163743
# PageRank Centralization: 0.005796467371620567
# Average Clustering Coefficient: 0.5869362045349196
# Transitivity: 0.6107015825558019
# Betweenness Centralization: 0.0017772085023763048
# PageRank Centralization: 0.007905861024788687
# Average Clustering Coefficient: 0.5165187443838557
# Transitivity: 0.5182638590459819
# Betweenness Centralization: 0.0018406830293582312
# PageRank Centralization: 0.0070045203145622514
# Average Clustering Coefficient: 0.4905955572931392
# Transitivity: 0.5570231140462281
# Betweenness Centralization: 0.002748580775769094
# PageRank Centralization: 0.010279770526470021
# Average Clustering Coefficient: 0.4290175964984149
# Transitivity: 0.4423162583518931
# Betweenness Centralization: 0.0014548378299896747
# PageRank Centralization: 0.007860471802886196
# Average Clustering Coefficient: 0.4967037934872027
# Transitivity: 0.5266781411359724
# Betweenness Centralization: 0.0015214000187080319
# PageRank Centralization: 0.007710659486328563
# Average Clustering Coefficient: 0.5396897344021344
# Transitivity: 0.5660377358490566
# Betweenness Centralization: 0.003143181177377644
# PageRank Centralization: 0.007776016187272174
# Average Clustering Coefficient: 0.48636614360298563
# Transitivity: 0.5793103448275863
# Betweenness Centralization: 0.001153929854321324
# PageRank Centralization: 0.007678637189075843
# Average Clustering Coefficient: 0.5015672207871695
# Transitivity: 0.5571955719557196
# Betweenness Centralization: 0.001221193688232065
# PageRank Centralization: 0.008166432544445651
# Average Clustering Coefficient: 0.5506971290159608
# Transitivity: 0.5129310344827587
# Betweenness Centralization: 0.0020882242291116724
# PageRank Centralization: 0.008645815469638864
# Average Clustering Coefficient: 0.45140015929489596
# Transitivity: 0.49372862029646525
# Betweenness Centralization: 0.001441315237227554
# PageRank Centralization: 0.007015291444377978
# Average Clustering Coefficient: 0.4846807594532319
# Transitivity: 0.5687782805429864
# Betweenness Centralization: 0.0011691560433981412
# PageRank Centralization: 0.005501557396257284
# Average Clustering Coefficient: 0.5265996680803985
# Transitivity: 0.5482584011048028
# Betweenness Centralization: 0.0015978478527442737
# PageRank Centralization: 0.006437581375896987
# Average Clustering Coefficient: 0.5291891680523312
# Transitivity: 0.5464116511668714
# Betweenness Centralization: 0.0031392408736351674
# PageRank Centralization: 0.007907535709188597
# Average Clustering Coefficient: 0.5527940501522868
# Transitivity: 0.6205957137667999
# Betweenness Centralization: 0.0030631534962912714
# PageRank Centralization: 0.010736461102019531
# Average Clustering Coefficient: 0.3920474262579527
# Transitivity: 0.4397208121827411
# Betweenness Centralization: 0.0009772104452371493
# PageRank Centralization: 0.006118050446914107
# Average Clustering Coefficient: 0.5057515701677182
# Transitivity: 0.5290716350787023
# Betweenness Centralization: 0.0012898084572926095
# PageRank Centralization: 0.007840890754945417
# Average Clustering Coefficient: 0.5133172439460469
# Transitivity: 0.6132524902555219
# Betweenness Centralization: 0.00216053812988188
# PageRank Centralization: 0.0060846604890118705
# Average Clustering Coefficient: 0.5699089229584147
# Transitivity: 0.6804396662387676
# Betweenness Centralization: 0.0017812404382816169
# PageRank Centralization: 0.006814403848246366
# Average Clustering Coefficient: 0.5131173733861358
# Transitivity: 0.5240506329113924
# Betweenness Centralization: 0.0013515191714167025
# PageRank Centralization: 0.008209275985484668
# Average Clustering Coefficient: 0.4346765013900563
# Transitivity: 0.5006002400960384
# Betweenness Centralization: 0.003811824067590862
# PageRank Centralization: 0.009298661760910537
# Average Clustering Coefficient: 0.5126262712176025
# Transitivity: 0.47168554297135246
# Betweenness Centralization: 0.0011323571048395132
# PageRank Centralization: 0.00628828329505326
# Average Clustering Coefficient: 0.5542531737416707
# Transitivity: 0.5345139139862667
# Betweenness Centralization: 0.0017621201573401362
# PageRank Centralization: 0.009032397258894022
# Average Clustering Coefficient: 0.5718327852769938
# Transitivity: 0.5432704727460604
# Betweenness Centralization: 0.0023363595266365717
# PageRank Centralization: 0.007665048719632586
# Average Clustering Coefficient: 0.46182321798231324
# Transitivity: 0.5512680877547845
# Betweenness Centralization: 0.0015700247928315527
# PageRank Centralization: 0.0077926085572050515
# Average Clustering Coefficient: 0.3573371582545893
# Transitivity: 0.43322475570032576
# Betweenness Centralization: 0.002434454399202533
# PageRank Centralization: 0.008529603066524408
# Average Clustering Coefficient: 0.5301029214286623
# Transitivity: 0.5759753593429158
# Betweenness Centralization: 0.0024933416232372396
# PageRank Centralization: 0.008590099911098378
# Average Clustering Coefficient: 0.40600776139569245
# Transitivity: 0.44933920704845814
# Betweenness Centralization: 0.0011111606346975663
# PageRank Centralization: 0.006743586904748618
# Average Clustering Coefficient: 0.5250153350972718
# Transitivity: 0.5010706638115632
# Betweenness Centralization: 0.0022971386716427746
# PageRank Centralization: 0.00785831916128399
# Average Clustering Coefficient: 0.48807007393198026
# Transitivity: 0.590213553051959
# Betweenness Centralization: 0.0015621700068080638
# PageRank Centralization: 0.007077184486270896
# Average Clustering Coefficient: 0.50714000656699
# Transitivity: 0.5173909115547927
# Betweenness Centralization: 0.0010266475764315632
# PageRank Centralization: 0.008085975708401704
# Average Clustering Coefficient: 0.44890245744374585
# Transitivity: 0.4336099585062241
# Betweenness Centralization: 0.0023702847918319627
# PageRank Centralization: 0.008772849376665646
# Average Clustering Coefficient: 0.4765489932590401
# Transitivity: 0.5311004784688995
# Betweenness Centralization: 0.0012890329150960882
# PageRank Centralization: 0.006995304847333998
# Average Clustering Coefficient: 0.5722466704351246
# Transitivity: 0.5542312276519666
# Betweenness Centralization: 0.003573158825440704
# PageRank Centralization: 0.008364980803509739
# Average Clustering Coefficient: 0.4575601601463671
# Transitivity: 0.5011363636363636
# Betweenness Centralization: 0.0011457204501199283
# PageRank Centralization: 0.004794527341233725
# Average Clustering Coefficient: 0.6362094317139193
# Transitivity: 0.6390611902766136
# Betweenness Centralization: 0.0015200004379776683
# PageRank Centralization: 0.006470081241039484
# Average Clustering Coefficient: 0.6031669755427123
# Transitivity: 0.6513464526152253
# Betweenness Centralization: 0.0018130422210154533
# PageRank Centralization: 0.005157848707737996
# Average Clustering Coefficient: 0.5149069321483113
# Transitivity: 0.5604558969276512
# Betweenness Centralization: 0.0006455590906807535
# PageRank Centralization: 0.00616522977321775
# Average Clustering Coefficient: 0.4781515197997262
# Transitivity: 0.5141950273320403
# Betweenness Centralization: 0.0018203673654359255
# PageRank Centralization: 0.007147031697340111
# Average Clustering Coefficient: 0.4969713912411682
# Transitivity: 0.4693569270608546
# Betweenness Centralization: 0.0016494146200354827
# PageRank Centralization: 0.007833006151079805
# Average Clustering Coefficient: 0.5417520622019766
# Transitivity: 0.5177895533686601
# Betweenness Centralization: 0.0016024607162301034
# PageRank Centralization: 0.008011892746391053
# Average Clustering Coefficient: 0.5318215059884442
# Transitivity: 0.512705798138869
# Betweenness Centralization: 0.001162148076923222
# PageRank Centralization: 0.007145103237351428
# Average Clustering Coefficient: 0.4802668943869435
# Transitivity: 0.5367577756833176
# Betweenness Centralization: 0.001507008183020808
# PageRank Centralization: 0.006051570403263156
# Average Clustering Coefficient: 0.4559481711958492
# Transitivity: 0.5163934426229508
# Betweenness Centralization: 0.0028220548001398537
# PageRank Centralization: 0.007251997101123163
# Average Clustering Coefficient: 0.5290627113062257
# Transitivity: 0.5658969804618117
# Betweenness Centralization: 0.0020437058943104
# PageRank Centralization: 0.0066047577179911155
# Average Clustering Coefficient: 0.5180208440984303
# Transitivity: 0.49273643640675957
# Betweenness Centralization: 0.0009527631168796904
# PageRank Centralization: 0.007098011572520999
# Average Clustering Coefficient: 0.5190386422927813
# Transitivity: 0.5018157058556514
# Betweenness Centralization: 0.001966862419542267
# PageRank Centralization: 0.007705484599457182
# Average Clustering Coefficient: 0.4976823228371217
# Transitivity: 0.5850033776176536
# Betweenness Centralization: 0.001298148636408867
# PageRank Centralization: 0.008560510742852688
# Average Clustering Coefficient: 0.4393253705657798
# Transitivity: 0.4146624166908143
# Betweenness Centralization: 0.001604053463532585
# PageRank Centralization: 0.007527477090243623
# Average Clustering Coefficient: 0.5977276248378647
# Transitivity: 0.5821350762527233
# Betweenness Centralization: 0.0011947798067503915
# PageRank Centralization: 0.007606160648010181
# Average Clustering Coefficient: 0.5260312403380109
# Transitivity: 0.5004228329809726
# Betweenness Centralization: 0.002854595610890828
# PageRank Centralization: 0.007871958804545586
# Average Clustering Coefficient: 0.43918390637140625
# Transitivity: 0.49222065063649223
# Betweenness Centralization: 0.0017413535128554935
# PageRank Centralization: 0.008148323889779572
# Average Clustering Coefficient: 0.5292778133160421
# Transitivity: 0.5435667752442996
# Betweenness Centralization: 0.001500738689379352
# PageRank Centralization: 0.008590657500967065
# Average Clustering Coefficient: 0.4957071937454908
# Transitivity: 0.5464426877470355
# Betweenness Centralization: 0.0007006051200786407
# PageRank Centralization: 0.007458282429241628
# Average Clustering Coefficient: 0.5616077681805994
# Transitivity: 0.6061326360827193
# Betweenness Centralization: 0.0026838857131962534
# PageRank Centralization: 0.0074553747312953045
# Average Clustering Coefficient: 0.5222419000504998
# Transitivity: 0.6353965183752418
# Betweenness Centralization: 0.0008885560693531453
# PageRank Centralization: 0.006390516987815024
# Average Clustering Coefficient: 0.44486447742025864
# Transitivity: 0.4658808933002481
# Betweenness Centralization: 0.001350455905267542
# PageRank Centralization: 0.007120624211246619
# Average Clustering Coefficient: 0.5199647425606505
# Transitivity: 0.5037280047718461
# Betweenness Centralization: 0.0016558614866047582
# PageRank Centralization: 0.0075324686182682565
# Average Clustering Coefficient: 0.5356358279113234
# Transitivity: 0.530655672296848
# Betweenness Centralization: 0.0013609969374986436
# PageRank Centralization: 0.005298458134532398
# Average Clustering Coefficient: 0.4717678000385914
# Transitivity: 0.5491785790484318
# Betweenness Centralization: 0.0017638420293392158
# PageRank Centralization: 0.00896628963219809
# Average Clustering Coefficient: 0.5309644885943329
# Transitivity: 0.5893613682723992
# Betweenness Centralization: 0.002159127147156991
# PageRank Centralization: 0.00788878330788602
# Average Clustering Coefficient: 0.457207558523348
# Transitivity: 0.5134498991257566
# Betweenness Centralization: 0.001259092922296655
# PageRank Centralization: 0.008819357092285875
# Average Clustering Coefficient: 0.5224649204138365
# Transitivity: 0.5404442007129148
# Betweenness Centralization: 0.0021680685711685534
# PageRank Centralization: 0.007098025301425343
# Average Clustering Coefficient: 0.4940970898147979
# Transitivity: 0.5132864735127721
# Betweenness Centralization: 0.0011425877608591125
# PageRank Centralization: 0.006054275669992906
# Average Clustering Coefficient: 0.6013013538008201
# Transitivity: 0.5637149028077754
# Betweenness Centralization: 0.001481195264687537
# PageRank Centralization: 0.010704209857868656
# Average Clustering Coefficient: 0.4425980590794566
# Transitivity: 0.4263565891472868
# Betweenness Centralization: 0.0013323042238327677
# PageRank Centralization: 0.010173235103462118
# Average Clustering Coefficient: 0.543104304395795
# Transitivity: 0.5146116893514812
# Betweenness Centralization: 0.003305880165709943
# PageRank Centralization: 0.008895094701349577
# Average Clustering Coefficient: 0.5305824847335355
# Transitivity: 0.583351684650958
# Betweenness Centralization: 0.0018454241711567442
# PageRank Centralization: 0.0087696937304058
# Average Clustering Coefficient: 0.47484497127192227
# Transitivity: 0.5263157894736842
# Betweenness Centralization: 0.008045880667737556
# PageRank Centralization: 0.007216069057496165
# Average Clustering Coefficient: 0.5234907422960517
# Transitivity: 0.6134105960264901
# Betweenness Centralization: 0.001893618417326343
# PageRank Centralization: 0.008018709148418216
# Average Clustering Coefficient: 0.4879158738291863
# Transitivity: 0.5491638795986622
# Betweenness Centralization: 0.002195513722451707
# PageRank Centralization: 0.007662131175655396
# Average Clustering Coefficient: 0.4610381207456325
# Transitivity: 0.467201166180758
# Betweenness Centralization: 0.00042250811606735293
# PageRank Centralization: 0.005919834156852832
# Average Clustering Coefficient: 0.46059438312360795
# ...
# Betweenness Centralization: 0.001368288868245678
# PageRank Centralization: 0.007824864412042835
# Average Clustering Coefficient: 0.49649760657971725
# Transitivity: 0.5257120253164557
# Betweenness Centralization: 0.0010090557239000105
# PageRank Centralization: 0.006049294042805697
# Average Clustering Coefficient: 0.5585069378346192
# Transitivity: 0.6115193826933676
# Betweenness Centralization: 0.0010987976589941334
# PageRank Centralization: 0.007760769516586535
# Average Clustering Coefficient: 0.49927449719538997
# Transitivity: 0.5106215578284815
# Betweenness Centralization: 0.0018148715820867024
# PageRank Centralization: 0.006577119086106093
# Average Clustering Coefficient: 0.522827808735737
# Transitivity: 0.5561152528712472
# Betweenness Centralization: 0.0043869326505629564
# PageRank Centralization: 0.010001204782289113
# Average Clustering Coefficient: 0.5832852071127747
# Transitivity: 0.6353080102342059
# Betweenness Centralization: 0.0011765906220133967
# PageRank Centralization: 0.010977766138834798
# Average Clustering Coefficient: 0.42001319271207554
# Transitivity: 0.47163695299837927
# Betweenness Centralization: 0.0005063694783259407
# PageRank Centralization: 0.005676306330661271
# Average Clustering Coefficient: 0.5310075845409725
# Transitivity: 0.5486468351599195
# Betweenness Centralization: 0.002022639899138072
# PageRank Centralization: 0.006536693489958508
# Average Clustering Coefficient: 0.5938452588412995
# Transitivity: 0.6086800830767027
# Betweenness Centralization: 0.0014380404454004349
# PageRank Centralization: 0.006873260934648456
# Average Clustering Coefficient: 0.43978027939664766
# Transitivity: 0.5332518337408313
# Betweenness Centralization: 0.0016356601709099923
# PageRank Centralization: 0.008897534207293754
# Average Clustering Coefficient: 0.502264513875791
# Transitivity: 0.47616936377743296
# Betweenness Centralization: 0.002818876537578845
# PageRank Centralization: 0.007041820883552073
# Average Clustering Coefficient: 0.5104067866998903
# Transitivity: 0.5430338891877353
# Betweenness Centralization: 0.001159043135332093
# PageRank Centralization: 0.005705430755533083
# Average Clustering Coefficient: 0.5392670119757231
# Transitivity: 0.5356685177274669
# Betweenness Centralization: 0.0010906266865349484
# PageRank Centralization: 0.008552307621720046
# Average Clustering Coefficient: 0.436434969295677
# Transitivity: 0.43027591349739003
# Betweenness Centralization: 0.004214605853583735
# PageRank Centralization: 0.007288122008270084
# Average Clustering Coefficient: 0.5824712944297773
# Transitivity: 0.6308106429236982
# Betweenness Centralization: 0.0024188167081628416
# PageRank Centralization: 0.009030570611413893
# Average Clustering Coefficient: 0.4941616170132794
# Transitivity: 0.5387669313404951
# Betweenness Centralization: 0.0014925278590534536
# PageRank Centralization: 0.007488208498517584
# Average Clustering Coefficient: 0.5797758779096187
# Transitivity: 0.5682982859162397
# Betweenness Centralization: 0.0035348770237191057
# PageRank Centralization: 0.009899469183186222
# Average Clustering Coefficient: 0.4932012255741837
# Transitivity: 0.5824742268041238
# Betweenness Centralization: 0.0012505366541302552
# PageRank Centralization: 0.007080224445317922
# Average Clustering Coefficient: 0.5254483752135083
# Transitivity: 0.51374321880651
# Betweenness Centralization: 0.001082895198748761
# PageRank Centralization: 0.006859545049631722
# Average Clustering Coefficient: 0.5573959108277122
# Transitivity: 0.5938706420383679
# Betweenness Centralization: 0.0033107100892118164
# PageRank Centralization: 0.010806926739990456
# Average Clustering Coefficient: 0.3859810384537089
# Transitivity: 0.5359712230215827
# Betweenness Centralization: 0.0011954810698081785
# PageRank Centralization: 0.005420051999219024
# Average Clustering Coefficient: 0.592960868550589
# Transitivity: 0.6021474992935858
# Betweenness Centralization: 0.0016081518305997807
# PageRank Centralization: 0.0097720479179581
# Average Clustering Coefficient: 0.4710362912949117
# Transitivity: 0.4735526863806747
# Betweenness Centralization: 0.0018474225581455446
# PageRank Centralization: 0.0075084404020218385
# Average Clustering Coefficient: 0.59268134628322
# Transitivity: 0.6229967499719825
# Betweenness Centralization: 0.0009277442693949849
# PageRank Centralization: 0.008277928200828545
# Average Clustering Coefficient: 0.5172447826474798
# Transitivity: 0.4982226645812598
# Betweenness Centralization: 0.0016744766051800814
# PageRank Centralization: 0.009399014563006399
# Average Clustering Coefficient: 0.49684350252608495
# Transitivity: 0.511906567571667
# Betweenness Centralization: 0.0013926762390349592
# PageRank Centralization: 0.007340749649648025
# Average Clustering Coefficient: 0.5128385024936748
# Transitivity: 0.4489655172413793
# Betweenness Centralization: 0.0006799039276700234
# PageRank Centralization: 0.006474061281667495
# Average Clustering Coefficient: 0.49255438959519754
# Transitivity: 0.5012634238787113
# Betweenness Centralization: 0.0015561502141005696
# PageRank Centralization: 0.006688794893732017
# Average Clustering Coefficient: 0.4774687787845681
# Transitivity: 0.5342333654773385
# Betweenness Centralization: 0.000920246019919985
# PageRank Centralization: 0.007137027066269486
# Average Clustering Coefficient: 0.4236759828865094
# Transitivity: 0.4537712895377129
# Betweenness Centralization: 0.0032111819976511557
# PageRank Centralization: 0.008024469452058484
# Average Clustering Coefficient: 0.5751223655648765
# Transitivity: 0.6681514476614699
# Betweenness Centralization: 0.001998415060185339
# PageRank Centralization: 0.006564108476343633
# Average Clustering Coefficient: 0.5724340575346913
# Transitivity: 0.5815868263473054
# Betweenness Centralization: 0.0012174386541165428
# PageRank Centralization: 0.007870314130720545
# Average Clustering Coefficient: 0.48094036764450016
# Transitivity: 0.4541577825159915
# Betweenness Centralization: 0.0012743803963423932
# PageRank Centralization: 0.008997779673872948
# Average Clustering Coefficient: 0.48689367802069505
# Transitivity: 0.4842068726136758
# Betweenness Centralization: 0.0005901813317861272
# PageRank Centralization: 0.006988674819371332
# Average Clustering Coefficient: 0.49644265357623196
# Transitivity: 0.4910048266783677
# Betweenness Centralization: 0.0026374285393526626
# PageRank Centralization: 0.009567750387003478
# Average Clustering Coefficient: 0.5535499381707157
# Transitivity: 0.5973810957254666
# Betweenness Centralization: 0.0019994594012894286
# PageRank Centralization: 0.005633194966798594
# Average Clustering Coefficient: 0.5458226581453128
# Transitivity: 0.5148710166919576
# Betweenness Centralization: 0.0016913317496088157
# PageRank Centralization: 0.009045067827381462
# Average Clustering Coefficient: 0.4617912917835516
# Transitivity: 0.5106719367588933
# Betweenness Centralization: 0.0018308318365871088
# PageRank Centralization: 0.006910674668422935
# Average Clustering Coefficient: 0.5660386328861576
# Transitivity: 0.5844768439108061
# Betweenness Centralization: 0.0022628349137667147
# PageRank Centralization: 0.007688593611046329
# Average Clustering Coefficient: 0.5575585089056585
# Transitivity: 0.6214689265536724
# Betweenness Centralization: 0.003389129208216121
# PageRank Centralization: 0.008412183211752756
# Average Clustering Coefficient: 0.5481894148222749
# Transitivity: 0.5969101123595506
# Betweenness Centralization: 0.0011346903577437672
# PageRank Centralization: 0.007168492553035721
# Average Clustering Coefficient: 0.49236058718750597
# Transitivity: 0.5408965135583841
# Betweenness Centralization: 0.0009563654728319378
# PageRank Centralization: 0.0075924337189224
# Average Clustering Coefficient: 0.4154811424207975
# Transitivity: 0.4195906432748538
# Betweenness Centralization: 0.0016058599861877843
# PageRank Centralization: 0.008511570236235994
# Average Clustering Coefficient: 0.4744873443075907
# Transitivity: 0.5081547064305685
# Betweenness Centralization: 0.0008557440197377516
# PageRank Centralization: 0.00639441877428565
# Average Clustering Coefficient: 0.5589018421446118
# Transitivity: 0.59128393808678
# Betweenness Centralization: 0.0016606177264180816
# PageRank Centralization: 0.007468914237077634
# Average Clustering Coefficient: 0.45159622324936727
# Transitivity: 0.47372549019607846
# Betweenness Centralization: 0.0008042423075156059
# PageRank Centralization: 0.005913116696058833
# Average Clustering Coefficient: 0.5422117094858762
# Transitivity: 0.5972599358183165
# Betweenness Centralization: 0.0017784071126918848
# PageRank Centralization: 0.007804855993069516
# Average Clustering Coefficient: 0.449705492276486
# Transitivity: 0.48263642806520196
# Betweenness Centralization: 0.0008508439151856538
# PageRank Centralization: 0.0056940820897897265
# Average Clustering Coefficient: 0.5048277404955105
# Transitivity: 0.4743935309973046
# Betweenness Centralization: 0.0013019566071910459
# PageRank Centralization: 0.006317717082260149
# Average Clustering Coefficient: 0.49219738542894265
# Transitivity: 0.5394524959742351
# Betweenness Centralization: 0.0017414879436683992
# PageRank Centralization: 0.00675757177336518
# Average Clustering Coefficient: 0.5197487856970617
# Transitivity: 0.5186953062848051
# Betweenness Centralization: 0.0012793608560862518
# PageRank Centralization: 0.007388528275369631
# Average Clustering Coefficient: 0.5004140392571854
# Transitivity: 0.5232488525244462
# Betweenness Centralization: 0.0015305239263019483
# PageRank Centralization: 0.008856395193842024
# Average Clustering Coefficient: 0.46981861417922804
# Transitivity: 0.4643510054844607
# Betweenness Centralization: 0.0012252567342990277
# PageRank Centralization: 0.0067757939997324925
# Average Clustering Coefficient: 0.4360655669990709
# Transitivity: 0.471326552694222
# Betweenness Centralization: 0.0015329826559174562
# PageRank Centralization: 0.007640800295271964
# Average Clustering Coefficient: 0.5185033574452543
# Transitivity: 0.5070185289163391
# Betweenness Centralization: 0.0018789686766659374
# PageRank Centralization: 0.006120061804078178
# Average Clustering Coefficient: 0.5355409907204286
# Transitivity: 0.5905868680999419
# Betweenness Centralization: 0.0022958861888146315
# PageRank Centralization: 0.007041441613069971
# Average Clustering Coefficient: 0.4206964012998496
# Transitivity: 0.4206103494029191
# Betweenness Centralization: 0.001989396673659014
# PageRank Centralization: 0.006890261737348976
# Average Clustering Coefficient: 0.5705376995539835
# Transitivity: 0.6238923163208077
# Betweenness Centralization: 0.002751796785496164
# PageRank Centralization: 0.0074519069506736365
# Average Clustering Coefficient: 0.5538555953551242
# Transitivity: 0.5599721059972106
# Betweenness Centralization: 0.0013839476940816192
# PageRank Centralization: 0.008895664780037858
# Average Clustering Coefficient: 0.47983624728369734
# Transitivity: 0.5060858424087123
# Betweenness Centralization: 0.0038893200685687166
# PageRank Centralization: 0.010710864793809944
# Average Clustering Coefficient: 0.5505831338945831
# Transitivity: 0.5780553077609277
# Betweenness Centralization: 0.0008232270757044208
# PageRank Centralization: 0.007341579770319
# Average Clustering Coefficient: 0.5297192186673949
# Transitivity: 0.558295174357168
# Betweenness Centralization: 0.0017151449736280723
# PageRank Centralization: 0.006859520328812198
# Average Clustering Coefficient: 0.5361646875211781
# Transitivity: 0.5593725178713265
# Betweenness Centralization: 0.0012157077342301
# PageRank Centralization: 0.005366561754290895
# Average Clustering Coefficient: 0.5884149477207
# Transitivity: 0.6186310517529215
# Betweenness Centralization: 0.0026815434848760744
# PageRank Centralization: 0.009789066107112858
# Average Clustering Coefficient: 0.5339011317802554
# Transitivity: 0.529208491031759
# Betweenness Centralization: 0.0007883370552727922
# PageRank Centralization: 0.0067360511792551574
# Average Clustering Coefficient: 0.516700753886922
# Transitivity: 0.5720985929547949
# Betweenness Centralization: 0.002866286634794013
# PageRank Centralization: 0.00809333502686546
# Average Clustering Coefficient: 0.39091985309376615
# Transitivity: 0.4802158273381295
# Betweenness Centralization: 0.0007067054723414808
# PageRank Centralization: 0.007215436032967322
# Average Clustering Coefficient: 0.5120177810619917
# Transitivity: 0.5181712739222888
# Betweenness Centralization: 0.0015199997912894066
# PageRank Centralization: 0.011689083730036763
# Average Clustering Coefficient: 0.4148640387175605
# Transitivity: 0.4809736989367655
# Betweenness Centralization: 0.0015373918807877972
# PageRank Centralization: 0.007514299614117607
# Average Clustering Coefficient: 0.4904389813085465
# Transitivity: 0.5466143277723258
# Betweenness Centralization: 0.001379803071994924
# PageRank Centralization: 0.00747576372212389
# Average Clustering Coefficient: 0.5406764590907814
# Transitivity: 0.5833006664053313
# Betweenness Centralization: 0.0016763205637386007
# PageRank Centralization: 0.0062484435946763
# Average Clustering Coefficient: 0.5694145780650612
# Transitivity: 0.5491018749180543
# Betweenness Centralization: 0.0018171985962561598
# PageRank Centralization: 0.0085392387632996
# Average Clustering Coefficient: 0.5282837779124754
# Transitivity: 0.5682704811443433
# Betweenness Centralization: 0.0007339457570283665
# PageRank Centralization: 0.008268328889815407
# Average Clustering Coefficient: 0.4686917150913093
# Transitivity: 0.48092423428264375
# Betweenness Centralization: 0.0011947951888648532
# PageRank Centralization: 0.008639424480261301
# Average Clustering Coefficient: 0.4267842139015917
# Transitivity: 0.4572624028690974
# Betweenness Centralization: 0.0025580604590133187
# PageRank Centralization: 0.009547979853420206
# Average Clustering Coefficient: 0.5487056963037141
# Transitivity: 0.6088919172131846
# Betweenness Centralization: 0.0028638388936855883
# PageRank Centralization: 0.007123266485156496
# Average Clustering Coefficient: 0.5374166896653099
# Transitivity: 0.6193970646568822
# Betweenness Centralization: 0.0011943923875153927
# PageRank Centralization: 0.005672327524391137
# Average Clustering Coefficient: 0.5681367586039572
# Transitivity: 0.5965367965367966
# Betweenness Centralization: 0.001597801867580839
# PageRank Centralization: 0.005524325943836689
# Average Clustering Coefficient: 0.5425678981433456
# Transitivity: 0.5743884173739391
# Betweenness Centralization: 0.0011560968194454274
# PageRank Centralization: 0.005902390891429254
# Average Clustering Coefficient: 0.605883197270236
# Transitivity: 0.6048053567911771
# Betweenness Centralization: 0.0037638995157002783
# PageRank Centralization: 0.006398617367736194
# Average Clustering Coefficient: 0.4300144300144299
# Transitivity: 0.4833091436865022
# Betweenness Centralization: 0.004095408194763946
# PageRank Centralization: 0.008302741992341827
# Average Clustering Coefficient: 0.5109552817590343
# Transitivity: 0.5154929577464789
# Betweenness Centralization: 0.0009732247694446972
# PageRank Centralization: 0.007811711634593827
# Average Clustering Coefficient: 0.4350316350316349
# Transitivity: 0.5028169014084507
# Betweenness Centralization: 0.004488191262294363
# PageRank Centralization: 0.011025346793657588
# Average Clustering Coefficient: 0.4884424328158343
# Transitivity: 0.5610047846889952
# Betweenness Centralization: 0.0037678341703052025
# PageRank Centralization: 0.0066976796834489856
# Average Clustering Coefficient: 0.48873525899387965
# Transitivity: 0.5137211855104281
# Betweenness Centralization: 0.001189110027504226
# PageRank Centralization: 0.009151591218318399
# Average Clustering Coefficient: 0.47315222927927514
# Transitivity: 0.5149779735682819
# Betweenness Centralization: 0.000718772363680482
# PageRank Centralization: 0.00763765570350702
# Average Clustering Coefficient: 0.5431172342392758
# Transitivity: 0.5555555555555556
# Betweenness Centralization: 0.0028123903278336414
# PageRank Centralization: 0.008615573807826488
# Average Clustering Coefficient: 0.48920302145454253
# Transitivity: 0.6047465572809845
# Betweenness Centralization: 0.001455691864512744
# PageRank Centralization: 0.009029668388684069
# Average Clustering Coefficient: 0.4494925206639202
# Transitivity: 0.484201537147737
# Betweenness Centralization: 0.001265292163572899
# PageRank Centralization: 0.005900142015885802
# Average Clustering Coefficient: 0.5035507621033937
# Transitivity: 0.476687543493389

# %%
import pickle as pkl
#load the properties
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "rb") as f:
    train_properties_long = pkl.load(f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "rb") as f:
    test_properties_long = pkl.load(f)

# %%
#print the names of the properties
# print(train_properties_long[0].keys())

#print the first element of the properties
# print(train_properties_long[0])

#copare train_properties and train_properties_long
# print(train_properties[0])
print(train_properties_long[0])
print(len(train_properties_long))
# Out:
# (116, 717, 0.10749625187406296, 2.6724137931034484, 5, 4, 0.5179222969842621, 0.5032389055399787, 0.3963636188813396, 263, 1735.0, 6.64946643069199, 116, 12.362068965517242, 0.014670296430732001, 19.012397668010436, -4.8477452060801, 1434.0000000000016, 3.8189481561413796, 0.001086061741981193, 0.009889108225082894, 0.5179222969842621, 1.0011815259942418)
# 1044

# %% [markdown]
# ### Diagnostic classifier

# %%
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']
train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
#create a dictionary where we will store the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    # Flatten the embeddings before determining the input size
    train_embedding_flat = train_embedding.view(train_embedding.size(0), -1)
    test_embedding_flat = test_embedding.view(test_embedding.size(0), -1)
    #print the shapes
    print(train_embedding_flat.shape)
    print(test_embedding_flat.shape)
    input_size = train_embedding_flat.shape[1]

    for i, property_name in enumerate(property_names_long):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 2000000  # Maximum number of epochs
        min_epochs = 1000  # Minimum number of epochs
        patience = 3000  # Number of epochs to wait for improvement
        tolerance = 1e-6  # Tolerance for considering the loss as stable

        best_loss = float('inf')
        no_improve_count = 0
        
        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding_flat).squeeze()
            target = train_y_long[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Print every 1000 epochs
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

            # Check for early stopping, but only after minimum epochs
            if epoch >= min_epochs:
                if loss.item() < best_loss - tolerance:
                    best_loss = loss.item()
                    no_improve_count = 0
                else:
                    no_improve_count += 1

                if no_improve_count >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding_flat).squeeze().cpu().numpy()
            test_pred = model(test_embedding_flat).squeeze().cpu().numpy()

            train_target = train_y_long[:, i].cpu().numpy()
            test_target = test_y_long[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embedding = embeddings_names[ii]
            results[(name_of_embedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1


#save results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long_full_embedding.pkl", "wb") as f:
    pkl.dump(results, f)
# Out:
# /scratch-local/tpelletreaudur.7651293/ipykernel_3546827/225588825.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#   train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
# /scratch-local/tpelletreaudur.7651293/ipykernel_3546827/225588825.py:3: ComplexWarning: Casting complex values to real discards the imaginary part
#   test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/2000000], Property: num_nodes, Loss: 1.4909
# Epoch [2000/2000000], Property: num_nodes, Loss: 0.0575
# Epoch [3000/2000000], Property: num_nodes, Loss: 0.0008
# Epoch [4000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/2000000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7300
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 38.9838
#   Train R²: 1.0000, Test R²: -43.2665
# Epoch [1000/2000000], Property: num_edges, Loss: 1549.0776
# Epoch [2000/2000000], Property: num_edges, Loss: 581.8322
# Epoch [3000/2000000], Property: num_edges, Loss: 230.2829
# Epoch [4000/2000000], Property: num_edges, Loss: 75.5839
# Epoch [5000/2000000], Property: num_edges, Loss: 17.5902
# Epoch [6000/2000000], Property: num_edges, Loss: 2.3508
# Epoch [7000/2000000], Property: num_edges, Loss: 0.1303
# Epoch [8000/2000000], Property: num_edges, Loss: 0.0025
# Epoch [9000/2000000], Property: num_edges, Loss: 0.0001
# Epoch [10000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [11000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [12000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [13000/2000000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 13674
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 1842.3923
#   Train R²: 1.0000, Test R²: 0.8972
# Epoch [1000/2000000], Property: density, Loss: 0.0000
# Epoch [2000/2000000], Property: density, Loss: 0.0000
# Epoch [3000/2000000], Property: density, Loss: 0.0000
# Epoch [4000/2000000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1083
#   Train R²: 1.0000, Test R²: -269.4121
# Epoch [1000/2000000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_path_len, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.2351
#   Train R²: 1.0000, Test R²: 0.2057
# Epoch [1000/2000000], Property: diameter, Loss: 0.0000
# Epoch [2000/2000000], Property: diameter, Loss: 0.0000
# Epoch [3000/2000000], Property: diameter, Loss: 0.0000
# Epoch [4000/2000000], Property: diameter, Loss: 0.0011
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: diameter
#   Train MSE: 0.0014, Test MSE: 3.3271
#   Train R²: 0.9995, Test R²: 0.1291
# Epoch [1000/2000000], Property: radius, Loss: 0.0000
# Epoch [2000/2000000], Property: radius, Loss: 0.0000
# Epoch [3000/2000000], Property: radius, Loss: 0.0000
# Epoch [4000/2000000], Property: radius, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: radius
#   Train MSE: 0.0000, Test MSE: 0.5746
#   Train R²: 1.0000, Test R²: 0.0685
# Epoch [1000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [2000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [3000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [4000/2000000], Property: clustering_coeff, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: clustering_coeff
#   Train MSE: 0.0000, Test MSE: 0.1101
#   Train R²: 1.0000, Test R²: -43.1337
# Epoch [1000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [2000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [3000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [4000/2000000], Property: transitivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: transitivity
#   Train MSE: 0.0000, Test MSE: 0.0844
#   Train R²: 1.0000, Test R²: -28.8615
# Epoch [1000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [2000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [3000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [4000/2000000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1009
#   Train R²: 1.0000, Test R²: -8.9155
# Epoch [1000/2000000], Property: num_cliques, Loss: 62.6335
# Epoch [2000/2000000], Property: num_cliques, Loss: 6.3713
# Epoch [3000/2000000], Property: num_cliques, Loss: 0.3911
# Epoch [4000/2000000], Property: num_cliques, Loss: 0.0089
# Epoch [5000/2000000], Property: num_cliques, Loss: 0.0001
# Epoch [6000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [8000/2000000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 8880
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 373.1369
#   Train R²: 1.0000, Test R²: 0.5137
# Epoch [1000/2000000], Property: num_triangles, Loss: 138323.2500
# Epoch [2000/2000000], Property: num_triangles, Loss: 56317.4258
# Epoch [3000/2000000], Property: num_triangles, Loss: 33404.7344
# Epoch [4000/2000000], Property: num_triangles, Loss: 20507.6230
# Epoch [5000/2000000], Property: num_triangles, Loss: 11613.1064
# Epoch [6000/2000000], Property: num_triangles, Loss: 5716.2856
# Epoch [7000/2000000], Property: num_triangles, Loss: 2276.1340
# Epoch [8000/2000000], Property: num_triangles, Loss: 651.6770
# Epoch [9000/2000000], Property: num_triangles, Loss: 111.1226
# Epoch [10000/2000000], Property: num_triangles, Loss: 8.8611
# Epoch [11000/2000000], Property: num_triangles, Loss: 0.3817
# Epoch [12000/2000000], Property: num_triangles, Loss: 0.0174
# Epoch [13000/2000000], Property: num_triangles, Loss: 0.0003
# Epoch [14000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [17000/2000000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 17015
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 55246.9414
#   Train R²: 1.0000, Test R²: 0.8751
# Epoch [1000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [2000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [3000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [4000/2000000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 0.6803
#   Train R²: 1.0000, Test R²: 0.5393
# Epoch [1000/2000000], Property: largest_component_size, Loss: 1.6696
# Epoch [2000/2000000], Property: largest_component_size, Loss: 0.0703
# Epoch [3000/2000000], Property: largest_component_size, Loss: 0.0010
# Epoch [4000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [5000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [6000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [7000/2000000], Property: largest_component_size, Loss: 0.0000
# Early stopping at epoch 7133
# Embedding: torch.Size([1044, 116, 128])
# Property: largest_component_size
#   Train MSE: 0.0000, Test MSE: 45.3645
#   Train R²: 1.0000, Test R²: -14.0568
# Epoch [1000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_degree, Loss: 0.0030
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_degree
#   Train MSE: 0.0019, Test MSE: 0.7706
#   Train R²: 0.9997, Test R²: 0.8548
# Epoch [1000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_betweenness_centrality
#   Train MSE: 0.0000, Test MSE: 0.1233
#   Train R²: 1.0000, Test R²: -6142.3750
# Epoch [1000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [2000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [3000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [4000/2000000], Property: spectral_radius, Loss: 0.0000
# Early stopping at epoch 4219
# Embedding: torch.Size([1044, 116, 128])
# Property: spectral_radius
#   Train MSE: 0.0000, Test MSE: 2.8809
#   Train R²: 1.0000, Test R²: 0.7243
# Epoch [1000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [2000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [3000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [4000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: algebraic_connectivity
#   Train MSE: 0.0000, Test MSE: 0.2164
#   Train R²: 1.0000, Test R²: -0.7213
# Epoch [1000/2000000], Property: graph_energy, Loss: 14847.8252
# Epoch [2000/2000000], Property: graph_energy, Loss: 5630.5537
# Epoch [3000/2000000], Property: graph_energy, Loss: 2991.2954
# Epoch [4000/2000000], Property: graph_energy, Loss: 1580.7131
# Epoch [5000/2000000], Property: graph_energy, Loss: 742.5992
# Epoch [6000/2000000], Property: graph_energy, Loss: 282.3306
# Epoch [7000/2000000], Property: graph_energy, Loss: 77.1583
# Epoch [8000/2000000], Property: graph_energy, Loss: 12.6163
# Epoch [9000/2000000], Property: graph_energy, Loss: 0.9150
# Epoch [10000/2000000], Property: graph_energy, Loss: 0.0216
# Epoch [11000/2000000], Property: graph_energy, Loss: 0.0005
# Epoch [12000/2000000], Property: graph_energy, Loss: 0.0000
# Epoch [13000/2000000], Property: graph_energy, Loss: 0.0000
# Epoch [14000/2000000], Property: graph_energy, Loss: 0.0000
# Epoch [15000/2000000], Property: graph_energy, Loss: 0.0000
# Early stopping at epoch 15395
# Embedding: torch.Size([1044, 116, 128])
# Property: graph_energy
#   Train MSE: 0.0239, Test MSE: 7341.1572
#   Train R²: 1.0000, Test R²: 0.8976
# Epoch [1000/2000000], Property: small_world_coefficient, Loss: 0.0001
# Epoch [2000/2000000], Property: small_world_coefficient, Loss: 0.0001
# Epoch [3000/2000000], Property: small_world_coefficient, Loss: 0.0001
# Epoch [4000/2000000], Property: small_world_coefficient, Loss: 0.0001
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world_coefficient
#   Train MSE: 0.0001, Test MSE: 1.1449
#   Train R²: 0.9999, Test R²: -0.5187
# Epoch [1000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [2000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [3000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [4000/2000000], Property: betweenness_cent, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: betweenness_cent
#   Train MSE: 0.0000, Test MSE: 0.0809
#   Train R²: 1.0000, Test R²: -93009.2578
# Epoch [1000/2000000], Property: pagerank_cent, Loss: 0.0000
# Epoch [2000/2000000], Property: pagerank_cent, Loss: 0.0000
# Epoch [3000/2000000], Property: pagerank_cent, Loss: 4.3107
# Epoch [4000/2000000], Property: pagerank_cent, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: pagerank_cent
#   Train MSE: 0.0000, Test MSE: 0.0671
#   Train R²: 1.0000, Test R²: -33761.0430
# Epoch [1000/2000000], Property: avg_clustering, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_clustering, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_clustering, Loss: 0.0485
# Epoch [4000/2000000], Property: avg_clustering, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_clustering
#   Train MSE: 0.0000, Test MSE: 0.1006
#   Train R²: 1.0000, Test R²: -39.3045
# Epoch [1000/2000000], Property: small_world_index, Loss: 0.0000
# Epoch [2000/2000000], Property: small_world_index, Loss: 0.0000
# Epoch [3000/2000000], Property: small_world_index, Loss: 0.0002
# Epoch [4000/2000000], Property: small_world_index, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world_index
#   Train MSE: 0.0000, Test MSE: 0.1423
#   Train R²: 1.0000, Test R²: -9.7413
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/2000000], Property: num_nodes, Loss: 2.0375
# Epoch [2000/2000000], Property: num_nodes, Loss: 0.0590
# Epoch [3000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [4000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [5000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [6000/2000000], Property: num_nodes, Loss: 0.0000
# Epoch [7000/2000000], Property: num_nodes, Loss: 0.0000
# Early stopping at epoch 7506
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0000, Test MSE: 47.5952
#   Train R²: 1.0000, Test R²: -53.0448
# Epoch [1000/2000000], Property: num_edges, Loss: 3040.2051
# Epoch [2000/2000000], Property: num_edges, Loss: 1015.1707
# Epoch [3000/2000000], Property: num_edges, Loss: 349.1619
# Epoch [4000/2000000], Property: num_edges, Loss: 99.5172
# Epoch [5000/2000000], Property: num_edges, Loss: 19.3812
# Epoch [6000/2000000], Property: num_edges, Loss: 2.0433
# Epoch [7000/2000000], Property: num_edges, Loss: 0.1007
# Epoch [8000/2000000], Property: num_edges, Loss: 0.0056
# Epoch [9000/2000000], Property: num_edges, Loss: 0.0002
# Epoch [10000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [11000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [12000/2000000], Property: num_edges, Loss: 0.0000
# Epoch [13000/2000000], Property: num_edges, Loss: 0.0000
# Early stopping at epoch 13079
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 0.0000, Test MSE: 4166.4766
#   Train R²: 1.0000, Test R²: 0.7675
# Epoch [1000/2000000], Property: density, Loss: 0.0000
# Epoch [2000/2000000], Property: density, Loss: 0.0000
# Epoch [3000/2000000], Property: density, Loss: 0.0000
# Epoch [4000/2000000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1039
#   Train R²: 1.0000, Test R²: -258.5269
# Epoch [1000/2000000], Property: avg_path_len, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_path_len, Loss: 1.2410
# Epoch [3000/2000000], Property: avg_path_len, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_path_len, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0000, Test MSE: 0.2320
#   Train R²: 1.0000, Test R²: 0.2162
# Epoch [1000/2000000], Property: diameter, Loss: 0.0000
# Epoch [2000/2000000], Property: diameter, Loss: 0.0000
# Epoch [3000/2000000], Property: diameter, Loss: 0.0000
# Epoch [4000/2000000], Property: diameter, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: diameter
#   Train MSE: 0.0000, Test MSE: 2.9006
#   Train R²: 1.0000, Test R²: 0.2407
# Epoch [1000/2000000], Property: radius, Loss: 0.0000
# Epoch [2000/2000000], Property: radius, Loss: 0.0000
# Epoch [3000/2000000], Property: radius, Loss: 0.0000
# Epoch [4000/2000000], Property: radius, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: radius
#   Train MSE: 0.0000, Test MSE: 0.7878
#   Train R²: 1.0000, Test R²: -0.2771
# Epoch [1000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [2000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [3000/2000000], Property: clustering_coeff, Loss: 0.0005
# Epoch [4000/2000000], Property: clustering_coeff, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: clustering_coeff
#   Train MSE: 0.0000, Test MSE: 0.1013
#   Train R²: 1.0000, Test R²: -39.5805
# Epoch [1000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [2000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [3000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [4000/2000000], Property: transitivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: transitivity
#   Train MSE: 0.0000, Test MSE: 0.0983
#   Train R²: 1.0000, Test R²: -33.7777
# Epoch [1000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [2000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [3000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [4000/2000000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1617
#   Train R²: 1.0000, Test R²: -14.9001
# Epoch [1000/2000000], Property: num_cliques, Loss: 67.0142
# Epoch [2000/2000000], Property: num_cliques, Loss: 5.3848
# Epoch [3000/2000000], Property: num_cliques, Loss: 0.2176
# Epoch [4000/2000000], Property: num_cliques, Loss: 0.0030
# Epoch [5000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [6000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [7000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [8000/2000000], Property: num_cliques, Loss: 0.0000
# Epoch [9000/2000000], Property: num_cliques, Loss: 0.0000
# Early stopping at epoch 9114
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.0000, Test MSE: 563.2783
#   Train R²: 1.0000, Test R²: 0.2659
# Epoch [1000/2000000], Property: num_triangles, Loss: 139071.7656
# Epoch [2000/2000000], Property: num_triangles, Loss: 67086.7344
# Epoch [3000/2000000], Property: num_triangles, Loss: 39188.5703
# Epoch [4000/2000000], Property: num_triangles, Loss: 22489.7422
# Epoch [5000/2000000], Property: num_triangles, Loss: 11834.1768
# Epoch [6000/2000000], Property: num_triangles, Loss: 5363.5884
# Epoch [7000/2000000], Property: num_triangles, Loss: 1922.1890
# Epoch [8000/2000000], Property: num_triangles, Loss: 473.9846
# Epoch [9000/2000000], Property: num_triangles, Loss: 64.3183
# Epoch [10000/2000000], Property: num_triangles, Loss: 3.4701
# Epoch [11000/2000000], Property: num_triangles, Loss: 0.0653
# Epoch [12000/2000000], Property: num_triangles, Loss: 0.0010
# Epoch [13000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [14000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [15000/2000000], Property: num_triangles, Loss: 0.0000
# Epoch [16000/2000000], Property: num_triangles, Loss: 0.0000
# Early stopping at epoch 16365
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0000, Test MSE: 82134.4219
#   Train R²: 1.0000, Test R²: 0.8143
# Epoch [1000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [2000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [3000/2000000], Property: num_squares, Loss: 0.0000
# Epoch [4000/2000000], Property: num_squares, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0000, Test MSE: 0.6264
#   Train R²: 1.0000, Test R²: 0.5757
# Epoch [1000/2000000], Property: largest_component_size, Loss: 2.2705
# Epoch [2000/2000000], Property: largest_component_size, Loss: 0.0646
# Epoch [3000/2000000], Property: largest_component_size, Loss: 0.0006
# Epoch [4000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [5000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [6000/2000000], Property: largest_component_size, Loss: 0.0000
# Epoch [7000/2000000], Property: largest_component_size, Loss: 0.0000
# Early stopping at epoch 7568
# Embedding: torch.Size([1044, 116, 128])
# Property: largest_component_size
#   Train MSE: 0.0000, Test MSE: 50.4462
#   Train R²: 1.0000, Test R²: -15.7435
# Epoch [1000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_degree, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_degree, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_degree
#   Train MSE: 0.0000, Test MSE: 1.2154
#   Train R²: 1.0000, Test R²: 0.7710
# Epoch [1000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_betweenness_centrality
#   Train MSE: 0.0000, Test MSE: 0.1022
#   Train R²: 1.0000, Test R²: -5089.1206
# Epoch [1000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [2000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [3000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [4000/2000000], Property: spectral_radius, Loss: 0.0481
# Early stopping at epoch 4163
# Embedding: torch.Size([1044, 116, 128])
# Property: spectral_radius
#   Train MSE: 0.0000, Test MSE: 2.6818
#   Train R²: 1.0000, Test R²: 0.7433
# Epoch [1000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [2000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [3000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Epoch [4000/2000000], Property: algebraic_connectivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: algebraic_connectivity
#   Train MSE: 0.0000, Test MSE: 0.1839
#   Train R²: 1.0000, Test R²: -0.4627
# Epoch [1000/2000000], Property: graph_energy, Loss: 24526.7207
# Epoch [2000/2000000], Property: graph_energy, Loss: 11049.2041
# Epoch [3000/2000000], Property: graph_energy, Loss: 5479.0171
# Epoch [4000/2000000], Property: graph_energy, Loss: 2624.9038
# Epoch [5000/2000000], Property: graph_energy, Loss: 1115.6163
# Epoch [6000/2000000], Property: graph_energy, Loss: 379.7368
# Epoch [7000/2000000], Property: graph_energy, Loss: 89.5937
# Epoch [8000/2000000], Property: graph_energy, Loss: 11.9217
# Epoch [9000/2000000], Property: graph_energy, Loss: 0.7333
# Epoch [10000/2000000], Property: graph_energy, Loss: 0.0389
# Epoch [11000/2000000], Property: graph_energy, Loss: 0.0022

# %%
#load results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long_full_embedding.pkl", "rb") as f:
    results = pkl.load(f)

# %% [markdown]
# ### Plots

# %%
#import plt
import matplotlib.pyplot as plt
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']
#make a color list for the properties names but with different colors
colors_long = [
    (0.0, 0.45, 0.70),  # Blue
    (0.85, 0.37, 0.01),  # Orange
    (0.8, 0.47, 0.74),   # Magenta
    (0.0, 0.62, 0.45),   # Green
    (0.95, 0.90, 0.25),  # Yellow
    (0.9, 0.6, 0.0),     # Brown
    (0.35, 0.7, 0.9),    # Sky Blue
    (0.8, 0.6, 0.7),     # Light Pink
    (0.3, 0.3, 0.3),     # Dark Gray
    (0.5, 0.5, 0.0),     # Olive
    (0.0, 0.75, 0.75),   # Cyan
    (0.6, 0.6, 0.6),     # Light Gray
    (0.7, 0.3, 0.1),     # Dark Orange
    (0.6, 0.2, 0.5),     # Purple
    (0.9, 0.4, 0.3),     # Salmon
    (0.4, 0.4, 0.8),     # Light Blue
    (0.2, 0.8, 0.2),     # Light Green
    (0.6, 0.6, 0.3),     # Mustard
    (0.3, 0.55, 0.55),    # Teal
    (0.8, 0.5, 0.2),     # Dark Salmon
    (0.5, 0.5, 0.5),     # Gray
    (0.2, 0.2, 0.2),     # Black-Gray
    (0.0, 0.0, 0.0)      # Black
]
plt.figure(figsize=(12, 8))

for i, property_names_long in enumerate(property_names_long):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_names_long)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_names_long, color=colors_long[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_test_R2_plot_limited_cv_long_full_embedding.png', dpi=300, bbox_inches='tight')

# %%
#print the R2 values in order (bigger to smaller) for x_global

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']

embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

#sort the R2 values for x_global
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x_global', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.6090954542160034, 0.5785549283027649, 0.5785547494888306, 0.5710922479629517, 0.5627355575561523, 0.5171620845794678, 0.48370879888534546, 0.481626033782959, 0.47943955659866333, 0.47933870553970337, 0.4641278386116028, 0.4609038829803467, 0.45253467559814453, 0.4325084686279297, 0.4175136089324951, 0.3686663508415222, 0.3647555112838745, 0.18807393312454224, 0.13714563846588135, 0.04869192838668823, -0.05669963359832764, -0.09409618377685547, -1.3222777843475342]
# ['num_squares', 'graph_energy', 'num_edges', 'avg_degree', 'density', 'transitivity', 'small_world_index', 'avg_path_len', 'avg_clustering', 'clustering_coeff', 'spectral_radius', 'num_cliques', 'avg_betweenness_centrality', 'algebraic_connectivity', 'num_triangles', 'radius', 'diameter', 'largest_component_size', 'pagerank_cent', 'assortativity', 'num_nodes', 'small_world_coefficient', 'betweenness_cent']

# %%
#same for x6

#sort the R2 values for x6
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x6', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.522092878818512, 0.522091269493103, 0.5128549337387085, 0.5025855898857117, 0.4524869918823242, 0.4169384837150574, 0.4147563576698303, 0.4137481451034546, 0.4122782349586487, 0.39186936616897583, 0.3865439295768738, 0.37806111574172974, 0.35091328620910645, 0.33920663595199585, 0.3346071243286133, 0.3290066123008728, 0.3087393045425415, 0.29865479469299316, 0.16403818130493164, 0.060342609882354736, -0.09877514839172363, -0.14251136779785156, -0.22295606136322021]
# ['graph_energy', 'num_edges', 'avg_degree', 'density', 'avg_path_len', 'num_cliques', 'algebraic_connectivity', 'avg_betweenness_centrality', 'radius', 'small_world_index', 'diameter', 'spectral_radius', 'num_squares', 'num_triangles', 'avg_clustering', 'clustering_coeff', 'largest_component_size', 'transitivity', 'betweenness_cent', 'pagerank_cent', 'num_nodes', 'small_world_coefficient', 'assortativity']

# %%
#same for x7

#sort the R2 values for x7
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x7', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.0011767745018005371, 1.1265277862548828e-05, -0.006779909133911133, -0.006829738616943359, -0.007808685302734375, -0.007820963859558105, -0.009294867515563965, -0.010425329208374023, -0.01376485824584961, -0.016520977020263672, -0.016980409622192383, -0.01721322536468506, -0.017390012741088867, -0.017391204833984375, -0.024333953857421875, -0.025952935218811035, -0.026882529258728027, -0.02892780303955078, -0.02993631362915039, -0.03466188907623291, -0.051340341567993164, -0.06316637992858887, -0.08530426025390625]
# ['spectral_radius', 'num_triangles', 'avg_clustering', 'clustering_coeff', 'small_world_index', 'radius', 'largest_component_size', 'diameter', 'avg_path_len', 'avg_betweenness_centrality', 'density', 'avg_degree', 'num_edges', 'graph_energy', 'transitivity', 'num_squares', 'pagerank_cent', 'assortativity', 'algebraic_connectivity', 'betweenness_cent', 'num_cliques', 'num_nodes', 'small_world_coefficient']

# %%
plt.figure(figsize=(12, 8))
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']

for i, property_names_long in enumerate(property_names_long):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        train_r2 = results[(name_of_embedding, property_names_long)][2]
        if train_r2 < -0.05:  # Handle negative R² values
            train_r2 = -0.05
        x_points.append(j)
        y_points.append(train_r2)

    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_names_long, color=colors_long[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+"_"+MODEL+'_train_R2_plot_limited_cv_long_full_embedding.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Comparison with a gnn train on random (the y are shuffled)

# %%
from Datasets.FC.create_dataset import read_dataset
dataset = read_dataset()
MODEL = "GCN_w_edge_weight"
DATASET = "FC_suffled"

from models.models_FC import GCN_framework_wo_edge_weight as framework # import the model

# %%
#shuffle the y values of the dataset
# import numpy as np
# import torch

# y = np.array([data.y for data in dataset])
# print(y)
# y = np.array(y, dtype=np.int64)  # Ensure y is a numeric array of type int64

# np.random.shuffle(y)

# #make y torch.int64, tensor([0]) instead of [0]
# y = torch.tensor(y, dtype=torch.int64)

# for i in range(len(dataset)):
#     dataset[i].y = y[i]

#check if the y values are shuffled
# y = np.array([data.y for data in dataset])
# print(y)

# %%
#save the dataset
# import pickle as pkl
# with open("Datasets/FC/"+DATASET+"_"+MODEL+".pkl", "wb") as f:
#     pkl.dump(dataset, f)

#load the dataset
import pickle as pkl
with open("Datasets/FC/"+DATASET+"_"+MODEL+".pkl", "rb") as f:
    dataset = pkl.load(f)

# %%
gnn = framework(dataset)
# Out:
# c:\Users\tomdu\miniconda3\lib\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
# gnn.iterate()

# %%
#save the model 
# gnn.save_model(path="models/"+DATASET+"_"+MODEL+".pt")

# %%
#load the model
gnn.load_model(path="models/"+DATASET+"_"+MODEL+".pt", map_location='cpu')

# %%
gnn.evaluate()
# Out:
# Test Loss: 0.984, Train Acc: 0.494 Test Acc: 0.491

# %%
train_features, test_features = gnn.evaluate_with_features2()

# %%
train_idx_list = gnn.train_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in train_idx_list]
train_properties_long = compute_graph_properties(selected_dataset)
test_idx_list = gnn.test_idx.tolist()
selected_dataset = [gnn.dataset[i] for i in test_idx_list]
test_properties_long = compute_graph_properties(selected_dataset)

#save the properties in a file
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "wb") as f:
    pkl.dump(train_properties_long, f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "wb") as f:
    pkl.dump(test_properties_long, f)

# %%
import pickle as pkl
#save the properties in a file
# with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "wb") as f:
#     pkl.dump(train_properties_long, f)

# with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "wb") as f:
#     pkl.dump(test_properties_long, f)

#load the properties
with open("results/"+DATASET+"_"+MODEL+"_train_properties_long.pkl", "rb") as f:
    train_properties_long = pkl.load(f)

with open("results/"+DATASET+"_"+MODEL+"_test_properties_long.pkl", "rb") as f:
    test_properties_long = pkl.load(f)

# %%
"""
The embeddings of GCN are like this:
return F.log_softmax(x7, dim=-1), (x1, x2, x3, x4, x5, x_global, x6, x7)
"""


import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
output_size = 1  # Predicting one property at a time
# Define the linear model
class LinearModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearModel, self).__init__()
        self.linear = nn.Linear(input_size, output_size)

    def forward(self, x):
        return self.linear(x)

# Assume we have already evaluated to get features
#train_features, test_features = gnn.evaluate_with_features2()

# Extract x embeddings
train_x = np.array([feat[0] for feat in train_features])
test_x = np.array([feat[0] for feat in test_features])

# Extract 2, 3, 4, global, 5, 6, 7 embeddings
train_x2 = np.array([feat[1] for feat in train_features])
test_x2 = np.array([feat[1] for feat in test_features])

train_x3 = np.array([feat[2] for feat in train_features])
test_x3 = np.array([feat[2] for feat in test_features])

train_x4 = np.array([feat[3] for feat in train_features])
test_x4 = np.array([feat[3] for feat in test_features])

train_x5 = np.array([feat[4] for feat in train_features])
test_x5 = np.array([feat[4] for feat in test_features])

train_x_global = np.array([feat[5] for feat in train_features])
test_x_global = np.array([feat[5] for feat in test_features])

train_x6 = np.array([feat[6] for feat in train_features])
test_x6 = np.array([feat[6] for feat in test_features])

train_x7 = np.array([feat[7] for feat in train_features])
test_x7 = np.array([feat[7] for feat in test_features])

# Compute graph properties
# train_properties = compute_graph_properties(gnn.dataset[gnn.train_idx])
# test_properties = compute_graph_properties(gnn.dataset[gnn.test_idx])

# Convert to PyTorch tensors
train_x = torch.tensor(train_x, dtype=torch.float32)
train_x2 = torch.tensor(train_x2, dtype=torch.float32)
train_x3 = torch.tensor(train_x3, dtype=torch.float32)
train_x4 = torch.tensor(train_x4, dtype=torch.float32)
train_x5 = torch.tensor(train_x5, dtype=torch.float32)
train_x_global = torch.tensor(train_x_global, dtype=torch.float32)
train_x6 = torch.tensor(train_x6, dtype=torch.float32)
train_x7 = torch.tensor(train_x7, dtype=torch.float32)

test_x = torch.tensor(test_x, dtype=torch.float32)
test_x2 = torch.tensor(test_x2, dtype=torch.float32)
test_x3 = torch.tensor(test_x3, dtype=torch.float32)
test_x4 = torch.tensor(test_x4, dtype=torch.float32)
test_x5 = torch.tensor(test_x5, dtype=torch.float32)
test_x_global = torch.tensor(test_x_global, dtype=torch.float32)
test_x6 = torch.tensor(test_x6, dtype=torch.float32)
test_x7 = torch.tensor(test_x7, dtype=torch.float32)

# train_y = torch.tensor(train_properties, dtype=torch.float32)
# test_y = torch.tensor(test_properties, dtype=torch.float32)

# Train and evaluate a model for each graph property and each embedding
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']
embeddings = [(train_x, test_x), (train_x2, test_x2), (train_x3, test_x3), (train_x4, test_x4), (train_x5, test_x5), (train_x_global, test_x_global), (train_x6, test_x6), (train_x7, test_x7)]
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

# %%
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']
train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
#create a dictionary where we will store the results for each embeddings, each property
results = {}

ii = 0

for train_embedding, test_embedding in embeddings:
    # Flatten the embeddings before determining the input size
    train_embedding_flat = train_embedding.view(train_embedding.size(0), -1)
    test_embedding_flat = test_embedding.view(test_embedding.size(0), -1)
    #print the shapes
    print(train_embedding_flat.shape)
    print(test_embedding_flat.shape)
    input_size = train_embedding_flat.shape[1]

    for i, property_name in enumerate(property_names_long):
        model = LinearModel(input_size, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        num_epochs = 2000000  # Maximum number of epochs
        min_epochs = 1000  # Minimum number of epochs
        patience = 3000  # Number of epochs to wait for improvement
        tolerance = 1e-6  # Tolerance for considering the loss as stable

        best_loss = float('inf')
        no_improve_count = 0
        
        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            outputs = model(train_embedding_flat).squeeze()
            target = train_y_long[:, i].squeeze()

            loss = criterion(outputs, target)
            loss.backward()
            optimizer.step()

            if (epoch+1) % 1000 == 0:  # Print every 1000 epochs
                print(f'Epoch [{epoch+1}/{num_epochs}], Property: {property_name}, Loss: {loss.item():.4f}')

            # Check for early stopping, but only after minimum epochs
            if epoch >= min_epochs:
                if loss.item() < best_loss - tolerance:
                    best_loss = loss.item()
                    no_improve_count = 0
                else:
                    no_improve_count += 1

                if no_improve_count >= patience:
                    print(f'Early stopping at epoch {epoch+1}')
                    break

        # Evaluate the model
        model.eval()
        with torch.no_grad():
            train_pred = model(train_embedding_flat).squeeze().cpu().numpy()
            test_pred = model(test_embedding_flat).squeeze().cpu().numpy()

            train_target = train_y_long[:, i].cpu().numpy()
            test_target = test_y_long[:, i].cpu().numpy()

            train_mse = mean_squared_error(train_target, train_pred)
            test_mse = mean_squared_error(test_target, test_pred)

            train_r2 = r2_score(train_target, train_pred)
            test_r2 = r2_score(test_target, test_pred)

            print(f'Embedding: {train_embedding.shape}')
            print(f'Property: {property_name}')
            print(f'  Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}')
            print(f'  Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}')

            #add the results to the dictionary
            name_of_embedding = embeddings_names[ii]
            results[(name_of_embedding, property_name)] = (train_mse, test_mse, train_r2, test_r2)

    ii += 1


#save results
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long_full_embedding.pkl", "wb") as f:
    pkl.dump(results, f)
# Out:
# /scratch-local/tpelletreaudur.7734772/ipykernel_4097216/225588825.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#   train_y_long = torch.tensor(train_properties_long, dtype=torch.float32)
# /scratch-local/tpelletreaudur.7734772/ipykernel_4097216/225588825.py:3: ComplexWarning: Casting complex values to real discards the imaginary part
#   test_y_long = torch.tensor(test_properties_long, dtype=torch.float32)
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/2000000], Property: num_nodes, Loss: 1.8647
# Epoch [2000/2000000], Property: num_nodes, Loss: 0.0854
# Epoch [3000/2000000], Property: num_nodes, Loss: 0.0019
# Epoch [4000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [5000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [6000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [7000/2000000], Property: num_nodes, Loss: 0.0005
# Early stopping at epoch 7281
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0005, Test MSE: 27.5947
#   Train R²: 0.9998, Test R²: -30.3340
# Epoch [1000/2000000], Property: num_edges, Loss: 13250.2549
# Epoch [2000/2000000], Property: num_edges, Loss: 7183.0410
# Epoch [3000/2000000], Property: num_edges, Loss: 3540.9373
# Epoch [4000/2000000], Property: num_edges, Loss: 1460.7985
# Epoch [5000/2000000], Property: num_edges, Loss: 443.8512
# Epoch [6000/2000000], Property: num_edges, Loss: 82.5867
# Epoch [7000/2000000], Property: num_edges, Loss: 8.6983
# Epoch [8000/2000000], Property: num_edges, Loss: 2.3972
# Epoch [9000/2000000], Property: num_edges, Loss: 2.2204
# Epoch [10000/2000000], Property: num_edges, Loss: 2.2147
# Epoch [11000/2000000], Property: num_edges, Loss: 2.2146
# Epoch [12000/2000000], Property: num_edges, Loss: 2.2146
# Epoch [13000/2000000], Property: num_edges, Loss: 2.2186
# Epoch [14000/2000000], Property: num_edges, Loss: 2.2146
# Early stopping at epoch 14790
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 2.2146, Test MSE: 24058.0273
#   Train R²: 0.9999, Test R²: -0.3422
# Epoch [1000/2000000], Property: density, Loss: 0.0000
# Epoch [2000/2000000], Property: density, Loss: 0.0000
# Epoch [3000/2000000], Property: density, Loss: 0.0000
# Epoch [4000/2000000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.0933
#   Train R²: 0.9999, Test R²: -232.1144
# Epoch [1000/2000000], Property: avg_path_len, Loss: 0.0003
# Epoch [2000/2000000], Property: avg_path_len, Loss: 0.0003
# Epoch [3000/2000000], Property: avg_path_len, Loss: 0.0003
# Epoch [4000/2000000], Property: avg_path_len, Loss: 0.0003
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0003, Test MSE: 0.5683
#   Train R²: 0.9989, Test R²: -0.9198
# Epoch [1000/2000000], Property: diameter, Loss: 0.0019
# Epoch [2000/2000000], Property: diameter, Loss: 0.0019
# Epoch [3000/2000000], Property: diameter, Loss: 0.0019
# Epoch [4000/2000000], Property: diameter, Loss: 0.0019
# Early stopping at epoch 4301
# Embedding: torch.Size([1044, 116, 128])
# Property: diameter
#   Train MSE: 0.0019, Test MSE: 6.2056
#   Train R²: 0.9994, Test R²: -0.6244
# Epoch [1000/2000000], Property: radius, Loss: 0.0019
# Epoch [2000/2000000], Property: radius, Loss: 0.0019
# Epoch [3000/2000000], Property: radius, Loss: 0.0019
# Epoch [4000/2000000], Property: radius, Loss: 0.0019
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: radius
#   Train MSE: 0.0019, Test MSE: 1.2055
#   Train R²: 0.9971, Test R²: -0.9543
# Epoch [1000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [2000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [3000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [4000/2000000], Property: clustering_coeff, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: clustering_coeff
#   Train MSE: 0.0000, Test MSE: 0.0804
#   Train R²: 0.9986, Test R²: -31.2245
# Epoch [1000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [2000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [3000/2000000], Property: transitivity, Loss: 0.9889
# Epoch [4000/2000000], Property: transitivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: transitivity
#   Train MSE: 0.0000, Test MSE: 0.0605
#   Train R²: 0.9986, Test R²: -20.3906
# Epoch [1000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [2000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [3000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [4000/2000000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1277
#   Train R²: 0.9996, Test R²: -11.5563
# Epoch [1000/2000000], Property: num_cliques, Loss: 193.7356
# Epoch [2000/2000000], Property: num_cliques, Loss: 27.0831
# Epoch [3000/2000000], Property: num_cliques, Loss: 2.3712
# Epoch [4000/2000000], Property: num_cliques, Loss: 0.3873
# Epoch [5000/2000000], Property: num_cliques, Loss: 0.2646
# Epoch [6000/2000000], Property: num_cliques, Loss: 0.2536
# Epoch [7000/2000000], Property: num_cliques, Loss: 0.2534
# Epoch [8000/2000000], Property: num_cliques, Loss: 0.2534
# Epoch [9000/2000000], Property: num_cliques, Loss: 0.2723
# Epoch [10000/2000000], Property: num_cliques, Loss: 0.2534
# Early stopping at epoch 10061
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.2534, Test MSE: 1157.0487
#   Train R²: 0.9998, Test R²: -0.5079
# Epoch [1000/2000000], Property: num_triangles, Loss: 491491.0625
# Epoch [2000/2000000], Property: num_triangles, Loss: 389655.8750
# Epoch [3000/2000000], Property: num_triangles, Loss: 299868.9375
# Epoch [4000/2000000], Property: num_triangles, Loss: 221362.8438
# Epoch [5000/2000000], Property: num_triangles, Loss: 155096.7500
# Epoch [6000/2000000], Property: num_triangles, Loss: 101654.1875
# Epoch [7000/2000000], Property: num_triangles, Loss: 60919.3633
# Epoch [8000/2000000], Property: num_triangles, Loss: 32194.4902
# Epoch [9000/2000000], Property: num_triangles, Loss: 14128.6514
# Epoch [10000/2000000], Property: num_triangles, Loss: 4640.5625
# Epoch [11000/2000000], Property: num_triangles, Loss: 958.3101
# Epoch [12000/2000000], Property: num_triangles, Loss: 101.4534
# Epoch [13000/2000000], Property: num_triangles, Loss: 6.2944
# Epoch [14000/2000000], Property: num_triangles, Loss: 0.2574
# Epoch [15000/2000000], Property: num_triangles, Loss: 0.0588
# Epoch [16000/2000000], Property: num_triangles, Loss: 0.0580
# Epoch [17000/2000000], Property: num_triangles, Loss: 0.0580
# Epoch [18000/2000000], Property: num_triangles, Loss: 0.0580
# Epoch [19000/2000000], Property: num_triangles, Loss: 0.0580
# Early stopping at epoch 19278
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0580, Test MSE: 658601.6250
#   Train R²: 1.0000, Test R²: -0.4891
# Epoch [1000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [2000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [3000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [4000/2000000], Property: num_squares, Loss: 0.0031
# Early stopping at epoch 4139
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0031, Test MSE: 2.7793
#   Train R²: 0.9982, Test R²: -0.8824
# Epoch [1000/2000000], Property: largest_component_size, Loss: 2.4120
# Epoch [2000/2000000], Property: largest_component_size, Loss: 0.1229
# Epoch [3000/2000000], Property: largest_component_size, Loss: 0.0027
# Epoch [4000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [5000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [6000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [7000/2000000], Property: largest_component_size, Loss: 0.0005
# Early stopping at epoch 7281
# Embedding: torch.Size([1044, 116, 128])
# Property: largest_component_size
#   Train MSE: 0.0005, Test MSE: 30.9351
#   Train R²: 0.9999, Test R²: -9.2676
# Epoch [1000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [2000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [3000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [4000/2000000], Property: avg_degree, Loss: 0.0006
# Early stopping at epoch 4147
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_degree
#   Train MSE: 0.0006, Test MSE: 7.3993
#   Train R²: 0.9999, Test R²: -0.3942
# Epoch [1000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_betweenness_centrality
#   Train MSE: 0.0000, Test MSE: 0.0968
#   Train R²: 0.9987, Test R²: -4821.7876
# Epoch [1000/2000000], Property: spectral_radius, Loss: 0.0009
# Epoch [2000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [3000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [4000/2000000], Property: spectral_radius, Loss: 0.0000
# Early stopping at epoch 4863
# Embedding: torch.Size([1044, 116, 128])
# Property: spectral_radius
#   Train MSE: 0.0000, Test MSE: 19.6926
#   Train R²: 1.0000, Test R²: -0.8848
# Epoch [1000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [2000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [3000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [4000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: algebraic_connectivity
#   Train MSE: 0.0001, Test MSE: 0.3293
#   Train R²: 0.9994, Test R²: -1.6189
# Epoch [1000/2000000], Property: graph_energy, Loss: 71506.0156
# Epoch [2000/2000000], Property: graph_energy, Loss: 50683.4141
# Epoch [3000/2000000], Property: graph_energy, Loss: 34901.9688
# Epoch [4000/2000000], Property: graph_energy, Loss: 22436.6621
# Epoch [5000/2000000], Property: graph_energy, Loss: 13033.2842
# Epoch [6000/2000000], Property: graph_energy, Loss: 6502.4561
# Epoch [7000/2000000], Property: graph_energy, Loss: 2562.5349
# Epoch [8000/2000000], Property: graph_energy, Loss: 697.5737
# Epoch [9000/2000000], Property: graph_energy, Loss: 109.2304
# Epoch [10000/2000000], Property: graph_energy, Loss: 14.3396
# Epoch [11000/2000000], Property: graph_energy, Loss: 8.9755
# Epoch [12000/2000000], Property: graph_energy, Loss: 8.8619
# Epoch [13000/2000000], Property: graph_energy, Loss: 8.8583
# Epoch [14000/2000000], Property: graph_energy, Loss: 8.8583
# Epoch [15000/2000000], Property: graph_energy, Loss: 8.8583
# Epoch [16000/2000000], Property: graph_energy, Loss: 8.8582
# Early stopping at epoch 16576
# Embedding: torch.Size([1044, 116, 128])
# Property: graph_energy
#   Train MSE: 8.8583, Test MSE: 96142.7422
#   Train R²: 0.9999, Test R²: -0.3410
# Epoch [1000/2000000], Property: small_world_coefficient, Loss: 0.0019
# Epoch [2000/2000000], Property: small_world_coefficient, Loss: 0.0021
# Epoch [3000/2000000], Property: small_world_coefficient, Loss: 0.0019
# Epoch [4000/2000000], Property: small_world_coefficient, Loss: 0.0019
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world_coefficient
#   Train MSE: 0.0019, Test MSE: 1.3901
#   Train R²: 0.9984, Test R²: -0.5634
# Epoch [1000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [2000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [3000/2000000], Property: betweenness_cent, Loss: 0.0000
# Epoch [4000/2000000], Property: betweenness_cent, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: betweenness_cent
#   Train MSE: 0.0000, Test MSE: 0.0972
#   Train R²: 0.9989, Test R²: -111732.2500
# Epoch [1000/2000000], Property: pagerank_cent, Loss: 0.0000
# Epoch [2000/2000000], Property: pagerank_cent, Loss: 0.0000
# Epoch [3000/2000000], Property: pagerank_cent, Loss: 0.0000
# Epoch [4000/2000000], Property: pagerank_cent, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: pagerank_cent
#   Train MSE: 0.0000, Test MSE: 0.1008
#   Train R²: 0.9999, Test R²: -50701.0586
# Epoch [3000/2000000], Property: small_world_index, Loss: 0.0035
# Epoch [4000/2000000], Property: small_world_index, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: small_world_index
#   Train MSE: 0.0000, Test MSE: 0.1328
#   Train R²: 0.9995, Test R²: -8.9949
# torch.Size([1044, 14848])
# torch.Size([55, 14848])
# Epoch [1000/2000000], Property: num_nodes, Loss: 2.5865
# Epoch [2000/2000000], Property: num_nodes, Loss: 0.0951
# Epoch [3000/2000000], Property: num_nodes, Loss: 0.0026
# Epoch [4000/2000000], Property: num_nodes, Loss: 0.0006
# Epoch [5000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [6000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [7000/2000000], Property: num_nodes, Loss: 0.0005
# Epoch [8000/2000000], Property: num_nodes, Loss: 0.0005
# Early stopping at epoch 8171
# Embedding: torch.Size([1044, 116, 128])
# Property: num_nodes
#   Train MSE: 0.0005, Test MSE: 52.4635
#   Train R²: 0.9998, Test R²: -58.5729
# Epoch [1000/2000000], Property: num_edges, Loss: 13319.5820
# Epoch [2000/2000000], Property: num_edges, Loss: 6837.5986
# Epoch [3000/2000000], Property: num_edges, Loss: 3120.2854
# Epoch [4000/2000000], Property: num_edges, Loss: 1162.4348
# Epoch [5000/2000000], Property: num_edges, Loss: 309.7957
# Epoch [6000/2000000], Property: num_edges, Loss: 48.7454
# Epoch [7000/2000000], Property: num_edges, Loss: 5.1299
# Epoch [8000/2000000], Property: num_edges, Loss: 2.2980
# Epoch [9000/2000000], Property: num_edges, Loss: 2.2188
# Epoch [10000/2000000], Property: num_edges, Loss: 2.2146
# Epoch [11000/2000000], Property: num_edges, Loss: 2.2146
# Epoch [12000/2000000], Property: num_edges, Loss: 2.2146
# Epoch [13000/2000000], Property: num_edges, Loss: 2.2146
# Early stopping at epoch 13738
# Embedding: torch.Size([1044, 116, 128])
# Property: num_edges
#   Train MSE: 2.2586, Test MSE: 22578.5293
#   Train R²: 0.9999, Test R²: -0.2597
# Epoch [1000/2000000], Property: density, Loss: 0.0000
# Epoch [2000/2000000], Property: density, Loss: 0.0000
# Epoch [3000/2000000], Property: density, Loss: 0.0000
# Epoch [4000/2000000], Property: density, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: density
#   Train MSE: 0.0000, Test MSE: 0.1032
#   Train R²: 0.9999, Test R²: -256.7409
# Epoch [1000/2000000], Property: avg_path_len, Loss: 0.0003
# Epoch [2000/2000000], Property: avg_path_len, Loss: 0.0073
# Epoch [3000/2000000], Property: avg_path_len, Loss: 0.0003
# Epoch [4000/2000000], Property: avg_path_len, Loss: 0.0003
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_path_len
#   Train MSE: 0.0003, Test MSE: 0.5735
#   Train R²: 0.9989, Test R²: -0.9372
# Epoch [1000/2000000], Property: diameter, Loss: 0.0019
# Epoch [2000/2000000], Property: diameter, Loss: 0.0019
# Epoch [3000/2000000], Property: diameter, Loss: 0.0019
# Epoch [4000/2000000], Property: diameter, Loss: 0.0019
# Early stopping at epoch 4212
# Embedding: torch.Size([1044, 116, 128])
# Property: diameter
#   Train MSE: 0.0019, Test MSE: 6.0683
#   Train R²: 0.9994, Test R²: -0.5885
# Epoch [1000/2000000], Property: radius, Loss: 0.0019
# Epoch [2000/2000000], Property: radius, Loss: 0.0019
# Epoch [3000/2000000], Property: radius, Loss: 0.0019
# Epoch [4000/2000000], Property: radius, Loss: 0.0019
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: radius
#   Train MSE: 0.0019, Test MSE: 1.1856
#   Train R²: 0.9971, Test R²: -0.9220
# Epoch [1000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [2000/2000000], Property: clustering_coeff, Loss: 0.0000
# Epoch [3000/2000000], Property: clustering_coeff, Loss: 64.6815
# Epoch [4000/2000000], Property: clustering_coeff, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: clustering_coeff
#   Train MSE: 0.0000, Test MSE: 0.0718
#   Train R²: 0.9986, Test R²: -27.7827
# Epoch [1000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [2000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [3000/2000000], Property: transitivity, Loss: 0.0000
# Epoch [4000/2000000], Property: transitivity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: transitivity
#   Train MSE: 0.0000, Test MSE: 0.1372
#   Train R²: 0.9986, Test R²: -47.5272
# Epoch [1000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [2000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [3000/2000000], Property: assortativity, Loss: 0.0000
# Epoch [4000/2000000], Property: assortativity, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: assortativity
#   Train MSE: 0.0000, Test MSE: 0.1405
#   Train R²: 0.9996, Test R²: -12.8135
# Epoch [1000/2000000], Property: num_cliques, Loss: 172.3306
# Epoch [2000/2000000], Property: num_cliques, Loss: 20.5876
# Epoch [3000/2000000], Property: num_cliques, Loss: 1.6286
# Epoch [4000/2000000], Property: num_cliques, Loss: 0.3348
# Epoch [5000/2000000], Property: num_cliques, Loss: 0.2595
# Epoch [6000/2000000], Property: num_cliques, Loss: 0.2535
# Epoch [7000/2000000], Property: num_cliques, Loss: 0.2534
# Epoch [8000/2000000], Property: num_cliques, Loss: 0.2534
# Epoch [9000/2000000], Property: num_cliques, Loss: 0.2534
# Epoch [10000/2000000], Property: num_cliques, Loss: 0.2575
# Early stopping at epoch 10141
# Embedding: torch.Size([1044, 116, 128])
# Property: num_cliques
#   Train MSE: 0.2534, Test MSE: 1136.3630
#   Train R²: 0.9998, Test R²: -0.4810
# Epoch [1000/2000000], Property: num_triangles, Loss: 487476.4688
# Epoch [2000/2000000], Property: num_triangles, Loss: 380335.2188
# Epoch [3000/2000000], Property: num_triangles, Loss: 288899.5625
# Epoch [4000/2000000], Property: num_triangles, Loss: 209812.5625
# Epoch [5000/2000000], Property: num_triangles, Loss: 143518.2812
# Epoch [6000/2000000], Property: num_triangles, Loss: 90808.1328
# Epoch [7000/2000000], Property: num_triangles, Loss: 51745.2695
# Epoch [8000/2000000], Property: num_triangles, Loss: 25440.3398
# Epoch [9000/2000000], Property: num_triangles, Loss: 10043.0762
# Epoch [10000/2000000], Property: num_triangles, Loss: 2816.6792
# Epoch [11000/2000000], Property: num_triangles, Loss: 469.8267
# Epoch [12000/2000000], Property: num_triangles, Loss: 45.3815
# Epoch [13000/2000000], Property: num_triangles, Loss: 3.4229
# Epoch [14000/2000000], Property: num_triangles, Loss: 0.1439
# Epoch [15000/2000000], Property: num_triangles, Loss: 0.0582
# Epoch [16000/2000000], Property: num_triangles, Loss: 0.0579
# Epoch [17000/2000000], Property: num_triangles, Loss: 0.0580
# Epoch [18000/2000000], Property: num_triangles, Loss: 0.0579
# Epoch [19000/2000000], Property: num_triangles, Loss: 0.0579
# Early stopping at epoch 19249
# Embedding: torch.Size([1044, 116, 128])
# Property: num_triangles
#   Train MSE: 0.0579, Test MSE: 607567.3750
#   Train R²: 1.0000, Test R²: -0.3737
# Epoch [1000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [2000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [3000/2000000], Property: num_squares, Loss: 0.0031
# Epoch [4000/2000000], Property: num_squares, Loss: 0.0031
# Early stopping at epoch 4100
# Embedding: torch.Size([1044, 116, 128])
# Property: num_squares
#   Train MSE: 0.0031, Test MSE: 2.5966
#   Train R²: 0.9982, Test R²: -0.7587
# Epoch [1000/2000000], Property: largest_component_size, Loss: 2.8777
# Epoch [2000/2000000], Property: largest_component_size, Loss: 0.1063
# Epoch [3000/2000000], Property: largest_component_size, Loss: 0.0025
# Epoch [4000/2000000], Property: largest_component_size, Loss: 0.0006
# Epoch [5000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [6000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [7000/2000000], Property: largest_component_size, Loss: 0.0005
# Epoch [8000/2000000], Property: largest_component_size, Loss: 0.0005
# Early stopping at epoch 8355
# Embedding: torch.Size([1044, 116, 128])
# Property: largest_component_size
#   Train MSE: 0.0005, Test MSE: 55.7864
#   Train R²: 0.9999, Test R²: -17.5159
# Epoch [1000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [2000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [3000/2000000], Property: avg_degree, Loss: 0.0006
# Epoch [4000/2000000], Property: avg_degree, Loss: 0.0006
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_degree
#   Train MSE: 0.0006, Test MSE: 6.7661
#   Train R²: 0.9999, Test R²: -0.2749
# Epoch [1000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [2000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [3000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Epoch [4000/2000000], Property: avg_betweenness_centrality, Loss: 0.0000
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: avg_betweenness_centrality
#   Train MSE: 0.0000, Test MSE: 0.1144
#   Train R²: 0.9987, Test R²: -5697.1387
# Epoch [1000/2000000], Property: spectral_radius, Loss: 0.0005
# Epoch [2000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [3000/2000000], Property: spectral_radius, Loss: 0.0000
# Epoch [4000/2000000], Property: spectral_radius, Loss: 0.0000
# Early stopping at epoch 4713
# Embedding: torch.Size([1044, 116, 128])
# Property: spectral_radius
#   Train MSE: 0.0167, Test MSE: 15.8440
#   Train R²: 0.9986, Test R²: -0.5165
# Epoch [1000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [2000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [3000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Epoch [4000/2000000], Property: algebraic_connectivity, Loss: 0.0001
# Early stopping at epoch 4001
# Embedding: torch.Size([1044, 116, 128])
# Property: algebraic_connectivity
#   Train MSE: 0.0001, Test MSE: 0.3297
#   Train R²: 0.9994, Test R²: -1.6219
# Epoch [1000/2000000], Property: graph_energy, Loss: 73706.8125
# Epoch [2000/2000000], Property: graph_energy, Loss: 50835.3164
# Epoch [3000/2000000], Property: graph_energy, Loss: 33954.1797
# Epoch [4000/2000000], Property: graph_energy, Loss: 20926.6191
# Epoch [5000/2000000], Property: graph_energy, Loss: 11466.4854
# Epoch [6000/2000000], Property: graph_energy, Loss: 5287.4277
# Epoch [7000/2000000], Property: graph_energy, Loss: 1872.9248
# Epoch [8000/2000000], Property: graph_energy, Loss: 438.2242
# Epoch [9000/2000000], Property: graph_energy, Loss: 58.1634
# Epoch [10000/2000000], Property: graph_energy, Loss: 10.9939
# Epoch [11000/2000000], Property: graph_energy, Loss: 8.9450
# Epoch [12000/2000000], Property: graph_energy, Loss: 8.8614
# Epoch [13000/2000000], Property: graph_energy, Loss: 8.8583
# Epoch [14000/2000000], Property: graph_energy, Loss: 8.8582
# Epoch [15000/2000000], Property: graph_energy, Loss: 8.8582
# Epoch [16000/2000000], Property: graph_energy, Loss: 8.8582
# Early stopping at epoch 16746
# Embedding: torch.Size([1044, 116, 128])
# Property: graph_energy
#   Train MSE: 8.8582, Test MSE: 89769.2734
#   Train R²: 0.9999, Test R²: -0.2521

# %%
#load results 
with open("results/"+DATASET+"_"+MODEL+"_results_limited_cv_long_full_embedding.pkl", "rb") as f:
    results = pkl.load(f)

# %%
import matplotlib.pyplot as plt
colors_long = [
    (0.0, 0.45, 0.70),  # Blue
    (0.85, 0.37, 0.01),  # Orange
    (0.8, 0.47, 0.74),   # Magenta
    (0.0, 0.62, 0.45),   # Green
    (0.95, 0.90, 0.25),  # Yellow
    (0.9, 0.6, 0.0),     # Brown
    (0.35, 0.7, 0.9),    # Sky Blue
    (0.8, 0.6, 0.7),     # Light Pink
    (0.3, 0.3, 0.3),     # Dark Gray
    (0.5, 0.5, 0.0),     # Olive
    (0.0, 0.75, 0.75),   # Cyan
    (0.6, 0.6, 0.6),     # Light Gray
    (0.7, 0.3, 0.1),     # Dark Orange
    (0.6, 0.2, 0.5),     # Purple
    (0.9, 0.4, 0.3),     # Salmon
    (0.4, 0.4, 0.8),     # Light Blue
    (0.2, 0.8, 0.2),     # Light Green
    (0.6, 0.6, 0.3),     # Mustard
    (0.3, 0.55, 0.55),    # Teal
    (0.8, 0.5, 0.2),     # Dark Salmon
    (0.5, 0.5, 0.5),     # Gray
    (0.2, 0.2, 0.2),      # Black-Gray
    (0.0, 0.0, 0.0)      # Black
]

property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']
embeddings_names = ['x1', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

plt.figure(figsize=(12, 8))

for i, property_names_long in enumerate(property_names_long):
    x_points = []
    y_points = []
    for j, embedding in enumerate(embeddings):
        name_of_embedding = embeddings_names[j]
        test_r2 = results[(name_of_embedding, property_names_long)][3]
        if test_r2 < -0.05:  # Handle negative R² values
            test_r2 = -0.05
        x_points.append(j)
        y_points.append(test_r2)
    
    # Plotting the line for the current property
    plt.plot(x_points, y_points, label=property_names_long, color=colors_long[i], marker='x')

plt.xticks(range(len(embeddings)), embeddings_names)
plt.xlabel('Embedding')
plt.ylabel('R²')
plt.legend()
plt.title('FC matrice - GCN - R² for different embeddings and properties')
plt.show()

#save the plot
plt.savefig('results/'+DATASET+'_'+MODEL+'test_R2_plot_long_random_full_embedding.png')

# %%
#print the R2 values in order (bigger to smaller) for x_global

# Assuming results, embeddings, and other necessary variables are defined as in your context
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']

embeddings_names = ['x', 'x2', 'x3', 'x4', 'x5', 'x_global', 'x6', 'x7']

#sort the R2 values for x_global
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x_global', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.06914067268371582, 0.050679147243499756, 0.05044150352478027, 0.026500582695007324, -0.005432486534118652, -0.012398242950439453, -0.012400627136230469, -0.012825608253479004, -0.013605594635009766, -0.03568887710571289, -0.04329860210418701, -0.05225646495819092, -0.08554315567016602, -0.10692238807678223, -0.12106728553771973, -0.13230538368225098, -0.13417291641235352, -0.14429616928100586, -0.14429998397827148, -0.1757577657699585, -0.1930246353149414, -0.24357819557189941, -4.383932113647461]
# ['num_cliques', 'radius', 'small_world_coefficient', 'avg_path_len', 'algebraic_connectivity', 'num_edges', 'graph_energy', 'avg_degree', 'density', 'diameter', 'num_triangles', 'betweenness_cent', 'assortativity', 'spectral_radius', 'small_world_index', 'pagerank_cent', 'num_squares', 'clustering_coeff', 'avg_clustering', 'transitivity', 'num_nodes', 'largest_component_size', 'avg_betweenness_centrality']

# %%
#same for x6
property_names_long = ['num_nodes', 'num_edges', 'density', 'avg_path_len', 'diameter', 'radius', 'clustering_coeff', 'transitivity', 'assortativity', 'num_cliques', 'num_triangles', 'num_squares', 'largest_component_size', 'avg_degree', 'avg_betweenness_centrality', 'spectral_radius', 'algebraic_connectivity', 'graph_energy', 'small_world_coefficient', 'betweenness_cent', 'pagerank_cent', 'avg_clustering', 'small_world_index']

#sort the R2 values for x6
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x6', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.14497721195220947, 0.12307411432266235, 0.11857771873474121, 0.1148032546043396, 0.10062903165817261, 0.09815621376037598, 0.08943510055541992, 0.05306369066238403, 0.053063273429870605, 0.049779415130615234, 0.04612255096435547, -0.0193406343460083, -0.023358702659606934, -0.025427937507629395, -0.058141112327575684, -0.0838860273361206, -0.08689224720001221, -0.09310543537139893, -0.14667737483978271, -0.16109204292297363, -0.16226434707641602, -0.16324758529663086, -0.22269487380981445]
# ['num_cliques', 'avg_betweenness_centrality', 'avg_path_len', 'radius', 'betweenness_cent', 'diameter', 'algebraic_connectivity', 'graph_energy', 'num_edges', 'avg_degree', 'density', 'small_world_coefficient', 'small_world_index', 'assortativity', 'num_triangles', 'avg_clustering', 'clustering_coeff', 'spectral_radius', 'num_squares', 'pagerank_cent', 'transitivity', 'num_nodes', 'largest_component_size']

# %%
#same for x7

#sort the R2 values for x7
r2_values = []
for property_name in property_names_long:
    r2_values.append(results[('x7', property_name)][3])

r2_values_sorted = sorted(r2_values, reverse=True)
print(r2_values_sorted)

#sort the property names
property_names_long_sorted = [x for _, x in sorted(zip(r2_values, property_names_long), reverse=True)]
print(property_names_long_sorted)
# Out:
# [0.007584691047668457, 0.005602478981018066, 0.004599869251251221, 0.003593623638153076, 0.003201425075531006, 0.0015357136726379395, 0.0008099675178527832, 0.00029474496841430664, -0.0008599758148193359, -0.0008884668350219727, -0.000888824462890625, -0.001524209976196289, -0.0015250444412231445, -0.0016846656799316406, -0.00238645076751709, -0.0033818483352661133, -0.0040656328201293945, -0.00501251220703125, -0.010980844497680664, -0.0133589506149292, -0.014475226402282715, -0.026517033576965332, -0.06092226505279541]
# ['diameter', 'num_triangles', 'small_world_index', 'avg_betweenness_centrality', 'avg_path_len', 'density', 'assortativity', 'avg_degree', 'spectral_radius', 'num_edges', 'graph_energy', 'avg_clustering', 'clustering_coeff', 'num_cliques', 'radius', 'small_world_coefficient', 'transitivity', 'betweenness_cent', 'num_squares', 'algebraic_connectivity', 'largest_component_size', 'pagerank_cent', 'num_nodes']

# %% [markdown]
# # Node embedding probing
#
# /!\ Try to not forget that we need to change the batch_size to 1 if we want to probe for node properties as we need the forward pass to be made 1 graph by 1 graph at a time.

# %%
from Datasets.FC.create_dataset import read_dataset
dataset = read_dataset()
import torch
torch.manual_seed(37)
MODEL = "GCN_wo_edge_weight"
DATASET = "FC"
from models.models_FC import GCN_framework_wo_edge_weight as framework # import the model
gnn = framework(dataset)
#load the model
gnn.load_model(path="models/"+DATASET+"_"+MODEL+"server.pt")
gnn.evaluate()
# Out:
# /home/tpelletreaudur/.local/lib/python3.10/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Test Loss: 0.728, Train Acc: 1.000 Test Acc: 0.564

# %% [markdown]
# ## Visualisation
#
# For visualisation, we take into account the disconnected subgraph

# %%
import networkx as nx

# Define function to compute node-level properties
def compute_node_properties(data):
    properties = []
    for graph_data in data:
        try:
            # Convert edge index to NetworkX graph
            G = nx.from_edgelist(graph_data.edge_index.t().tolist())
            
            # Add all nodes to the graph to handle disconnected nodes
            all_nodes = range(len(graph_data.x))
            connected_nodes = set(G.nodes())
            disconnected_nodes = set(all_nodes) - connected_nodes
            
            # Compute node-level properties for connected nodes
            node_degrees = dict(G.degree())
            clustering_coeffs = nx.clustering(G)
            betweenness_centralities = nx.betweenness_centrality(G)
            eigenvector_centralities = nx.eigenvector_centrality(G, max_iter=10000)
            
            # Initialize properties with zeros for all nodes
            node_degrees_full = [0] * len(graph_data.x)
            clustering_coeffs_full = [0] * len(graph_data.x)
            betweenness_centralities_full = [0] * len(graph_data.x)
            eigenvector_centralities_full = [0] * len(graph_data.x)
            
            # Assign computed properties to the respective nodes
            for node in connected_nodes:
                node_degrees_full[node] = node_degrees[node]
                clustering_coeffs_full[node] = clustering_coeffs[node]
                betweenness_centralities_full[node] = betweenness_centralities[node]
                eigenvector_centralities_full[node] = eigenvector_centralities[node]

            # Append properties as a tuple
            properties.append((node_degrees_full, clustering_coeffs_full, betweenness_centralities_full, eigenvector_centralities_full))
        except Exception as e:
            print(f"Error processing graph: {e}")
            properties.append(([], [], [], []))  # Append empty properties in case of error
    return properties

# Ensure gnn.train_idx and gnn.test_idx are lists of integers
train_idx = gnn.train_idx.tolist() if isinstance(gnn.train_idx, torch.Tensor) else gnn.train_idx
test_idx = gnn.test_idx.tolist() if isinstance(gnn.test_idx, torch.Tensor) else gnn.test_idx

# Compute node-level properties for train and test sets
train_node_properties = compute_node_properties([gnn.dataset[i] for i in train_idx])
test_node_properties = compute_node_properties([gnn.dataset[i] for i in test_idx])

# train_node_properties is a list of tuples, where each tuple contains 4 lists,
# each list contains the node-level property for each node in the graph

# %%
train_node_properties

# %%
train_idx[0]

# %%
len(train_node_properties), len(test_node_properties)

# %%
# Check the length of the first three betweenness centralities of the three first graphs in the train set
[len(train_node_properties[i][2]) for i in range(15)]

# %%
import networkx as nx
# Ensure gnn.test_idx is a list of integers
test_idx = gnn.test_idx.tolist() if isinstance(gnn.test_idx, torch.Tensor) else gnn.test_idx

# Visualize the first graph of the test set to see if the properties are correct
G = nx.from_edgelist(gnn.dataset[test_idx[1]].edge_index.t().tolist())
nx.draw(G, with_labels=True)

# %%
import matplotlib.pyplot as plt
#represent the properties of betweenness centrality on the graph by chaging the size of the nodes
node_degrees = test_node_properties[0][0]

plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_size=[v * 100 for v in node_degrees], node_color=node_degrees, cmap='viridis')
plt.show()

# %%
import matplotlib.pyplot as plt
#represent the properties of betweenness centrality on the graph by chaging the size of the nodes
betweenness_centrality = test_node_properties[0][2]
node_degrees = test_node_properties[0][0]

plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_size=[v * 10000 for v in betweenness_centrality], node_color=node_degrees, cmap='viridis')
plt.show()

# %%
#same for eigenvector centrality
eigenvector_centralities = test_node_properties[0][3]

plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_size=[v * 10000 for v in eigenvector_centralities], node_color=node_degrees, cmap='viridis')
plt.show()

# %%
#same for local clustering coefficients
Local_clustering_coefficients = test_node_properties[0][1]

plt.figure(figsize=(10, 10))
nx.draw(G, with_labels=True, node_size=[v * 1000 for v in Local_clustering_coefficients], node_color=node_degrees, cmap='viridis')
plt.show()

# %% [markdown]
# There might be more discriminative features based on the eigeivector centrality.
#
# We see that for each graph, the length of the betweenness centralities, and in general the length of properties, are equal to the number of nodes in the graph and thus
# is equal to the length of the x matrix in the features.

# %% [markdown]
# ## Node Properties
#
# For our probing purposes, we don't take into account the disconnected graphs

# %%
import networkx as nx
import torch

def compute_node_properties(data, indices):
    properties = []
    for idx in indices:
        graph_data = data[idx]
        G = nx.from_edgelist(graph_data.edge_index.t().tolist())
        
        # Add all nodes to the graph to handle disconnected nodes
        all_nodes = set(range(len(graph_data.x)))
        connected_nodes = set(G.nodes())
        disconnected_nodes = all_nodes - connected_nodes
        
        # Calculate node properties using NetworkX for connected nodes
        degree = dict(G.degree())
        clustering = nx.clustering(G)
        betweenness = nx.betweenness_centrality(G)
        closeness = nx.closeness_centrality(G)
        eigenvector = nx.eigenvector_centrality(G, max_iter=10000)
        pagerank = nx.pagerank(G)

        # Initialize properties with zeros for all nodes
        node_properties = [{'degree': 0, 'clustering': 0, 'betweenness': 0, 'closeness': 0, 'eigenvector': 0, 'pagerank': 0} for _ in all_nodes]
        
        # Store properties for each connected node in the graph
        for node in connected_nodes:
            node_properties[node] = {
                'degree': degree[node],
                'clustering': clustering[node],
                'betweenness': betweenness[node],
                'closeness': closeness[node],
                'eigenvector': eigenvector[node],
                'pagerank': pagerank[node]
            }

        #if there a disconnected nodes : print 
        # if disconnected_nodes:
        #     print(f"Graph {idx}: Disconnected nodes: {disconnected_nodes}")
        #     print(node_properties)

        properties.append(node_properties)
    return properties

# Ensure gnn.train_idx and gnn.test_idx are lists of integers
train_idx = gnn.train_idx.tolist() if isinstance(gnn.train_idx, torch.Tensor) else gnn.train_idx
test_idx = gnn.test_idx.tolist() if isinstance(gnn.test_idx, torch.Tensor) else gnn.test_idx

# Compute node-level properties for train and test sets
train_node_properties = compute_node_properties(gnn.dataset, train_idx)
test_node_properties = compute_node_properties(gnn.dataset, test_idx)

# %% [markdown]
# ## Features

# %%
train_features, test_features = gnn.evaluate_with_features2(return_node_embeddings=True)
# Out:
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# ...
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)
# len of features:  5
# features[0].shape:  torch.Size([116, 128])
# features[1].shape:  torch.Size([116, 128])
# features[2].shape:  torch.Size([116, 128])
# features[3].shape:  torch.Size([116, 128])
# features[4].shape:  torch.Size([116, 128])
# train_features[0][0].shape:  (116, 128)

# %%
len(train_features), len(test_features)
# Out:
# (1044, 55)

# %%
# Check the shape of the first graph's features
first_graph_features = train_features[1]
for i, feature in enumerate(first_graph_features):
    print(f"Feature {i+1} shape:", feature.shape)
# Out:
# Feature 1 shape: (116, 128)
# Feature 2 shape: (116, 128)
# Feature 3 shape: (116, 128)
# Feature 4 shape: (116, 128)
# Feature 5 shape: (116, 128)

# %%
train_features[1][0][115]
# Out:
# array([-0.3768596 ,  1.6929059 ,  1.7549721 , -0.59884256, -0.7069929 ,
#        -0.64360166, -0.597654  , -0.58719116, -0.6589397 , -0.58917546,
#        -0.6371779 ,  0.7570746 , -0.678448  , -0.57999843,  0.9958532 ,
#         0.7851749 , -0.7277082 ,  2.59916   , -0.6501185 , -0.6727714 ,
#         0.88018125,  3.4121273 , -0.62779766, -0.6337086 , -0.687071  ,
#         0.9279617 ,  1.7032542 , -0.6746877 , -0.17400445, -0.6686538 ,
#        -0.65484655, -0.6692905 , -0.67351073, -0.65264136,  0.6912536 ,
#         0.07277143, -0.69103795, -0.6376403 , -0.5185264 , -0.69764876,
#        -0.6681054 , -0.7185582 , -0.71772814,  0.5283295 , -0.73103005,
#         0.28918484, -0.66227067, -0.6802141 , -0.6193606 , -0.67815536,
#        -0.60691845,  1.8839593 , -0.5943558 , -0.02621269, -0.71328527,
#        -0.68886244, -0.6890107 , -0.6547946 ,  0.6078464 , -0.701213  ,
#         1.2887503 ,  2.1272626 , -0.58606315,  2.8298757 , -0.18379898,
#        -0.54030734, -0.76094735, -0.32233348,  0.40016896, -0.10887058,
#        -0.6472725 , -0.7084739 , -0.6977172 , -0.6465418 ,  1.3915485 ,
#        -0.6270409 , -0.65311515,  1.0710747 , -0.7383908 , -0.7355136 ,
#        -0.6290444 ,  2.2574174 ,  1.9109606 ,  0.7331517 , -0.615721  ,
#        -0.60923076,  0.09882358, -0.7446471 , -0.6084292 , -0.6459573 ,
#        -0.609887  , -0.62054455,  0.9457442 , -0.15760726, -0.48769644,
#         0.18100466, -0.11543807, -0.6153602 ,  0.2039315 , -0.60390383,
#        -0.62119704,  0.9369777 , -0.6072321 , -0.6540122 , -0.60601825,
#        -0.5714578 ,  0.31834447, -0.6633055 , -0.5856847 , -0.7168189 ,
#        -0.7779249 ,  1.4791274 ,  0.19007748, -0.73520046, -0.7434725 ,
#        -0.69642925, -0.4373339 , -0.66237104, -0.58985186,  1.372949  ,
#        -0.70684415, -0.7079896 ,  3.653366  , -0.5828283 ,  1.0550777 ,
#        -0.61758065, -0.60343397, -0.6571797 ], dtype=float32)

# %%
print(len(train_features))
print(len(train_features[0]))
print(train_features[0][0].shape)
# Out:
# 1044
# 5
# (116, 128)

# %%
print(len(train_node_properties))
print(len(train_node_properties[0]))
print(train_node_properties[0][0])
# Out:
# 1044
# 116
# {'degree': 9, 'clustering': 0.6666666666666666, 'betweenness': 0.0073517232342515905, 'closeness': 0.34023668639053256, 'eigenvector': 0.0012984180038352537, 'pagerank': 0.007510481485631736}

# %% [markdown]
# ## Linear classifier
#
# **Probe**
#
# Example data structure for multiple graphs
#
# train_features: List of graphs, each with multiple layers of features
#
# ```plaintext
# train_features = [
#     [np.array([...]), np.array([...]), ...],  # Graph 1: features for each layer
#     [np.array([...]), np.array([...]), ...],  # Graph 2: features for each layer
#     ...
# ]
# ```
# train_node_properties: List of graphs, each with a list of node properties
#
# ```plaintext
# train_node_properties = [
#     [{'degree': ..., 'clustering': ..., ...}, {'degree': ..., ...}, ...],  # Graph 1: properties for each node
#     [{'degree': ..., 'clustering': ..., ...}, {'degree': ..., ...}, ...],  # Graph 2: properties for each node
#     ...
# ]
# ```
# test_features and test_node_properties would be similarly structured for the test set

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

class LinearModel(nn.Module):
    def __init__(self, input_size):
        super(LinearModel, self).__init__()
        self.linear = nn.Linear(input_size, 1)

    def forward(self, x):
        return self.linear(x)

# %%
def train_probe_for_layer(features, property_values, test_features, test_property_values, num_epochs=10000, learning_rate=0.01):
    # Convert features and property values to PyTorch tensors if they are NumPy arrays
    if isinstance(features, np.ndarray):
        features = torch.tensor(features, dtype=torch.float32)
    if isinstance(property_values, np.ndarray):
        property_values = torch.tensor(property_values, dtype=torch.float32)

    if isinstance(test_features, np.ndarray):
        test_features = torch.tensor(test_features, dtype=torch.float32)
    if isinstance(test_property_values, np.ndarray):
        test_property_values = torch.tensor(test_property_values, dtype=torch.float32)

    print(f"Training on features with shape: {features.shape} for property values shape: {property_values.shape}")

    model = LinearModel(features.shape[1])  # Features should be 2D: (num_nodes, feature_size)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        output = model(features).squeeze()  # Remove single-dimensional entries
        loss = criterion(output, property_values)
        loss.backward()
        optimizer.step()

    # Evaluate on test data
    model.eval()
    with torch.no_grad():
        pred = model(test_features).squeeze()
        mse = criterion(pred, test_property_values).item()
        # Flatten the tensors for proper use of r2_score
        r2 = r2_score(test_property_values.cpu().numpy(), pred.cpu().numpy())

    return mse, r2

# %% [markdown]
# Where inspiring from the techniques developped in AIFB probing for one graph : to handle multiple graphs, we have a couple of options:
#
# ### Option 1: Train a Separate Classifier for Each Graph
#
# This approach involves training a separate probe (classifier) for each graph independently. This means that for each graph, you would train a different probe for each property at each layer. This approach assumes that each graph might have a different structure and properties that are best modeled independently.
#
# **Code :**
#
# We would modify the `evaluate_layer_probes` function from the AIFB_probing_GCN to loop over the graphs and train separate models for each.
#
# This will produce separate R² scores for each graph, layer, and property.

# %%
def evaluate_layer_probes_per_graph(train_features_list, test_features_list, train_properties_list, test_properties_list):
    results = []

    num_test_graphs = len(test_features_list)  # Number of graphs in the test set

    # Iterate over the number of graphs in the training set
    for graph_idx in range(len(train_features_list)):
        train_features = train_features_list[graph_idx]
        train_properties = train_properties_list[graph_idx]

        # Use modulo to cycle through the test graphs
        test_idx = graph_idx % num_test_graphs
        test_features = test_features_list[test_idx]
        test_properties = test_properties_list[test_idx]

        num_layers = len(train_features)

        for layer_idx in range(num_layers):
            layer_train_features = train_features[layer_idx]
            layer_test_features = test_features[layer_idx]

            # Stack node features into a single matrix for each layer
            train_feature_matrix = np.vstack(layer_train_features)  # Shape: (num_nodes, feature_size)
            test_feature_matrix = np.vstack(layer_test_features)

            # Print the number of nodes to check for inconsistencies
            print(f"Graph {graph_idx}, Layer {layer_idx}: Train nodes = {train_feature_matrix.shape[0]}, Test nodes = {test_feature_matrix.shape[0]}")
            print(f"Graph {graph_idx}, Layer {layer_idx}: Train properties = {len(train_properties)}, Test properties = {len(test_properties)}")

            # Train and evaluate probe for each property
            for property_name in train_properties[0].keys():  # Assuming all nodes have the same properties
                train_property_values = np.array([node[property_name] for node in train_properties])
                test_property_values = np.array([node[property_name] for node in test_properties])

                mse, r2 = train_probe_for_layer(train_feature_matrix, train_property_values, test_feature_matrix, test_property_values)
                
                results.append({
                    'graph': graph_idx,
                    'layer': layer_idx,
                    'property': property_name,
                    'mse': mse,
                    'r2': r2
                })

    return results

# %%
# Assuming train_features, test_features, train_properties, test_properties are already defined
results_per_graph = evaluate_layer_probes_per_graph(train_features, test_features, train_node_properties, test_node_properties)

# %%
def plot_results_per_graph(results):
    layers = sorted(set(result['layer'] for result in results))
    properties = sorted(set(result['property'] for result in results))
    graphs = sorted(set(result['graph'] for result in results))
    
    plt.figure(figsize=(12, 6))  # Increase the figure size for better readability
    
    for property_name in properties:
        plt.figure(figsize=(12, 6))
        for graph_idx in graphs:
            r2_scores = []
            for layer in layers:
                layer_results = [r for r in results if r['layer'] == layer and r['property'] == property_name and r['graph'] == graph_idx]
                # Calculate mean R² score for the layer
                mean_r2 = np.mean([r['r2'] for r in layer_results])
                # Set any R² value below -0.05 to -0.05
                if mean_r2 < -0.05:
                    mean_r2 = -0.05
                r2_scores.append(mean_r2)
            
            # Plot the R² scores with crosses and lines, one line per graph
            plt.plot(layers, r2_scores, marker='x', linestyle='-', label=f'Graph {graph_idx}')
        
        plt.title(f'R² Scores Across Layers for Property: {property_name}')
        plt.xlabel('Layer')
        plt.ylabel('R² Score')
        plt.legend()
        plt.grid(True)  # Add grid for better visibility of points and lines
        plt.show()

# %%
plot_results_per_graph(results_per_graph)

# %% [markdown]
# ### Option 2: Train a Single Classifier Across All Graphs
#
# This approach involves combining data from all graphs to train a single probe for each property across the graphs. This assumes that the properties across different graphs share some common structure that can be captured by a single model. We modify the `evaluate_layer_probes` function to aggregate features and properties across all graphs before training.
#
# This approach results in a single probe being trained for each property at each layer, but the probe is trained on data aggregated from all graphs.

# %%
def evaluate_layer_probes_across_graphs(train_features_list, test_features_list, train_properties_list, test_properties_list):
    num_layers = len(train_features_list[0])  # Assuming all graphs have the same number of layers
    results = []

    num_test_graphs = len(test_features_list)  # Number of graphs in the test set

    for layer_idx in range(num_layers):
        combined_train_features = []
        combined_test_features = []
        combined_train_properties = []
        combined_test_properties = []

        # Aggregate features and properties across all graphs
        for graph_idx in range(len(train_features_list)):
            combined_train_features.append(np.vstack(train_features_list[graph_idx][layer_idx]))

            # Use modulo to cycle through the test graphs
            test_idx = graph_idx % num_test_graphs
            combined_test_features.append(np.vstack(test_features_list[test_idx][layer_idx]))

            combined_train_properties.extend(train_properties_list[graph_idx])
            combined_test_properties.extend(test_properties_list[test_idx])

        combined_train_features = np.vstack(combined_train_features)  # Combine features across graphs
        combined_test_features = np.vstack(combined_test_features)

        # Train and evaluate probe for each property across all graphs
        for property_name in combined_train_properties[0].keys():  # Assuming all nodes have the same properties
            train_property_values = np.array([node[property_name] for node in combined_train_properties])
            test_property_values = np.array([node[property_name] for node in combined_test_properties])

            mse, r2 = train_probe_for_layer(combined_train_features, train_property_values, combined_test_features, test_property_values)
            
            results.append({
                'layer': layer_idx,
                'property': property_name,
                'mse': mse,
                'r2': r2
            })

    return results

# %%
results_across_graphs = evaluate_layer_probes_across_graphs(train_features, test_features, train_node_properties, test_node_properties)

#save the results
with open("results/"+DATASET+"_"+MODEL+"_node_results_across_graphs.pkl", "wb") as f:
    pkl.dump(results_across_graphs, f)
# Out:
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# Training on features with shape: torch.Size([121104, 128]) for property values shape: torch.Size([121104])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 5
#       3 #save the results
#       4 with open("results/"+DATASET+"_"+MODEL+"_node_results_across_graphs.pkl", "wb") as f:
# ----> 5     pkl.dump(results_across_graphs, f)
#
# NameError: name 'pkl' is not defined

# %%
import pickle as pkl

with open("results/"+DATASET+"_"+MODEL+"_node_results_across_graphs.pkl", "wb") as f:
    pkl.dump(results_across_graphs, f)

# %%
#load the results
with open("results/"+DATASET+"_"+MODEL+"_node_results_across_graphs.pkl", "rb") as f:
    results_across_graphs = pkl.load(f)

# %% [markdown]
# ### Choosing Between Options:
#
# - If our graphs are very similar in nature and you expect the relationships between node embeddings and their properties to be consistent across all graphs, **Option 2** (Single Classifier Across Graphs) will be the better choice.
#
# - If our graphs are diverse, or we expect the relationships to vary significantly between graphs, *Option 1* (Separate Classifiers) might be more appropriate.
#
# We experiment with both approaches and compare the performance to see which one gives us the best results : we decided to keep option 2

# %% [markdown]
# ### Results:
#
# - *Layers and Properties*: The function iterate over the layers and properties to aggregate and visualize the R² scores.
#
# - *Mean R² Calculation*: The mean R² scores are calculated for each layer and property. If any R² value is below `-0.05`, it is set to `-0.05` to prevent extreme values from skewing the visualization.
#
# - *Plotting*:
#   - *Option 1 (`plot_results_per_graph`)*: Plots a separate line for each graph, allowing you to see how the R² scores vary across layers and graphs.
#   - *Option 2 (`plot_results_across_graphs`)*: Plots a single line for each property, aggregating the results across all graphs. This provides a high-level view of how each property behaves across layers when considering all graphs together.
#
# We decided to keep option 2 as it makes more sense. This function is designed to visualize the results from the `evaluate_layer_probes_across_graphs` function. It will plot the R² scores for each property across layers, combining the results from all graphs into single lines.

# %%
import pickle as pkl
import matplotlib.pyplot as plt
def plot_results_across_graphs(results):
    layers = sorted(set(result['layer'] for result in results))
    properties = sorted(set(result['property'] for result in results))
    
    plt.figure(figsize=(12, 6))  # Increase the figure size for better readability
    
    for property_name in properties:
        r2_scores = []
        for layer in layers:
            layer_results = [r for r in results if r['layer'] == layer and r['property'] == property_name]
            # Calculate mean R² score for the layer
            mean_r2 = np.mean([r['r2'] for r in layer_results])
            # Set any R² value below -0.05 to -0.05
            if mean_r2 < -0.05:
                mean_r2 = -0.05
            r2_scores.append(mean_r2)
        
        # Plot the R² scores with crosses and lines, one line per property across all graphs
        plt.plot(layers, r2_scores, marker='x', linestyle='-', label=property_name)

    plt.title('R² Scores Across Layers for Different Properties (Aggregated Across Graphs)')
    plt.xticks(layers, [f'Layer {i+1}' for i in layers])  # Set the x-axis labels to layer numbers
    plt.xlabel('Layer')
    plt.ylabel('R² Score')
    plt.legend()
    plt.grid(True)  # Add grid for better visibility of points and lines
    plt.show()

    # Save the plot
    with open("results/"+DATASET+"_"+MODEL+"_node_results_across_graphs.pkl", "wb") as f:
        pkl.dump(results, f)

# %%
# Plot the results across all graphs
plot_results_across_graphs(results_across_graphs)
